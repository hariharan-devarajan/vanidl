# %% [markdown]
# # DLProfile Example using l2hmc-qcd

# %% [markdown]
# ## Set imports and neccessary environment variables

# %%
import pathlib
import os
import sys
import matplotlib.pyplot as plt
import warnings
import pprint
import pandas
import ntpath

# %%
VANIDL_DIR="{}".format(pathlib.Path(os.getcwd()).parent.absolute())
sys.path.insert(0, VANIDL_DIR)
warnings.filterwarnings('ignore')

# %%
os.environ["DARSHAN_DIR"] = "/soft/perftools/darshan/darshan-3.1.8"
os.environ["VANIDL_DIR"] = VANIDL_DIR

# %% [markdown]
# #### Formatting

# %%
pp = pprint.PrettyPrinter(indent=1)
class color:
    PURPLE = '\033[95m'
    CYAN = '\033[96m'
    DARKCYAN = '\033[36m'
    BLUE = '\033[94m'
    GREEN = '\033[92m'
    YELLOW = '\033[93m'
    RED = '\033[91m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'
    END = '\033[0m'

# %% [markdown]
# ## Create instrance of DL Profile and load the darshan file

# %%
from src.vanidl import VaniDL
profile = VaniDL()

# %%
#import shutil
#shutil.rmtree('/tmp/temp_analysis')

# %%
DATAPATH_INCLUDES = []
status = profile.Load("/home/dhari/darshan-logs/apps/l2hmc-qcd/l2hmc_run2_p8.darshan", data_paths_include=DATAPATH_INCLUDES)
if status:
    print("Darshan Trace loaded Successfully!")
else:
    print("Darshan Trace load Failed!")
    print(profile._error_str())
# Out:
# Loaded Pre-processed DXT DF from file: /tmp/temp_analysis/l2hmc_run2_p8_io_dxt_df.csv
# Loaded Pre-processed DF from file: /tmp/temp_analysis/l2hmc_run2_p8_io_df.csv
# Loaded Pre-processed Pattern file: /tmp/temp_analysis/l2hmc_run2_p8_pattern.json
# Darshan Trace loaded Successfully!

# %% [markdown]
# ## Use Profile object to analyze the darshan I/O trace.

# %% [markdown]
# ### Verify if object works
#
# The GetDXTAsDF() function enables users to perform analysis

# %%
df = profile.GetDXTAsDF()
pp.pprint("Files used in the application")
pp.pprint(df['Filename'].unique().tolist())
# Out:
# 'Files used in the application'
# []

# %%
df_normal = profile.GetTraceAsDF()
pp.pprint("Files used in the application")
pp.pprint(df_normal['Filename'].unique().tolist())
# Out:
# 'Files used in the application'
# ['/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/checkpoint.tmp1aba5788d2bb4894a770124815ccea57',
#  '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/graph.pbtxt.tmpa14255dbe3834f45b758ec4703bc9b6d',
#  '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-45_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.data-00000-of-00001.tempstate6307127464834357184',
#  '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-75.index',
#  '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/checkpoint.tmp05c56c64574344d2b88ee58cd661cb0a',
#  '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/checkpoint.tmpafa9118f89a34350994521602b4856ca',
#  '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-0.index',
#  '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-15_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.data-00000-of-00001.tempstate9804660416386708781',
#  '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-90.index',
#  '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-45.index',
#  '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-105_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.index.tempstate16077201702985775298',
#  '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-90_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.index.tempstate4489253541929235252',
#  '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-90.meta.tmpa12b5e47aa69440ebbe92d09841dc217',
#  '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/checkpoint.tmpb4b197e144a048a79ccb319c73a26e65',
#  '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/checkpoint.tmp7576ea61e5fe46a9bb191a56d431ef4d',
#  '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-15_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.index.tempstate17637325061969226306',
#  '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-45.meta.tmpa864c9ea5474456a934c108901f0e27f',
#  '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-30_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.data-00000-of-00001.tempstate5286267822303063113',
#  '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-75_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.data-00000-of-00001.tempstate302663950693300301',
#  '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-0_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.index.tempstate3719425310044319935',
#  '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-75_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.index.tempstate14757626047192857251',
#  '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-75.meta.tmpa4f43dc21b8741d8942547be290a64fa',
#  '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/checkpoint.tmp4b670dddd44d44ca926bc17ba4b3184a',
#  '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-0.meta.tmp0203df2e01a0441d993907608a87cf83',
#  '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-30.index',
#  '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/checkpoint.tmp66636a1b285d4110877738817e9cb88a',
#  '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/events.out.tfevents.1591902661.nid00008',
#  '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-0_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.data-00000-of-00001.tempstate178319442380524411',
#  '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-105_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.data-00000-of-00001.tempstate12403677363233613037',
#  '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-60_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.index.tempstate9658202305539044460',
#  '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-15.index',
#  '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-60.meta.tmpc32bc8b599a848098cb58c16a9bface3',
#  '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-30_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.index.tempstate17681400027653203074',
#  '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/checkpoint.tmp4f4b52f1a744486b977244f799d76aa7',
#  '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-105.meta.tmp2bb0439975384774a22ca41a0dfe5df7',
#  '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-105.index',
#  '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-30.meta.tmpddf884f9ddbf40a39f5915a9f2c6e262',
#  '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-60.index',
#  '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-60_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.data-00000-of-00001.tempstate5439394137918407120',
#  '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-15.meta.tmp744e2dc3e68f47ea831e3528dd0cf5f7',
#  '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-90_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.data-00000-of-00001.tempstate9254592585878756557',
#  '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-45_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.index.tempstate16361452837582772528',
#  '<STDERR>']

# %% [markdown]
# ### Collect the summary of the Application

# %%
summary = profile.GetSummary()
print("\n")
print(color.BOLD + "Data Access Summary (from Darshan):"+ color.END)
print("Total Job time\t\t\t:\t{:0.2f} seconds".format(summary['job_time']))
#FIXME: calculate time per rank and then take max across it.
print("Time spent in I/O\t\t:\t{:0.2f} seconds".format(summary['total_io_time']))
print("% Time spent in I/O\t\t:\t{:0.2f}%".format(float(summary['total_io_time'])*100/summary['job_time']))
print("Total Data Accessed\t\t:\t{:0.2f} GB".format(float(summary['total_io_bytes'])/1024.0/1024.0/1024.0))
print("Data Access Modules used\t:\t{}".format(summary['io_interface_used']))
print("Data Operations\t\t\t:\t{}".format(summary['io_operations_used']))
print("# of files used\t\t\t:\t{}".format(len(summary['files_used'])))
print("# of MPI Ranks\t\t\t:\t{:0.0f} ranks".format(8))
      
     
print(color.UNDERLINE + "Access Pattern:"+ color.END)
print("\tSequential\t\t:\t{:0.2f}%".format(float(summary['access_pattern']['sequential'])))
print("\tConsecutive\t\t:\t{:0.2f}%".format(float(summary['access_pattern']['consecutive'])))
#An I/O op issued at an offset greater than where the previous I/O op ended.
#An I/O op issued at the offset immediately after the end of the previous I/O

print("\n")
print(color.BOLD + "Files Summary:"+ color.END)
print("File Types\t\t\t:\t{}".format(summary['file_used_summary']['types']))
print(color.UNDERLINE + "Dataset Size:"+ color.END)
print("\tTotal\t\t\t:\t{:0.3f} GB".format(float(summary['file_used_summary']['size']['total'])/1024.0/1024.0/1024.0))
print("\tMin,Max\t\t\t:\t{:0.3f} GB and {:0.3f} GB".format(float(summary['file_used_summary']['size']['min'])/1024.0/1024.0/1024.0,float(summary['file_used_summary']['size']['max'])/1024.0/1024.0/1024.0))
print("\tAverage\t\t\t:\t{:0.3f} GB".format(float(summary['file_used_summary']['size']['mean'])/1024.0/1024.0/1024.0))
# Out:
# Data Access Summary (from Darshan):
# Total Job time			:	385.00 seconds
# Time spent in I/O		:	4.14 seconds
# % Time spent in I/O		:	1.08%
# Total Data Accessed		:	0.34 GB
# Data Access Modules used	:	['STDIO']
# Data Operations			:	['write']
# # of files used			:	43
# # of MPI Ranks			:	8 ranks
# Access Pattern:
# 	Sequential		:	nan%
# 	Consecutive		:	nan%
#
#
# Files Summary:
# File Types			:	[]
# Dataset Size:
# 	Total			:	0.000 GB
# 	Min,Max			:	0.000 GB and 0.000 GB
# 	Average			:	0.000 GB

# %%
pp.pprint("Job time : {} seconds".format(profile.GetJobTime()))
# Out:
# 'Job time : 385.0 seconds'

# %%
pp.pprint("Time spent by application on I/O: {} seconds".format(profile.GetIOTime()))
# Out:
# 'Time spent by application on I/O: 4.140188 seconds'

# %% [markdown]
# ### I/O time spent on each file

# %%
for file in df_normal['Filename'].unique():
    filename = os.path.splitext(ntpath.basename(file))[0]
    print("I/O time for file {}: {:0.2f} seconds".format(filename,profile.GetIOTime(filepath=file)))
# Out:
# I/O time for file checkpoint: 0.02 seconds
# I/O time for file graph.pbtxt: 0.15 seconds
# I/O time for file part-00000-of-00001.data-00000-of-00001: 0.28 seconds
# I/O time for file model.ckpt-75: 0.02 seconds
# I/O time for file checkpoint: 0.03 seconds
# I/O time for file checkpoint: 0.03 seconds
# I/O time for file model.ckpt-0: 0.02 seconds
# I/O time for file part-00000-of-00001.data-00000-of-00001: 0.29 seconds
# I/O time for file model.ckpt-90: 0.02 seconds
# I/O time for file model.ckpt-45: 0.02 seconds
# I/O time for file part-00000-of-00001.index: 0.02 seconds
# I/O time for file part-00000-of-00001.index: 0.02 seconds
# I/O time for file model.ckpt-90.meta: 0.16 seconds
# I/O time for file checkpoint: 0.02 seconds
# I/O time for file checkpoint: 0.02 seconds
# I/O time for file part-00000-of-00001.index: 0.02 seconds
# I/O time for file model.ckpt-45.meta: 0.12 seconds
# I/O time for file part-00000-of-00001.data-00000-of-00001: 0.26 seconds
# I/O time for file part-00000-of-00001.data-00000-of-00001: 0.32 seconds
# I/O time for file part-00000-of-00001.index: 0.03 seconds
# I/O time for file part-00000-of-00001.index: 0.02 seconds
# I/O time for file model.ckpt-75.meta: 0.09 seconds
# I/O time for file checkpoint: 0.02 seconds
# I/O time for file model.ckpt-0.meta: 0.08 seconds
# I/O time for file model.ckpt-30: 0.02 seconds
# I/O time for file checkpoint: 0.02 seconds
# I/O time for file events.out.tfevents.1591902661: 0.13 seconds
# I/O time for file part-00000-of-00001.data-00000-of-00001: 0.36 seconds
# I/O time for file part-00000-of-00001.data-00000-of-00001: 0.27 seconds
# I/O time for file part-00000-of-00001.index: 0.02 seconds
# I/O time for file model.ckpt-15: 0.02 seconds
# I/O time for file model.ckpt-60.meta: 0.12 seconds
# I/O time for file part-00000-of-00001.index: 0.02 seconds
# I/O time for file checkpoint: 0.03 seconds
# I/O time for file model.ckpt-105.meta: 0.13 seconds
# I/O time for file model.ckpt-105: 0.02 seconds
# I/O time for file model.ckpt-30.meta: 0.17 seconds
# I/O time for file model.ckpt-60: 0.03 seconds
# I/O time for file part-00000-of-00001.data-00000-of-00001: 0.27 seconds
# I/O time for file model.ckpt-15.meta: 0.12 seconds
# I/O time for file part-00000-of-00001.data-00000-of-00001: 0.27 seconds
# I/O time for file part-00000-of-00001.index: 0.02 seconds
# I/O time for file <STDERR>: 0.03 seconds

# %% [markdown]
# ### I/O Time spent per rank

# %%
for rank in df['Rank'].unique():
    print("I/O time for rank {}: {:0.2f} seconds".format(rank,profile.GetIOTime(rank=rank)))

# %%
"Total I/O performed by application: {:0.2f} GB".format(float(profile.GetIOSize())/1024.0/1024.0/1024.0)
# Out:
# 'Total I/O performed by application: 0.34 GB'

# %% [markdown]
# ### I/O performed on each file

# %%
for file in df_normal['Filename'].unique():
    filename = os.path.splitext(ntpath.basename(file))[0]
    print("I/O performed on file {}: {:0.2f} KB".format(filename,float(profile.GetIOSize(filepath=file))/1024.0))
# Out:
# I/O performed on file checkpoint: 1.12 KB
# I/O performed on file graph.pbtxt: 7407.53 KB
# I/O performed on file part-00000-of-00001.data-00000-of-00001: 35436.03 KB
# I/O performed on file model.ckpt-75: 4.72 KB
# I/O performed on file checkpoint: 0.93 KB
# I/O performed on file checkpoint: 1.12 KB
# I/O performed on file model.ckpt-0: 4.72 KB
# I/O performed on file part-00000-of-00001.data-00000-of-00001: 35436.03 KB
# I/O performed on file model.ckpt-90: 4.72 KB
# I/O performed on file model.ckpt-45: 4.72 KB
# I/O performed on file part-00000-of-00001.index: 4.72 KB
# I/O performed on file part-00000-of-00001.index: 4.72 KB
# I/O performed on file model.ckpt-90.meta: 5321.34 KB
# I/O performed on file checkpoint: 0.74 KB
# I/O performed on file checkpoint: 0.37 KB
# I/O performed on file part-00000-of-00001.index: 4.72 KB
# I/O performed on file model.ckpt-45.meta: 5321.34 KB
# I/O performed on file part-00000-of-00001.data-00000-of-00001: 35436.03 KB
# I/O performed on file part-00000-of-00001.data-00000-of-00001: 35436.03 KB
# I/O performed on file part-00000-of-00001.index: 4.72 KB
# I/O performed on file part-00000-of-00001.index: 4.72 KB
# I/O performed on file model.ckpt-75.meta: 5321.34 KB
# I/O performed on file checkpoint: 1.12 KB
# I/O performed on file model.ckpt-0.meta: 5321.34 KB
# I/O performed on file model.ckpt-30: 4.72 KB
# I/O performed on file checkpoint: 0.56 KB
# I/O performed on file events.out.tfevents.1591902661: 19126.65 KB
# I/O performed on file part-00000-of-00001.data-00000-of-00001: 35436.03 KB
# I/O performed on file part-00000-of-00001.data-00000-of-00001: 35436.03 KB
# I/O performed on file part-00000-of-00001.index: 4.72 KB
# I/O performed on file model.ckpt-15: 4.72 KB
# I/O performed on file model.ckpt-60.meta: 5321.34 KB
# I/O performed on file part-00000-of-00001.index: 4.72 KB
# I/O performed on file checkpoint: 1.12 KB
# I/O performed on file model.ckpt-105.meta: 5321.34 KB
# I/O performed on file model.ckpt-105: 4.72 KB
# I/O performed on file model.ckpt-30.meta: 5321.34 KB
# I/O performed on file model.ckpt-60: 4.72 KB
# I/O performed on file part-00000-of-00001.data-00000-of-00001: 35436.03 KB
# I/O performed on file model.ckpt-15.meta: 5321.34 KB
# I/O performed on file part-00000-of-00001.data-00000-of-00001: 35436.03 KB
# I/O performed on file part-00000-of-00001.index: 4.72 KB
# I/O performed on file <STDERR>: 33.02 KB

# %%
for col in df_normal.columns:
    print(col)
# Out:
# Module
# Rank
# POSIX_OPENS
# Filename
# Mount
# FS
# POSIX_FILENOS
# POSIX_DUPS
# POSIX_READS
# POSIX_WRITES
# POSIX_SEEKS
# POSIX_STATS
# POSIX_MMAPS
# POSIX_FSYNCS
# POSIX_FDSYNCS
# POSIX_RENAME_SOURCES
# POSIX_RENAME_TARGETS
# POSIX_RENAMED_FROM
# POSIX_MODE
# POSIX_BYTES_READ
# POSIX_BYTES_WRITTEN
# POSIX_MAX_BYTE_READ
# POSIX_MAX_BYTE_WRITTEN
# POSIX_CONSEC_READS
# POSIX_CONSEC_WRITES
# POSIX_SEQ_READS
# POSIX_SEQ_WRITES
# POSIX_RW_SWITCHES
# POSIX_MEM_NOT_ALIGNED
# POSIX_MEM_ALIGNMENT
# POSIX_FILE_NOT_ALIGNED
# POSIX_FILE_ALIGNMENT
# POSIX_MAX_READ_TIME_SIZE
# POSIX_MAX_WRITE_TIME_SIZE
# POSIX_SIZE_READ_0_100
# POSIX_SIZE_READ_100_1K
# POSIX_SIZE_READ_1K_10K
# POSIX_SIZE_READ_10K_100K
# POSIX_SIZE_READ_100K_1M
# POSIX_SIZE_READ_1M_4M
# POSIX_SIZE_READ_4M_10M
# POSIX_SIZE_READ_10M_100M
# POSIX_SIZE_READ_100M_1G
# POSIX_SIZE_READ_1G_PLUS
# POSIX_SIZE_WRITE_0_100
# POSIX_SIZE_WRITE_100_1K
# POSIX_SIZE_WRITE_1K_10K
# POSIX_SIZE_WRITE_10K_100K
# POSIX_SIZE_WRITE_100K_1M
# POSIX_SIZE_WRITE_1M_4M
# POSIX_SIZE_WRITE_4M_10M
# POSIX_SIZE_WRITE_10M_100M
# POSIX_SIZE_WRITE_100M_1G
# POSIX_SIZE_WRITE_1G_PLUS
# POSIX_STRIDE1_STRIDE
# POSIX_STRIDE2_STRIDE
# POSIX_STRIDE3_STRIDE
# POSIX_STRIDE4_STRIDE
# POSIX_STRIDE1_COUNT
# POSIX_STRIDE2_COUNT
# POSIX_STRIDE3_COUNT
# POSIX_STRIDE4_COUNT
# POSIX_ACCESS1_ACCESS
# POSIX_ACCESS2_ACCESS
# POSIX_ACCESS3_ACCESS
# POSIX_ACCESS4_ACCESS
# POSIX_ACCESS1_COUNT
# POSIX_ACCESS2_COUNT
# POSIX_ACCESS3_COUNT
# POSIX_ACCESS4_COUNT
# POSIX_FASTEST_RANK
# POSIX_FASTEST_RANK_BYTES
# POSIX_SLOWEST_RANK
# POSIX_SLOWEST_RANK_BYTES
# POSIX_F_OPEN_START_TIMESTAMP
# POSIX_F_READ_START_TIMESTAMP
# POSIX_F_WRITE_START_TIMESTAMP
# POSIX_F_CLOSE_START_TIMESTAMP
# POSIX_F_OPEN_END_TIMESTAMP
# POSIX_F_READ_END_TIMESTAMP
# POSIX_F_WRITE_END_TIMESTAMP
# POSIX_F_CLOSE_END_TIMESTAMP
# POSIX_F_READ_TIME
# POSIX_F_WRITE_TIME
# POSIX_F_META_TIME
# POSIX_F_MAX_READ_TIME
# POSIX_F_MAX_WRITE_TIME
# POSIX_F_FASTEST_RANK_TIME
# POSIX_F_SLOWEST_RANK_TIME
# POSIX_F_VARIANCE_RANK_TIME
# POSIX_F_VARIANCE_RANK_BYTES
# STDIO_OPENS
# STDIO_FDOPENS
# STDIO_READS
# STDIO_WRITES
# STDIO_SEEKS
# STDIO_FLUSHES
# STDIO_BYTES_WRITTEN
# STDIO_BYTES_READ
# STDIO_MAX_BYTE_READ
# STDIO_MAX_BYTE_WRITTEN
# STDIO_FASTEST_RANK
# STDIO_FASTEST_RANK_BYTES
# STDIO_SLOWEST_RANK
# STDIO_SLOWEST_RANK_BYTES
# STDIO_F_META_TIME
# STDIO_F_WRITE_TIME
# STDIO_F_READ_TIME
# STDIO_F_OPEN_START_TIMESTAMP
# STDIO_F_CLOSE_START_TIMESTAMP
# STDIO_F_WRITE_START_TIMESTAMP
# STDIO_F_READ_START_TIMESTAMP
# STDIO_F_OPEN_END_TIMESTAMP
# STDIO_F_CLOSE_END_TIMESTAMP
# STDIO_F_WRITE_END_TIMESTAMP
# STDIO_F_READ_END_TIMESTAMP
# STDIO_F_FASTEST_RANK_TIME
# STDIO_F_SLOWEST_RANK_TIME
# STDIO_F_VARIANCE_RANK_TIME
# STDIO_F_VARIANCE_RANK_BYTES
# ext

# %%
for index, row in df_normal.iterrows():
    if row['Module'] == "STDIO":
        if row['STDIO_BYTES_READ'] != 0:
            print(row['Filename'], row['STDIO_F_READ_START_TIMESTAMP'],row['STDIO_F_READ_END_TIMESTAMP'])
        if row['STDIO_BYTES_WRITTEN'] != 0:
            print(row['Filename'], row['STDIO_F_WRITE_START_TIMESTAMP'],row['STDIO_F_WRITE_END_TIMESTAMP'])
# Out:
# /gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/checkpoint.tmp1aba5788d2bb4894a770124815ccea57 337.589208 337.58979700000003
# /gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/graph.pbtxt.tmpa14255dbe3834f45b758ec4703bc9b6d 176.370032 176.381415
# /gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-45_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.data-00000-of-00001.tempstate6307127464834357184 322.93347 323.010064
# /gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-75.index 351.900977 351.901356
# /gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/checkpoint.tmp05c56c64574344d2b88ee58cd661cb0a 323.31262000000004 323.313122
# /gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/checkpoint.tmpafa9118f89a34350994521602b4856ca 351.953633 351.954642
# /gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-0.index 184.64128200000002 184.641601
# /gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-15_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.data-00000-of-00001.tempstate9804660416386708781 294.090889 294.168181
# /gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-90.index 366.178194 366.178663
# /gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-45.index 323.26068 323.261144
# /gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-105_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.index.tempstate16077201702985775298 380.463924 380.464396
# /gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-90_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.index.tempstate4489253541929235252 366.137649 366.138142
# /gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-90.meta.tmpa12b5e47aa69440ebbe92d09841dc217 369.58002400000004 369.58984300000003
# /gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/checkpoint.tmpb4b197e144a048a79ccb319c73a26e65 308.793613 308.794256
# /gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/checkpoint.tmp7576ea61e5fe46a9bb191a56d431ef4d 184.68327 184.683696
# /gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-15_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.index.tempstate17637325061969226306 294.385904 294.386402
# /gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-45.meta.tmpa864c9ea5474456a934c108901f0e27f 326.604827 326.614504
# /gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-30_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.data-00000-of-00001.tempstate5286267822303063113 308.43122200000005 308.50436099999996
# /gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-75_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.data-00000-of-00001.tempstate302663950693300301 351.537483 351.614582
# /gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-0_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.index.tempstate3719425310044319935 184.580651 184.58095500000002
# /gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-75_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.index.tempstate14757626047192857251 351.862186 351.862793
# /gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-75.meta.tmpa4f43dc21b8741d8942547be290a64fa 355.30271 355.31606600000003
# /gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/checkpoint.tmp4b670dddd44d44ca926bc17ba4b3184a 380.542825 380.543451
# /gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-0.meta.tmp0203df2e01a0441d993907608a87cf83 188.03706200000002 188.04576200000002
# /gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-30.index 308.749421 308.749816
# /gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/checkpoint.tmp66636a1b285d4110877738817e9cb88a 294.46606299999996 294.466648
# /gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/events.out.tfevents.1591902661.nid00008 140.144304 384.2744
# /gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-0_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.data-00000-of-00001.tempstate178319442380524411 184.196066 184.279909
# /gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-105_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.data-00000-of-00001.tempstate12403677363233613037 380.197865 380.27381099999997
# /gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-60_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.index.tempstate9658202305539044460 337.49686099999997 337.497454
# /gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-15.index 294.422761 294.423188
# /gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-60.meta.tmpc32bc8b599a848098cb58c16a9bface3 340.894778 340.905879
# /gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-30_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.index.tempstate17681400027653203074 308.712518 308.712944
# /gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/checkpoint.tmp4f4b52f1a744486b977244f799d76aa7 366.232048 366.23263399999996
# /gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-105.meta.tmp2bb0439975384774a22ca41a0dfe5df7 383.881795 383.895797
# /gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-105.index 380.497994 380.49857599999996
# /gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-30.meta.tmpddf884f9ddbf40a39f5915a9f2c6e262 312.079276 312.08973399999996
# /gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-60.index 337.542727 337.54316
# /gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-60_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.data-00000-of-00001.tempstate5439394137918407120 337.208353 337.283375
# /gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-15.meta.tmp744e2dc3e68f47ea831e3528dd0cf5f7 297.750179 297.763027
# /gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-90_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.data-00000-of-00001.tempstate9254592585878756557 365.85301699999997 365.935819
# /gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-45_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.index.tempstate16361452837582772528 323.221944 323.222554
# <STDERR> 141.281073 283.409789

# %%
ranks_set=[0,1,2,3,4,5,6,7]
def progress(count, total, status=''):
    bar_len = 60
    filled_len = int(round(bar_len * count / float(total)))
    percents = round(100.0 * count / float(total), 1)
    bar = '=' * filled_len + '-' * (bar_len - filled_len)
    if count == 1:
        print("")
    print("\r[{}] {}% {} of {} {} ".format(bar, percents, count, total, status), end='')
    if count == total:
        print("")
    os.sys.stdout.flush()
timestamps = []
data = []
pb_total = df_normal.count()['Module'];
i = 1
for index, row in df_normal.iterrows():
    if i % 100 == 0 or i == pb_total:
        progress(i, pb_total, status='Creating Darshan Timeline')
    i += 1
    if row['Module'] == "STDIO":
        args_val = {
            "Module": row['Module'],
            "Rank": row['Rank'],
            "Filename": row['Filename'],
            "STDIO_OPENS": row['STDIO_OPENS'],
            "STDIO_FDOPENS": row['STDIO_FDOPENS'],
            "STDIO_READS": row['STDIO_READS'],
            "STDIO_WRITES": row['STDIO_WRITES'],
            "STDIO_SEEKS": row['STDIO_SEEKS'],
            "STDIO_FLUSHES": row['STDIO_FLUSHES'],
            "STDIO_BYTES_WRITTEN": row['STDIO_BYTES_WRITTEN'],
            "STDIO_BYTES_READ": row['STDIO_BYTES_READ'],
            "STDIO_MAX_BYTE_READ": row['STDIO_MAX_BYTE_READ'],
            "STDIO_MAX_BYTE_WRITTEN": row['STDIO_MAX_BYTE_WRITTEN'],
            "STDIO_FASTEST_RANK": row['STDIO_FASTEST_RANK'],
            "STDIO_FASTEST_RANK_BYTES": row['STDIO_FASTEST_RANK_BYTES'],
            "STDIO_SLOWEST_RANK": row['STDIO_SLOWEST_RANK'],
            "STDIO_SLOWEST_RANK_BYTES": row['STDIO_SLOWEST_RANK_BYTES'],
            "STDIO_F_META_TIME": row['STDIO_F_META_TIME'],
            "STDIO_F_WRITE_TIME": row['STDIO_F_WRITE_TIME'],
            "STDIO_F_READ_TIME": row['STDIO_F_READ_TIME'],
            "STDIO_F_OPEN_START_TIMESTAMP": row['STDIO_F_OPEN_START_TIMESTAMP'],
            "STDIO_F_CLOSE_START_TIMESTAMP": row['STDIO_F_CLOSE_START_TIMESTAMP'],
            "STDIO_F_WRITE_START_TIMESTAMP": row['STDIO_F_WRITE_START_TIMESTAMP'],
            "STDIO_F_READ_START_TIMESTAMP": row['STDIO_F_READ_START_TIMESTAMP'],
            "STDIO_F_OPEN_END_TIMESTAMP": row['STDIO_F_OPEN_END_TIMESTAMP'],
            "STDIO_F_CLOSE_END_TIMESTAMP": row['STDIO_F_CLOSE_END_TIMESTAMP'],
            "STDIO_F_WRITE_END_TIMESTAMP": row['STDIO_F_WRITE_END_TIMESTAMP'],
            "STDIO_F_READ_END_TIMESTAMP": row['STDIO_F_READ_END_TIMESTAMP'],
            "STDIO_F_FASTEST_RANK_TIME": row['STDIO_F_FASTEST_RANK_TIME'],
            "STDIO_F_SLOWEST_RANK_TIME": row['STDIO_F_SLOWEST_RANK_TIME'],
            "STDIO_F_VARIANCE_RANK_TIME": row['STDIO_F_VARIANCE_RANK_TIME'],
            "STDIO_F_VARIANCE_RANK_BYTES": row['STDIO_F_VARIANCE_RANK_BYTES']
        }
        ranks = []
        if row['Rank'] != -1:
            ranks.append(int(row['Rank']))
        else:
            ranks.extend(list(ranks_set))
        for rank in ranks:
            if row['STDIO_BYTES_READ'] != 0:
                event_start = {"name": "darshan", "cat": row['Module'], "ph": "B",
                               "ts": int(float(row['STDIO_F_READ_START_TIMESTAMP']) * 1e6),
                               "pid": rank, "tid": 1,
                               "args": args_val
                               }
                event_end = {"ph": "E", "ts": int(float(row['STDIO_F_READ_END_TIMESTAMP']) * 1e6),
                             "pid": rank, "tid": 1,
                             "args": args_val
                             }
                timestamps.append(int(float(row['STDIO_F_READ_START_TIMESTAMP']) * 1e6))
                data.append(event_start)
                timestamps.append(int(float(row['STDIO_F_READ_END_TIMESTAMP']) * 1e6))
                data.append(event_end)
            if row['STDIO_BYTES_WRITTEN'] != 0:
                event_start = {"name": "darshan", "cat": row['Module'], "ph": "B",
                               "ts": int(float(row['STDIO_F_WRITE_START_TIMESTAMP']) * 1e6),
                               "pid": rank, "tid": 1,
                               "args": args_val
                               }
                event_end = {"ph": "E", "ts": int(float(row['STDIO_F_WRITE_END_TIMESTAMP']) * 1e6),
                             "pid": rank, "tid": 1,
                             "args": args_val
                             }
                timestamps.append(int(float(row['STDIO_F_WRITE_START_TIMESTAMP']) * 1e6))
                data.append(event_start)
                timestamps.append(int(float(row['STDIO_F_WRITE_END_TIMESTAMP']) * 1e6))
                data.append(event_end)
# Out:
# [============================================================] 100.0% 43 of 43 Creating Darshan Timeline

# %%
data
# Out:
# [{'name': 'darshan',
#   'cat': 'STDIO',
#   'ph': 'B',
#   'ts': 337589208,
#   'pid': 0,
#   'tid': 1,
#   'args': {'Module': 'STDIO',
#    'Rank': 0,
#    'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/checkpoint.tmp1aba5788d2bb4894a770124815ccea57',
#    'STDIO_OPENS': 1.0,
#    'STDIO_FDOPENS': 0.0,
#    'STDIO_READS': 0.0,
#    'STDIO_WRITES': 1.0,
#    'STDIO_SEEKS': 0.0,
#    'STDIO_FLUSHES': 0.0,
#    'STDIO_BYTES_WRITTEN': 1146,
#    'STDIO_BYTES_READ': 0,
#    'STDIO_MAX_BYTE_READ': 0.0,
#    'STDIO_MAX_BYTE_WRITTEN': 1145.0,
#    'STDIO_FASTEST_RANK': 0.0,
#    'STDIO_FASTEST_RANK_BYTES': 0.0,
#    'STDIO_SLOWEST_RANK': 0.0,
#    'STDIO_SLOWEST_RANK_BYTES': 0.0,
#    'STDIO_F_META_TIME': 0.022563999999999997,
#    'STDIO_F_WRITE_TIME': 0.000589,
#    'STDIO_F_READ_TIME': 0.0,
#    'STDIO_F_OPEN_START_TIMESTAMP': 337.569495,
#    'STDIO_F_CLOSE_START_TIMESTAMP': 337.589873,
#    'STDIO_F_WRITE_START_TIMESTAMP': 337.589208,
#    'STDIO_F_READ_START_TIMESTAMP': 0.0,
#    'STDIO_F_OPEN_END_TIMESTAMP': 337.588981,
#    'STDIO_F_CLOSE_END_TIMESTAMP': 337.59295099999997,
#    'STDIO_F_WRITE_END_TIMESTAMP': 337.58979700000003,
#    'STDIO_F_READ_END_TIMESTAMP': 0.0,
#    'STDIO_F_FASTEST_RANK_TIME': 0.0,
#    'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#  {'ph': 'E',
#   'ts': 337589797,
#   'pid': 0,
#   'tid': 1,
#   'args': {'Module': 'STDIO',
#    'Rank': 0,
#    'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/checkpoint.tmp1aba5788d2bb4894a770124815ccea57',
#    'STDIO_OPENS': 1.0,
#    'STDIO_FDOPENS': 0.0,
#    'STDIO_READS': 0.0,
#    'STDIO_WRITES': 1.0,
#    'STDIO_SEEKS': 0.0,
#    'STDIO_FLUSHES': 0.0,
#    'STDIO_BYTES_WRITTEN': 1146,
#    'STDIO_BYTES_READ': 0,
#    'STDIO_MAX_BYTE_READ': 0.0,
#    'STDIO_MAX_BYTE_WRITTEN': 1145.0,
#    'STDIO_FASTEST_RANK': 0.0,
#    'STDIO_FASTEST_RANK_BYTES': 0.0,
#    'STDIO_SLOWEST_RANK': 0.0,
#    'STDIO_SLOWEST_RANK_BYTES': 0.0,
#    'STDIO_F_META_TIME': 0.022563999999999997,
#    'STDIO_F_WRITE_TIME': 0.000589,
#    'STDIO_F_READ_TIME': 0.0,
#    'STDIO_F_OPEN_START_TIMESTAMP': 337.569495,
#    'STDIO_F_CLOSE_START_TIMESTAMP': 337.589873,
#    'STDIO_F_WRITE_START_TIMESTAMP': 337.589208,
#    'STDIO_F_READ_START_TIMESTAMP': 0.0,
#    'STDIO_F_OPEN_END_TIMESTAMP': 337.588981,
#    'STDIO_F_CLOSE_END_TIMESTAMP': 337.59295099999997,
#    'STDIO_F_WRITE_END_TIMESTAMP': 337.58979700000003,
#    'STDIO_F_READ_END_TIMESTAMP': 0.0,
#    'STDIO_F_FASTEST_RANK_TIME': 0.0,
#    'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#  {'name': 'darshan',
#   'cat': 'STDIO',
#   'ph': 'B',
#   'ts': 176370032,
#   'pid': 0,
#   'tid': 1,
#   'args': {'Module': 'STDIO',
#    'Rank': 0,
#    'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/graph.pbtxt.tmpa14255dbe3834f45b758ec4703bc9b6d',
#    'STDIO_OPENS': 1.0,
#    'STDIO_FDOPENS': 0.0,
#    'STDIO_READS': 0.0,
#    'STDIO_WRITES': 1.0,
#    'STDIO_SEEKS': 0.0,
#    'STDIO_FLUSHES': 0.0,
#    'STDIO_BYTES_WRITTEN': 7585314,
#    'STDIO_BYTES_READ': 0,
#    'STDIO_MAX_BYTE_READ': 0.0,
#    'STDIO_MAX_BYTE_WRITTEN': 7585313.0,
#    'STDIO_FASTEST_RANK': 0.0,
#    'STDIO_FASTEST_RANK_BYTES': 0.0,
#    'STDIO_SLOWEST_RANK': 0.0,
#    'STDIO_SLOWEST_RANK_BYTES': 0.0,
#    'STDIO_F_META_TIME': 0.140362,
#    'STDIO_F_WRITE_TIME': 0.011382999999999999,
#    'STDIO_F_READ_TIME': 0.0,
#    'STDIO_F_OPEN_START_TIMESTAMP': 176.3377,
#    'STDIO_F_CLOSE_START_TIMESTAMP': 176.382513,
#    'STDIO_F_WRITE_START_TIMESTAMP': 176.370032,
#    'STDIO_F_READ_START_TIMESTAMP': 0.0,
#    'STDIO_F_OPEN_END_TIMESTAMP': 176.353444,
#    'STDIO_F_CLOSE_END_TIMESTAMP': 176.50713100000002,
#    'STDIO_F_WRITE_END_TIMESTAMP': 176.381415,
#    'STDIO_F_READ_END_TIMESTAMP': 0.0,
#    'STDIO_F_FASTEST_RANK_TIME': 0.0,
#    'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#  {'ph': 'E',
#   'ts': 176381415,
#   'pid': 0,
#   'tid': 1,
#   'args': {'Module': 'STDIO',
#    'Rank': 0,
#    'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/graph.pbtxt.tmpa14255dbe3834f45b758ec4703bc9b6d',
#    'STDIO_OPENS': 1.0,
#    'STDIO_FDOPENS': 0.0,
#    'STDIO_READS': 0.0,
#    'STDIO_WRITES': 1.0,
#    'STDIO_SEEKS': 0.0,
#    'STDIO_FLUSHES': 0.0,
#    'STDIO_BYTES_WRITTEN': 7585314,
#    'STDIO_BYTES_READ': 0,
#    'STDIO_MAX_BYTE_READ': 0.0,
#    'STDIO_MAX_BYTE_WRITTEN': 7585313.0,
#    'STDIO_FASTEST_RANK': 0.0,
#    'STDIO_FASTEST_RANK_BYTES': 0.0,
#    'STDIO_SLOWEST_RANK': 0.0,
#    'STDIO_SLOWEST_RANK_BYTES': 0.0,
#    'STDIO_F_META_TIME': 0.140362,
#    'STDIO_F_WRITE_TIME': 0.011382999999999999,
#    'STDIO_F_READ_TIME': 0.0,
#    'STDIO_F_OPEN_START_TIMESTAMP': 176.3377,
#    'STDIO_F_CLOSE_START_TIMESTAMP': 176.382513,
#    'STDIO_F_WRITE_START_TIMESTAMP': 176.370032,
#    'STDIO_F_READ_START_TIMESTAMP': 0.0,
#    'STDIO_F_OPEN_END_TIMESTAMP': 176.353444,
#    'STDIO_F_CLOSE_END_TIMESTAMP': 176.50713100000002,
#    'STDIO_F_WRITE_END_TIMESTAMP': 176.381415,
#    'STDIO_F_READ_END_TIMESTAMP': 0.0,
#    'STDIO_F_FASTEST_RANK_TIME': 0.0,
#    'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#  {'name': 'darshan',
#   'cat': 'STDIO',
#   'ph': 'B',
#   'ts': 322933470,
#   'pid': 0,
#   'tid': 1,
#   'args': {'Module': 'STDIO',
#    'Rank': 0,
#    'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-45_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.data-00000-of-00001.tempstate6307127464834357184',
#    'STDIO_OPENS': 1.0,
#    'STDIO_FDOPENS': 0.0,
#    'STDIO_READS': 0.0,
#    'STDIO_WRITES': 5.0,
#    'STDIO_SEEKS': 0.0,
#    'STDIO_FLUSHES': 0.0,
#    'STDIO_BYTES_WRITTEN': 36286492,
#    'STDIO_BYTES_READ': 0,
#    'STDIO_MAX_BYTE_READ': 0.0,
#    'STDIO_MAX_BYTE_WRITTEN': 36286491.0,
#    'STDIO_FASTEST_RANK': 0.0,
#    'STDIO_FASTEST_RANK_BYTES': 0.0,
#    'STDIO_SLOWEST_RANK': 0.0,
#    'STDIO_SLOWEST_RANK_BYTES': 0.0,
#    'STDIO_F_META_TIME': 0.218925,
#    'STDIO_F_WRITE_TIME': 0.056674,
#    'STDIO_F_READ_TIME': 0.0,
#    'STDIO_F_OPEN_START_TIMESTAMP': 322.878929,
#    'STDIO_F_CLOSE_START_TIMESTAMP': 323.010075,
#    'STDIO_F_WRITE_START_TIMESTAMP': 322.93347,
#    'STDIO_F_READ_START_TIMESTAMP': 0.0,
#    'STDIO_F_OPEN_END_TIMESTAMP': 322.913282,
#    'STDIO_F_CLOSE_END_TIMESTAMP': 323.19464700000003,
#    'STDIO_F_WRITE_END_TIMESTAMP': 323.010064,
#    'STDIO_F_READ_END_TIMESTAMP': 0.0,
#    'STDIO_F_FASTEST_RANK_TIME': 0.0,
#    'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#  {'ph': 'E',
#   'ts': 323010064,
#   'pid': 0,
#   'tid': 1,
#   'args': {'Module': 'STDIO',
#    'Rank': 0,
#    'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-45_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.data-00000-of-00001.tempstate6307127464834357184',
#    'STDIO_OPENS': 1.0,
#    'STDIO_FDOPENS': 0.0,
#    'STDIO_READS': 0.0,
#    'STDIO_WRITES': 5.0,
#    'STDIO_SEEKS': 0.0,
#    'STDIO_FLUSHES': 0.0,
#    'STDIO_BYTES_WRITTEN': 36286492,
#    'STDIO_BYTES_READ': 0,
#    'STDIO_MAX_BYTE_READ': 0.0,
#    'STDIO_MAX_BYTE_WRITTEN': 36286491.0,
#    'STDIO_FASTEST_RANK': 0.0,
#    'STDIO_FASTEST_RANK_BYTES': 0.0,
#    'STDIO_SLOWEST_RANK': 0.0,
#    'STDIO_SLOWEST_RANK_BYTES': 0.0,
#    'STDIO_F_META_TIME': 0.218925,
#    'STDIO_F_WRITE_TIME': 0.056674,
#    'STDIO_F_READ_TIME': 0.0,
#    'STDIO_F_OPEN_START_TIMESTAMP': 322.878929,
#    'STDIO_F_CLOSE_START_TIMESTAMP': 323.010075,
#    'STDIO_F_WRITE_START_TIMESTAMP': 322.93347,
#    'STDIO_F_READ_START_TIMESTAMP': 0.0,
#    'STDIO_F_OPEN_END_TIMESTAMP': 322.913282,
#    'STDIO_F_CLOSE_END_TIMESTAMP': 323.19464700000003,
#    'STDIO_F_WRITE_END_TIMESTAMP': 323.010064,
#    'STDIO_F_READ_END_TIMESTAMP': 0.0,
#    'STDIO_F_FASTEST_RANK_TIME': 0.0,
#    'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#  {'name': 'darshan',
#   'cat': 'STDIO',
#   'ph': 'B',
#   'ts': 351900977,
#   'pid': 0,
#   'tid': 1,
#   'args': {'Module': 'STDIO',
#    'Rank': 0,
#    'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-75.index',
#    'STDIO_OPENS': 1.0,
#    'STDIO_FDOPENS': 0.0,
#    'STDIO_READS': 0.0,
#    'STDIO_WRITES': 7.0,
#    'STDIO_SEEKS': 0.0,
#    'STDIO_FLUSHES': 0.0,
#    'STDIO_BYTES_WRITTEN': 4829,
#    'STDIO_BYTES_READ': 0,
#    'STDIO_MAX_BYTE_READ': 0.0,
#    'STDIO_MAX_BYTE_WRITTEN': 4828.0,
#    'STDIO_FASTEST_RANK': 0.0,
#    'STDIO_FASTEST_RANK_BYTES': 0.0,
#    'STDIO_SLOWEST_RANK': 0.0,
#    'STDIO_SLOWEST_RANK_BYTES': 0.0,
#    'STDIO_F_META_TIME': 0.019826,
#    'STDIO_F_WRITE_TIME': 0.000356,
#    'STDIO_F_READ_TIME': 0.0,
#    'STDIO_F_OPEN_START_TIMESTAMP': 351.884458,
#    'STDIO_F_CLOSE_START_TIMESTAMP': 351.901367,
#    'STDIO_F_WRITE_START_TIMESTAMP': 351.900977,
#    'STDIO_F_READ_START_TIMESTAMP': 0.0,
#    'STDIO_F_OPEN_END_TIMESTAMP': 351.900559,
#    'STDIO_F_CLOSE_END_TIMESTAMP': 351.90509199999997,
#    'STDIO_F_WRITE_END_TIMESTAMP': 351.901356,
#    'STDIO_F_READ_END_TIMESTAMP': 0.0,
#    'STDIO_F_FASTEST_RANK_TIME': 0.0,
#    'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#  {'ph': 'E',
#   'ts': 351901356,
#   'pid': 0,
#   'tid': 1,
#   'args': {'Module': 'STDIO',
#    'Rank': 0,
#    'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-75.index',
#    'STDIO_OPENS': 1.0,
#    'STDIO_FDOPENS': 0.0,
#    'STDIO_READS': 0.0,
#    'STDIO_WRITES': 7.0,
#    'STDIO_SEEKS': 0.0,
#    'STDIO_FLUSHES': 0.0,
#    'STDIO_BYTES_WRITTEN': 4829,
#    'STDIO_BYTES_READ': 0,
#    'STDIO_MAX_BYTE_READ': 0.0,
#    'STDIO_MAX_BYTE_WRITTEN': 4828.0,
#    'STDIO_FASTEST_RANK': 0.0,
#    'STDIO_FASTEST_RANK_BYTES': 0.0,
#    'STDIO_SLOWEST_RANK': 0.0,
#    'STDIO_SLOWEST_RANK_BYTES': 0.0,
#    'STDIO_F_META_TIME': 0.019826,
#    'STDIO_F_WRITE_TIME': 0.000356,
#    'STDIO_F_READ_TIME': 0.0,
#    'STDIO_F_OPEN_START_TIMESTAMP': 351.884458,
#    'STDIO_F_CLOSE_START_TIMESTAMP': 351.901367,
#    'STDIO_F_WRITE_START_TIMESTAMP': 351.900977,
#    'STDIO_F_READ_START_TIMESTAMP': 0.0,
#    'STDIO_F_OPEN_END_TIMESTAMP': 351.900559,
#    'STDIO_F_CLOSE_END_TIMESTAMP': 351.90509199999997,
#    'STDIO_F_WRITE_END_TIMESTAMP': 351.901356,
#    'STDIO_F_READ_END_TIMESTAMP': 0.0,
#    'STDIO_F_FASTEST_RANK_TIME': 0.0,
#    'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#  {'name': 'darshan',
#   'cat': 'STDIO',
#   'ph': 'B',
#   'ts': 323312620,
#   'pid': 0,
#   'tid': 1,
#   'args': {'Module': 'STDIO',
#    'Rank': 0,
#    'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/checkpoint.tmp05c56c64574344d2b88ee58cd661cb0a',
#    'STDIO_OPENS': 1.0,
#    'STDIO_FDOPENS': 0.0,
#    'STDIO_READS': 0.0,
#    'STDIO_WRITES': 1.0,
#    'STDIO_SEEKS': 0.0,
#    'STDIO_FLUSHES': 0.0,
#    'STDIO_BYTES_WRITTEN': 954,
#    'STDIO_BYTES_READ': 0,
#    'STDIO_MAX_BYTE_READ': 0.0,
#    'STDIO_MAX_BYTE_WRITTEN': 953.0,
#    'STDIO_FASTEST_RANK': 0.0,
#    'STDIO_FASTEST_RANK_BYTES': 0.0,
#    'STDIO_SLOWEST_RANK': 0.0,
#    'STDIO_SLOWEST_RANK_BYTES': 0.0,
#    'STDIO_F_META_TIME': 0.02833,
#    'STDIO_F_WRITE_TIME': 0.000502,
#    'STDIO_F_READ_TIME': 0.0,
#    'STDIO_F_OPEN_START_TIMESTAMP': 323.28828300000004,
#    'STDIO_F_CLOSE_START_TIMESTAMP': 323.3132,
#    'STDIO_F_WRITE_START_TIMESTAMP': 323.31262000000004,
#    'STDIO_F_READ_START_TIMESTAMP': 0.0,
#    'STDIO_F_OPEN_END_TIMESTAMP': 323.312398,
#    'STDIO_F_CLOSE_END_TIMESTAMP': 323.317415,
#    'STDIO_F_WRITE_END_TIMESTAMP': 323.313122,
#    'STDIO_F_READ_END_TIMESTAMP': 0.0,
#    'STDIO_F_FASTEST_RANK_TIME': 0.0,
#    'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#  {'ph': 'E',
#   'ts': 323313122,
#   'pid': 0,
#   'tid': 1,
#   'args': {'Module': 'STDIO',
#    'Rank': 0,
#    'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/checkpoint.tmp05c56c64574344d2b88ee58cd661cb0a',
#    'STDIO_OPENS': 1.0,
#    'STDIO_FDOPENS': 0.0,
#    'STDIO_READS': 0.0,
#    'STDIO_WRITES': 1.0,
#    'STDIO_SEEKS': 0.0,
#    'STDIO_FLUSHES': 0.0,
#    'STDIO_BYTES_WRITTEN': 954,
#    'STDIO_BYTES_READ': 0,
#    'STDIO_MAX_BYTE_READ': 0.0,
#    'STDIO_MAX_BYTE_WRITTEN': 953.0,
#    'STDIO_FASTEST_RANK': 0.0,
#    'STDIO_FASTEST_RANK_BYTES': 0.0,
#    'STDIO_SLOWEST_RANK': 0.0,
#    'STDIO_SLOWEST_RANK_BYTES': 0.0,
#    'STDIO_F_META_TIME': 0.02833,
#    'STDIO_F_WRITE_TIME': 0.000502,
#    'STDIO_F_READ_TIME': 0.0,
#    'STDIO_F_OPEN_START_TIMESTAMP': 323.28828300000004,
#    'STDIO_F_CLOSE_START_TIMESTAMP': 323.3132,
#    'STDIO_F_WRITE_START_TIMESTAMP': 323.31262000000004,
#    'STDIO_F_READ_START_TIMESTAMP': 0.0,
#    'STDIO_F_OPEN_END_TIMESTAMP': 323.312398,
#    'STDIO_F_CLOSE_END_TIMESTAMP': 323.317415,
#    'STDIO_F_WRITE_END_TIMESTAMP': 323.313122,
#    'STDIO_F_READ_END_TIMESTAMP': 0.0,
#    'STDIO_F_FASTEST_RANK_TIME': 0.0,
#    'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#  {'name': 'darshan',
#   'cat': 'STDIO',
#   'ph': 'B',
#   'ts': 351953633,
#   'pid': 0,
#   'tid': 1,
#   'args': {'Module': 'STDIO',
#    'Rank': 0,
#    'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/checkpoint.tmpafa9118f89a34350994521602b4856ca',
#    'STDIO_OPENS': 1.0,
#    'STDIO_FDOPENS': 0.0,
#    'STDIO_READS': 0.0,
#    'STDIO_WRITES': 1.0,
#    'STDIO_SEEKS': 0.0,
#    'STDIO_FLUSHES': 0.0,
#    'STDIO_BYTES_WRITTEN': 1147,
#    'STDIO_BYTES_READ': 0,
#    'STDIO_MAX_BYTE_READ': 0.0,
#    'STDIO_MAX_BYTE_WRITTEN': 1146.0,
#    'STDIO_FASTEST_RANK': 0.0,
#    'STDIO_FASTEST_RANK_BYTES': 0.0,
#    'STDIO_SLOWEST_RANK': 0.0,
#    'STDIO_SLOWEST_RANK_BYTES': 0.0,
#    'STDIO_F_META_TIME': 0.027927999999999998,
#    'STDIO_F_WRITE_TIME': 0.001009,
#    'STDIO_F_READ_TIME': 0.0,
#    'STDIO_F_OPEN_START_TIMESTAMP': 351.92919700000004,
#    'STDIO_F_CLOSE_START_TIMESTAMP': 351.954721,
#    'STDIO_F_WRITE_START_TIMESTAMP': 351.953633,
#    'STDIO_F_READ_START_TIMESTAMP': 0.0,
#    'STDIO_F_OPEN_END_TIMESTAMP': 351.953405,
#    'STDIO_F_CLOSE_END_TIMESTAMP': 351.958441,
#    'STDIO_F_WRITE_END_TIMESTAMP': 351.954642,
#    'STDIO_F_READ_END_TIMESTAMP': 0.0,
#    'STDIO_F_FASTEST_RANK_TIME': 0.0,
#    'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#  {'ph': 'E',
#   'ts': 351954642,
#   'pid': 0,
#   'tid': 1,
#   'args': {'Module': 'STDIO',
#    'Rank': 0,
#    'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/checkpoint.tmpafa9118f89a34350994521602b4856ca',
#    'STDIO_OPENS': 1.0,
#    'STDIO_FDOPENS': 0.0,
#    'STDIO_READS': 0.0,
#    'STDIO_WRITES': 1.0,
#    'STDIO_SEEKS': 0.0,
#    'STDIO_FLUSHES': 0.0,
#    'STDIO_BYTES_WRITTEN': 1147,
#    'STDIO_BYTES_READ': 0,
#    'STDIO_MAX_BYTE_READ': 0.0,
#    'STDIO_MAX_BYTE_WRITTEN': 1146.0,
#    'STDIO_FASTEST_RANK': 0.0,
#    'STDIO_FASTEST_RANK_BYTES': 0.0,
#    'STDIO_SLOWEST_RANK': 0.0,
#    'STDIO_SLOWEST_RANK_BYTES': 0.0,
#    'STDIO_F_META_TIME': 0.027927999999999998,
#    'STDIO_F_WRITE_TIME': 0.001009,
#    'STDIO_F_READ_TIME': 0.0,
#    'STDIO_F_OPEN_START_TIMESTAMP': 351.92919700000004,
#    'STDIO_F_CLOSE_START_TIMESTAMP': 351.954721,
#    'STDIO_F_WRITE_START_TIMESTAMP': 351.953633,
#    'STDIO_F_READ_START_TIMESTAMP': 0.0,
#    'STDIO_F_OPEN_END_TIMESTAMP': 351.953405,
#    'STDIO_F_CLOSE_END_TIMESTAMP': 351.958441,
#    'STDIO_F_WRITE_END_TIMESTAMP': 351.954642,
#    'STDIO_F_READ_END_TIMESTAMP': 0.0,
#    'STDIO_F_FASTEST_RANK_TIME': 0.0,
#    'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#  {'name': 'darshan',
#   'cat': 'STDIO',
#   'ph': 'B',
#   'ts': 184641282,
#   'pid': 0,
#   'tid': 1,
#   'args': {'Module': 'STDIO',
#    'Rank': 0,
#    'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-0.index',
#    'STDIO_OPENS': 1.0,
#    'STDIO_FDOPENS': 0.0,
#    'STDIO_READS': 0.0,
#    'STDIO_WRITES': 7.0,
#    'STDIO_SEEKS': 0.0,
#    'STDIO_FLUSHES': 0.0,
#    'STDIO_BYTES_WRITTEN': 4829,
#    'STDIO_BYTES_READ': 0,
#    'STDIO_MAX_BYTE_READ': 0.0,
#    'STDIO_MAX_BYTE_WRITTEN': 4828.0,
#    'STDIO_FASTEST_RANK': 0.0,
#    'STDIO_FASTEST_RANK_BYTES': 0.0,
#    'STDIO_SLOWEST_RANK': 0.0,
#    'STDIO_SLOWEST_RANK_BYTES': 0.0,
#    'STDIO_F_META_TIME': 0.018504,
#    'STDIO_F_WRITE_TIME': 0.000299,
#    'STDIO_F_READ_TIME': 0.0,
#    'STDIO_F_OPEN_START_TIMESTAMP': 184.625499,
#    'STDIO_F_CLOSE_START_TIMESTAMP': 184.64160800000002,
#    'STDIO_F_WRITE_START_TIMESTAMP': 184.64128200000002,
#    'STDIO_F_READ_START_TIMESTAMP': 0.0,
#    'STDIO_F_OPEN_END_TIMESTAMP': 184.64091299999998,
#    'STDIO_F_CLOSE_END_TIMESTAMP': 184.644698,
#    'STDIO_F_WRITE_END_TIMESTAMP': 184.641601,
#    'STDIO_F_READ_END_TIMESTAMP': 0.0,
#    'STDIO_F_FASTEST_RANK_TIME': 0.0,
#    'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#  {'ph': 'E',
#   'ts': 184641601,
#   'pid': 0,
#   'tid': 1,
#   'args': {'Module': 'STDIO',
#    'Rank': 0,
#    'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-0.index',
#    'STDIO_OPENS': 1.0,
#    'STDIO_FDOPENS': 0.0,
#    'STDIO_READS': 0.0,
#    'STDIO_WRITES': 7.0,
#    'STDIO_SEEKS': 0.0,
#    'STDIO_FLUSHES': 0.0,
#    'STDIO_BYTES_WRITTEN': 4829,
#    'STDIO_BYTES_READ': 0,
#    'STDIO_MAX_BYTE_READ': 0.0,
#    'STDIO_MAX_BYTE_WRITTEN': 4828.0,
#    'STDIO_FASTEST_RANK': 0.0,
#    'STDIO_FASTEST_RANK_BYTES': 0.0,
#    'STDIO_SLOWEST_RANK': 0.0,
#    'STDIO_SLOWEST_RANK_BYTES': 0.0,
#    'STDIO_F_META_TIME': 0.018504,
#    'STDIO_F_WRITE_TIME': 0.000299,
#    'STDIO_F_READ_TIME': 0.0,
#    'STDIO_F_OPEN_START_TIMESTAMP': 184.625499,
#    'STDIO_F_CLOSE_START_TIMESTAMP': 184.64160800000002,
#    'STDIO_F_WRITE_START_TIMESTAMP': 184.64128200000002,
#    'STDIO_F_READ_START_TIMESTAMP': 0.0,
#    'STDIO_F_OPEN_END_TIMESTAMP': 184.64091299999998,
#    'STDIO_F_CLOSE_END_TIMESTAMP': 184.644698,
#    'STDIO_F_WRITE_END_TIMESTAMP': 184.641601,
#    'STDIO_F_READ_END_TIMESTAMP': 0.0,
#    'STDIO_F_FASTEST_RANK_TIME': 0.0,
#    'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#  {'name': 'darshan',
#   'cat': 'STDIO',
#   'ph': 'B',
#   'ts': 294090889,
#   'pid': 0,
#   'tid': 1,
#   'args': {'Module': 'STDIO',
#    'Rank': 0,
#    'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-15_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.data-00000-of-00001.tempstate9804660416386708781',
#    'STDIO_OPENS': 1.0,
#    'STDIO_FDOPENS': 0.0,
#    'STDIO_READS': 0.0,
#    'STDIO_WRITES': 5.0,
#    'STDIO_SEEKS': 0.0,
#    'STDIO_FLUSHES': 0.0,
#    'STDIO_BYTES_WRITTEN': 36286492,
#    'STDIO_BYTES_READ': 0,
#    'STDIO_MAX_BYTE_READ': 0.0,
#    'STDIO_MAX_BYTE_WRITTEN': 36286491.0,
#    'STDIO_FASTEST_RANK': 0.0,
#    'STDIO_FASTEST_RANK_BYTES': 0.0,
#    'STDIO_SLOWEST_RANK': 0.0,
#    'STDIO_SLOWEST_RANK_BYTES': 0.0,
#    'STDIO_F_META_TIME': 0.23074699999999998,
#    'STDIO_F_WRITE_TIME': 0.057064,
#    'STDIO_F_READ_TIME': 0.0,
#    'STDIO_F_OPEN_START_TIMESTAMP': 294.034413,
#    'STDIO_F_CLOSE_START_TIMESTAMP': 294.16819100000004,
#    'STDIO_F_WRITE_START_TIMESTAMP': 294.090889,
#    'STDIO_F_READ_START_TIMESTAMP': 0.0,
#    'STDIO_F_OPEN_END_TIMESTAMP': 294.070854,
#    'STDIO_F_CLOSE_END_TIMESTAMP': 294.362497,
#    'STDIO_F_WRITE_END_TIMESTAMP': 294.168181,
#    'STDIO_F_READ_END_TIMESTAMP': 0.0,
#    'STDIO_F_FASTEST_RANK_TIME': 0.0,
#    'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#  {'ph': 'E',
#   'ts': 294168181,
#   'pid': 0,
#   'tid': 1,
#   'args': {'Module': 'STDIO',
#    'Rank': 0,
#    'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-15_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.data-00000-of-00001.tempstate9804660416386708781',
#    'STDIO_OPENS': 1.0,
#    'STDIO_FDOPENS': 0.0,
#    'STDIO_READS': 0.0,
#    'STDIO_WRITES': 5.0,
#    'STDIO_SEEKS': 0.0,
#    'STDIO_FLUSHES': 0.0,
#    'STDIO_BYTES_WRITTEN': 36286492,
#    'STDIO_BYTES_READ': 0,
#    'STDIO_MAX_BYTE_READ': 0.0,
#    'STDIO_MAX_BYTE_WRITTEN': 36286491.0,
#    'STDIO_FASTEST_RANK': 0.0,
#    'STDIO_FASTEST_RANK_BYTES': 0.0,
#    'STDIO_SLOWEST_RANK': 0.0,
#    'STDIO_SLOWEST_RANK_BYTES': 0.0,
#    'STDIO_F_META_TIME': 0.23074699999999998,
#    'STDIO_F_WRITE_TIME': 0.057064,
#    'STDIO_F_READ_TIME': 0.0,
#    'STDIO_F_OPEN_START_TIMESTAMP': 294.034413,
#    'STDIO_F_CLOSE_START_TIMESTAMP': 294.16819100000004,
#    'STDIO_F_WRITE_START_TIMESTAMP': 294.090889,
#    'STDIO_F_READ_START_TIMESTAMP': 0.0,
#    'STDIO_F_OPEN_END_TIMESTAMP': 294.070854,
#    'STDIO_F_CLOSE_END_TIMESTAMP': 294.362497,
#    'STDIO_F_WRITE_END_TIMESTAMP': 294.168181,
#    'STDIO_F_READ_END_TIMESTAMP': 0.0,
#    'STDIO_F_FASTEST_RANK_TIME': 0.0,
#    'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#  {'name': 'darshan',
#   'cat': 'STDIO',
#   'ph': 'B',
#   'ts': 366178194,
#   'pid': 0,
#   'tid': 1,
#   'args': {'Module': 'STDIO',
#    'Rank': 0,
#    'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-90.index',
#    'STDIO_OPENS': 1.0,
#    'STDIO_FDOPENS': 0.0,
#    'STDIO_READS': 0.0,
#    'STDIO_WRITES': 7.0,
#    'STDIO_SEEKS': 0.0,
#    'STDIO_FLUSHES': 0.0,
#    'STDIO_BYTES_WRITTEN': 4829,
#    'STDIO_BYTES_READ': 0,
#    'STDIO_MAX_BYTE_READ': 0.0,
#    'STDIO_MAX_BYTE_WRITTEN': 4828.0,
#    'STDIO_FASTEST_RANK': 0.0,
#    'STDIO_FASTEST_RANK_BYTES': 0.0,
#    'STDIO_SLOWEST_RANK': 0.0,
#    'STDIO_SLOWEST_RANK_BYTES': 0.0,
#    'STDIO_F_META_TIME': 0.023521,
#    'STDIO_F_WRITE_TIME': 0.00042300000000000004,
#    'STDIO_F_READ_TIME': 0.0,
#    'STDIO_F_OPEN_START_TIMESTAMP': 366.157864,
#    'STDIO_F_CLOSE_START_TIMESTAMP': 366.17868,
#    'STDIO_F_WRITE_START_TIMESTAMP': 366.178194,
#    'STDIO_F_READ_START_TIMESTAMP': 0.0,
#    'STDIO_F_OPEN_END_TIMESTAMP': 366.177781,
#    'STDIO_F_CLOSE_END_TIMESTAMP': 366.182284,
#    'STDIO_F_WRITE_END_TIMESTAMP': 366.178663,
#    'STDIO_F_READ_END_TIMESTAMP': 0.0,
#    'STDIO_F_FASTEST_RANK_TIME': 0.0,
#    'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#  {'ph': 'E',
#   'ts': 366178663,
#   'pid': 0,
#   'tid': 1,
#   'args': {'Module': 'STDIO',
#    'Rank': 0,
#    'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-90.index',
#    'STDIO_OPENS': 1.0,
#    'STDIO_FDOPENS': 0.0,
#    'STDIO_READS': 0.0,
#    'STDIO_WRITES': 7.0,
#    'STDIO_SEEKS': 0.0,
#    'STDIO_FLUSHES': 0.0,
#    'STDIO_BYTES_WRITTEN': 4829,
#    'STDIO_BYTES_READ': 0,
#    'STDIO_MAX_BYTE_READ': 0.0,
#    'STDIO_MAX_BYTE_WRITTEN': 4828.0,
#    'STDIO_FASTEST_RANK': 0.0,
#    'STDIO_FASTEST_RANK_BYTES': 0.0,
#    'STDIO_SLOWEST_RANK': 0.0,
#    'STDIO_SLOWEST_RANK_BYTES': 0.0,
#    'STDIO_F_META_TIME': 0.023521,
#    'STDIO_F_WRITE_TIME': 0.00042300000000000004,
#    'STDIO_F_READ_TIME': 0.0,
#    'STDIO_F_OPEN_START_TIMESTAMP': 366.157864,
#    'STDIO_F_CLOSE_START_TIMESTAMP': 366.17868,
#    'STDIO_F_WRITE_START_TIMESTAMP': 366.178194,
#    'STDIO_F_READ_START_TIMESTAMP': 0.0,
#    'STDIO_F_OPEN_END_TIMESTAMP': 366.177781,
#    'STDIO_F_CLOSE_END_TIMESTAMP': 366.182284,
#    'STDIO_F_WRITE_END_TIMESTAMP': 366.178663,
#    'STDIO_F_READ_END_TIMESTAMP': 0.0,
#    'STDIO_F_FASTEST_RANK_TIME': 0.0,
#    'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#  {'name': 'darshan',
#   'cat': 'STDIO',
#   'ph': 'B',
#   'ts': 323260680,
#   'pid': 0,
#   'tid': 1,
#   'args': {'Module': 'STDIO',
#    'Rank': 0,
#    'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-45.index',
#    'STDIO_OPENS': 1.0,
#    'STDIO_FDOPENS': 0.0,
#    'STDIO_READS': 0.0,
#    'STDIO_WRITES': 7.0,
#    'STDIO_SEEKS': 0.0,
#    'STDIO_FLUSHES': 0.0,
#    'STDIO_BYTES_WRITTEN': 4829,
#    'STDIO_BYTES_READ': 0,
#    'STDIO_MAX_BYTE_READ': 0.0,
#    'STDIO_MAX_BYTE_WRITTEN': 4828.0,
#    'STDIO_FASTEST_RANK': 0.0,
#    'STDIO_FASTEST_RANK_BYTES': 0.0,
#    'STDIO_SLOWEST_RANK': 0.0,
#    'STDIO_SLOWEST_RANK_BYTES': 0.0,
#    'STDIO_F_META_TIME': 0.018954,
#    'STDIO_F_WRITE_TIME': 0.00044,
#    'STDIO_F_READ_TIME': 0.0,
#    'STDIO_F_OPEN_START_TIMESTAMP': 323.244157,
#    'STDIO_F_CLOSE_START_TIMESTAMP': 323.261155,
#    'STDIO_F_WRITE_START_TIMESTAMP': 323.26068,
#    'STDIO_F_READ_START_TIMESTAMP': 0.0,
#    'STDIO_F_OPEN_END_TIMESTAMP': 323.26027400000004,
#    'STDIO_F_CLOSE_END_TIMESTAMP': 323.263992,
#    'STDIO_F_WRITE_END_TIMESTAMP': 323.261144,
#    'STDIO_F_READ_END_TIMESTAMP': 0.0,
#    'STDIO_F_FASTEST_RANK_TIME': 0.0,
#    'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#  {'ph': 'E',
#   'ts': 323261144,
#   'pid': 0,
#   'tid': 1,
#   'args': {'Module': 'STDIO',
#    'Rank': 0,
#    'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-45.index',
#    'STDIO_OPENS': 1.0,
#    'STDIO_FDOPENS': 0.0,
#    'STDIO_READS': 0.0,
#    'STDIO_WRITES': 7.0,
#    'STDIO_SEEKS': 0.0,
#    'STDIO_FLUSHES': 0.0,
#    'STDIO_BYTES_WRITTEN': 4829,
#    'STDIO_BYTES_READ': 0,
#    'STDIO_MAX_BYTE_READ': 0.0,
#    'STDIO_MAX_BYTE_WRITTEN': 4828.0,
#    'STDIO_FASTEST_RANK': 0.0,
#    'STDIO_FASTEST_RANK_BYTES': 0.0,
#    'STDIO_SLOWEST_RANK': 0.0,
#    'STDIO_SLOWEST_RANK_BYTES': 0.0,
#    'STDIO_F_META_TIME': 0.018954,
#    'STDIO_F_WRITE_TIME': 0.00044,
#    'STDIO_F_READ_TIME': 0.0,
#    'STDIO_F_OPEN_START_TIMESTAMP': 323.244157,
#    'STDIO_F_CLOSE_START_TIMESTAMP': 323.261155,
#    'STDIO_F_WRITE_START_TIMESTAMP': 323.26068,
#    'STDIO_F_READ_START_TIMESTAMP': 0.0,
#    'STDIO_F_OPEN_END_TIMESTAMP': 323.26027400000004,
#    'STDIO_F_CLOSE_END_TIMESTAMP': 323.263992,
#    'STDIO_F_WRITE_END_TIMESTAMP': 323.261144,
#    'STDIO_F_READ_END_TIMESTAMP': 0.0,
#    'STDIO_F_FASTEST_RANK_TIME': 0.0,
#    'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#  {'name': 'darshan',
#   'cat': 'STDIO',
#   'ph': 'B',
#   'ts': 380463924,
#   'pid': 0,
#   'tid': 1,
#   'args': {'Module': 'STDIO',
#    'Rank': 0,
#    'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-105_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.index.tempstate16077201702985775298',
#    'STDIO_OPENS': 1.0,
#    'STDIO_FDOPENS': 0.0,
#    'STDIO_READS': 0.0,
#    'STDIO_WRITES': 7.0,
#    'STDIO_SEEKS': 0.0,
#    'STDIO_FLUSHES': 0.0,
#    'STDIO_BYTES_WRITTEN': 4829,
#    'STDIO_BYTES_READ': 0,
#    'STDIO_MAX_BYTE_READ': 0.0,
#    'STDIO_MAX_BYTE_WRITTEN': 4828.0,
#    'STDIO_FASTEST_RANK': 0.0,
#    'STDIO_FASTEST_RANK_BYTES': 0.0,
#    'STDIO_SLOWEST_RANK': 0.0,
#    'STDIO_SLOWEST_RANK_BYTES': 0.0,
#    'STDIO_F_META_TIME': 0.017905,
#    'STDIO_F_WRITE_TIME': 0.000429,
#    'STDIO_F_READ_TIME': 0.0,
#    'STDIO_F_OPEN_START_TIMESTAMP': 380.44844,
#    'STDIO_F_CLOSE_START_TIMESTAMP': 380.464407,
#    'STDIO_F_WRITE_START_TIMESTAMP': 380.463924,
#    'STDIO_F_READ_START_TIMESTAMP': 0.0,
#    'STDIO_F_OPEN_END_TIMESTAMP': 380.463552,
#    'STDIO_F_CLOSE_END_TIMESTAMP': 380.4672,
#    'STDIO_F_WRITE_END_TIMESTAMP': 380.464396,
#    'STDIO_F_READ_END_TIMESTAMP': 0.0,
#    'STDIO_F_FASTEST_RANK_TIME': 0.0,
#    'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#  {'ph': 'E',
#   'ts': 380464396,
#   'pid': 0,
#   'tid': 1,
#   'args': {'Module': 'STDIO',
#    'Rank': 0,
#    'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-105_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.index.tempstate16077201702985775298',
#    'STDIO_OPENS': 1.0,
#    'STDIO_FDOPENS': 0.0,
#    'STDIO_READS': 0.0,
#    'STDIO_WRITES': 7.0,
#    'STDIO_SEEKS': 0.0,
#    'STDIO_FLUSHES': 0.0,
#    'STDIO_BYTES_WRITTEN': 4829,
#    'STDIO_BYTES_READ': 0,
#    'STDIO_MAX_BYTE_READ': 0.0,
#    'STDIO_MAX_BYTE_WRITTEN': 4828.0,
#    'STDIO_FASTEST_RANK': 0.0,
#    'STDIO_FASTEST_RANK_BYTES': 0.0,
#    'STDIO_SLOWEST_RANK': 0.0,
#    'STDIO_SLOWEST_RANK_BYTES': 0.0,
#    'STDIO_F_META_TIME': 0.017905,
#    'STDIO_F_WRITE_TIME': 0.000429,
#    'STDIO_F_READ_TIME': 0.0,
#    'STDIO_F_OPEN_START_TIMESTAMP': 380.44844,
#    'STDIO_F_CLOSE_START_TIMESTAMP': 380.464407,
#    'STDIO_F_WRITE_START_TIMESTAMP': 380.463924,
#    'STDIO_F_READ_START_TIMESTAMP': 0.0,
#    'STDIO_F_OPEN_END_TIMESTAMP': 380.463552,
#    'STDIO_F_CLOSE_END_TIMESTAMP': 380.4672,
#    'STDIO_F_WRITE_END_TIMESTAMP': 380.464396,
#    'STDIO_F_READ_END_TIMESTAMP': 0.0,
#    'STDIO_F_FASTEST_RANK_TIME': 0.0,
#    'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#  {'name': 'darshan',
#   'cat': 'STDIO',
#   'ph': 'B',
#   'ts': 366137649,
#   'pid': 0,
#   'tid': 1,
#   'args': {'Module': 'STDIO',
#    'Rank': 0,
#    'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-90_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.index.tempstate4489253541929235252',
#    'STDIO_OPENS': 1.0,
#    'STDIO_FDOPENS': 0.0,
#    'STDIO_READS': 0.0,
#    'STDIO_WRITES': 7.0,
#    'STDIO_SEEKS': 0.0,
#    'STDIO_FLUSHES': 0.0,
#    'STDIO_BYTES_WRITTEN': 4829,
#    'STDIO_BYTES_READ': 0,
#    'STDIO_MAX_BYTE_READ': 0.0,
#    'STDIO_MAX_BYTE_WRITTEN': 4828.0,
#    'STDIO_FASTEST_RANK': 0.0,
#    'STDIO_FASTEST_RANK_BYTES': 0.0,
#    'STDIO_SLOWEST_RANK': 0.0,
#    'STDIO_SLOWEST_RANK_BYTES': 0.0,
#    'STDIO_F_META_TIME': 0.020538,
#    'STDIO_F_WRITE_TIME': 0.000446,
#    'STDIO_F_READ_TIME': 0.0,
#    'STDIO_F_OPEN_START_TIMESTAMP': 366.119685,
#    'STDIO_F_CLOSE_START_TIMESTAMP': 366.138155,
#    'STDIO_F_WRITE_START_TIMESTAMP': 366.137649,
#    'STDIO_F_READ_START_TIMESTAMP': 0.0,
#    'STDIO_F_OPEN_END_TIMESTAMP': 366.137268,
#    'STDIO_F_CLOSE_END_TIMESTAMP': 366.14111,
#    'STDIO_F_WRITE_END_TIMESTAMP': 366.138142,
#    'STDIO_F_READ_END_TIMESTAMP': 0.0,
#    'STDIO_F_FASTEST_RANK_TIME': 0.0,
#    'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#  {'ph': 'E',
#   'ts': 366138142,
#   'pid': 0,
#   'tid': 1,
#   'args': {'Module': 'STDIO',
#    'Rank': 0,
#    'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-90_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.index.tempstate4489253541929235252',
#    'STDIO_OPENS': 1.0,
#    'STDIO_FDOPENS': 0.0,
#    'STDIO_READS': 0.0,
#    'STDIO_WRITES': 7.0,
#    'STDIO_SEEKS': 0.0,
#    'STDIO_FLUSHES': 0.0,
#    'STDIO_BYTES_WRITTEN': 4829,
#    'STDIO_BYTES_READ': 0,
#    'STDIO_MAX_BYTE_READ': 0.0,
#    'STDIO_MAX_BYTE_WRITTEN': 4828.0,
#    'STDIO_FASTEST_RANK': 0.0,
#    'STDIO_FASTEST_RANK_BYTES': 0.0,
#    'STDIO_SLOWEST_RANK': 0.0,
#    'STDIO_SLOWEST_RANK_BYTES': 0.0,
#    'STDIO_F_META_TIME': 0.020538,
#    'STDIO_F_WRITE_TIME': 0.000446,
#    'STDIO_F_READ_TIME': 0.0,
#    'STDIO_F_OPEN_START_TIMESTAMP': 366.119685,
#    'STDIO_F_CLOSE_START_TIMESTAMP': 366.138155,
#    'STDIO_F_WRITE_START_TIMESTAMP': 366.137649,
#    'STDIO_F_READ_START_TIMESTAMP': 0.0,
#    'STDIO_F_OPEN_END_TIMESTAMP': 366.137268,
#    'STDIO_F_CLOSE_END_TIMESTAMP': 366.14111,
#    'STDIO_F_WRITE_END_TIMESTAMP': 366.138142,
#    'STDIO_F_READ_END_TIMESTAMP': 0.0,
#    'STDIO_F_FASTEST_RANK_TIME': 0.0,
#    'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#  {'name': 'darshan',
#   'cat': 'STDIO',
#   'ph': 'B',
#   'ts': 369580024,
#   'pid': 0,
#   'tid': 1,
#   'args': {'Module': 'STDIO',
#    'Rank': 0,
#    'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-90.meta.tmpa12b5e47aa69440ebbe92d09841dc217',
#    'STDIO_OPENS': 1.0,
#    'STDIO_FDOPENS': 0.0,
#    'STDIO_READS': 0.0,
#    'STDIO_WRITES': 1.0,
#    'STDIO_SEEKS': 0.0,
#    'STDIO_FLUSHES': 0.0,
#    'STDIO_BYTES_WRITTEN': 5449053,
#    'STDIO_BYTES_READ': 0,
#    'STDIO_MAX_BYTE_READ': 0.0,
#    'STDIO_MAX_BYTE_WRITTEN': 5449052.0,
#    'STDIO_FASTEST_RANK': 0.0,
#    'STDIO_FASTEST_RANK_BYTES': 0.0,
#    'STDIO_SLOWEST_RANK': 0.0,
#    'STDIO_SLOWEST_RANK_BYTES': 0.0,
#    'STDIO_F_META_TIME': 0.154343,
#    'STDIO_F_WRITE_TIME': 0.009819,
#    'STDIO_F_READ_TIME': 0.0,
#    'STDIO_F_OPEN_START_TIMESTAMP': 369.557619,
#    'STDIO_F_CLOSE_START_TIMESTAMP': 369.58999700000004,
#    'STDIO_F_WRITE_START_TIMESTAMP': 369.58002400000004,
#    'STDIO_F_READ_START_TIMESTAMP': 0.0,
#    'STDIO_F_OPEN_END_TIMESTAMP': 369.57887999999997,
#    'STDIO_F_CLOSE_END_TIMESTAMP': 369.723079,
#    'STDIO_F_WRITE_END_TIMESTAMP': 369.58984300000003,
#    'STDIO_F_READ_END_TIMESTAMP': 0.0,
#    'STDIO_F_FASTEST_RANK_TIME': 0.0,
#    'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#  {'ph': 'E',
#   'ts': 369589843,
#   'pid': 0,
#   'tid': 1,
#   'args': {'Module': 'STDIO',
#    'Rank': 0,
#    'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-90.meta.tmpa12b5e47aa69440ebbe92d09841dc217',
#    'STDIO_OPENS': 1.0,
#    'STDIO_FDOPENS': 0.0,
#    'STDIO_READS': 0.0,
#    'STDIO_WRITES': 1.0,
#    'STDIO_SEEKS': 0.0,
#    'STDIO_FLUSHES': 0.0,
#    'STDIO_BYTES_WRITTEN': 5449053,
#    'STDIO_BYTES_READ': 0,
#    'STDIO_MAX_BYTE_READ': 0.0,
#    'STDIO_MAX_BYTE_WRITTEN': 5449052.0,
#    'STDIO_FASTEST_RANK': 0.0,
#    'STDIO_FASTEST_RANK_BYTES': 0.0,
#    'STDIO_SLOWEST_RANK': 0.0,
#    'STDIO_SLOWEST_RANK_BYTES': 0.0,
#    'STDIO_F_META_TIME': 0.154343,
#    'STDIO_F_WRITE_TIME': 0.009819,
#    'STDIO_F_READ_TIME': 0.0,
#    'STDIO_F_OPEN_START_TIMESTAMP': 369.557619,
#    'STDIO_F_CLOSE_START_TIMESTAMP': 369.58999700000004,
#    'STDIO_F_WRITE_START_TIMESTAMP': 369.58002400000004,
#    'STDIO_F_READ_START_TIMESTAMP': 0.0,
#    'STDIO_F_OPEN_END_TIMESTAMP': 369.57887999999997,
#    'STDIO_F_CLOSE_END_TIMESTAMP': 369.723079,
#    'STDIO_F_WRITE_END_TIMESTAMP': 369.58984300000003,
#    'STDIO_F_READ_END_TIMESTAMP': 0.0,
#    'STDIO_F_FASTEST_RANK_TIME': 0.0,
#    'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#  {'name': 'darshan',
#   'cat': 'STDIO',
#   'ph': 'B',
#   'ts': 308793613,
#   'pid': 0,
#   'tid': 1,
#   'args': {'Module': 'STDIO',
#    'Rank': 0,
#    'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/checkpoint.tmpb4b197e144a048a79ccb319c73a26e65',
#    'STDIO_OPENS': 1.0,
#    'STDIO_FDOPENS': 0.0,
#    'STDIO_READS': 0.0,
#    'STDIO_WRITES': 1.0,
#    'STDIO_SEEKS': 0.0,
#    'STDIO_FLUSHES': 0.0,
#    'STDIO_BYTES_WRITTEN': 762,
#    'STDIO_BYTES_READ': 0,
#    'STDIO_MAX_BYTE_READ': 0.0,
#    'STDIO_MAX_BYTE_WRITTEN': 761.0,
#    'STDIO_FASTEST_RANK': 0.0,
#    'STDIO_FASTEST_RANK_BYTES': 0.0,
#    'STDIO_SLOWEST_RANK': 0.0,
#    'STDIO_SLOWEST_RANK_BYTES': 0.0,
#    'STDIO_F_META_TIME': 0.019969999999999998,
#    'STDIO_F_WRITE_TIME': 0.000643,
#    'STDIO_F_READ_TIME': 0.0,
#    'STDIO_F_OPEN_START_TIMESTAMP': 308.77563599999996,
#    'STDIO_F_CLOSE_START_TIMESTAMP': 308.794337,
#    'STDIO_F_WRITE_START_TIMESTAMP': 308.793613,
#    'STDIO_F_READ_START_TIMESTAMP': 0.0,
#    'STDIO_F_OPEN_END_TIMESTAMP': 308.79337599999997,
#    'STDIO_F_CLOSE_END_TIMESTAMP': 308.796567,
#    'STDIO_F_WRITE_END_TIMESTAMP': 308.794256,
#    'STDIO_F_READ_END_TIMESTAMP': 0.0,
#    'STDIO_F_FASTEST_RANK_TIME': 0.0,
#    'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#  {'ph': 'E',
#   'ts': 308794256,
#   'pid': 0,
#   'tid': 1,
#   'args': {'Module': 'STDIO',
#    'Rank': 0,
#    'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/checkpoint.tmpb4b197e144a048a79ccb319c73a26e65',
#    'STDIO_OPENS': 1.0,
#    'STDIO_FDOPENS': 0.0,
#    'STDIO_READS': 0.0,
#    'STDIO_WRITES': 1.0,
#    'STDIO_SEEKS': 0.0,
#    'STDIO_FLUSHES': 0.0,
#    'STDIO_BYTES_WRITTEN': 762,
#    'STDIO_BYTES_READ': 0,
#    'STDIO_MAX_BYTE_READ': 0.0,
#    'STDIO_MAX_BYTE_WRITTEN': 761.0,
#    'STDIO_FASTEST_RANK': 0.0,
#    'STDIO_FASTEST_RANK_BYTES': 0.0,
#    'STDIO_SLOWEST_RANK': 0.0,
#    'STDIO_SLOWEST_RANK_BYTES': 0.0,
#    'STDIO_F_META_TIME': 0.019969999999999998,
#    'STDIO_F_WRITE_TIME': 0.000643,
#    'STDIO_F_READ_TIME': 0.0,
#    'STDIO_F_OPEN_START_TIMESTAMP': 308.77563599999996,
#    'STDIO_F_CLOSE_START_TIMESTAMP': 308.794337,
#    'STDIO_F_WRITE_START_TIMESTAMP': 308.793613,
#    'STDIO_F_READ_START_TIMESTAMP': 0.0,
#    'STDIO_F_OPEN_END_TIMESTAMP': 308.79337599999997,
#    'STDIO_F_CLOSE_END_TIMESTAMP': 308.796567,
#    'STDIO_F_WRITE_END_TIMESTAMP': 308.794256,
#    'STDIO_F_READ_END_TIMESTAMP': 0.0,
#    'STDIO_F_FASTEST_RANK_TIME': 0.0,
#    'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#  {'name': 'darshan',
#   'cat': 'STDIO',
#   'ph': 'B',
#   'ts': 184683270,
#   'pid': 0,
#   'tid': 1,
#   'args': {'Module': 'STDIO',
#    'Rank': 0,
#    'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/checkpoint.tmp7576ea61e5fe46a9bb191a56d431ef4d',
#    'STDIO_OPENS': 1.0,
#    'STDIO_FDOPENS': 0.0,
#    'STDIO_READS': 0.0,
#    'STDIO_WRITES': 1.0,
#    'STDIO_SEEKS': 0.0,
#    'STDIO_FLUSHES': 0.0,
#    'STDIO_BYTES_WRITTEN': 377,
#    'STDIO_BYTES_READ': 0,
#    'STDIO_MAX_BYTE_READ': 0.0,
#    'STDIO_MAX_BYTE_WRITTEN': 376.0,
#    'STDIO_FASTEST_RANK': 0.0,
#    'STDIO_FASTEST_RANK_BYTES': 0.0,
#    'STDIO_SLOWEST_RANK': 0.0,
#    'STDIO_SLOWEST_RANK_BYTES': 0.0,
#    'STDIO_F_META_TIME': 0.01944,
#    'STDIO_F_WRITE_TIME': 0.000426,
#    'STDIO_F_READ_TIME': 0.0,
#    'STDIO_F_OPEN_START_TIMESTAMP': 184.665441,
#    'STDIO_F_CLOSE_START_TIMESTAMP': 184.683845,
#    'STDIO_F_WRITE_START_TIMESTAMP': 184.68327,
#    'STDIO_F_READ_START_TIMESTAMP': 0.0,
#    'STDIO_F_OPEN_END_TIMESTAMP': 184.683056,
#    'STDIO_F_CLOSE_END_TIMESTAMP': 184.68567,
#    'STDIO_F_WRITE_END_TIMESTAMP': 184.683696,
#    'STDIO_F_READ_END_TIMESTAMP': 0.0,
#    'STDIO_F_FASTEST_RANK_TIME': 0.0,
#    'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#  {'ph': 'E',
#   'ts': 184683696,
#   'pid': 0,
#   'tid': 1,
#   'args': {'Module': 'STDIO',
#    'Rank': 0,
#    'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/checkpoint.tmp7576ea61e5fe46a9bb191a56d431ef4d',
#    'STDIO_OPENS': 1.0,
#    'STDIO_FDOPENS': 0.0,
#    'STDIO_READS': 0.0,
#    'STDIO_WRITES': 1.0,
#    'STDIO_SEEKS': 0.0,
#    'STDIO_FLUSHES': 0.0,
#    'STDIO_BYTES_WRITTEN': 377,
#    'STDIO_BYTES_READ': 0,
#    'STDIO_MAX_BYTE_READ': 0.0,
#    'STDIO_MAX_BYTE_WRITTEN': 376.0,
#    'STDIO_FASTEST_RANK': 0.0,
#    'STDIO_FASTEST_RANK_BYTES': 0.0,
#    'STDIO_SLOWEST_RANK': 0.0,
#    'STDIO_SLOWEST_RANK_BYTES': 0.0,
#    'STDIO_F_META_TIME': 0.01944,
#    'STDIO_F_WRITE_TIME': 0.000426,
#    'STDIO_F_READ_TIME': 0.0,
#    'STDIO_F_OPEN_START_TIMESTAMP': 184.665441,
#    'STDIO_F_CLOSE_START_TIMESTAMP': 184.683845,
#    'STDIO_F_WRITE_START_TIMESTAMP': 184.68327,
#    'STDIO_F_READ_START_TIMESTAMP': 0.0,
#    'STDIO_F_OPEN_END_TIMESTAMP': 184.683056,
#    'STDIO_F_CLOSE_END_TIMESTAMP': 184.68567,
#    'STDIO_F_WRITE_END_TIMESTAMP': 184.683696,
#    'STDIO_F_READ_END_TIMESTAMP': 0.0,
#    'STDIO_F_FASTEST_RANK_TIME': 0.0,
#    'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#  {'name': 'darshan',
#   'cat': 'STDIO',
#   'ph': 'B',
#   'ts': 294385904,
#   'pid': 0,
#   'tid': 1,
#   'args': {'Module': 'STDIO',
#    'Rank': 0,
#    'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-15_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.index.tempstate17637325061969226306',
#    'STDIO_OPENS': 1.0,
#    'STDIO_FDOPENS': 0.0,
#    'STDIO_READS': 0.0,
#    'STDIO_WRITES': 7.0,
#    'STDIO_SEEKS': 0.0,
#    'STDIO_FLUSHES': 0.0,
#    'STDIO_BYTES_WRITTEN': 4829,
#    'STDIO_BYTES_READ': 0,
#    'STDIO_MAX_BYTE_READ': 0.0,
#    'STDIO_MAX_BYTE_WRITTEN': 4828.0,
#    'STDIO_FASTEST_RANK': 0.0,
#    'STDIO_FASTEST_RANK_BYTES': 0.0,
#    'STDIO_SLOWEST_RANK': 0.0,
#    'STDIO_SLOWEST_RANK_BYTES': 0.0,
#    'STDIO_F_META_TIME': 0.021263999999999998,
#    'STDIO_F_WRITE_TIME': 0.00043,
#    'STDIO_F_READ_TIME': 0.0,
#    'STDIO_F_OPEN_START_TIMESTAMP': 294.36691099999996,
#    'STDIO_F_CLOSE_START_TIMESTAMP': 294.386413,
#    'STDIO_F_WRITE_START_TIMESTAMP': 294.385904,
#    'STDIO_F_READ_START_TIMESTAMP': 0.0,
#    'STDIO_F_OPEN_END_TIMESTAMP': 294.385379,
#    'STDIO_F_CLOSE_END_TIMESTAMP': 294.389209,
#    'STDIO_F_WRITE_END_TIMESTAMP': 294.386402,
#    'STDIO_F_READ_END_TIMESTAMP': 0.0,
#    'STDIO_F_FASTEST_RANK_TIME': 0.0,
#    'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#  {'ph': 'E',
#   'ts': 294386402,
#   'pid': 0,
#   'tid': 1,
#   'args': {'Module': 'STDIO',
#    'Rank': 0,
#    'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-15_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.index.tempstate17637325061969226306',
#    'STDIO_OPENS': 1.0,
#    'STDIO_FDOPENS': 0.0,
#    'STDIO_READS': 0.0,
#    'STDIO_WRITES': 7.0,
#    'STDIO_SEEKS': 0.0,
#    'STDIO_FLUSHES': 0.0,
#    'STDIO_BYTES_WRITTEN': 4829,
#    'STDIO_BYTES_READ': 0,
#    'STDIO_MAX_BYTE_READ': 0.0,
#    'STDIO_MAX_BYTE_WRITTEN': 4828.0,
#    'STDIO_FASTEST_RANK': 0.0,
#    'STDIO_FASTEST_RANK_BYTES': 0.0,
#    'STDIO_SLOWEST_RANK': 0.0,
#    'STDIO_SLOWEST_RANK_BYTES': 0.0,
#    'STDIO_F_META_TIME': 0.021263999999999998,
#    'STDIO_F_WRITE_TIME': 0.00043,
#    'STDIO_F_READ_TIME': 0.0,
#    'STDIO_F_OPEN_START_TIMESTAMP': 294.36691099999996,
#    'STDIO_F_CLOSE_START_TIMESTAMP': 294.386413,
#    'STDIO_F_WRITE_START_TIMESTAMP': 294.385904,
#    'STDIO_F_READ_START_TIMESTAMP': 0.0,
#    'STDIO_F_OPEN_END_TIMESTAMP': 294.385379,
#    'STDIO_F_CLOSE_END_TIMESTAMP': 294.389209,
#    'STDIO_F_WRITE_END_TIMESTAMP': 294.386402,
#    'STDIO_F_READ_END_TIMESTAMP': 0.0,
#    'STDIO_F_FASTEST_RANK_TIME': 0.0,
#    'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#  {'name': 'darshan',
#   'cat': 'STDIO',
#   'ph': 'B',
#   'ts': 326604827,
#   'pid': 0,
#   'tid': 1,
#   'args': {'Module': 'STDIO',
#    'Rank': 0,
#    'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-45.meta.tmpa864c9ea5474456a934c108901f0e27f',
#    'STDIO_OPENS': 1.0,
#    'STDIO_FDOPENS': 0.0,
#    'STDIO_READS': 0.0,
#    'STDIO_WRITES': 1.0,
#    'STDIO_SEEKS': 0.0,
#    'STDIO_FLUSHES': 0.0,
#    'STDIO_BYTES_WRITTEN': 5449053,
#    'STDIO_BYTES_READ': 0,
#    'STDIO_MAX_BYTE_READ': 0.0,
#    'STDIO_MAX_BYTE_WRITTEN': 5449052.0,
#    'STDIO_FASTEST_RANK': 0.0,
#    'STDIO_FASTEST_RANK_BYTES': 0.0,
#    'STDIO_SLOWEST_RANK': 0.0,
#    'STDIO_SLOWEST_RANK_BYTES': 0.0,
#    'STDIO_F_META_TIME': 0.110774,
#    'STDIO_F_WRITE_TIME': 0.009677,
#    'STDIO_F_READ_TIME': 0.0,
#    'STDIO_F_OPEN_START_TIMESTAMP': 326.58187200000003,
#    'STDIO_F_CLOSE_START_TIMESTAMP': 326.61464700000005,
#    'STDIO_F_WRITE_START_TIMESTAMP': 326.604827,
#    'STDIO_F_READ_START_TIMESTAMP': 0.0,
#    'STDIO_F_OPEN_END_TIMESTAMP': 326.603754,
#    'STDIO_F_CLOSE_END_TIMESTAMP': 326.70353900000003,
#    'STDIO_F_WRITE_END_TIMESTAMP': 326.614504,
#    'STDIO_F_READ_END_TIMESTAMP': 0.0,
#    'STDIO_F_FASTEST_RANK_TIME': 0.0,
#    'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#  {'ph': 'E',
#   'ts': 326614504,
#   'pid': 0,
#   'tid': 1,
#   'args': {'Module': 'STDIO',
#    'Rank': 0,
#    'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-45.meta.tmpa864c9ea5474456a934c108901f0e27f',
#    'STDIO_OPENS': 1.0,
#    'STDIO_FDOPENS': 0.0,
#    'STDIO_READS': 0.0,
#    'STDIO_WRITES': 1.0,
#    'STDIO_SEEKS': 0.0,
#    'STDIO_FLUSHES': 0.0,
#    'STDIO_BYTES_WRITTEN': 5449053,
#    'STDIO_BYTES_READ': 0,
#    'STDIO_MAX_BYTE_READ': 0.0,
#    'STDIO_MAX_BYTE_WRITTEN': 5449052.0,
#    'STDIO_FASTEST_RANK': 0.0,
#    'STDIO_FASTEST_RANK_BYTES': 0.0,
#    'STDIO_SLOWEST_RANK': 0.0,
#    'STDIO_SLOWEST_RANK_BYTES': 0.0,
#    'STDIO_F_META_TIME': 0.110774,
#    'STDIO_F_WRITE_TIME': 0.009677,
#    'STDIO_F_READ_TIME': 0.0,
#    'STDIO_F_OPEN_START_TIMESTAMP': 326.58187200000003,
#    'STDIO_F_CLOSE_START_TIMESTAMP': 326.61464700000005,
#    'STDIO_F_WRITE_START_TIMESTAMP': 326.604827,
#    'STDIO_F_READ_START_TIMESTAMP': 0.0,
#    'STDIO_F_OPEN_END_TIMESTAMP': 326.603754,
#    'STDIO_F_CLOSE_END_TIMESTAMP': 326.70353900000003,
#    'STDIO_F_WRITE_END_TIMESTAMP': 326.614504,
#    'STDIO_F_READ_END_TIMESTAMP': 0.0,
#    'STDIO_F_FASTEST_RANK_TIME': 0.0,
#    'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#    'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#  {'name': 'darshan',
#   'cat': 'STDIO',
#   'ph': 'B',
#   'ts': 308431222,
#   'pid': 0,
#   'tid': 1,
#   'args': {'Module': 'STDIO',
#    'Rank': 0,
#    'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-30_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.data-00000-of-00001.tempstate5286267822303063113',
#    'STDIO_OPENS': 1.0,
#    'STDIO_FDOPENS': 0.0,
#    'STDIO_READS': 0.0,
#    'STDIO_WRITES': 5.0,
#    'STDIO_SEEKS': 0.0,
#    'STDIO_FLUSHES': 0.0,
#    'STDIO_BYTES_WRITTEN': 36286492,
#    'STDIO_BYTES_READ': 0,
#    'STDIO_MAX_BYTE_READ': 0.0,
#    'STDIO_MAX_BYTE_WRITTEN': 36286491.0,
#    'STDIO_FASTEST_RANK': 0.0,
#    'STDIO_FASTEST_RANK_BYTES': 0.0,
#    'STDIO_SLOWEST_RANK': 0.0,
#    'STDIO_SLOWEST_RANK_BYTES': 0.0,
#    'STDIO_F_META_TIME': 0.2066,
#    'STDIO_F_WRITE_TIME': 0.053277,
#    'STDIO_F_READ_TIME': 0.0,
#    'STDIO_F_OPEN_START_TIMESTAMP': 308.388139,
#    'STDIO_F_CLOSE_START_TIMESTAMP': 308.50437200000005,
#    'STDIO_F_WRITE_START_TIMESTAMP': 308.43122200000005,
#    'STDIO_F_READ_START_TIMESTAMP': 0.0,
#    'STDIO_F_OPEN_END_TIMESTAMP': 308.4109,
#    'STDIO_F_CLOSE_END_TIMESTAMP': 308.68821099999997,
#    'STDIO_F_WRITE_END_TIMESTAMP': 308.50436099999996,
# ...
#    'STDIO_OPENS': 4.0,
#    'STDIO_FDOPENS': 0.0,
#    'STDIO_READS': 0.0,
#    'STDIO_WRITES': 420.0,
#    'STDIO_SEEKS': 0.0,
#    'STDIO_FLUSHES': 416.0,
#    'STDIO_BYTES_WRITTEN': 33811,
#    'STDIO_BYTES_READ': 0,
#    'STDIO_MAX_BYTE_READ': 0.0,
#    'STDIO_MAX_BYTE_WRITTEN': 8491.0,
#    'STDIO_FASTEST_RANK': 1.0,
#    'STDIO_FASTEST_RANK_BYTES': 8442.0,
#    'STDIO_SLOWEST_RANK': 0.0,
#    'STDIO_SLOWEST_RANK_BYTES': 8398.0,
#    'STDIO_F_META_TIME': 0.0,
#    'STDIO_F_WRITE_TIME': 0.029312,
#    'STDIO_F_READ_TIME': 0.0,
#    'STDIO_F_OPEN_START_TIMESTAMP': 0.0,
#    'STDIO_F_CLOSE_START_TIMESTAMP': 0.0,
#    'STDIO_F_WRITE_START_TIMESTAMP': 141.281073,
#    'STDIO_F_READ_START_TIMESTAMP': 0.0,
#    'STDIO_F_OPEN_END_TIMESTAMP': 0.0,
#    'STDIO_F_CLOSE_END_TIMESTAMP': 0.0,
#    'STDIO_F_WRITE_END_TIMESTAMP': 283.409789,
#    'STDIO_F_READ_END_TIMESTAMP': 0.0,
#    'STDIO_F_FASTEST_RANK_TIME': 0.005163,
#    'STDIO_F_SLOWEST_RANK_TIME': 0.011283,
#    'STDIO_F_VARIANCE_RANK_TIME': 6e-06,
#    'STDIO_F_VARIANCE_RANK_BYTES': 1335.6875}},
#  {'ph': 'E',
#   'ts': 283409789,
#   'pid': 1,
#   'tid': 1,
#   'args': {'Module': 'STDIO',
#    'Rank': -1,
#    'Filename': '<STDERR>',
#    'STDIO_OPENS': 4.0,
#    'STDIO_FDOPENS': 0.0,
#    'STDIO_READS': 0.0,
#    'STDIO_WRITES': 420.0,
#    'STDIO_SEEKS': 0.0,
#    'STDIO_FLUSHES': 416.0,
#    'STDIO_BYTES_WRITTEN': 33811,
#    'STDIO_BYTES_READ': 0,
#    'STDIO_MAX_BYTE_READ': 0.0,
#    'STDIO_MAX_BYTE_WRITTEN': 8491.0,
#    'STDIO_FASTEST_RANK': 1.0,
#    'STDIO_FASTEST_RANK_BYTES': 8442.0,
#    'STDIO_SLOWEST_RANK': 0.0,
#    'STDIO_SLOWEST_RANK_BYTES': 8398.0,
#    'STDIO_F_META_TIME': 0.0,
#    'STDIO_F_WRITE_TIME': 0.029312,
#    'STDIO_F_READ_TIME': 0.0,
#    'STDIO_F_OPEN_START_TIMESTAMP': 0.0,
#    'STDIO_F_CLOSE_START_TIMESTAMP': 0.0,
#    'STDIO_F_WRITE_START_TIMESTAMP': 141.281073,
#    'STDIO_F_READ_START_TIMESTAMP': 0.0,
#    'STDIO_F_OPEN_END_TIMESTAMP': 0.0,
#    'STDIO_F_CLOSE_END_TIMESTAMP': 0.0,
#    'STDIO_F_WRITE_END_TIMESTAMP': 283.409789,
#    'STDIO_F_READ_END_TIMESTAMP': 0.0,
#    'STDIO_F_FASTEST_RANK_TIME': 0.005163,
#    'STDIO_F_SLOWEST_RANK_TIME': 0.011283,
#    'STDIO_F_VARIANCE_RANK_TIME': 6e-06,
#    'STDIO_F_VARIANCE_RANK_BYTES': 1335.6875}},
#  {'name': 'darshan',
#   'cat': 'STDIO',
#   'ph': 'B',
#   'ts': 141281073,
#   'pid': 2,
#   'tid': 1,
#   'args': {'Module': 'STDIO',
#    'Rank': -1,
#    'Filename': '<STDERR>',
#    'STDIO_OPENS': 4.0,
#    'STDIO_FDOPENS': 0.0,
#    'STDIO_READS': 0.0,
#    'STDIO_WRITES': 420.0,
#    'STDIO_SEEKS': 0.0,
#    'STDIO_FLUSHES': 416.0,
#    'STDIO_BYTES_WRITTEN': 33811,
#    'STDIO_BYTES_READ': 0,
#    'STDIO_MAX_BYTE_READ': 0.0,
#    'STDIO_MAX_BYTE_WRITTEN': 8491.0,
#    'STDIO_FASTEST_RANK': 1.0,
#    'STDIO_FASTEST_RANK_BYTES': 8442.0,
#    'STDIO_SLOWEST_RANK': 0.0,
#    'STDIO_SLOWEST_RANK_BYTES': 8398.0,
#    'STDIO_F_META_TIME': 0.0,
#    'STDIO_F_WRITE_TIME': 0.029312,
#    'STDIO_F_READ_TIME': 0.0,
#    'STDIO_F_OPEN_START_TIMESTAMP': 0.0,
#    'STDIO_F_CLOSE_START_TIMESTAMP': 0.0,
#    'STDIO_F_WRITE_START_TIMESTAMP': 141.281073,
#    'STDIO_F_READ_START_TIMESTAMP': 0.0,
#    'STDIO_F_OPEN_END_TIMESTAMP': 0.0,
#    'STDIO_F_CLOSE_END_TIMESTAMP': 0.0,
#    'STDIO_F_WRITE_END_TIMESTAMP': 283.409789,
#    'STDIO_F_READ_END_TIMESTAMP': 0.0,
#    'STDIO_F_FASTEST_RANK_TIME': 0.005163,
#    'STDIO_F_SLOWEST_RANK_TIME': 0.011283,
#    'STDIO_F_VARIANCE_RANK_TIME': 6e-06,
#    'STDIO_F_VARIANCE_RANK_BYTES': 1335.6875}},
#  {'ph': 'E',
#   'ts': 283409789,
#   'pid': 2,
#   'tid': 1,
#   'args': {'Module': 'STDIO',
#    'Rank': -1,
#    'Filename': '<STDERR>',
#    'STDIO_OPENS': 4.0,
#    'STDIO_FDOPENS': 0.0,
#    'STDIO_READS': 0.0,
#    'STDIO_WRITES': 420.0,
#    'STDIO_SEEKS': 0.0,
#    'STDIO_FLUSHES': 416.0,
#    'STDIO_BYTES_WRITTEN': 33811,
#    'STDIO_BYTES_READ': 0,
#    'STDIO_MAX_BYTE_READ': 0.0,
#    'STDIO_MAX_BYTE_WRITTEN': 8491.0,
#    'STDIO_FASTEST_RANK': 1.0,
#    'STDIO_FASTEST_RANK_BYTES': 8442.0,
#    'STDIO_SLOWEST_RANK': 0.0,
#    'STDIO_SLOWEST_RANK_BYTES': 8398.0,
#    'STDIO_F_META_TIME': 0.0,
#    'STDIO_F_WRITE_TIME': 0.029312,
#    'STDIO_F_READ_TIME': 0.0,
#    'STDIO_F_OPEN_START_TIMESTAMP': 0.0,
#    'STDIO_F_CLOSE_START_TIMESTAMP': 0.0,
#    'STDIO_F_WRITE_START_TIMESTAMP': 141.281073,
#    'STDIO_F_READ_START_TIMESTAMP': 0.0,
#    'STDIO_F_OPEN_END_TIMESTAMP': 0.0,
#    'STDIO_F_CLOSE_END_TIMESTAMP': 0.0,
#    'STDIO_F_WRITE_END_TIMESTAMP': 283.409789,
#    'STDIO_F_READ_END_TIMESTAMP': 0.0,
#    'STDIO_F_FASTEST_RANK_TIME': 0.005163,
#    'STDIO_F_SLOWEST_RANK_TIME': 0.011283,
#    'STDIO_F_VARIANCE_RANK_TIME': 6e-06,
#    'STDIO_F_VARIANCE_RANK_BYTES': 1335.6875}},
#  {'name': 'darshan',
#   'cat': 'STDIO',
#   'ph': 'B',
#   'ts': 141281073,
#   'pid': 3,
#   'tid': 1,
#   'args': {'Module': 'STDIO',
#    'Rank': -1,
#    'Filename': '<STDERR>',
#    'STDIO_OPENS': 4.0,
#    'STDIO_FDOPENS': 0.0,
#    'STDIO_READS': 0.0,
#    'STDIO_WRITES': 420.0,
#    'STDIO_SEEKS': 0.0,
#    'STDIO_FLUSHES': 416.0,
#    'STDIO_BYTES_WRITTEN': 33811,
#    'STDIO_BYTES_READ': 0,
#    'STDIO_MAX_BYTE_READ': 0.0,
#    'STDIO_MAX_BYTE_WRITTEN': 8491.0,
#    'STDIO_FASTEST_RANK': 1.0,
#    'STDIO_FASTEST_RANK_BYTES': 8442.0,
#    'STDIO_SLOWEST_RANK': 0.0,
#    'STDIO_SLOWEST_RANK_BYTES': 8398.0,
#    'STDIO_F_META_TIME': 0.0,
#    'STDIO_F_WRITE_TIME': 0.029312,
#    'STDIO_F_READ_TIME': 0.0,
#    'STDIO_F_OPEN_START_TIMESTAMP': 0.0,
#    'STDIO_F_CLOSE_START_TIMESTAMP': 0.0,
#    'STDIO_F_WRITE_START_TIMESTAMP': 141.281073,
#    'STDIO_F_READ_START_TIMESTAMP': 0.0,
#    'STDIO_F_OPEN_END_TIMESTAMP': 0.0,
#    'STDIO_F_CLOSE_END_TIMESTAMP': 0.0,
#    'STDIO_F_WRITE_END_TIMESTAMP': 283.409789,
#    'STDIO_F_READ_END_TIMESTAMP': 0.0,
#    'STDIO_F_FASTEST_RANK_TIME': 0.005163,
#    'STDIO_F_SLOWEST_RANK_TIME': 0.011283,
#    'STDIO_F_VARIANCE_RANK_TIME': 6e-06,
#    'STDIO_F_VARIANCE_RANK_BYTES': 1335.6875}},
#  {'ph': 'E',
#   'ts': 283409789,
#   'pid': 3,
#   'tid': 1,
#   'args': {'Module': 'STDIO',
#    'Rank': -1,
#    'Filename': '<STDERR>',
#    'STDIO_OPENS': 4.0,
#    'STDIO_FDOPENS': 0.0,
#    'STDIO_READS': 0.0,
#    'STDIO_WRITES': 420.0,
#    'STDIO_SEEKS': 0.0,
#    'STDIO_FLUSHES': 416.0,
#    'STDIO_BYTES_WRITTEN': 33811,
#    'STDIO_BYTES_READ': 0,
#    'STDIO_MAX_BYTE_READ': 0.0,
#    'STDIO_MAX_BYTE_WRITTEN': 8491.0,
#    'STDIO_FASTEST_RANK': 1.0,
#    'STDIO_FASTEST_RANK_BYTES': 8442.0,
#    'STDIO_SLOWEST_RANK': 0.0,
#    'STDIO_SLOWEST_RANK_BYTES': 8398.0,
#    'STDIO_F_META_TIME': 0.0,
#    'STDIO_F_WRITE_TIME': 0.029312,
#    'STDIO_F_READ_TIME': 0.0,
#    'STDIO_F_OPEN_START_TIMESTAMP': 0.0,
#    'STDIO_F_CLOSE_START_TIMESTAMP': 0.0,
#    'STDIO_F_WRITE_START_TIMESTAMP': 141.281073,
#    'STDIO_F_READ_START_TIMESTAMP': 0.0,
#    'STDIO_F_OPEN_END_TIMESTAMP': 0.0,
#    'STDIO_F_CLOSE_END_TIMESTAMP': 0.0,
#    'STDIO_F_WRITE_END_TIMESTAMP': 283.409789,
#    'STDIO_F_READ_END_TIMESTAMP': 0.0,
#    'STDIO_F_FASTEST_RANK_TIME': 0.005163,
#    'STDIO_F_SLOWEST_RANK_TIME': 0.011283,
#    'STDIO_F_VARIANCE_RANK_TIME': 6e-06,
#    'STDIO_F_VARIANCE_RANK_BYTES': 1335.6875}},
#  {'name': 'darshan',
#   'cat': 'STDIO',
#   'ph': 'B',
#   'ts': 141281073,
#   'pid': 4,
#   'tid': 1,
#   'args': {'Module': 'STDIO',
#    'Rank': -1,
#    'Filename': '<STDERR>',
#    'STDIO_OPENS': 4.0,
#    'STDIO_FDOPENS': 0.0,
#    'STDIO_READS': 0.0,
#    'STDIO_WRITES': 420.0,
#    'STDIO_SEEKS': 0.0,
#    'STDIO_FLUSHES': 416.0,
#    'STDIO_BYTES_WRITTEN': 33811,
#    'STDIO_BYTES_READ': 0,
#    'STDIO_MAX_BYTE_READ': 0.0,
#    'STDIO_MAX_BYTE_WRITTEN': 8491.0,
#    'STDIO_FASTEST_RANK': 1.0,
#    'STDIO_FASTEST_RANK_BYTES': 8442.0,
#    'STDIO_SLOWEST_RANK': 0.0,
#    'STDIO_SLOWEST_RANK_BYTES': 8398.0,
#    'STDIO_F_META_TIME': 0.0,
#    'STDIO_F_WRITE_TIME': 0.029312,
#    'STDIO_F_READ_TIME': 0.0,
#    'STDIO_F_OPEN_START_TIMESTAMP': 0.0,
#    'STDIO_F_CLOSE_START_TIMESTAMP': 0.0,
#    'STDIO_F_WRITE_START_TIMESTAMP': 141.281073,
#    'STDIO_F_READ_START_TIMESTAMP': 0.0,
#    'STDIO_F_OPEN_END_TIMESTAMP': 0.0,
#    'STDIO_F_CLOSE_END_TIMESTAMP': 0.0,
#    'STDIO_F_WRITE_END_TIMESTAMP': 283.409789,
#    'STDIO_F_READ_END_TIMESTAMP': 0.0,
#    'STDIO_F_FASTEST_RANK_TIME': 0.005163,
#    'STDIO_F_SLOWEST_RANK_TIME': 0.011283,
#    'STDIO_F_VARIANCE_RANK_TIME': 6e-06,
#    'STDIO_F_VARIANCE_RANK_BYTES': 1335.6875}},
#  {'ph': 'E',
#   'ts': 283409789,
#   'pid': 4,
#   'tid': 1,
#   'args': {'Module': 'STDIO',
#    'Rank': -1,
#    'Filename': '<STDERR>',
#    'STDIO_OPENS': 4.0,
#    'STDIO_FDOPENS': 0.0,
#    'STDIO_READS': 0.0,
#    'STDIO_WRITES': 420.0,
#    'STDIO_SEEKS': 0.0,
#    'STDIO_FLUSHES': 416.0,
#    'STDIO_BYTES_WRITTEN': 33811,
#    'STDIO_BYTES_READ': 0,
#    'STDIO_MAX_BYTE_READ': 0.0,
#    'STDIO_MAX_BYTE_WRITTEN': 8491.0,
#    'STDIO_FASTEST_RANK': 1.0,
#    'STDIO_FASTEST_RANK_BYTES': 8442.0,
#    'STDIO_SLOWEST_RANK': 0.0,
#    'STDIO_SLOWEST_RANK_BYTES': 8398.0,
#    'STDIO_F_META_TIME': 0.0,
#    'STDIO_F_WRITE_TIME': 0.029312,
#    'STDIO_F_READ_TIME': 0.0,
#    'STDIO_F_OPEN_START_TIMESTAMP': 0.0,
#    'STDIO_F_CLOSE_START_TIMESTAMP': 0.0,
#    'STDIO_F_WRITE_START_TIMESTAMP': 141.281073,
#    'STDIO_F_READ_START_TIMESTAMP': 0.0,
#    'STDIO_F_OPEN_END_TIMESTAMP': 0.0,
#    'STDIO_F_CLOSE_END_TIMESTAMP': 0.0,
#    'STDIO_F_WRITE_END_TIMESTAMP': 283.409789,
#    'STDIO_F_READ_END_TIMESTAMP': 0.0,
#    'STDIO_F_FASTEST_RANK_TIME': 0.005163,
#    'STDIO_F_SLOWEST_RANK_TIME': 0.011283,
#    'STDIO_F_VARIANCE_RANK_TIME': 6e-06,
#    'STDIO_F_VARIANCE_RANK_BYTES': 1335.6875}},
#  {'name': 'darshan',
#   'cat': 'STDIO',
#   'ph': 'B',
#   'ts': 141281073,
#   'pid': 5,
#   'tid': 1,
#   'args': {'Module': 'STDIO',
#    'Rank': -1,
#    'Filename': '<STDERR>',
#    'STDIO_OPENS': 4.0,
#    'STDIO_FDOPENS': 0.0,
#    'STDIO_READS': 0.0,
#    'STDIO_WRITES': 420.0,
#    'STDIO_SEEKS': 0.0,
#    'STDIO_FLUSHES': 416.0,
#    'STDIO_BYTES_WRITTEN': 33811,
#    'STDIO_BYTES_READ': 0,
#    'STDIO_MAX_BYTE_READ': 0.0,
#    'STDIO_MAX_BYTE_WRITTEN': 8491.0,
#    'STDIO_FASTEST_RANK': 1.0,
#    'STDIO_FASTEST_RANK_BYTES': 8442.0,
#    'STDIO_SLOWEST_RANK': 0.0,
#    'STDIO_SLOWEST_RANK_BYTES': 8398.0,
#    'STDIO_F_META_TIME': 0.0,
#    'STDIO_F_WRITE_TIME': 0.029312,
#    'STDIO_F_READ_TIME': 0.0,
#    'STDIO_F_OPEN_START_TIMESTAMP': 0.0,
#    'STDIO_F_CLOSE_START_TIMESTAMP': 0.0,
#    'STDIO_F_WRITE_START_TIMESTAMP': 141.281073,
#    'STDIO_F_READ_START_TIMESTAMP': 0.0,
#    'STDIO_F_OPEN_END_TIMESTAMP': 0.0,
#    'STDIO_F_CLOSE_END_TIMESTAMP': 0.0,
#    'STDIO_F_WRITE_END_TIMESTAMP': 283.409789,
#    'STDIO_F_READ_END_TIMESTAMP': 0.0,
#    'STDIO_F_FASTEST_RANK_TIME': 0.005163,
#    'STDIO_F_SLOWEST_RANK_TIME': 0.011283,
#    'STDIO_F_VARIANCE_RANK_TIME': 6e-06,
#    'STDIO_F_VARIANCE_RANK_BYTES': 1335.6875}},
#  {'ph': 'E',
#   'ts': 283409789,
#   'pid': 5,
#   'tid': 1,
#   'args': {'Module': 'STDIO',
#    'Rank': -1,
#    'Filename': '<STDERR>',
#    'STDIO_OPENS': 4.0,
#    'STDIO_FDOPENS': 0.0,
#    'STDIO_READS': 0.0,
#    'STDIO_WRITES': 420.0,
#    'STDIO_SEEKS': 0.0,
#    'STDIO_FLUSHES': 416.0,
#    'STDIO_BYTES_WRITTEN': 33811,
#    'STDIO_BYTES_READ': 0,
#    'STDIO_MAX_BYTE_READ': 0.0,
#    'STDIO_MAX_BYTE_WRITTEN': 8491.0,
#    'STDIO_FASTEST_RANK': 1.0,
#    'STDIO_FASTEST_RANK_BYTES': 8442.0,
#    'STDIO_SLOWEST_RANK': 0.0,
#    'STDIO_SLOWEST_RANK_BYTES': 8398.0,
#    'STDIO_F_META_TIME': 0.0,
#    'STDIO_F_WRITE_TIME': 0.029312,
#    'STDIO_F_READ_TIME': 0.0,
#    'STDIO_F_OPEN_START_TIMESTAMP': 0.0,
#    'STDIO_F_CLOSE_START_TIMESTAMP': 0.0,
#    'STDIO_F_WRITE_START_TIMESTAMP': 141.281073,
#    'STDIO_F_READ_START_TIMESTAMP': 0.0,
#    'STDIO_F_OPEN_END_TIMESTAMP': 0.0,
#    'STDIO_F_CLOSE_END_TIMESTAMP': 0.0,
#    'STDIO_F_WRITE_END_TIMESTAMP': 283.409789,
#    'STDIO_F_READ_END_TIMESTAMP': 0.0,
#    'STDIO_F_FASTEST_RANK_TIME': 0.005163,
#    'STDIO_F_SLOWEST_RANK_TIME': 0.011283,
#    'STDIO_F_VARIANCE_RANK_TIME': 6e-06,
#    'STDIO_F_VARIANCE_RANK_BYTES': 1335.6875}},
#  {'name': 'darshan',
#   'cat': 'STDIO',
#   'ph': 'B',
#   'ts': 141281073,
#   'pid': 6,
#   'tid': 1,
#   'args': {'Module': 'STDIO',
#    'Rank': -1,
#    'Filename': '<STDERR>',
#    'STDIO_OPENS': 4.0,
#    'STDIO_FDOPENS': 0.0,
#    'STDIO_READS': 0.0,
#    'STDIO_WRITES': 420.0,
#    'STDIO_SEEKS': 0.0,
#    'STDIO_FLUSHES': 416.0,
#    'STDIO_BYTES_WRITTEN': 33811,
#    'STDIO_BYTES_READ': 0,
#    'STDIO_MAX_BYTE_READ': 0.0,
#    'STDIO_MAX_BYTE_WRITTEN': 8491.0,
#    'STDIO_FASTEST_RANK': 1.0,
#    'STDIO_FASTEST_RANK_BYTES': 8442.0,
#    'STDIO_SLOWEST_RANK': 0.0,
#    'STDIO_SLOWEST_RANK_BYTES': 8398.0,
#    'STDIO_F_META_TIME': 0.0,
#    'STDIO_F_WRITE_TIME': 0.029312,
#    'STDIO_F_READ_TIME': 0.0,
#    'STDIO_F_OPEN_START_TIMESTAMP': 0.0,
#    'STDIO_F_CLOSE_START_TIMESTAMP': 0.0,
#    'STDIO_F_WRITE_START_TIMESTAMP': 141.281073,
#    'STDIO_F_READ_START_TIMESTAMP': 0.0,
#    'STDIO_F_OPEN_END_TIMESTAMP': 0.0,
#    'STDIO_F_CLOSE_END_TIMESTAMP': 0.0,
#    'STDIO_F_WRITE_END_TIMESTAMP': 283.409789,
#    'STDIO_F_READ_END_TIMESTAMP': 0.0,
#    'STDIO_F_FASTEST_RANK_TIME': 0.005163,
#    'STDIO_F_SLOWEST_RANK_TIME': 0.011283,
#    'STDIO_F_VARIANCE_RANK_TIME': 6e-06,
#    'STDIO_F_VARIANCE_RANK_BYTES': 1335.6875}},
#  {'ph': 'E',
#   'ts': 283409789,
#   'pid': 6,
#   'tid': 1,
#   'args': {'Module': 'STDIO',
#    'Rank': -1,
#    'Filename': '<STDERR>',
#    'STDIO_OPENS': 4.0,
#    'STDIO_FDOPENS': 0.0,
#    'STDIO_READS': 0.0,
#    'STDIO_WRITES': 420.0,
#    'STDIO_SEEKS': 0.0,
#    'STDIO_FLUSHES': 416.0,
#    'STDIO_BYTES_WRITTEN': 33811,
#    'STDIO_BYTES_READ': 0,
#    'STDIO_MAX_BYTE_READ': 0.0,
#    'STDIO_MAX_BYTE_WRITTEN': 8491.0,
#    'STDIO_FASTEST_RANK': 1.0,
#    'STDIO_FASTEST_RANK_BYTES': 8442.0,
#    'STDIO_SLOWEST_RANK': 0.0,
#    'STDIO_SLOWEST_RANK_BYTES': 8398.0,
#    'STDIO_F_META_TIME': 0.0,
#    'STDIO_F_WRITE_TIME': 0.029312,
#    'STDIO_F_READ_TIME': 0.0,
#    'STDIO_F_OPEN_START_TIMESTAMP': 0.0,
#    'STDIO_F_CLOSE_START_TIMESTAMP': 0.0,
#    'STDIO_F_WRITE_START_TIMESTAMP': 141.281073,
#    'STDIO_F_READ_START_TIMESTAMP': 0.0,
#    'STDIO_F_OPEN_END_TIMESTAMP': 0.0,
#    'STDIO_F_CLOSE_END_TIMESTAMP': 0.0,
#    'STDIO_F_WRITE_END_TIMESTAMP': 283.409789,
#    'STDIO_F_READ_END_TIMESTAMP': 0.0,
#    'STDIO_F_FASTEST_RANK_TIME': 0.005163,
#    'STDIO_F_SLOWEST_RANK_TIME': 0.011283,
#    'STDIO_F_VARIANCE_RANK_TIME': 6e-06,
#    'STDIO_F_VARIANCE_RANK_BYTES': 1335.6875}},
#  {'name': 'darshan',
#   'cat': 'STDIO',
#   'ph': 'B',
#   'ts': 141281073,
#   'pid': 7,
#   'tid': 1,
#   'args': {'Module': 'STDIO',
#    'Rank': -1,
#    'Filename': '<STDERR>',
#    'STDIO_OPENS': 4.0,
#    'STDIO_FDOPENS': 0.0,
#    'STDIO_READS': 0.0,
#    'STDIO_WRITES': 420.0,
#    'STDIO_SEEKS': 0.0,
#    'STDIO_FLUSHES': 416.0,
#    'STDIO_BYTES_WRITTEN': 33811,
#    'STDIO_BYTES_READ': 0,
#    'STDIO_MAX_BYTE_READ': 0.0,
#    'STDIO_MAX_BYTE_WRITTEN': 8491.0,
#    'STDIO_FASTEST_RANK': 1.0,
#    'STDIO_FASTEST_RANK_BYTES': 8442.0,
#    'STDIO_SLOWEST_RANK': 0.0,
#    'STDIO_SLOWEST_RANK_BYTES': 8398.0,
#    'STDIO_F_META_TIME': 0.0,
#    'STDIO_F_WRITE_TIME': 0.029312,
#    'STDIO_F_READ_TIME': 0.0,
#    'STDIO_F_OPEN_START_TIMESTAMP': 0.0,
#    'STDIO_F_CLOSE_START_TIMESTAMP': 0.0,
#    'STDIO_F_WRITE_START_TIMESTAMP': 141.281073,
#    'STDIO_F_READ_START_TIMESTAMP': 0.0,
#    'STDIO_F_OPEN_END_TIMESTAMP': 0.0,
#    'STDIO_F_CLOSE_END_TIMESTAMP': 0.0,
#    'STDIO_F_WRITE_END_TIMESTAMP': 283.409789,
#    'STDIO_F_READ_END_TIMESTAMP': 0.0,
#    'STDIO_F_FASTEST_RANK_TIME': 0.005163,
#    'STDIO_F_SLOWEST_RANK_TIME': 0.011283,
#    'STDIO_F_VARIANCE_RANK_TIME': 6e-06,
#    'STDIO_F_VARIANCE_RANK_BYTES': 1335.6875}},
#  {'ph': 'E',
#   'ts': 283409789,
#   'pid': 7,
#   'tid': 1,
#   'args': {'Module': 'STDIO',
#    'Rank': -1,
#    'Filename': '<STDERR>',
#    'STDIO_OPENS': 4.0,
#    'STDIO_FDOPENS': 0.0,
#    'STDIO_READS': 0.0,
#    'STDIO_WRITES': 420.0,
#    'STDIO_SEEKS': 0.0,
#    'STDIO_FLUSHES': 416.0,
#    'STDIO_BYTES_WRITTEN': 33811,
#    'STDIO_BYTES_READ': 0,
#    'STDIO_MAX_BYTE_READ': 0.0,
#    'STDIO_MAX_BYTE_WRITTEN': 8491.0,
#    'STDIO_FASTEST_RANK': 1.0,
#    'STDIO_FASTEST_RANK_BYTES': 8442.0,
#    'STDIO_SLOWEST_RANK': 0.0,
#    'STDIO_SLOWEST_RANK_BYTES': 8398.0,
#    'STDIO_F_META_TIME': 0.0,
#    'STDIO_F_WRITE_TIME': 0.029312,
#    'STDIO_F_READ_TIME': 0.0,
#    'STDIO_F_OPEN_START_TIMESTAMP': 0.0,
#    'STDIO_F_CLOSE_START_TIMESTAMP': 0.0,
#    'STDIO_F_WRITE_START_TIMESTAMP': 141.281073,
#    'STDIO_F_READ_START_TIMESTAMP': 0.0,
#    'STDIO_F_OPEN_END_TIMESTAMP': 0.0,
#    'STDIO_F_CLOSE_END_TIMESTAMP': 0.0,
#    'STDIO_F_WRITE_END_TIMESTAMP': 283.409789,
#    'STDIO_F_READ_END_TIMESTAMP': 0.0,
#    'STDIO_F_FASTEST_RANK_TIME': 0.005163,
#    'STDIO_F_SLOWEST_RANK_TIME': 0.011283,
#    'STDIO_F_VARIANCE_RANK_TIME': 6e-06,
#    'STDIO_F_VARIANCE_RANK_BYTES': 1335.6875}}]

# %%
profile.CreateChromeTimeline(location="/home/dhari", filename="l2hmc_run2_p8_io.json")
# Out:
# [============================================================] 100.0% 42 of 42 Creating DXT Timeline
# {'traceEvents': [{'name': 'darshan',
#    'cat': 'STDIO',
#    'ph': 'B',
#    'ts': 140144304,
#    'pid': 0,
#    'tid': 1,
#    'args': {'Module': 'STDIO',
#     'Rank': 0,
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/events.out.tfevents.1591902661.nid00008',
#     'STDIO_OPENS': 1.0,
#     'STDIO_FDOPENS': 0.0,
#     'STDIO_READS': 0.0,
#     'STDIO_WRITES': 42.0,
#     'STDIO_SEEKS': 0.0,
#     'STDIO_FLUSHES': 6.0,
#     'STDIO_BYTES_WRITTEN': 19585691,
#     'STDIO_BYTES_READ': 0,
#     'STDIO_MAX_BYTE_READ': 0.0,
#     'STDIO_MAX_BYTE_WRITTEN': 19585690.0,
#     'STDIO_FASTEST_RANK': 0.0,
#     'STDIO_FASTEST_RANK_BYTES': 0.0,
#     'STDIO_SLOWEST_RANK': 0.0,
#     'STDIO_SLOWEST_RANK_BYTES': 0.0,
#     'STDIO_F_META_TIME': 0.042486,
#     'STDIO_F_WRITE_TIME': 0.08765099999999999,
#     'STDIO_F_READ_TIME': 0.0,
#     'STDIO_F_OPEN_START_TIMESTAMP': 140.10161100000002,
#     'STDIO_F_CLOSE_START_TIMESTAMP': 0.0,
#     'STDIO_F_WRITE_START_TIMESTAMP': 140.144304,
#     'STDIO_F_READ_START_TIMESTAMP': 0.0,
#     'STDIO_F_OPEN_END_TIMESTAMP': 140.144097,
#     'STDIO_F_CLOSE_END_TIMESTAMP': 0.0,
#     'STDIO_F_WRITE_END_TIMESTAMP': 384.2744,
#     'STDIO_F_READ_END_TIMESTAMP': 0.0,
#     'STDIO_F_FASTEST_RANK_TIME': 0.0,
#     'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#   {'name': 'darshan',
#    'cat': 'STDIO',
#    'ph': 'B',
#    'ts': 176370032,
#    'pid': 0,
#    'tid': 1,
#    'args': {'Module': 'STDIO',
#     'Rank': 0,
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/graph.pbtxt.tmpa14255dbe3834f45b758ec4703bc9b6d',
#     'STDIO_OPENS': 1.0,
#     'STDIO_FDOPENS': 0.0,
#     'STDIO_READS': 0.0,
#     'STDIO_WRITES': 1.0,
#     'STDIO_SEEKS': 0.0,
#     'STDIO_FLUSHES': 0.0,
#     'STDIO_BYTES_WRITTEN': 7585314,
#     'STDIO_BYTES_READ': 0,
#     'STDIO_MAX_BYTE_READ': 0.0,
#     'STDIO_MAX_BYTE_WRITTEN': 7585313.0,
#     'STDIO_FASTEST_RANK': 0.0,
#     'STDIO_FASTEST_RANK_BYTES': 0.0,
#     'STDIO_SLOWEST_RANK': 0.0,
#     'STDIO_SLOWEST_RANK_BYTES': 0.0,
#     'STDIO_F_META_TIME': 0.140362,
#     'STDIO_F_WRITE_TIME': 0.011382999999999999,
#     'STDIO_F_READ_TIME': 0.0,
#     'STDIO_F_OPEN_START_TIMESTAMP': 176.3377,
#     'STDIO_F_CLOSE_START_TIMESTAMP': 176.382513,
#     'STDIO_F_WRITE_START_TIMESTAMP': 176.370032,
#     'STDIO_F_READ_START_TIMESTAMP': 0.0,
#     'STDIO_F_OPEN_END_TIMESTAMP': 176.353444,
#     'STDIO_F_CLOSE_END_TIMESTAMP': 176.50713100000002,
#     'STDIO_F_WRITE_END_TIMESTAMP': 176.381415,
#     'STDIO_F_READ_END_TIMESTAMP': 0.0,
#     'STDIO_F_FASTEST_RANK_TIME': 0.0,
#     'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#   {'ph': 'E',
#    'ts': 176381415,
#    'pid': 0,
#    'tid': 1,
#    'args': {'Module': 'STDIO',
#     'Rank': 0,
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/graph.pbtxt.tmpa14255dbe3834f45b758ec4703bc9b6d',
#     'STDIO_OPENS': 1.0,
#     'STDIO_FDOPENS': 0.0,
#     'STDIO_READS': 0.0,
#     'STDIO_WRITES': 1.0,
#     'STDIO_SEEKS': 0.0,
#     'STDIO_FLUSHES': 0.0,
#     'STDIO_BYTES_WRITTEN': 7585314,
#     'STDIO_BYTES_READ': 0,
#     'STDIO_MAX_BYTE_READ': 0.0,
#     'STDIO_MAX_BYTE_WRITTEN': 7585313.0,
#     'STDIO_FASTEST_RANK': 0.0,
#     'STDIO_FASTEST_RANK_BYTES': 0.0,
#     'STDIO_SLOWEST_RANK': 0.0,
#     'STDIO_SLOWEST_RANK_BYTES': 0.0,
#     'STDIO_F_META_TIME': 0.140362,
#     'STDIO_F_WRITE_TIME': 0.011382999999999999,
#     'STDIO_F_READ_TIME': 0.0,
#     'STDIO_F_OPEN_START_TIMESTAMP': 176.3377,
#     'STDIO_F_CLOSE_START_TIMESTAMP': 176.382513,
#     'STDIO_F_WRITE_START_TIMESTAMP': 176.370032,
#     'STDIO_F_READ_START_TIMESTAMP': 0.0,
#     'STDIO_F_OPEN_END_TIMESTAMP': 176.353444,
#     'STDIO_F_CLOSE_END_TIMESTAMP': 176.50713100000002,
#     'STDIO_F_WRITE_END_TIMESTAMP': 176.381415,
#     'STDIO_F_READ_END_TIMESTAMP': 0.0,
#     'STDIO_F_FASTEST_RANK_TIME': 0.0,
#     'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#   {'name': 'darshan',
#    'cat': 'STDIO',
#    'ph': 'B',
#    'ts': 184196066,
#    'pid': 0,
#    'tid': 1,
#    'args': {'Module': 'STDIO',
#     'Rank': 0,
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-0_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.data-00000-of-00001.tempstate178319442380524411',
#     'STDIO_OPENS': 1.0,
#     'STDIO_FDOPENS': 0.0,
#     'STDIO_READS': 0.0,
#     'STDIO_WRITES': 5.0,
#     'STDIO_SEEKS': 0.0,
#     'STDIO_FLUSHES': 0.0,
#     'STDIO_BYTES_WRITTEN': 36286492,
#     'STDIO_BYTES_READ': 0,
#     'STDIO_MAX_BYTE_READ': 0.0,
#     'STDIO_MAX_BYTE_WRITTEN': 36286491.0,
#     'STDIO_FASTEST_RANK': 0.0,
#     'STDIO_FASTEST_RANK_BYTES': 0.0,
#     'STDIO_SLOWEST_RANK': 0.0,
#     'STDIO_SLOWEST_RANK_BYTES': 0.0,
#     'STDIO_F_META_TIME': 0.301202,
#     'STDIO_F_WRITE_TIME': 0.061530999999999995,
#     'STDIO_F_READ_TIME': 0.0,
#     'STDIO_F_OPEN_START_TIMESTAMP': 184.12743600000002,
#     'STDIO_F_CLOSE_START_TIMESTAMP': 184.27992,
#     'STDIO_F_WRITE_START_TIMESTAMP': 184.196066,
#     'STDIO_F_READ_START_TIMESTAMP': 0.0,
#     'STDIO_F_OPEN_END_TIMESTAMP': 184.15212,
#     'STDIO_F_CLOSE_END_TIMESTAMP': 184.55643799999999,
#     'STDIO_F_WRITE_END_TIMESTAMP': 184.279909,
#     'STDIO_F_READ_END_TIMESTAMP': 0.0,
#     'STDIO_F_FASTEST_RANK_TIME': 0.0,
#     'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#   {'ph': 'E',
#    'ts': 184279909,
#    'pid': 0,
#    'tid': 1,
#    'args': {'Module': 'STDIO',
#     'Rank': 0,
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-0_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.data-00000-of-00001.tempstate178319442380524411',
#     'STDIO_OPENS': 1.0,
#     'STDIO_FDOPENS': 0.0,
#     'STDIO_READS': 0.0,
#     'STDIO_WRITES': 5.0,
#     'STDIO_SEEKS': 0.0,
#     'STDIO_FLUSHES': 0.0,
#     'STDIO_BYTES_WRITTEN': 36286492,
#     'STDIO_BYTES_READ': 0,
#     'STDIO_MAX_BYTE_READ': 0.0,
#     'STDIO_MAX_BYTE_WRITTEN': 36286491.0,
#     'STDIO_FASTEST_RANK': 0.0,
#     'STDIO_FASTEST_RANK_BYTES': 0.0,
#     'STDIO_SLOWEST_RANK': 0.0,
#     'STDIO_SLOWEST_RANK_BYTES': 0.0,
#     'STDIO_F_META_TIME': 0.301202,
#     'STDIO_F_WRITE_TIME': 0.061530999999999995,
#     'STDIO_F_READ_TIME': 0.0,
#     'STDIO_F_OPEN_START_TIMESTAMP': 184.12743600000002,
#     'STDIO_F_CLOSE_START_TIMESTAMP': 184.27992,
#     'STDIO_F_WRITE_START_TIMESTAMP': 184.196066,
#     'STDIO_F_READ_START_TIMESTAMP': 0.0,
#     'STDIO_F_OPEN_END_TIMESTAMP': 184.15212,
#     'STDIO_F_CLOSE_END_TIMESTAMP': 184.55643799999999,
#     'STDIO_F_WRITE_END_TIMESTAMP': 184.279909,
#     'STDIO_F_READ_END_TIMESTAMP': 0.0,
#     'STDIO_F_FASTEST_RANK_TIME': 0.0,
#     'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#   {'name': 'darshan',
#    'cat': 'STDIO',
#    'ph': 'B',
#    'ts': 184580651,
#    'pid': 0,
#    'tid': 1,
#    'args': {'Module': 'STDIO',
#     'Rank': 0,
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-0_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.index.tempstate3719425310044319935',
#     'STDIO_OPENS': 1.0,
#     'STDIO_FDOPENS': 0.0,
#     'STDIO_READS': 0.0,
#     'STDIO_WRITES': 7.0,
#     'STDIO_SEEKS': 0.0,
#     'STDIO_FLUSHES': 0.0,
#     'STDIO_BYTES_WRITTEN': 4829,
#     'STDIO_BYTES_READ': 0,
#     'STDIO_MAX_BYTE_READ': 0.0,
#     'STDIO_MAX_BYTE_WRITTEN': 4828.0,
#     'STDIO_FASTEST_RANK': 0.0,
#     'STDIO_FASTEST_RANK_BYTES': 0.0,
#     'STDIO_SLOWEST_RANK': 0.0,
#     'STDIO_SLOWEST_RANK_BYTES': 0.0,
#     'STDIO_F_META_TIME': 0.030338,
#     'STDIO_F_WRITE_TIME': 0.00027,
#     'STDIO_F_READ_TIME': 0.0,
#     'STDIO_F_OPEN_START_TIMESTAMP': 184.561869,
#     'STDIO_F_CLOSE_START_TIMESTAMP': 184.580961,
#     'STDIO_F_WRITE_START_TIMESTAMP': 184.580651,
#     'STDIO_F_READ_START_TIMESTAMP': 0.0,
#     'STDIO_F_OPEN_END_TIMESTAMP': 184.580183,
#     'STDIO_F_CLOSE_END_TIMESTAMP': 184.592985,
#     'STDIO_F_WRITE_END_TIMESTAMP': 184.58095500000002,
#     'STDIO_F_READ_END_TIMESTAMP': 0.0,
#     'STDIO_F_FASTEST_RANK_TIME': 0.0,
#     'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#   {'ph': 'E',
#    'ts': 184580955,
#    'pid': 0,
#    'tid': 1,
#    'args': {'Module': 'STDIO',
#     'Rank': 0,
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-0_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.index.tempstate3719425310044319935',
#     'STDIO_OPENS': 1.0,
#     'STDIO_FDOPENS': 0.0,
#     'STDIO_READS': 0.0,
#     'STDIO_WRITES': 7.0,
#     'STDIO_SEEKS': 0.0,
#     'STDIO_FLUSHES': 0.0,
#     'STDIO_BYTES_WRITTEN': 4829,
#     'STDIO_BYTES_READ': 0,
#     'STDIO_MAX_BYTE_READ': 0.0,
#     'STDIO_MAX_BYTE_WRITTEN': 4828.0,
#     'STDIO_FASTEST_RANK': 0.0,
#     'STDIO_FASTEST_RANK_BYTES': 0.0,
#     'STDIO_SLOWEST_RANK': 0.0,
#     'STDIO_SLOWEST_RANK_BYTES': 0.0,
#     'STDIO_F_META_TIME': 0.030338,
#     'STDIO_F_WRITE_TIME': 0.00027,
#     'STDIO_F_READ_TIME': 0.0,
#     'STDIO_F_OPEN_START_TIMESTAMP': 184.561869,
#     'STDIO_F_CLOSE_START_TIMESTAMP': 184.580961,
#     'STDIO_F_WRITE_START_TIMESTAMP': 184.580651,
#     'STDIO_F_READ_START_TIMESTAMP': 0.0,
#     'STDIO_F_OPEN_END_TIMESTAMP': 184.580183,
#     'STDIO_F_CLOSE_END_TIMESTAMP': 184.592985,
#     'STDIO_F_WRITE_END_TIMESTAMP': 184.58095500000002,
#     'STDIO_F_READ_END_TIMESTAMP': 0.0,
#     'STDIO_F_FASTEST_RANK_TIME': 0.0,
#     'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#   {'name': 'darshan',
#    'cat': 'STDIO',
#    'ph': 'B',
#    'ts': 184641282,
#    'pid': 0,
#    'tid': 1,
#    'args': {'Module': 'STDIO',
#     'Rank': 0,
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-0.index',
#     'STDIO_OPENS': 1.0,
#     'STDIO_FDOPENS': 0.0,
#     'STDIO_READS': 0.0,
#     'STDIO_WRITES': 7.0,
#     'STDIO_SEEKS': 0.0,
#     'STDIO_FLUSHES': 0.0,
#     'STDIO_BYTES_WRITTEN': 4829,
#     'STDIO_BYTES_READ': 0,
#     'STDIO_MAX_BYTE_READ': 0.0,
#     'STDIO_MAX_BYTE_WRITTEN': 4828.0,
#     'STDIO_FASTEST_RANK': 0.0,
#     'STDIO_FASTEST_RANK_BYTES': 0.0,
#     'STDIO_SLOWEST_RANK': 0.0,
#     'STDIO_SLOWEST_RANK_BYTES': 0.0,
#     'STDIO_F_META_TIME': 0.018504,
#     'STDIO_F_WRITE_TIME': 0.000299,
#     'STDIO_F_READ_TIME': 0.0,
#     'STDIO_F_OPEN_START_TIMESTAMP': 184.625499,
#     'STDIO_F_CLOSE_START_TIMESTAMP': 184.64160800000002,
#     'STDIO_F_WRITE_START_TIMESTAMP': 184.64128200000002,
#     'STDIO_F_READ_START_TIMESTAMP': 0.0,
#     'STDIO_F_OPEN_END_TIMESTAMP': 184.64091299999998,
#     'STDIO_F_CLOSE_END_TIMESTAMP': 184.644698,
#     'STDIO_F_WRITE_END_TIMESTAMP': 184.641601,
#     'STDIO_F_READ_END_TIMESTAMP': 0.0,
#     'STDIO_F_FASTEST_RANK_TIME': 0.0,
#     'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#   {'ph': 'E',
#    'ts': 184641601,
#    'pid': 0,
#    'tid': 1,
#    'args': {'Module': 'STDIO',
#     'Rank': 0,
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-0.index',
#     'STDIO_OPENS': 1.0,
#     'STDIO_FDOPENS': 0.0,
#     'STDIO_READS': 0.0,
#     'STDIO_WRITES': 7.0,
#     'STDIO_SEEKS': 0.0,
#     'STDIO_FLUSHES': 0.0,
#     'STDIO_BYTES_WRITTEN': 4829,
#     'STDIO_BYTES_READ': 0,
#     'STDIO_MAX_BYTE_READ': 0.0,
#     'STDIO_MAX_BYTE_WRITTEN': 4828.0,
#     'STDIO_FASTEST_RANK': 0.0,
#     'STDIO_FASTEST_RANK_BYTES': 0.0,
#     'STDIO_SLOWEST_RANK': 0.0,
#     'STDIO_SLOWEST_RANK_BYTES': 0.0,
#     'STDIO_F_META_TIME': 0.018504,
#     'STDIO_F_WRITE_TIME': 0.000299,
#     'STDIO_F_READ_TIME': 0.0,
#     'STDIO_F_OPEN_START_TIMESTAMP': 184.625499,
#     'STDIO_F_CLOSE_START_TIMESTAMP': 184.64160800000002,
#     'STDIO_F_WRITE_START_TIMESTAMP': 184.64128200000002,
#     'STDIO_F_READ_START_TIMESTAMP': 0.0,
#     'STDIO_F_OPEN_END_TIMESTAMP': 184.64091299999998,
#     'STDIO_F_CLOSE_END_TIMESTAMP': 184.644698,
#     'STDIO_F_WRITE_END_TIMESTAMP': 184.641601,
#     'STDIO_F_READ_END_TIMESTAMP': 0.0,
#     'STDIO_F_FASTEST_RANK_TIME': 0.0,
#     'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#   {'name': 'darshan',
#    'cat': 'STDIO',
#    'ph': 'B',
#    'ts': 184683270,
#    'pid': 0,
#    'tid': 1,
#    'args': {'Module': 'STDIO',
#     'Rank': 0,
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/checkpoint.tmp7576ea61e5fe46a9bb191a56d431ef4d',
#     'STDIO_OPENS': 1.0,
#     'STDIO_FDOPENS': 0.0,
#     'STDIO_READS': 0.0,
#     'STDIO_WRITES': 1.0,
#     'STDIO_SEEKS': 0.0,
#     'STDIO_FLUSHES': 0.0,
#     'STDIO_BYTES_WRITTEN': 377,
#     'STDIO_BYTES_READ': 0,
#     'STDIO_MAX_BYTE_READ': 0.0,
#     'STDIO_MAX_BYTE_WRITTEN': 376.0,
#     'STDIO_FASTEST_RANK': 0.0,
#     'STDIO_FASTEST_RANK_BYTES': 0.0,
#     'STDIO_SLOWEST_RANK': 0.0,
#     'STDIO_SLOWEST_RANK_BYTES': 0.0,
#     'STDIO_F_META_TIME': 0.01944,
#     'STDIO_F_WRITE_TIME': 0.000426,
#     'STDIO_F_READ_TIME': 0.0,
#     'STDIO_F_OPEN_START_TIMESTAMP': 184.665441,
#     'STDIO_F_CLOSE_START_TIMESTAMP': 184.683845,
#     'STDIO_F_WRITE_START_TIMESTAMP': 184.68327,
#     'STDIO_F_READ_START_TIMESTAMP': 0.0,
#     'STDIO_F_OPEN_END_TIMESTAMP': 184.683056,
#     'STDIO_F_CLOSE_END_TIMESTAMP': 184.68567,
#     'STDIO_F_WRITE_END_TIMESTAMP': 184.683696,
#     'STDIO_F_READ_END_TIMESTAMP': 0.0,
#     'STDIO_F_FASTEST_RANK_TIME': 0.0,
#     'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#   {'ph': 'E',
#    'ts': 184683696,
#    'pid': 0,
#    'tid': 1,
#    'args': {'Module': 'STDIO',
#     'Rank': 0,
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/checkpoint.tmp7576ea61e5fe46a9bb191a56d431ef4d',
#     'STDIO_OPENS': 1.0,
#     'STDIO_FDOPENS': 0.0,
#     'STDIO_READS': 0.0,
#     'STDIO_WRITES': 1.0,
#     'STDIO_SEEKS': 0.0,
#     'STDIO_FLUSHES': 0.0,
#     'STDIO_BYTES_WRITTEN': 377,
#     'STDIO_BYTES_READ': 0,
#     'STDIO_MAX_BYTE_READ': 0.0,
#     'STDIO_MAX_BYTE_WRITTEN': 376.0,
#     'STDIO_FASTEST_RANK': 0.0,
#     'STDIO_FASTEST_RANK_BYTES': 0.0,
#     'STDIO_SLOWEST_RANK': 0.0,
#     'STDIO_SLOWEST_RANK_BYTES': 0.0,
#     'STDIO_F_META_TIME': 0.01944,
#     'STDIO_F_WRITE_TIME': 0.000426,
#     'STDIO_F_READ_TIME': 0.0,
#     'STDIO_F_OPEN_START_TIMESTAMP': 184.665441,
#     'STDIO_F_CLOSE_START_TIMESTAMP': 184.683845,
#     'STDIO_F_WRITE_START_TIMESTAMP': 184.68327,
#     'STDIO_F_READ_START_TIMESTAMP': 0.0,
#     'STDIO_F_OPEN_END_TIMESTAMP': 184.683056,
#     'STDIO_F_CLOSE_END_TIMESTAMP': 184.68567,
#     'STDIO_F_WRITE_END_TIMESTAMP': 184.683696,
#     'STDIO_F_READ_END_TIMESTAMP': 0.0,
#     'STDIO_F_FASTEST_RANK_TIME': 0.0,
#     'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#   {'name': 'darshan',
#    'cat': 'STDIO',
#    'ph': 'B',
#    'ts': 188037062,
#    'pid': 0,
#    'tid': 1,
#    'args': {'Module': 'STDIO',
#     'Rank': 0,
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-0.meta.tmp0203df2e01a0441d993907608a87cf83',
#     'STDIO_OPENS': 1.0,
#     'STDIO_FDOPENS': 0.0,
#     'STDIO_READS': 0.0,
#     'STDIO_WRITES': 1.0,
#     'STDIO_SEEKS': 0.0,
#     'STDIO_FLUSHES': 0.0,
#     'STDIO_BYTES_WRITTEN': 5449053,
#     'STDIO_BYTES_READ': 0,
#     'STDIO_MAX_BYTE_READ': 0.0,
#     'STDIO_MAX_BYTE_WRITTEN': 5449052.0,
#     'STDIO_FASTEST_RANK': 0.0,
#     'STDIO_FASTEST_RANK_BYTES': 0.0,
#     'STDIO_SLOWEST_RANK': 0.0,
#     'STDIO_SLOWEST_RANK_BYTES': 0.0,
#     'STDIO_F_META_TIME': 0.06765800000000001,
#     'STDIO_F_WRITE_TIME': 0.0087,
#     'STDIO_F_READ_TIME': 0.0,
#     'STDIO_F_OPEN_START_TIMESTAMP': 188.016289,
#     'STDIO_F_CLOSE_START_TIMESTAMP': 188.04591100000002,
#     'STDIO_F_WRITE_START_TIMESTAMP': 188.03706200000002,
#     'STDIO_F_READ_START_TIMESTAMP': 0.0,
#     'STDIO_F_OPEN_END_TIMESTAMP': 188.036017,
#     'STDIO_F_CLOSE_END_TIMESTAMP': 188.093841,
#     'STDIO_F_WRITE_END_TIMESTAMP': 188.04576200000002,
#     'STDIO_F_READ_END_TIMESTAMP': 0.0,
#     'STDIO_F_FASTEST_RANK_TIME': 0.0,
#     'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#   {'ph': 'E',
#    'ts': 188045762,
#    'pid': 0,
#    'tid': 1,
#    'args': {'Module': 'STDIO',
#     'Rank': 0,
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-0.meta.tmp0203df2e01a0441d993907608a87cf83',
#     'STDIO_OPENS': 1.0,
#     'STDIO_FDOPENS': 0.0,
#     'STDIO_READS': 0.0,
#     'STDIO_WRITES': 1.0,
#     'STDIO_SEEKS': 0.0,
#     'STDIO_FLUSHES': 0.0,
#     'STDIO_BYTES_WRITTEN': 5449053,
#     'STDIO_BYTES_READ': 0,
#     'STDIO_MAX_BYTE_READ': 0.0,
#     'STDIO_MAX_BYTE_WRITTEN': 5449052.0,
#     'STDIO_FASTEST_RANK': 0.0,
#     'STDIO_FASTEST_RANK_BYTES': 0.0,
#     'STDIO_SLOWEST_RANK': 0.0,
#     'STDIO_SLOWEST_RANK_BYTES': 0.0,
#     'STDIO_F_META_TIME': 0.06765800000000001,
#     'STDIO_F_WRITE_TIME': 0.0087,
#     'STDIO_F_READ_TIME': 0.0,
#     'STDIO_F_OPEN_START_TIMESTAMP': 188.016289,
#     'STDIO_F_CLOSE_START_TIMESTAMP': 188.04591100000002,
#     'STDIO_F_WRITE_START_TIMESTAMP': 188.03706200000002,
#     'STDIO_F_READ_START_TIMESTAMP': 0.0,
#     'STDIO_F_OPEN_END_TIMESTAMP': 188.036017,
#     'STDIO_F_CLOSE_END_TIMESTAMP': 188.093841,
#     'STDIO_F_WRITE_END_TIMESTAMP': 188.04576200000002,
#     'STDIO_F_READ_END_TIMESTAMP': 0.0,
#     'STDIO_F_FASTEST_RANK_TIME': 0.0,
#     'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#   {'name': 'darshan',
#    'cat': 'STDIO',
#    'ph': 'B',
#    'ts': 294090889,
#    'pid': 0,
#    'tid': 1,
#    'args': {'Module': 'STDIO',
#     'Rank': 0,
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-15_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.data-00000-of-00001.tempstate9804660416386708781',
#     'STDIO_OPENS': 1.0,
#     'STDIO_FDOPENS': 0.0,
#     'STDIO_READS': 0.0,
#     'STDIO_WRITES': 5.0,
#     'STDIO_SEEKS': 0.0,
#     'STDIO_FLUSHES': 0.0,
#     'STDIO_BYTES_WRITTEN': 36286492,
#     'STDIO_BYTES_READ': 0,
#     'STDIO_MAX_BYTE_READ': 0.0,
#     'STDIO_MAX_BYTE_WRITTEN': 36286491.0,
#     'STDIO_FASTEST_RANK': 0.0,
#     'STDIO_FASTEST_RANK_BYTES': 0.0,
#     'STDIO_SLOWEST_RANK': 0.0,
#     'STDIO_SLOWEST_RANK_BYTES': 0.0,
#     'STDIO_F_META_TIME': 0.23074699999999998,
#     'STDIO_F_WRITE_TIME': 0.057064,
#     'STDIO_F_READ_TIME': 0.0,
#     'STDIO_F_OPEN_START_TIMESTAMP': 294.034413,
#     'STDIO_F_CLOSE_START_TIMESTAMP': 294.16819100000004,
#     'STDIO_F_WRITE_START_TIMESTAMP': 294.090889,
#     'STDIO_F_READ_START_TIMESTAMP': 0.0,
#     'STDIO_F_OPEN_END_TIMESTAMP': 294.070854,
#     'STDIO_F_CLOSE_END_TIMESTAMP': 294.362497,
#     'STDIO_F_WRITE_END_TIMESTAMP': 294.168181,
#     'STDIO_F_READ_END_TIMESTAMP': 0.0,
#     'STDIO_F_FASTEST_RANK_TIME': 0.0,
#     'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#   {'ph': 'E',
#    'ts': 294168181,
#    'pid': 0,
#    'tid': 1,
#    'args': {'Module': 'STDIO',
#     'Rank': 0,
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-15_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.data-00000-of-00001.tempstate9804660416386708781',
#     'STDIO_OPENS': 1.0,
#     'STDIO_FDOPENS': 0.0,
#     'STDIO_READS': 0.0,
#     'STDIO_WRITES': 5.0,
#     'STDIO_SEEKS': 0.0,
#     'STDIO_FLUSHES': 0.0,
#     'STDIO_BYTES_WRITTEN': 36286492,
#     'STDIO_BYTES_READ': 0,
#     'STDIO_MAX_BYTE_READ': 0.0,
#     'STDIO_MAX_BYTE_WRITTEN': 36286491.0,
#     'STDIO_FASTEST_RANK': 0.0,
#     'STDIO_FASTEST_RANK_BYTES': 0.0,
#     'STDIO_SLOWEST_RANK': 0.0,
#     'STDIO_SLOWEST_RANK_BYTES': 0.0,
#     'STDIO_F_META_TIME': 0.23074699999999998,
#     'STDIO_F_WRITE_TIME': 0.057064,
#     'STDIO_F_READ_TIME': 0.0,
#     'STDIO_F_OPEN_START_TIMESTAMP': 294.034413,
#     'STDIO_F_CLOSE_START_TIMESTAMP': 294.16819100000004,
#     'STDIO_F_WRITE_START_TIMESTAMP': 294.090889,
#     'STDIO_F_READ_START_TIMESTAMP': 0.0,
#     'STDIO_F_OPEN_END_TIMESTAMP': 294.070854,
#     'STDIO_F_CLOSE_END_TIMESTAMP': 294.362497,
#     'STDIO_F_WRITE_END_TIMESTAMP': 294.168181,
#     'STDIO_F_READ_END_TIMESTAMP': 0.0,
#     'STDIO_F_FASTEST_RANK_TIME': 0.0,
#     'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#   {'name': 'darshan',
#    'cat': 'STDIO',
#    'ph': 'B',
#    'ts': 294385904,
#    'pid': 0,
#    'tid': 1,
#    'args': {'Module': 'STDIO',
#     'Rank': 0,
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-15_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.index.tempstate17637325061969226306',
#     'STDIO_OPENS': 1.0,
#     'STDIO_FDOPENS': 0.0,
#     'STDIO_READS': 0.0,
#     'STDIO_WRITES': 7.0,
#     'STDIO_SEEKS': 0.0,
#     'STDIO_FLUSHES': 0.0,
#     'STDIO_BYTES_WRITTEN': 4829,
#     'STDIO_BYTES_READ': 0,
#     'STDIO_MAX_BYTE_READ': 0.0,
#     'STDIO_MAX_BYTE_WRITTEN': 4828.0,
#     'STDIO_FASTEST_RANK': 0.0,
#     'STDIO_FASTEST_RANK_BYTES': 0.0,
#     'STDIO_SLOWEST_RANK': 0.0,
#     'STDIO_SLOWEST_RANK_BYTES': 0.0,
#     'STDIO_F_META_TIME': 0.021263999999999998,
#     'STDIO_F_WRITE_TIME': 0.00043,
#     'STDIO_F_READ_TIME': 0.0,
#     'STDIO_F_OPEN_START_TIMESTAMP': 294.36691099999996,
#     'STDIO_F_CLOSE_START_TIMESTAMP': 294.386413,
#     'STDIO_F_WRITE_START_TIMESTAMP': 294.385904,
#     'STDIO_F_READ_START_TIMESTAMP': 0.0,
#     'STDIO_F_OPEN_END_TIMESTAMP': 294.385379,
#     'STDIO_F_CLOSE_END_TIMESTAMP': 294.389209,
#     'STDIO_F_WRITE_END_TIMESTAMP': 294.386402,
#     'STDIO_F_READ_END_TIMESTAMP': 0.0,
#     'STDIO_F_FASTEST_RANK_TIME': 0.0,
#     'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#   {'ph': 'E',
#    'ts': 294386402,
#    'pid': 0,
#    'tid': 1,
#    'args': {'Module': 'STDIO',
#     'Rank': 0,
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-15_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.index.tempstate17637325061969226306',
#     'STDIO_OPENS': 1.0,
#     'STDIO_FDOPENS': 0.0,
#     'STDIO_READS': 0.0,
#     'STDIO_WRITES': 7.0,
#     'STDIO_SEEKS': 0.0,
#     'STDIO_FLUSHES': 0.0,
#     'STDIO_BYTES_WRITTEN': 4829,
#     'STDIO_BYTES_READ': 0,
#     'STDIO_MAX_BYTE_READ': 0.0,
#     'STDIO_MAX_BYTE_WRITTEN': 4828.0,
#     'STDIO_FASTEST_RANK': 0.0,
#     'STDIO_FASTEST_RANK_BYTES': 0.0,
#     'STDIO_SLOWEST_RANK': 0.0,
#     'STDIO_SLOWEST_RANK_BYTES': 0.0,
#     'STDIO_F_META_TIME': 0.021263999999999998,
#     'STDIO_F_WRITE_TIME': 0.00043,
#     'STDIO_F_READ_TIME': 0.0,
#     'STDIO_F_OPEN_START_TIMESTAMP': 294.36691099999996,
#     'STDIO_F_CLOSE_START_TIMESTAMP': 294.386413,
#     'STDIO_F_WRITE_START_TIMESTAMP': 294.385904,
#     'STDIO_F_READ_START_TIMESTAMP': 0.0,
#     'STDIO_F_OPEN_END_TIMESTAMP': 294.385379,
#     'STDIO_F_CLOSE_END_TIMESTAMP': 294.389209,
#     'STDIO_F_WRITE_END_TIMESTAMP': 294.386402,
#     'STDIO_F_READ_END_TIMESTAMP': 0.0,
#     'STDIO_F_FASTEST_RANK_TIME': 0.0,
#     'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#   {'name': 'darshan',
#    'cat': 'STDIO',
#    'ph': 'B',
#    'ts': 294422761,
#    'pid': 0,
#    'tid': 1,
#    'args': {'Module': 'STDIO',
#     'Rank': 0,
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-15.index',
#     'STDIO_OPENS': 1.0,
#     'STDIO_FDOPENS': 0.0,
#     'STDIO_READS': 0.0,
#     'STDIO_WRITES': 7.0,
#     'STDIO_SEEKS': 0.0,
#     'STDIO_FLUSHES': 0.0,
#     'STDIO_BYTES_WRITTEN': 4829,
#     'STDIO_BYTES_READ': 0,
#     'STDIO_MAX_BYTE_READ': 0.0,
#     'STDIO_MAX_BYTE_WRITTEN': 4828.0,
#     'STDIO_FASTEST_RANK': 0.0,
#     'STDIO_FASTEST_RANK_BYTES': 0.0,
#     'STDIO_SLOWEST_RANK': 0.0,
#     'STDIO_SLOWEST_RANK_BYTES': 0.0,
#     'STDIO_F_META_TIME': 0.018798,
#     'STDIO_F_WRITE_TIME': 0.00038500000000000003,
#     'STDIO_F_READ_TIME': 0.0,
#     'STDIO_F_OPEN_START_TIMESTAMP': 294.406115,
#     'STDIO_F_CLOSE_START_TIMESTAMP': 294.423201,
#     'STDIO_F_WRITE_START_TIMESTAMP': 294.422761,
#     'STDIO_F_READ_START_TIMESTAMP': 0.0,
#     'STDIO_F_OPEN_END_TIMESTAMP': 294.422355,
#     'STDIO_F_CLOSE_END_TIMESTAMP': 294.42575899999997,
#     'STDIO_F_WRITE_END_TIMESTAMP': 294.423188,
#     'STDIO_F_READ_END_TIMESTAMP': 0.0,
#     'STDIO_F_FASTEST_RANK_TIME': 0.0,
#     'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#   {'ph': 'E',
#    'ts': 294423188,
#    'pid': 0,
#    'tid': 1,
#    'args': {'Module': 'STDIO',
#     'Rank': 0,
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-15.index',
#     'STDIO_OPENS': 1.0,
#     'STDIO_FDOPENS': 0.0,
#     'STDIO_READS': 0.0,
#     'STDIO_WRITES': 7.0,
#     'STDIO_SEEKS': 0.0,
#     'STDIO_FLUSHES': 0.0,
#     'STDIO_BYTES_WRITTEN': 4829,
#     'STDIO_BYTES_READ': 0,
#     'STDIO_MAX_BYTE_READ': 0.0,
#     'STDIO_MAX_BYTE_WRITTEN': 4828.0,
#     'STDIO_FASTEST_RANK': 0.0,
#     'STDIO_FASTEST_RANK_BYTES': 0.0,
#     'STDIO_SLOWEST_RANK': 0.0,
#     'STDIO_SLOWEST_RANK_BYTES': 0.0,
#     'STDIO_F_META_TIME': 0.018798,
#     'STDIO_F_WRITE_TIME': 0.00038500000000000003,
#     'STDIO_F_READ_TIME': 0.0,
#     'STDIO_F_OPEN_START_TIMESTAMP': 294.406115,
#     'STDIO_F_CLOSE_START_TIMESTAMP': 294.423201,
#     'STDIO_F_WRITE_START_TIMESTAMP': 294.422761,
#     'STDIO_F_READ_START_TIMESTAMP': 0.0,
#     'STDIO_F_OPEN_END_TIMESTAMP': 294.422355,
#     'STDIO_F_CLOSE_END_TIMESTAMP': 294.42575899999997,
#     'STDIO_F_WRITE_END_TIMESTAMP': 294.423188,
#     'STDIO_F_READ_END_TIMESTAMP': 0.0,
#     'STDIO_F_FASTEST_RANK_TIME': 0.0,
#     'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#   {'name': 'darshan',
#    'cat': 'STDIO',
#    'ph': 'B',
#    'ts': 294466062,
#    'pid': 0,
#    'tid': 1,
#    'args': {'Module': 'STDIO',
#     'Rank': 0,
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/checkpoint.tmp66636a1b285d4110877738817e9cb88a',
#     'STDIO_OPENS': 1.0,
#     'STDIO_FDOPENS': 0.0,
#     'STDIO_READS': 0.0,
#     'STDIO_WRITES': 1.0,
#     'STDIO_SEEKS': 0.0,
#     'STDIO_FLUSHES': 0.0,
#     'STDIO_BYTES_WRITTEN': 570,
#     'STDIO_BYTES_READ': 0,
#     'STDIO_MAX_BYTE_READ': 0.0,
#     'STDIO_MAX_BYTE_WRITTEN': 569.0,
#     'STDIO_FASTEST_RANK': 0.0,
#     'STDIO_FASTEST_RANK_BYTES': 0.0,
#     'STDIO_SLOWEST_RANK': 0.0,
#     'STDIO_SLOWEST_RANK_BYTES': 0.0,
#     'STDIO_F_META_TIME': 0.022112,
#     'STDIO_F_WRITE_TIME': 0.000585,
#     'STDIO_F_READ_TIME': 0.0,
#     'STDIO_F_OPEN_START_TIMESTAMP': 294.446198,
#     'STDIO_F_CLOSE_START_TIMESTAMP': 294.466742,
#     'STDIO_F_WRITE_START_TIMESTAMP': 294.46606299999996,
#     'STDIO_F_READ_START_TIMESTAMP': 0.0,
#     'STDIO_F_OPEN_END_TIMESTAMP': 294.465747,
#     'STDIO_F_CLOSE_END_TIMESTAMP': 294.46930499999996,
#     'STDIO_F_WRITE_END_TIMESTAMP': 294.466648,
#     'STDIO_F_READ_END_TIMESTAMP': 0.0,
#     'STDIO_F_FASTEST_RANK_TIME': 0.0,
#     'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#   {'ph': 'E',
#    'ts': 294466648,
#    'pid': 0,
#    'tid': 1,
#    'args': {'Module': 'STDIO',
#     'Rank': 0,
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/checkpoint.tmp66636a1b285d4110877738817e9cb88a',
#     'STDIO_OPENS': 1.0,
#     'STDIO_FDOPENS': 0.0,
#     'STDIO_READS': 0.0,
#     'STDIO_WRITES': 1.0,
#     'STDIO_SEEKS': 0.0,
#     'STDIO_FLUSHES': 0.0,
#     'STDIO_BYTES_WRITTEN': 570,
#     'STDIO_BYTES_READ': 0,
#     'STDIO_MAX_BYTE_READ': 0.0,
#     'STDIO_MAX_BYTE_WRITTEN': 569.0,
#     'STDIO_FASTEST_RANK': 0.0,
#     'STDIO_FASTEST_RANK_BYTES': 0.0,
#     'STDIO_SLOWEST_RANK': 0.0,
#     'STDIO_SLOWEST_RANK_BYTES': 0.0,
#     'STDIO_F_META_TIME': 0.022112,
#     'STDIO_F_WRITE_TIME': 0.000585,
#     'STDIO_F_READ_TIME': 0.0,
#     'STDIO_F_OPEN_START_TIMESTAMP': 294.446198,
#     'STDIO_F_CLOSE_START_TIMESTAMP': 294.466742,
#     'STDIO_F_WRITE_START_TIMESTAMP': 294.46606299999996,
#     'STDIO_F_READ_START_TIMESTAMP': 0.0,
#     'STDIO_F_OPEN_END_TIMESTAMP': 294.465747,
#     'STDIO_F_CLOSE_END_TIMESTAMP': 294.46930499999996,
#     'STDIO_F_WRITE_END_TIMESTAMP': 294.466648,
#     'STDIO_F_READ_END_TIMESTAMP': 0.0,
#     'STDIO_F_FASTEST_RANK_TIME': 0.0,
#     'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#   {'name': 'darshan',
#    'cat': 'STDIO',
#    'ph': 'B',
#    'ts': 297750179,
#    'pid': 0,
#    'tid': 1,
#    'args': {'Module': 'STDIO',
#     'Rank': 0,
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-15.meta.tmp744e2dc3e68f47ea831e3528dd0cf5f7',
#     'STDIO_OPENS': 1.0,
#     'STDIO_FDOPENS': 0.0,
#     'STDIO_READS': 0.0,
#     'STDIO_WRITES': 1.0,
#     'STDIO_SEEKS': 0.0,
#     'STDIO_FLUSHES': 0.0,
#     'STDIO_BYTES_WRITTEN': 5449053,
#     'STDIO_BYTES_READ': 0,
#     'STDIO_MAX_BYTE_READ': 0.0,
#     'STDIO_MAX_BYTE_WRITTEN': 5449052.0,
#     'STDIO_FASTEST_RANK': 0.0,
#     'STDIO_FASTEST_RANK_BYTES': 0.0,
#     'STDIO_SLOWEST_RANK': 0.0,
#     'STDIO_SLOWEST_RANK_BYTES': 0.0,
#     'STDIO_F_META_TIME': 0.10677400000000001,
#     'STDIO_F_WRITE_TIME': 0.012847999999999998,
#     'STDIO_F_READ_TIME': 0.0,
#     'STDIO_F_OPEN_START_TIMESTAMP': 297.727423,
#     'STDIO_F_CLOSE_START_TIMESTAMP': 297.763172,
#     'STDIO_F_WRITE_START_TIMESTAMP': 297.750179,
#     'STDIO_F_READ_START_TIMESTAMP': 0.0,
#     'STDIO_F_OPEN_END_TIMESTAMP': 297.749007,
#     'STDIO_F_CLOSE_END_TIMESTAMP': 297.848362,
#     'STDIO_F_WRITE_END_TIMESTAMP': 297.763027,
#     'STDIO_F_READ_END_TIMESTAMP': 0.0,
#     'STDIO_F_FASTEST_RANK_TIME': 0.0,
#     'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#   {'ph': 'E',
#    'ts': 297763027,
#    'pid': 0,
#    'tid': 1,
#    'args': {'Module': 'STDIO',
#     'Rank': 0,
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-15.meta.tmp744e2dc3e68f47ea831e3528dd0cf5f7',
#     'STDIO_OPENS': 1.0,
#     'STDIO_FDOPENS': 0.0,
#     'STDIO_READS': 0.0,
#     'STDIO_WRITES': 1.0,
#     'STDIO_SEEKS': 0.0,
#     'STDIO_FLUSHES': 0.0,
#     'STDIO_BYTES_WRITTEN': 5449053,
#     'STDIO_BYTES_READ': 0,
#     'STDIO_MAX_BYTE_READ': 0.0,
#     'STDIO_MAX_BYTE_WRITTEN': 5449052.0,
#     'STDIO_FASTEST_RANK': 0.0,
#     'STDIO_FASTEST_RANK_BYTES': 0.0,
#     'STDIO_SLOWEST_RANK': 0.0,
#     'STDIO_SLOWEST_RANK_BYTES': 0.0,
#     'STDIO_F_META_TIME': 0.10677400000000001,
#     'STDIO_F_WRITE_TIME': 0.012847999999999998,
#     'STDIO_F_READ_TIME': 0.0,
#     'STDIO_F_OPEN_START_TIMESTAMP': 297.727423,
#     'STDIO_F_CLOSE_START_TIMESTAMP': 297.763172,
#     'STDIO_F_WRITE_START_TIMESTAMP': 297.750179,
#     'STDIO_F_READ_START_TIMESTAMP': 0.0,
#     'STDIO_F_OPEN_END_TIMESTAMP': 297.749007,
#     'STDIO_F_CLOSE_END_TIMESTAMP': 297.848362,
#     'STDIO_F_WRITE_END_TIMESTAMP': 297.763027,
#     'STDIO_F_READ_END_TIMESTAMP': 0.0,
#     'STDIO_F_FASTEST_RANK_TIME': 0.0,
#     'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#   {'name': 'darshan',
#    'cat': 'STDIO',
#    'ph': 'B',
#    'ts': 308431222,
#    'pid': 0,
#    'tid': 1,
#    'args': {'Module': 'STDIO',
#     'Rank': 0,
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-30_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.data-00000-of-00001.tempstate5286267822303063113',
#     'STDIO_OPENS': 1.0,
#     'STDIO_FDOPENS': 0.0,
#     'STDIO_READS': 0.0,
#     'STDIO_WRITES': 5.0,
#     'STDIO_SEEKS': 0.0,
#     'STDIO_FLUSHES': 0.0,
#     'STDIO_BYTES_WRITTEN': 36286492,
#     'STDIO_BYTES_READ': 0,
#     'STDIO_MAX_BYTE_READ': 0.0,
#     'STDIO_MAX_BYTE_WRITTEN': 36286491.0,
#     'STDIO_FASTEST_RANK': 0.0,
#     'STDIO_FASTEST_RANK_BYTES': 0.0,
#     'STDIO_SLOWEST_RANK': 0.0,
#     'STDIO_SLOWEST_RANK_BYTES': 0.0,
#     'STDIO_F_META_TIME': 0.2066,
#     'STDIO_F_WRITE_TIME': 0.053277,
#     'STDIO_F_READ_TIME': 0.0,
#     'STDIO_F_OPEN_START_TIMESTAMP': 308.388139,
#     'STDIO_F_CLOSE_START_TIMESTAMP': 308.50437200000005,
#     'STDIO_F_WRITE_START_TIMESTAMP': 308.43122200000005,
#     'STDIO_F_READ_START_TIMESTAMP': 0.0,
#     'STDIO_F_OPEN_END_TIMESTAMP': 308.4109,
#     'STDIO_F_CLOSE_END_TIMESTAMP': 308.68821099999997,
#     'STDIO_F_WRITE_END_TIMESTAMP': 308.50436099999996,
#     'STDIO_F_READ_END_TIMESTAMP': 0.0,
#     'STDIO_F_FASTEST_RANK_TIME': 0.0,
#     'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#   {'ph': 'E',
#    'ts': 308504360,
#    'pid': 0,
#    'tid': 1,
#    'args': {'Module': 'STDIO',
#     'Rank': 0,
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-30_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.data-00000-of-00001.tempstate5286267822303063113',
#     'STDIO_OPENS': 1.0,
#     'STDIO_FDOPENS': 0.0,
#     'STDIO_READS': 0.0,
#     'STDIO_WRITES': 5.0,
#     'STDIO_SEEKS': 0.0,
#     'STDIO_FLUSHES': 0.0,
#     'STDIO_BYTES_WRITTEN': 36286492,
#     'STDIO_BYTES_READ': 0,
#     'STDIO_MAX_BYTE_READ': 0.0,
#     'STDIO_MAX_BYTE_WRITTEN': 36286491.0,
#     'STDIO_FASTEST_RANK': 0.0,
#     'STDIO_FASTEST_RANK_BYTES': 0.0,
#     'STDIO_SLOWEST_RANK': 0.0,
#     'STDIO_SLOWEST_RANK_BYTES': 0.0,
#     'STDIO_F_META_TIME': 0.2066,
#     'STDIO_F_WRITE_TIME': 0.053277,
#     'STDIO_F_READ_TIME': 0.0,
#     'STDIO_F_OPEN_START_TIMESTAMP': 308.388139,
#     'STDIO_F_CLOSE_START_TIMESTAMP': 308.50437200000005,
#     'STDIO_F_WRITE_START_TIMESTAMP': 308.43122200000005,
#     'STDIO_F_READ_START_TIMESTAMP': 0.0,
#     'STDIO_F_OPEN_END_TIMESTAMP': 308.4109,
#     'STDIO_F_CLOSE_END_TIMESTAMP': 308.68821099999997,
#     'STDIO_F_WRITE_END_TIMESTAMP': 308.50436099999996,
#     'STDIO_F_READ_END_TIMESTAMP': 0.0,
#     'STDIO_F_FASTEST_RANK_TIME': 0.0,
#     'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#   {'name': 'darshan',
#    'cat': 'STDIO',
#    'ph': 'B',
#    'ts': 308712518,
#    'pid': 0,
#    'tid': 1,
#    'args': {'Module': 'STDIO',
#     'Rank': 0,
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-30_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.index.tempstate17681400027653203074',
#     'STDIO_OPENS': 1.0,
#     'STDIO_FDOPENS': 0.0,
#     'STDIO_READS': 0.0,
#     'STDIO_WRITES': 7.0,
#     'STDIO_SEEKS': 0.0,
#     'STDIO_FLUSHES': 0.0,
#     'STDIO_BYTES_WRITTEN': 4829,
#     'STDIO_BYTES_READ': 0,
#     'STDIO_MAX_BYTE_READ': 0.0,
#     'STDIO_MAX_BYTE_WRITTEN': 4828.0,
#     'STDIO_FASTEST_RANK': 0.0,
#     'STDIO_FASTEST_RANK_BYTES': 0.0,
#     'STDIO_SLOWEST_RANK': 0.0,
#     'STDIO_SLOWEST_RANK_BYTES': 0.0,
#     'STDIO_F_META_TIME': 0.021287,
#     'STDIO_F_WRITE_TIME': 0.000398,
#     'STDIO_F_READ_TIME': 0.0,
#     'STDIO_F_OPEN_START_TIMESTAMP': 308.69361000000004,
#     'STDIO_F_CLOSE_START_TIMESTAMP': 308.71295200000003,
#     'STDIO_F_WRITE_START_TIMESTAMP': 308.712518,
#     'STDIO_F_READ_START_TIMESTAMP': 0.0,
#     'STDIO_F_OPEN_END_TIMESTAMP': 308.71207999999996,
#     'STDIO_F_CLOSE_END_TIMESTAMP': 308.71576899999997,
#     'STDIO_F_WRITE_END_TIMESTAMP': 308.712944,
#     'STDIO_F_READ_END_TIMESTAMP': 0.0,
#     'STDIO_F_FASTEST_RANK_TIME': 0.0,
#     'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#   {'ph': 'E',
#    'ts': 308712944,
#    'pid': 0,
#    'tid': 1,
#    'args': {'Module': 'STDIO',
#     'Rank': 0,
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-30_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.index.tempstate17681400027653203074',
#     'STDIO_OPENS': 1.0,
#     'STDIO_FDOPENS': 0.0,
#     'STDIO_READS': 0.0,
#     'STDIO_WRITES': 7.0,
#     'STDIO_SEEKS': 0.0,
#     'STDIO_FLUSHES': 0.0,
#     'STDIO_BYTES_WRITTEN': 4829,
#     'STDIO_BYTES_READ': 0,
#     'STDIO_MAX_BYTE_READ': 0.0,
#     'STDIO_MAX_BYTE_WRITTEN': 4828.0,
#     'STDIO_FASTEST_RANK': 0.0,
#     'STDIO_FASTEST_RANK_BYTES': 0.0,
#     'STDIO_SLOWEST_RANK': 0.0,
#     'STDIO_SLOWEST_RANK_BYTES': 0.0,
#     'STDIO_F_META_TIME': 0.021287,
#     'STDIO_F_WRITE_TIME': 0.000398,
#     'STDIO_F_READ_TIME': 0.0,
#     'STDIO_F_OPEN_START_TIMESTAMP': 308.69361000000004,
#     'STDIO_F_CLOSE_START_TIMESTAMP': 308.71295200000003,
#     'STDIO_F_WRITE_START_TIMESTAMP': 308.712518,
#     'STDIO_F_READ_START_TIMESTAMP': 0.0,
#     'STDIO_F_OPEN_END_TIMESTAMP': 308.71207999999996,
#     'STDIO_F_CLOSE_END_TIMESTAMP': 308.71576899999997,
#     'STDIO_F_WRITE_END_TIMESTAMP': 308.712944,
#     'STDIO_F_READ_END_TIMESTAMP': 0.0,
#     'STDIO_F_FASTEST_RANK_TIME': 0.0,
#     'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#   {'name': 'darshan',
#    'cat': 'STDIO',
#    'ph': 'B',
#    'ts': 308749421,
#    'pid': 0,
#    'tid': 1,
#    'args': {'Module': 'STDIO',
#     'Rank': 0,
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-30.index',
#     'STDIO_OPENS': 1.0,
#     'STDIO_FDOPENS': 0.0,
#     'STDIO_READS': 0.0,
#     'STDIO_WRITES': 7.0,
#     'STDIO_SEEKS': 0.0,
#     'STDIO_FLUSHES': 0.0,
#     'STDIO_BYTES_WRITTEN': 4829,
#     'STDIO_BYTES_READ': 0,
#     'STDIO_MAX_BYTE_READ': 0.0,
#     'STDIO_MAX_BYTE_WRITTEN': 4828.0,
#     'STDIO_FASTEST_RANK': 0.0,
#     'STDIO_FASTEST_RANK_BYTES': 0.0,
#     'STDIO_SLOWEST_RANK': 0.0,
#     'STDIO_SLOWEST_RANK_BYTES': 0.0,
#     'STDIO_F_META_TIME': 0.020252000000000003,
#     'STDIO_F_WRITE_TIME': 0.00037,
#     'STDIO_F_READ_TIME': 0.0,
#     'STDIO_F_OPEN_START_TIMESTAMP': 308.731917,
#     'STDIO_F_CLOSE_START_TIMESTAMP': 308.749826,
#     'STDIO_F_WRITE_START_TIMESTAMP': 308.749421,
#     'STDIO_F_READ_START_TIMESTAMP': 0.0,
#     'STDIO_F_OPEN_END_TIMESTAMP': 308.749013,
#     'STDIO_F_CLOSE_END_TIMESTAMP': 308.752982,
#     'STDIO_F_WRITE_END_TIMESTAMP': 308.749816,
#     'STDIO_F_READ_END_TIMESTAMP': 0.0,
#     'STDIO_F_FASTEST_RANK_TIME': 0.0,
#     'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#   {'ph': 'E',
#    'ts': 308749816,
#    'pid': 0,
#    'tid': 1,
#    'args': {'Module': 'STDIO',
#     'Rank': 0,
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-30.index',
#     'STDIO_OPENS': 1.0,
#     'STDIO_FDOPENS': 0.0,
#     'STDIO_READS': 0.0,
#     'STDIO_WRITES': 7.0,
#     'STDIO_SEEKS': 0.0,
#     'STDIO_FLUSHES': 0.0,
#     'STDIO_BYTES_WRITTEN': 4829,
#     'STDIO_BYTES_READ': 0,
#     'STDIO_MAX_BYTE_READ': 0.0,
#     'STDIO_MAX_BYTE_WRITTEN': 4828.0,
#     'STDIO_FASTEST_RANK': 0.0,
#     'STDIO_FASTEST_RANK_BYTES': 0.0,
#     'STDIO_SLOWEST_RANK': 0.0,
#     'STDIO_SLOWEST_RANK_BYTES': 0.0,
#     'STDIO_F_META_TIME': 0.020252000000000003,
#     'STDIO_F_WRITE_TIME': 0.00037,
#     'STDIO_F_READ_TIME': 0.0,
#     'STDIO_F_OPEN_START_TIMESTAMP': 308.731917,
#     'STDIO_F_CLOSE_START_TIMESTAMP': 308.749826,
#     'STDIO_F_WRITE_START_TIMESTAMP': 308.749421,
#     'STDIO_F_READ_START_TIMESTAMP': 0.0,
#     'STDIO_F_OPEN_END_TIMESTAMP': 308.749013,
#     'STDIO_F_CLOSE_END_TIMESTAMP': 308.752982,
#     'STDIO_F_WRITE_END_TIMESTAMP': 308.749816,
#     'STDIO_F_READ_END_TIMESTAMP': 0.0,
#     'STDIO_F_FASTEST_RANK_TIME': 0.0,
#     'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#   {'name': 'darshan',
#    'cat': 'STDIO',
#    'ph': 'B',
#    'ts': 308793613,
#    'pid': 0,
#    'tid': 1,
#    'args': {'Module': 'STDIO',
#     'Rank': 0,
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/checkpoint.tmpb4b197e144a048a79ccb319c73a26e65',
#     'STDIO_OPENS': 1.0,
#     'STDIO_FDOPENS': 0.0,
#     'STDIO_READS': 0.0,
#     'STDIO_WRITES': 1.0,
#     'STDIO_SEEKS': 0.0,
#     'STDIO_FLUSHES': 0.0,
#     'STDIO_BYTES_WRITTEN': 762,
#     'STDIO_BYTES_READ': 0,
#     'STDIO_MAX_BYTE_READ': 0.0,
#     'STDIO_MAX_BYTE_WRITTEN': 761.0,
#     'STDIO_FASTEST_RANK': 0.0,
#     'STDIO_FASTEST_RANK_BYTES': 0.0,
#     'STDIO_SLOWEST_RANK': 0.0,
#     'STDIO_SLOWEST_RANK_BYTES': 0.0,
#     'STDIO_F_META_TIME': 0.019969999999999998,
#     'STDIO_F_WRITE_TIME': 0.000643,
#     'STDIO_F_READ_TIME': 0.0,
#     'STDIO_F_OPEN_START_TIMESTAMP': 308.77563599999996,
#     'STDIO_F_CLOSE_START_TIMESTAMP': 308.794337,
#     'STDIO_F_WRITE_START_TIMESTAMP': 308.793613,
#     'STDIO_F_READ_START_TIMESTAMP': 0.0,
#     'STDIO_F_OPEN_END_TIMESTAMP': 308.79337599999997,
#     'STDIO_F_CLOSE_END_TIMESTAMP': 308.796567,
#     'STDIO_F_WRITE_END_TIMESTAMP': 308.794256,
#     'STDIO_F_READ_END_TIMESTAMP': 0.0,
#     'STDIO_F_FASTEST_RANK_TIME': 0.0,
#     'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#   {'ph': 'E',
#    'ts': 308794256,
#    'pid': 0,
#    'tid': 1,
#    'args': {'Module': 'STDIO',
#     'Rank': 0,
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/checkpoint.tmpb4b197e144a048a79ccb319c73a26e65',
#     'STDIO_OPENS': 1.0,
#     'STDIO_FDOPENS': 0.0,
#     'STDIO_READS': 0.0,
#     'STDIO_WRITES': 1.0,
#     'STDIO_SEEKS': 0.0,
#     'STDIO_FLUSHES': 0.0,
#     'STDIO_BYTES_WRITTEN': 762,
#     'STDIO_BYTES_READ': 0,
#     'STDIO_MAX_BYTE_READ': 0.0,
#     'STDIO_MAX_BYTE_WRITTEN': 761.0,
#     'STDIO_FASTEST_RANK': 0.0,
#     'STDIO_FASTEST_RANK_BYTES': 0.0,
#     'STDIO_SLOWEST_RANK': 0.0,
#     'STDIO_SLOWEST_RANK_BYTES': 0.0,
#     'STDIO_F_META_TIME': 0.019969999999999998,
#     'STDIO_F_WRITE_TIME': 0.000643,
#     'STDIO_F_READ_TIME': 0.0,
#     'STDIO_F_OPEN_START_TIMESTAMP': 308.77563599999996,
#     'STDIO_F_CLOSE_START_TIMESTAMP': 308.794337,
#     'STDIO_F_WRITE_START_TIMESTAMP': 308.793613,
#     'STDIO_F_READ_START_TIMESTAMP': 0.0,
#     'STDIO_F_OPEN_END_TIMESTAMP': 308.79337599999997,
#     'STDIO_F_CLOSE_END_TIMESTAMP': 308.796567,
#     'STDIO_F_WRITE_END_TIMESTAMP': 308.794256,
#     'STDIO_F_READ_END_TIMESTAMP': 0.0,
#     'STDIO_F_FASTEST_RANK_TIME': 0.0,
#     'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#   {'name': 'darshan',
#    'cat': 'STDIO',
#    'ph': 'B',
#    'ts': 312079276,
#    'pid': 0,
#    'tid': 1,
#    'args': {'Module': 'STDIO',
#     'Rank': 0,
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-30.meta.tmpddf884f9ddbf40a39f5915a9f2c6e262',
#     'STDIO_OPENS': 1.0,
#     'STDIO_FDOPENS': 0.0,
#     'STDIO_READS': 0.0,
#     'STDIO_WRITES': 1.0,
#     'STDIO_SEEKS': 0.0,
#     'STDIO_FLUSHES': 0.0,
#     'STDIO_BYTES_WRITTEN': 5449053,
#     'STDIO_BYTES_READ': 0,
#     'STDIO_MAX_BYTE_READ': 0.0,
#     'STDIO_MAX_BYTE_WRITTEN': 5449052.0,
#     'STDIO_FASTEST_RANK': 0.0,
#     'STDIO_FASTEST_RANK_BYTES': 0.0,
#     'STDIO_SLOWEST_RANK': 0.0,
#     'STDIO_SLOWEST_RANK_BYTES': 0.0,
#     'STDIO_F_META_TIME': 0.154595,
#     'STDIO_F_WRITE_TIME': 0.010458,
#     'STDIO_F_READ_TIME': 0.0,
#     'STDIO_F_OPEN_START_TIMESTAMP': 312.05669700000004,
#     'STDIO_F_CLOSE_START_TIMESTAMP': 312.089894,
#     'STDIO_F_WRITE_START_TIMESTAMP': 312.079276,
#     'STDIO_F_READ_START_TIMESTAMP': 0.0,
#     'STDIO_F_OPEN_END_TIMESTAMP': 312.078189,
#     'STDIO_F_CLOSE_END_TIMESTAMP': 312.222997,
#     'STDIO_F_WRITE_END_TIMESTAMP': 312.08973399999996,
#     'STDIO_F_READ_END_TIMESTAMP': 0.0,
#     'STDIO_F_FASTEST_RANK_TIME': 0.0,
#     'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#   {'ph': 'E',
#    'ts': 312089733,
#    'pid': 0,
#    'tid': 1,
#    'args': {'Module': 'STDIO',
#     'Rank': 0,
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-30.meta.tmpddf884f9ddbf40a39f5915a9f2c6e262',
#     'STDIO_OPENS': 1.0,
#     'STDIO_FDOPENS': 0.0,
#     'STDIO_READS': 0.0,
#     'STDIO_WRITES': 1.0,
#     'STDIO_SEEKS': 0.0,
#     'STDIO_FLUSHES': 0.0,
#     'STDIO_BYTES_WRITTEN': 5449053,
#     'STDIO_BYTES_READ': 0,
#     'STDIO_MAX_BYTE_READ': 0.0,
#     'STDIO_MAX_BYTE_WRITTEN': 5449052.0,
#     'STDIO_FASTEST_RANK': 0.0,
#     'STDIO_FASTEST_RANK_BYTES': 0.0,
#     'STDIO_SLOWEST_RANK': 0.0,
#     'STDIO_SLOWEST_RANK_BYTES': 0.0,
#     'STDIO_F_META_TIME': 0.154595,
#     'STDIO_F_WRITE_TIME': 0.010458,
#     'STDIO_F_READ_TIME': 0.0,
#     'STDIO_F_OPEN_START_TIMESTAMP': 312.05669700000004,
#     'STDIO_F_CLOSE_START_TIMESTAMP': 312.089894,
#     'STDIO_F_WRITE_START_TIMESTAMP': 312.079276,
#     'STDIO_F_READ_START_TIMESTAMP': 0.0,
#     'STDIO_F_OPEN_END_TIMESTAMP': 312.078189,
#     'STDIO_F_CLOSE_END_TIMESTAMP': 312.222997,
#     'STDIO_F_WRITE_END_TIMESTAMP': 312.08973399999996,
#     'STDIO_F_READ_END_TIMESTAMP': 0.0,
#     'STDIO_F_FASTEST_RANK_TIME': 0.0,
#     'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#   {'name': 'darshan',
#    'cat': 'STDIO',
#    'ph': 'B',
#    'ts': 322933470,
#    'pid': 0,
#    'tid': 1,
#    'args': {'Module': 'STDIO',
#     'Rank': 0,
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-45_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.data-00000-of-00001.tempstate6307127464834357184',
#     'STDIO_OPENS': 1.0,
#     'STDIO_FDOPENS': 0.0,
#     'STDIO_READS': 0.0,
#     'STDIO_WRITES': 5.0,
#     'STDIO_SEEKS': 0.0,
#     'STDIO_FLUSHES': 0.0,
#     'STDIO_BYTES_WRITTEN': 36286492,
#     'STDIO_BYTES_READ': 0,
#     'STDIO_MAX_BYTE_READ': 0.0,
#     'STDIO_MAX_BYTE_WRITTEN': 36286491.0,
#     'STDIO_FASTEST_RANK': 0.0,
#     'STDIO_FASTEST_RANK_BYTES': 0.0,
#     'STDIO_SLOWEST_RANK': 0.0,
#     'STDIO_SLOWEST_RANK_BYTES': 0.0,
#     'STDIO_F_META_TIME': 0.218925,
# ...
#     'STDIO_F_OPEN_END_TIMESTAMP': 369.57887999999997,
#     'STDIO_F_CLOSE_END_TIMESTAMP': 369.723079,
#     'STDIO_F_WRITE_END_TIMESTAMP': 369.58984300000003,
#     'STDIO_F_READ_END_TIMESTAMP': 0.0,
#     'STDIO_F_FASTEST_RANK_TIME': 0.0,
#     'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#   {'name': 'darshan',
#    'cat': 'STDIO',
#    'ph': 'B',
#    'ts': 380197865,
#    'pid': 0,
#    'tid': 1,
#    'args': {'Module': 'STDIO',
#     'Rank': 0,
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-105_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.data-00000-of-00001.tempstate12403677363233613037',
#     'STDIO_OPENS': 1.0,
#     'STDIO_FDOPENS': 0.0,
#     'STDIO_READS': 0.0,
#     'STDIO_WRITES': 5.0,
#     'STDIO_SEEKS': 0.0,
#     'STDIO_FLUSHES': 0.0,
#     'STDIO_BYTES_WRITTEN': 36286492,
#     'STDIO_BYTES_READ': 0,
#     'STDIO_MAX_BYTE_READ': 0.0,
#     'STDIO_MAX_BYTE_WRITTEN': 36286491.0,
#     'STDIO_FASTEST_RANK': 0.0,
#     'STDIO_FASTEST_RANK_BYTES': 0.0,
#     'STDIO_SLOWEST_RANK': 0.0,
#     'STDIO_SLOWEST_RANK_BYTES': 0.0,
#     'STDIO_F_META_TIME': 0.212502,
#     'STDIO_F_WRITE_TIME': 0.056191,
#     'STDIO_F_READ_TIME': 0.0,
#     'STDIO_F_OPEN_START_TIMESTAMP': 380.148508,
#     'STDIO_F_CLOSE_START_TIMESTAMP': 380.273829,
#     'STDIO_F_WRITE_START_TIMESTAMP': 380.197865,
#     'STDIO_F_READ_START_TIMESTAMP': 0.0,
#     'STDIO_F_OPEN_END_TIMESTAMP': 380.191072,
#     'STDIO_F_CLOSE_END_TIMESTAMP': 380.443767,
#     'STDIO_F_WRITE_END_TIMESTAMP': 380.27381099999997,
#     'STDIO_F_READ_END_TIMESTAMP': 0.0,
#     'STDIO_F_FASTEST_RANK_TIME': 0.0,
#     'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#   {'ph': 'E',
#    'ts': 380273810,
#    'pid': 0,
#    'tid': 1,
#    'args': {'Module': 'STDIO',
#     'Rank': 0,
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-105_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.data-00000-of-00001.tempstate12403677363233613037',
#     'STDIO_OPENS': 1.0,
#     'STDIO_FDOPENS': 0.0,
#     'STDIO_READS': 0.0,
#     'STDIO_WRITES': 5.0,
#     'STDIO_SEEKS': 0.0,
#     'STDIO_FLUSHES': 0.0,
#     'STDIO_BYTES_WRITTEN': 36286492,
#     'STDIO_BYTES_READ': 0,
#     'STDIO_MAX_BYTE_READ': 0.0,
#     'STDIO_MAX_BYTE_WRITTEN': 36286491.0,
#     'STDIO_FASTEST_RANK': 0.0,
#     'STDIO_FASTEST_RANK_BYTES': 0.0,
#     'STDIO_SLOWEST_RANK': 0.0,
#     'STDIO_SLOWEST_RANK_BYTES': 0.0,
#     'STDIO_F_META_TIME': 0.212502,
#     'STDIO_F_WRITE_TIME': 0.056191,
#     'STDIO_F_READ_TIME': 0.0,
#     'STDIO_F_OPEN_START_TIMESTAMP': 380.148508,
#     'STDIO_F_CLOSE_START_TIMESTAMP': 380.273829,
#     'STDIO_F_WRITE_START_TIMESTAMP': 380.197865,
#     'STDIO_F_READ_START_TIMESTAMP': 0.0,
#     'STDIO_F_OPEN_END_TIMESTAMP': 380.191072,
#     'STDIO_F_CLOSE_END_TIMESTAMP': 380.443767,
#     'STDIO_F_WRITE_END_TIMESTAMP': 380.27381099999997,
#     'STDIO_F_READ_END_TIMESTAMP': 0.0,
#     'STDIO_F_FASTEST_RANK_TIME': 0.0,
#     'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#   {'name': 'darshan',
#    'cat': 'STDIO',
#    'ph': 'B',
#    'ts': 380463924,
#    'pid': 0,
#    'tid': 1,
#    'args': {'Module': 'STDIO',
#     'Rank': 0,
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-105_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.index.tempstate16077201702985775298',
#     'STDIO_OPENS': 1.0,
#     'STDIO_FDOPENS': 0.0,
#     'STDIO_READS': 0.0,
#     'STDIO_WRITES': 7.0,
#     'STDIO_SEEKS': 0.0,
#     'STDIO_FLUSHES': 0.0,
#     'STDIO_BYTES_WRITTEN': 4829,
#     'STDIO_BYTES_READ': 0,
#     'STDIO_MAX_BYTE_READ': 0.0,
#     'STDIO_MAX_BYTE_WRITTEN': 4828.0,
#     'STDIO_FASTEST_RANK': 0.0,
#     'STDIO_FASTEST_RANK_BYTES': 0.0,
#     'STDIO_SLOWEST_RANK': 0.0,
#     'STDIO_SLOWEST_RANK_BYTES': 0.0,
#     'STDIO_F_META_TIME': 0.017905,
#     'STDIO_F_WRITE_TIME': 0.000429,
#     'STDIO_F_READ_TIME': 0.0,
#     'STDIO_F_OPEN_START_TIMESTAMP': 380.44844,
#     'STDIO_F_CLOSE_START_TIMESTAMP': 380.464407,
#     'STDIO_F_WRITE_START_TIMESTAMP': 380.463924,
#     'STDIO_F_READ_START_TIMESTAMP': 0.0,
#     'STDIO_F_OPEN_END_TIMESTAMP': 380.463552,
#     'STDIO_F_CLOSE_END_TIMESTAMP': 380.4672,
#     'STDIO_F_WRITE_END_TIMESTAMP': 380.464396,
#     'STDIO_F_READ_END_TIMESTAMP': 0.0,
#     'STDIO_F_FASTEST_RANK_TIME': 0.0,
#     'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#   {'ph': 'E',
#    'ts': 380464396,
#    'pid': 0,
#    'tid': 1,
#    'args': {'Module': 'STDIO',
#     'Rank': 0,
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-105_temp_6770bba4db834b5a9ef640a844920dde/part-00000-of-00001.index.tempstate16077201702985775298',
#     'STDIO_OPENS': 1.0,
#     'STDIO_FDOPENS': 0.0,
#     'STDIO_READS': 0.0,
#     'STDIO_WRITES': 7.0,
#     'STDIO_SEEKS': 0.0,
#     'STDIO_FLUSHES': 0.0,
#     'STDIO_BYTES_WRITTEN': 4829,
#     'STDIO_BYTES_READ': 0,
#     'STDIO_MAX_BYTE_READ': 0.0,
#     'STDIO_MAX_BYTE_WRITTEN': 4828.0,
#     'STDIO_FASTEST_RANK': 0.0,
#     'STDIO_FASTEST_RANK_BYTES': 0.0,
#     'STDIO_SLOWEST_RANK': 0.0,
#     'STDIO_SLOWEST_RANK_BYTES': 0.0,
#     'STDIO_F_META_TIME': 0.017905,
#     'STDIO_F_WRITE_TIME': 0.000429,
#     'STDIO_F_READ_TIME': 0.0,
#     'STDIO_F_OPEN_START_TIMESTAMP': 380.44844,
#     'STDIO_F_CLOSE_START_TIMESTAMP': 380.464407,
#     'STDIO_F_WRITE_START_TIMESTAMP': 380.463924,
#     'STDIO_F_READ_START_TIMESTAMP': 0.0,
#     'STDIO_F_OPEN_END_TIMESTAMP': 380.463552,
#     'STDIO_F_CLOSE_END_TIMESTAMP': 380.4672,
#     'STDIO_F_WRITE_END_TIMESTAMP': 380.464396,
#     'STDIO_F_READ_END_TIMESTAMP': 0.0,
#     'STDIO_F_FASTEST_RANK_TIME': 0.0,
#     'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#   {'name': 'darshan',
#    'cat': 'STDIO',
#    'ph': 'B',
#    'ts': 380497994,
#    'pid': 0,
#    'tid': 1,
#    'args': {'Module': 'STDIO',
#     'Rank': 0,
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-105.index',
#     'STDIO_OPENS': 1.0,
#     'STDIO_FDOPENS': 0.0,
#     'STDIO_READS': 0.0,
#     'STDIO_WRITES': 7.0,
#     'STDIO_SEEKS': 0.0,
#     'STDIO_FLUSHES': 0.0,
#     'STDIO_BYTES_WRITTEN': 4829,
#     'STDIO_BYTES_READ': 0,
#     'STDIO_MAX_BYTE_READ': 0.0,
#     'STDIO_MAX_BYTE_WRITTEN': 4828.0,
#     'STDIO_FASTEST_RANK': 0.0,
#     'STDIO_FASTEST_RANK_BYTES': 0.0,
#     'STDIO_SLOWEST_RANK': 0.0,
#     'STDIO_SLOWEST_RANK_BYTES': 0.0,
#     'STDIO_F_META_TIME': 0.018482,
#     'STDIO_F_WRITE_TIME': 0.000556,
#     'STDIO_F_READ_TIME': 0.0,
#     'STDIO_F_OPEN_START_TIMESTAMP': 380.482324,
#     'STDIO_F_CLOSE_START_TIMESTAMP': 380.498584,
#     'STDIO_F_WRITE_START_TIMESTAMP': 380.497994,
#     'STDIO_F_READ_START_TIMESTAMP': 0.0,
#     'STDIO_F_OPEN_END_TIMESTAMP': 380.497551,
#     'STDIO_F_CLOSE_END_TIMESTAMP': 380.501839,
#     'STDIO_F_WRITE_END_TIMESTAMP': 380.49857599999996,
#     'STDIO_F_READ_END_TIMESTAMP': 0.0,
#     'STDIO_F_FASTEST_RANK_TIME': 0.0,
#     'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#   {'ph': 'E',
#    'ts': 380498575,
#    'pid': 0,
#    'tid': 1,
#    'args': {'Module': 'STDIO',
#     'Rank': 0,
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-105.index',
#     'STDIO_OPENS': 1.0,
#     'STDIO_FDOPENS': 0.0,
#     'STDIO_READS': 0.0,
#     'STDIO_WRITES': 7.0,
#     'STDIO_SEEKS': 0.0,
#     'STDIO_FLUSHES': 0.0,
#     'STDIO_BYTES_WRITTEN': 4829,
#     'STDIO_BYTES_READ': 0,
#     'STDIO_MAX_BYTE_READ': 0.0,
#     'STDIO_MAX_BYTE_WRITTEN': 4828.0,
#     'STDIO_FASTEST_RANK': 0.0,
#     'STDIO_FASTEST_RANK_BYTES': 0.0,
#     'STDIO_SLOWEST_RANK': 0.0,
#     'STDIO_SLOWEST_RANK_BYTES': 0.0,
#     'STDIO_F_META_TIME': 0.018482,
#     'STDIO_F_WRITE_TIME': 0.000556,
#     'STDIO_F_READ_TIME': 0.0,
#     'STDIO_F_OPEN_START_TIMESTAMP': 380.482324,
#     'STDIO_F_CLOSE_START_TIMESTAMP': 380.498584,
#     'STDIO_F_WRITE_START_TIMESTAMP': 380.497994,
#     'STDIO_F_READ_START_TIMESTAMP': 0.0,
#     'STDIO_F_OPEN_END_TIMESTAMP': 380.497551,
#     'STDIO_F_CLOSE_END_TIMESTAMP': 380.501839,
#     'STDIO_F_WRITE_END_TIMESTAMP': 380.49857599999996,
#     'STDIO_F_READ_END_TIMESTAMP': 0.0,
#     'STDIO_F_FASTEST_RANK_TIME': 0.0,
#     'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#   {'name': 'darshan',
#    'cat': 'STDIO',
#    'ph': 'B',
#    'ts': 380542825,
#    'pid': 0,
#    'tid': 1,
#    'args': {'Module': 'STDIO',
#     'Rank': 0,
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/checkpoint.tmp4b670dddd44d44ca926bc17ba4b3184a',
#     'STDIO_OPENS': 1.0,
#     'STDIO_FDOPENS': 0.0,
#     'STDIO_READS': 0.0,
#     'STDIO_WRITES': 1.0,
#     'STDIO_SEEKS': 0.0,
#     'STDIO_FLUSHES': 0.0,
#     'STDIO_BYTES_WRITTEN': 1149,
#     'STDIO_BYTES_READ': 0,
#     'STDIO_MAX_BYTE_READ': 0.0,
#     'STDIO_MAX_BYTE_WRITTEN': 1148.0,
#     'STDIO_FASTEST_RANK': 0.0,
#     'STDIO_FASTEST_RANK_BYTES': 0.0,
#     'STDIO_SLOWEST_RANK': 0.0,
#     'STDIO_SLOWEST_RANK_BYTES': 0.0,
#     'STDIO_F_META_TIME': 0.023313,
#     'STDIO_F_WRITE_TIME': 0.0006259999999999999,
#     'STDIO_F_READ_TIME': 0.0,
#     'STDIO_F_OPEN_START_TIMESTAMP': 380.522068,
#     'STDIO_F_CLOSE_START_TIMESTAMP': 380.543529,
#     'STDIO_F_WRITE_START_TIMESTAMP': 380.542825,
#     'STDIO_F_READ_START_TIMESTAMP': 0.0,
#     'STDIO_F_OPEN_END_TIMESTAMP': 380.5426,
#     'STDIO_F_CLOSE_END_TIMESTAMP': 380.54631,
#     'STDIO_F_WRITE_END_TIMESTAMP': 380.543451,
#     'STDIO_F_READ_END_TIMESTAMP': 0.0,
#     'STDIO_F_FASTEST_RANK_TIME': 0.0,
#     'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#   {'ph': 'E',
#    'ts': 380543451,
#    'pid': 0,
#    'tid': 1,
#    'args': {'Module': 'STDIO',
#     'Rank': 0,
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/checkpoint.tmp4b670dddd44d44ca926bc17ba4b3184a',
#     'STDIO_OPENS': 1.0,
#     'STDIO_FDOPENS': 0.0,
#     'STDIO_READS': 0.0,
#     'STDIO_WRITES': 1.0,
#     'STDIO_SEEKS': 0.0,
#     'STDIO_FLUSHES': 0.0,
#     'STDIO_BYTES_WRITTEN': 1149,
#     'STDIO_BYTES_READ': 0,
#     'STDIO_MAX_BYTE_READ': 0.0,
#     'STDIO_MAX_BYTE_WRITTEN': 1148.0,
#     'STDIO_FASTEST_RANK': 0.0,
#     'STDIO_FASTEST_RANK_BYTES': 0.0,
#     'STDIO_SLOWEST_RANK': 0.0,
#     'STDIO_SLOWEST_RANK_BYTES': 0.0,
#     'STDIO_F_META_TIME': 0.023313,
#     'STDIO_F_WRITE_TIME': 0.0006259999999999999,
#     'STDIO_F_READ_TIME': 0.0,
#     'STDIO_F_OPEN_START_TIMESTAMP': 380.522068,
#     'STDIO_F_CLOSE_START_TIMESTAMP': 380.543529,
#     'STDIO_F_WRITE_START_TIMESTAMP': 380.542825,
#     'STDIO_F_READ_START_TIMESTAMP': 0.0,
#     'STDIO_F_OPEN_END_TIMESTAMP': 380.5426,
#     'STDIO_F_CLOSE_END_TIMESTAMP': 380.54631,
#     'STDIO_F_WRITE_END_TIMESTAMP': 380.543451,
#     'STDIO_F_READ_END_TIMESTAMP': 0.0,
#     'STDIO_F_FASTEST_RANK_TIME': 0.0,
#     'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#   {'name': 'darshan',
#    'cat': 'STDIO',
#    'ph': 'B',
#    'ts': 383881795,
#    'pid': 0,
#    'tid': 1,
#    'args': {'Module': 'STDIO',
#     'Rank': 0,
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-105.meta.tmp2bb0439975384774a22ca41a0dfe5df7',
#     'STDIO_OPENS': 1.0,
#     'STDIO_FDOPENS': 0.0,
#     'STDIO_READS': 0.0,
#     'STDIO_WRITES': 1.0,
#     'STDIO_SEEKS': 0.0,
#     'STDIO_FLUSHES': 0.0,
#     'STDIO_BYTES_WRITTEN': 5449053,
#     'STDIO_BYTES_READ': 0,
#     'STDIO_MAX_BYTE_READ': 0.0,
#     'STDIO_MAX_BYTE_WRITTEN': 5449052.0,
#     'STDIO_FASTEST_RANK': 0.0,
#     'STDIO_FASTEST_RANK_BYTES': 0.0,
#     'STDIO_SLOWEST_RANK': 0.0,
#     'STDIO_SLOWEST_RANK_BYTES': 0.0,
#     'STDIO_F_META_TIME': 0.11981199999999999,
#     'STDIO_F_WRITE_TIME': 0.014002,
#     'STDIO_F_READ_TIME': 0.0,
#     'STDIO_F_OPEN_START_TIMESTAMP': 383.860765,
#     'STDIO_F_CLOSE_START_TIMESTAMP': 383.895943,
#     'STDIO_F_WRITE_START_TIMESTAMP': 383.881795,
#     'STDIO_F_READ_START_TIMESTAMP': 0.0,
#     'STDIO_F_OPEN_END_TIMESTAMP': 383.880726,
#     'STDIO_F_CLOSE_END_TIMESTAMP': 383.995794,
#     'STDIO_F_WRITE_END_TIMESTAMP': 383.895797,
#     'STDIO_F_READ_END_TIMESTAMP': 0.0,
#     'STDIO_F_FASTEST_RANK_TIME': 0.0,
#     'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#   {'ph': 'E',
#    'ts': 383895797,
#    'pid': 0,
#    'tid': 1,
#    'args': {'Module': 'STDIO',
#     'Rank': 0,
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/model.ckpt-105.meta.tmp2bb0439975384774a22ca41a0dfe5df7',
#     'STDIO_OPENS': 1.0,
#     'STDIO_FDOPENS': 0.0,
#     'STDIO_READS': 0.0,
#     'STDIO_WRITES': 1.0,
#     'STDIO_SEEKS': 0.0,
#     'STDIO_FLUSHES': 0.0,
#     'STDIO_BYTES_WRITTEN': 5449053,
#     'STDIO_BYTES_READ': 0,
#     'STDIO_MAX_BYTE_READ': 0.0,
#     'STDIO_MAX_BYTE_WRITTEN': 5449052.0,
#     'STDIO_FASTEST_RANK': 0.0,
#     'STDIO_FASTEST_RANK_BYTES': 0.0,
#     'STDIO_SLOWEST_RANK': 0.0,
#     'STDIO_SLOWEST_RANK_BYTES': 0.0,
#     'STDIO_F_META_TIME': 0.11981199999999999,
#     'STDIO_F_WRITE_TIME': 0.014002,
#     'STDIO_F_READ_TIME': 0.0,
#     'STDIO_F_OPEN_START_TIMESTAMP': 383.860765,
#     'STDIO_F_CLOSE_START_TIMESTAMP': 383.895943,
#     'STDIO_F_WRITE_START_TIMESTAMP': 383.881795,
#     'STDIO_F_READ_START_TIMESTAMP': 0.0,
#     'STDIO_F_OPEN_END_TIMESTAMP': 383.880726,
#     'STDIO_F_CLOSE_END_TIMESTAMP': 383.995794,
#     'STDIO_F_WRITE_END_TIMESTAMP': 383.895797,
#     'STDIO_F_READ_END_TIMESTAMP': 0.0,
#     'STDIO_F_FASTEST_RANK_TIME': 0.0,
#     'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_BYTES': 0.0}},
#   {'ph': 'E',
#    'ts': 384274400,
#    'pid': 0,
#    'tid': 1,
#    'args': {'Module': 'STDIO',
#     'Rank': 0,
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/l2hmc-qcd/gauge_logs/2020_06_11/DEBUG_L16_b32_lf2_GaugeNetwork_aw00_qw01_dp025_f32_1909_1/checkpoints/events.out.tfevents.1591902661.nid00008',
#     'STDIO_OPENS': 1.0,
#     'STDIO_FDOPENS': 0.0,
#     'STDIO_READS': 0.0,
#     'STDIO_WRITES': 42.0,
#     'STDIO_SEEKS': 0.0,
#     'STDIO_FLUSHES': 6.0,
#     'STDIO_BYTES_WRITTEN': 19585691,
#     'STDIO_BYTES_READ': 0,
#     'STDIO_MAX_BYTE_READ': 0.0,
#     'STDIO_MAX_BYTE_WRITTEN': 19585690.0,
#     'STDIO_FASTEST_RANK': 0.0,
#     'STDIO_FASTEST_RANK_BYTES': 0.0,
#     'STDIO_SLOWEST_RANK': 0.0,
#     'STDIO_SLOWEST_RANK_BYTES': 0.0,
#     'STDIO_F_META_TIME': 0.042486,
#     'STDIO_F_WRITE_TIME': 0.08765099999999999,
#     'STDIO_F_READ_TIME': 0.0,
#     'STDIO_F_OPEN_START_TIMESTAMP': 140.10161100000002,
#     'STDIO_F_CLOSE_START_TIMESTAMP': 0.0,
#     'STDIO_F_WRITE_START_TIMESTAMP': 140.144304,
#     'STDIO_F_READ_START_TIMESTAMP': 0.0,
#     'STDIO_F_OPEN_END_TIMESTAMP': 140.144097,
#     'STDIO_F_CLOSE_END_TIMESTAMP': 0.0,
#     'STDIO_F_WRITE_END_TIMESTAMP': 384.2744,
#     'STDIO_F_READ_END_TIMESTAMP': 0.0,
#     'STDIO_F_FASTEST_RANK_TIME': 0.0,
#     'STDIO_F_SLOWEST_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_TIME': 0.0,
#     'STDIO_F_VARIANCE_RANK_BYTES': 0.0}}],
#  'displayTimeUnit': 'ms',
#  'systemTraceEvents': 'SystemTraceData',
#  'otherData': {'version': 'VaniDL v1.0'},
#  'stackFrames': {},
#  'samples': []}
