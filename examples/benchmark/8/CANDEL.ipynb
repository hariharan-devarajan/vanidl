# %% [markdown]
# # DLProfile Example using CANDEL Application

# %% [markdown]
# ## Set imports and neccessary environment variables

# %%
import pathlib
import os
import sys
import matplotlib.pyplot as plt
import warnings
import pprint
import pandas

# %%
VANIDL_DIR="{}".format(pathlib.Path(os.getcwd()).parent.parent.parent.absolute())
sys.path.insert(0, VANIDL_DIR)
warnings.filterwarnings('ignore')

# %%
os.environ["DARSHAN_DIR"] = "/soft/perftools/darshan/darshan-3.1.8"
os.environ["VANIDL_DIR"] = VANIDL_DIR

# %% [markdown]
# #### Formatting

# %%
pp = pprint.PrettyPrinter(indent=1)
class color:
    PURPLE = '\033[95m'
    CYAN = '\033[96m'
    DARKCYAN = '\033[36m'
    BLUE = '\033[94m'
    GREEN = '\033[92m'
    YELLOW = '\033[93m'
    RED = '\033[91m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'
    END = '\033[0m'

# %% [markdown]
# ## Create instrance of DL Profile and load the darshan file

# %%
from src.vanidl import VaniDL
profile = VaniDL()

# %%
#import shutil
#shutil.rmtree('/tmp/temp_analysis')

# %%
DATAPATH_INCLUDES = []
status = profile.Load("/home/dhari/darshan-logs/benchmark/candel/candel_run2_p8.darshan", data_paths_include=DATAPATH_INCLUDES)
if status:
    print("Darshan Trace loaded Successfully!")
else:
    print("Darshan Trace load Failed!")
    print(profile._error_str())
# Out:
# [============================================================] 100.0% 1041554 of 1041554 Parsing DXT File
# [============================================================] 100.0% 3855 of 3855 Parsing Darshan File
# Darshan Trace loaded Successfully!

# %% [markdown]
# ## Use Profile object to analyze the darshan I/O trace.

# %% [markdown]
# ### Verify if object works
#
# The GetDXTAsDF() function enables users to perform analysis

# %%
df = profile.GetDXTAsDF()
pp.pprint("Files used in the application")
pp.pprint(df['Filename'].unique().tolist())
# Out:
# 'Files used in the application'
# ['/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv']

# %% [markdown]
# ### Collect the summary of the Application

# %%
summary = profile.GetSummary()
print("\n")
print(color.BOLD + "Data Access Summary (from Darshan):"+ color.END)
print("Total Job time\t\t\t:\t{:0.2f} seconds".format(summary['job_time']))
#FIXME: calculate time per rank and then take max across it.
print("Time spent in I/O\t\t:\t{:0.2f} seconds".format(summary['total_io_time']))
print("% Time spent in I/O\t\t:\t{:0.2f}%".format(float(summary['total_io_time'])*100/summary['job_time']))
print("Total Data Accessed\t\t:\t{:0.2f} GB".format(float(summary['total_io_bytes'])/1024.0/1024.0/1024.0))
print("Data Access Modules used\t:\t{}".format(summary['io_interface_used']))
print("Data Operations\t\t\t:\t{}".format(summary['io_operations_used']))
print("# of files used\t\t\t:\t{}".format(len(summary['files_used'])))
print("# of MPI Ranks\t\t\t:\t{:0.0f} ranks".format(summary['num_ranks']))
      
print(color.UNDERLINE + "Data Transfer size:"+ color.END)
print("\tMin,Max\t\t\t:\t{:0.0f} bytes and {:0.0f} bytes".format(summary['data_transfer_size']['min'],summary['data_transfer_size']['max']))
print("\tAverage\t\t\t:\t{:0.0f} bytes".format(summary['data_transfer_size']['mean']))
print("\tMedian\t\t\t:\t{:0.0f} bytes".format(summary['data_transfer_size']['median']))
      
print(color.UNDERLINE + "Data Transfer bandwidth: (per rank)"+ color.END)
print("\tMin,Max\t\t\t:\t{:0.0f} B/s and {:0.0f} MB/s".format(summary['data_transfer_bandwidth']['min'],summary['data_transfer_bandwidth']['max']/1024.0/1024.0))
print("\tAverage\t\t\t:\t{:0.0f} MB/s".format(summary['data_transfer_bandwidth']['mean']/1024.0/1024.0))
print("\tMedian\t\t\t:\t{:0.0f} MB/s".format(summary['data_transfer_bandwidth']['median']/1024.0/1024.0))
      
print(color.UNDERLINE + "Access Pattern:"+ color.END)
print("\tSequential\t\t:\t{:0.2f}%".format(float(summary['access_pattern']['sequential'])))
print("\tConsecutive\t\t:\t{:0.2f}%".format(float(summary['access_pattern']['consecutive'])))
#An I/O op issued at an offset greater than where the previous I/O op ended.
#An I/O op issued at the offset immediately after the end of the previous I/O

print("\n")
print(color.BOLD + "Files Summary:"+ color.END)
print("File Types\t\t\t:\t{}".format(summary['file_used_summary']['types']))
print(color.UNDERLINE + "Dataset Size:"+ color.END)
print("\tTotal\t\t\t:\t{:0.3f} GB".format(float(summary['file_used_summary']['size']['total'])/1024.0/1024.0/1024.0))
print("\tMin,Max\t\t\t:\t{:0.3f} GB and {:0.3f} GB".format(float(summary['file_used_summary']['size']['min'])/1024.0/1024.0/1024.0,float(summary['file_used_summary']['size']['max'])/1024.0/1024.0/1024.0))
print("\tAverage\t\t\t:\t{:0.3f} GB".format(float(summary['file_used_summary']['size']['mean'])/1024.0/1024.0/1024.0))
# Out:
# Data Access Summary (from Darshan):
# Total Job time			:	650.00 seconds
# Time spent in I/O		:	117.39 seconds
# % Time spent in I/O		:	18.06%
# Total Data Accessed		:	42.15 GB
# Data Access Modules used	:	['X_POSIX']
# Data Operations			:	['read']
# # of files used			:	1
# # of MPI Ranks			:	8 ranks
# Data Transfer size:
# 	Min,Max			:	8192 bytes and 8192 bytes
# 	Average			:	8192 bytes
# 	Median			:	8192 bytes
# Data Transfer bandwidth: (per rank)
# 	Min,Max			:	62534 B/s and 78 MB/s
# 	Average			:	16 MB/s
# 	Median			:	8 MB/s
# Access Pattern:
# 	Sequential		:	100.00%
# 	Consecutive		:	100.00%
#
#
# Files Summary:
# File Types			:	['csv']
# Dataset Size:
# 	Total			:	5.268 GB
# 	Min,Max			:	0.000 GB and 5.268 GB
# 	Average			:	0.128 GB

# %%
pp.pprint("Job time : {} seconds".format(profile.GetJobTime()))
# Out:
# 'Job time : 650.0 seconds'

# %%
pp.pprint("Time spent by application on I/O: {} seconds".format(profile.GetIOTime()))
# Out:
# 'Time spent by application on I/O: 117.38764999785542 seconds'

# %% [markdown]
# ### I/O time spent on each file

# %%
for file in df['Filename'].unique():
    print("I/O time for file {}: {:0.2f} seconds".format(file,profile.GetIOTime(filepath=file)))
# Out:
# I/O time for file /projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv: 117.39 seconds

# %% [markdown]
# ### I/O Time spent per rank

# %%
for rank in df['Rank'].unique()[:16]:
    print("I/O time for rank {}: {:0.2f} seconds".format(rank,profile.GetIOTime(rank=rank)))
# Out:
# I/O time for rank 0: 117.18 seconds
# I/O time for rank 1: 117.38 seconds
# I/O time for rank 2: 117.50 seconds
# I/O time for rank 3: 117.27 seconds
# I/O time for rank 4: 117.84 seconds
# I/O time for rank 5: 117.19 seconds
# I/O time for rank 6: 117.42 seconds
# I/O time for rank 7: 117.32 seconds

# %%
"Total I/O performed by application: {:0.2f} GB".format(float(profile.GetIOSize())/1024.0/1024.0/1024.0)
# Out:
# 'Total I/O performed by application: 42.15 GB'

# %% [markdown]
# ### I/O performed on each file

# %%
for file in df['Filename'].unique():
    print("I/O performed on file {}: {:0.2f} MB".format(file,float(profile.GetIOSize(filepath=file))/1024.0/1024.0))
# Out:
# I/O performed on file /projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv: 43158.81 MB

# %%
for rank in df['Rank'].unique()[:16]:
    print("I/O performed by rank {}: {:0.2f} MB".format(rank, float(profile.GetIOSize(rank=rank))/1024.0/1024.0))
# Out:
# I/O performed by rank 0: 1016.09 MB
# I/O performed by rank 1: 1016.09 MB
# I/O performed by rank 2: 1016.09 MB
# I/O performed by rank 3: 1016.09 MB
# I/O performed by rank 4: 1016.09 MB
# I/O performed by rank 5: 1016.09 MB
# I/O performed by rank 6: 1016.09 MB
# I/O performed by rank 7: 1016.09 MB

# %%
print("Size of dataset (bytes)")
pp.pprint(profile.GetFileSizes())
# Out:
# Size of dataset (bytes)
# {'img_0_of_1': 5656911680.0,
#  'nid03830.input_pipeline': 1721.0,
#  'nid03830.kernel_stats': 0.0,
#  'nid03830.overview_page': 2663.0,
#  'nid03830.tensorflow_stats': 682.0,
#  'nid03830.trace.json': 1264.0,
#  'nid03832.input_pipeline': 1721.0,
#  'nid03832.kernel_stats': 0.0,
#  'nid03832.overview_page': 2663.0,
#  'nid03832.tensorflow_stats': 682.0,
#  'nid03832.trace.json': 1252.0,
#  'nid03833.input_pipeline': 1721.0,
#  'nid03833.kernel_stats': 0.0,
#  'nid03833.overview_page': 2663.0,
#  'nid03833.tensorflow_stats': 682.0,
#  'nid03833.trace.json': 1279.0,
#  'nid03834.input_pipeline': 1721.0,
#  'nid03834.kernel_stats': 0.0,
#  'nid03834.overview_page': 2663.0,
#  'nid03834.tensorflow_stats': 682.0,
#  'nid03834.trace.json': 1261.0,
#  'nid03835.input_pipeline': 1721.0,
#  'nid03835.kernel_stats': 0.0,
#  'nid03835.overview_page': 2663.0,
#  'nid03835.tensorflow_stats': 682.0,
#  'nid03835.trace.json': 1270.0,
#  'nid03836.input_pipeline': 1721.0,
#  'nid03836.kernel_stats': 0.0,
#  'nid03836.overview_page': 2663.0,
#  'nid03836.tensorflow_stats': 682.0,
#  'nid03836.trace.json': 1247.0,
#  'nid03838.input_pipeline': 1721.0,
#  'nid03838.kernel_stats': 0.0,
#  'nid03838.overview_page': 2663.0,
#  'nid03838.tensorflow_stats': 682.0,
#  'nid03838.trace.json': 1277.0,
#  'nid03839.input_pipeline': 1721.0,
#  'nid03839.kernel_stats': 0.0,
#  'nid03839.overview_page': 2663.0,
#  'nid03839.tensorflow_stats': 682.0,
#  'nid03839.trace.json': 1284.0}

# %% [markdown]
# ### How application access data over time.

# %%
tl = profile.CreateIOTimeline()
plt.figure(figsize=(8,4))
plt.grid()
plt.ylabel("# of operations")
plt.xlabel("Timeline (ms)")
plt.plot(tl['time_step'], tl['operation_count']);
# Out:
# [============================================================] 100.0% 1040480 of 1040480 Creating Timeline

# %%
plt.figure(figsize=(8,4))
plt.grid()
plt.ylabel("I/O performed (bytes)")
plt.xlabel("Timeline (ms)")
plt.plot(tl['time_step'], tl['io_bytes']);

# %% [markdown]
# ### How files are accessed over the duration of the Job.

# %%
for file in df['Filename'].unique():
    tl = profile.CreateIOTimeline(filepath=file,time_step=0.001)
    tl.plot(x='time_step',y='operation_count', title=file)
    plt.show()
# Out:
# [============================================================] 100.0% 1040480 of 1040480 Creating Timeline

# %% [markdown]
# ### Show how each file is accessed by each rank.

# %%
for rank in df['Rank'].unique()[:16]:
    tl = profile.CreateIOTimeline(rank=rank)
    tl.plot(x='time_step',y='operation_count', title=rank)
    plt.show()
# Out:
# [============================================================] 100.0% 130060 of 130060 Creating Timeline
# [============================================================] 100.0% 130060 of 130060 Creating Timeline
# [============================================================] 100.0% 130060 of 130060 Creating Timeline
# [============================================================] 100.0% 130060 of 130060 Creating Timeline
# [============================================================] 100.0% 130060 of 130060 Creating Timeline
# [============================================================] 100.0% 130060 of 130060 Creating Timeline
# [============================================================] 100.0% 130060 of 130060 Creating Timeline
# [============================================================] 100.0% 130060 of 130060 Creating Timeline

# %% [markdown]
# ### Data Transfer Size distribution within the application

# %%
request_df = profile.GetIORequestDistribution()
df['Length'].plot(kind='hist', figsize=(5, 3), bins=100);
plt.xlabel("Transfer Size (bytes)")
# Out:
# Text(0.5, 0, 'Transfer Size (bytes)')

# %% [markdown]
# ### Data Transfer Size distribution for each file.

# %%
for file in df['Filename'].unique():
    tl = profile.GetIORequestDistribution(filepath=file)
    tl.plot(kind='bar', figsize=(10, 4), title=file)
    plt.show()

# %% [markdown]
# ### Data Transfer Sizes per Rank

# %%
for rank in df['Rank'].unique()[:16]:
    tl = profile.GetIORequestDistribution(rank=rank)
    tl.plot(kind='bar', figsize=(10, 4), title=rank)
    plt.show()

# %% [markdown]
# ### File summary of each file accessed by the Application

# %%
pp = pprint.PrettyPrinter(indent=1)
for file in df['Filename'].unique():
    pp.pprint(profile.GetFileSummary(file))
# Out:
# {'ext': 'csv',
#  'filename': 'img_0_of_1',
#  'io_size': 45255293440,
#  'io_time': 117.38764999785542,
#  'path': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#  'size': 5656911680,
#  'special': {}}

# %%
profile.CreateChromeTimeline(location="/home/dhari/timeline/apps/candel", filename="candel_run1_n128.json")
# Out:
# [============================================================] 100.0% 1040480 of 1040480 Creating DXT Timeline
# [============================================================] 100.0% 41 of 41 Creating DXT Timeline
# {'traceEvents': [{'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1449600,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8192,
#     'Start': 1.4496,
#     'End': 1.5802}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1449700,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8192,
#     'Start': 1.4497,
#     'End': 1.5796}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1450100,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8192,
#     'Start': 1.4501,
#     'End': 1.5811}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1450200,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8192,
#     'Start': 1.4502,
#     'End': 1.5801}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1450200,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8192,
#     'Start': 1.4502,
#     'End': 1.5795}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1450200,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8192,
#     'Start': 1.4502,
#     'End': 1.5805}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1450300,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8192,
#     'Start': 1.4503,
#     'End': 1.5805}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1450500,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8192,
#     'Start': 1.4505,
#     'End': 1.5803}},
#   {'ph': 'E',
#    'ts': 1579500,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8192,
#     'Start': 1.4502,
#     'End': 1.5795}},
#   {'ph': 'E',
#    'ts': 1579600,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8192,
#     'Start': 1.4497,
#     'End': 1.5796}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1579700,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 8192,
#     'Length': 8192,
#     'Start': 1.5797,
#     'End': 1.6049}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1579900,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 8192,
#     'Length': 8192,
#     'Start': 1.5799,
#     'End': 1.6063}},
#   {'ph': 'E',
#    'ts': 1580100,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8192,
#     'Start': 1.4502,
#     'End': 1.5801}},
#   {'ph': 'E',
#    'ts': 1580200,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8192,
#     'Start': 1.4496,
#     'End': 1.5802}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1580300,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 8192,
#     'Length': 8192,
#     'Start': 1.5803,
#     'End': 1.6079}},
#   {'ph': 'E',
#    'ts': 1580300,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8192,
#     'Start': 1.4505,
#     'End': 1.5803}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1580400,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 8192,
#     'Length': 8192,
#     'Start': 1.5804,
#     'End': 1.6068}},
#   {'ph': 'E',
#    'ts': 1580500,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8192,
#     'Start': 1.4502,
#     'End': 1.5805}},
#   {'ph': 'E',
#    'ts': 1580500,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8192,
#     'Start': 1.4503,
#     'End': 1.5805}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1580500,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 8192,
#     'Length': 8192,
#     'Start': 1.5805,
#     'End': 1.6088}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1580800,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 8192,
#     'Length': 8192,
#     'Start': 1.5808,
#     'End': 1.612}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1580800,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 8192,
#     'Length': 8192,
#     'Start': 1.5808,
#     'End': 1.6104}},
#   {'ph': 'E',
#    'ts': 1581100,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8192,
#     'Start': 1.4501,
#     'End': 1.5811}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1581300,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 8192,
#     'Length': 8192,
#     'Start': 1.5813,
#     'End': 1.6124}},
#   {'ph': 'E',
#    'ts': 1604900,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 8192,
#     'Length': 8192,
#     'Start': 1.5797,
#     'End': 1.6049}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1605100,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16384,
#     'Length': 8192,
#     'Start': 1.6051,
#     'End': 1.6052}},
#   {'ph': 'E',
#    'ts': 1605200,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16384,
#     'Length': 8192,
#     'Start': 1.6051,
#     'End': 1.6052}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1605200,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 24576,
#     'Length': 8192,
#     'Start': 1.6052,
#     'End': 1.6052}},
#   {'ph': 'E',
#    'ts': 1605200,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 24576,
#     'Length': 8192,
#     'Start': 1.6052,
#     'End': 1.6052}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1605400,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 32768,
#     'Length': 8192,
#     'Start': 1.6054,
#     'End': 1.6054}},
#   {'ph': 'E',
#    'ts': 1605400,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 32768,
#     'Length': 8192,
#     'Start': 1.6054,
#     'End': 1.6054}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1605400,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 40960,
#     'Length': 8192,
#     'Start': 1.6054,
#     'End': 1.6261}},
#   {'ph': 'E',
#    'ts': 1606300,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 8192,
#     'Length': 8192,
#     'Start': 1.5799,
#     'End': 1.6063}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1606500,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16384,
#     'Length': 8192,
#     'Start': 1.6065,
#     'End': 1.6066}},
#   {'ph': 'E',
#    'ts': 1606600,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16384,
#     'Length': 8192,
#     'Start': 1.6065,
#     'End': 1.6066}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1606700,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 24576,
#     'Length': 8192,
#     'Start': 1.6067,
#     'End': 1.6067}},
#   {'ph': 'E',
#    'ts': 1606700,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 24576,
#     'Length': 8192,
#     'Start': 1.6067,
#     'End': 1.6067}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1606700,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 32768,
#     'Length': 8192,
#     'Start': 1.6067,
#     'End': 1.6068}},
#   {'ph': 'E',
#    'ts': 1606800,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 8192,
#     'Length': 8192,
#     'Start': 1.5804,
#     'End': 1.6068}},
#   {'ph': 'E',
#    'ts': 1606800,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 32768,
#     'Length': 8192,
#     'Start': 1.6067,
#     'End': 1.6068}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1606800,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 40960,
#     'Length': 8192,
#     'Start': 1.6068,
#     'End': 1.6273}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1607000,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16384,
#     'Length': 8192,
#     'Start': 1.607,
#     'End': 1.607}},
#   {'ph': 'E',
#    'ts': 1607000,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16384,
#     'Length': 8192,
#     'Start': 1.607,
#     'End': 1.607}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1607100,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 24576,
#     'Length': 8192,
#     'Start': 1.6071,
#     'End': 1.6071}},
#   {'ph': 'E',
#    'ts': 1607100,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 24576,
#     'Length': 8192,
#     'Start': 1.6071,
#     'End': 1.6071}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1607100,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 32768,
#     'Length': 8192,
#     'Start': 1.6071,
#     'End': 1.6072}},
#   {'ph': 'E',
#    'ts': 1607200,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 32768,
#     'Length': 8192,
#     'Start': 1.6071,
#     'End': 1.6072}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1607200,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 40960,
#     'Length': 8192,
#     'Start': 1.6072,
#     'End': 1.6276}},
#   {'ph': 'E',
#    'ts': 1607900,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 8192,
#     'Length': 8192,
#     'Start': 1.5803,
#     'End': 1.6079}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1608100,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16384,
#     'Length': 8192,
#     'Start': 1.6081,
#     'End': 1.6081}},
#   {'ph': 'E',
#    'ts': 1608100,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16384,
#     'Length': 8192,
#     'Start': 1.6081,
#     'End': 1.6081}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1608200,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 24576,
#     'Length': 8192,
#     'Start': 1.6082,
#     'End': 1.6082}},
#   {'ph': 'E',
#    'ts': 1608200,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 24576,
#     'Length': 8192,
#     'Start': 1.6082,
#     'End': 1.6082}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1608300,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 32768,
#     'Length': 8192,
#     'Start': 1.6083,
#     'End': 1.6083}},
#   {'ph': 'E',
#    'ts': 1608300,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 32768,
#     'Length': 8192,
#     'Start': 1.6083,
#     'End': 1.6083}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1608400,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 40960,
#     'Length': 8192,
#     'Start': 1.6084,
#     'End': 1.6289}},
#   {'ph': 'E',
#    'ts': 1608800,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 8192,
#     'Length': 8192,
#     'Start': 1.5805,
#     'End': 1.6088}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1609000,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16384,
#     'Length': 8192,
#     'Start': 1.609,
#     'End': 1.609}},
#   {'ph': 'E',
#    'ts': 1609000,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16384,
#     'Length': 8192,
#     'Start': 1.609,
#     'End': 1.609}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1609100,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 24576,
#     'Length': 8192,
#     'Start': 1.6091,
#     'End': 1.6091}},
#   {'ph': 'E',
#    'ts': 1609100,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 24576,
#     'Length': 8192,
#     'Start': 1.6091,
#     'End': 1.6091}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1609200,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 32768,
#     'Length': 8192,
#     'Start': 1.6092,
#     'End': 1.6092}},
#   {'ph': 'E',
#    'ts': 1609200,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 32768,
#     'Length': 8192,
#     'Start': 1.6092,
#     'End': 1.6092}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1609200,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 40960,
#     'Length': 8192,
#     'Start': 1.6092,
#     'End': 1.6296}},
#   {'ph': 'E',
#    'ts': 1610400,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 8192,
#     'Length': 8192,
#     'Start': 1.5808,
#     'End': 1.6104}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1610600,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16384,
#     'Length': 8192,
#     'Start': 1.6106,
#     'End': 1.6106}},
#   {'ph': 'E',
#    'ts': 1610600,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16384,
#     'Length': 8192,
#     'Start': 1.6106,
#     'End': 1.6106}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1610600,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 24576,
#     'Length': 8192,
#     'Start': 1.6106,
#     'End': 1.6107}},
#   {'ph': 'E',
#    'ts': 1610700,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 24576,
#     'Length': 8192,
#     'Start': 1.6106,
#     'End': 1.6107}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1610700,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 32768,
#     'Length': 8192,
#     'Start': 1.6107,
#     'End': 1.6107}},
#   {'ph': 'E',
#    'ts': 1610700,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 32768,
#     'Length': 8192,
#     'Start': 1.6107,
#     'End': 1.6107}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1610800,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 40960,
#     'Length': 8192,
#     'Start': 1.6108,
#     'End': 1.631}},
#   {'ph': 'E',
#    'ts': 1612000,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 8192,
#     'Length': 8192,
#     'Start': 1.5808,
#     'End': 1.612}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1612200,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16384,
#     'Length': 8192,
#     'Start': 1.6122,
#     'End': 1.6122}},
#   {'ph': 'E',
#    'ts': 1612200,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16384,
#     'Length': 8192,
#     'Start': 1.6122,
#     'End': 1.6122}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1612300,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 24576,
#     'Length': 8192,
#     'Start': 1.6123,
#     'End': 1.6123}},
#   {'ph': 'E',
#    'ts': 1612300,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 24576,
#     'Length': 8192,
#     'Start': 1.6123,
#     'End': 1.6123}},
#   {'ph': 'E',
#    'ts': 1612400,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 8192,
#     'Length': 8192,
#     'Start': 1.5813,
#     'End': 1.6124}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1612400,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 32768,
#     'Length': 8192,
#     'Start': 1.6124,
#     'End': 1.6124}},
#   {'ph': 'E',
#    'ts': 1612400,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 32768,
#     'Length': 8192,
#     'Start': 1.6124,
#     'End': 1.6124}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1612400,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 40960,
#     'Length': 8192,
#     'Start': 1.6124,
#     'End': 1.6327}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1612600,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16384,
#     'Length': 8192,
#     'Start': 1.6126,
#     'End': 1.6126}},
#   {'ph': 'E',
#    'ts': 1612600,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16384,
#     'Length': 8192,
#     'Start': 1.6126,
#     'End': 1.6126}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1612700,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 24576,
#     'Length': 8192,
#     'Start': 1.6127,
#     'End': 1.6127}},
#   {'ph': 'E',
#    'ts': 1612700,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 24576,
#     'Length': 8192,
#     'Start': 1.6127,
#     'End': 1.6127}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1612800,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 32768,
#     'Length': 8192,
#     'Start': 1.6128,
#     'End': 1.6128}},
#   {'ph': 'E',
#    'ts': 1612800,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 32768,
#     'Length': 8192,
#     'Start': 1.6128,
#     'End': 1.6128}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1612800,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 40960,
#     'Length': 8192,
#     'Start': 1.6128,
#     'End': 1.6331}},
#   {'ph': 'E',
#    'ts': 1626100,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 40960,
#     'Length': 8192,
#     'Start': 1.6054,
#     'End': 1.6261}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1626300,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 49152,
#     'Length': 8192,
#     'Start': 1.6263,
#     'End': 1.6263}},
#   {'ph': 'E',
#    'ts': 1626300,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 49152,
#     'Length': 8192,
#     'Start': 1.6263,
#     'End': 1.6263}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1626400,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 57344,
#     'Length': 8192,
#     'Start': 1.6264,
#     'End': 1.6264}},
#   {'ph': 'E',
#    'ts': 1626400,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 57344,
#     'Length': 8192,
#     'Start': 1.6264,
#     'End': 1.6264}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1626500,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 8,
#     'Offset': 65536,
#     'Length': 8192,
#     'Start': 1.6265,
#     'End': 1.6265}},
#   {'ph': 'E',
#    'ts': 1626500,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 8,
#     'Offset': 65536,
#     'Length': 8192,
#     'Start': 1.6265,
#     'End': 1.6265}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1626600,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 9,
#     'Offset': 73728,
#     'Length': 8192,
#     'Start': 1.6266,
#     'End': 1.6474}},
#   {'ph': 'E',
#    'ts': 1627300,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 40960,
#     'Length': 8192,
#     'Start': 1.6068,
#     'End': 1.6273}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1627500,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 49152,
#     'Length': 8192,
#     'Start': 1.6275,
#     'End': 1.6275}},
#   {'ph': 'E',
#    'ts': 1627500,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 49152,
#     'Length': 8192,
#     'Start': 1.6275,
#     'End': 1.6275}},
#   {'ph': 'E',
#    'ts': 1627600,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 40960,
#     'Length': 8192,
#     'Start': 1.6072,
#     'End': 1.6276}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1627600,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 57344,
#     'Length': 8192,
#     'Start': 1.6276,
#     'End': 1.6276}},
#   {'ph': 'E',
#    'ts': 1627600,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 57344,
#     'Length': 8192,
#     'Start': 1.6276,
#     'End': 1.6276}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1627700,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 8,
#     'Offset': 65536,
#     'Length': 8192,
#     'Start': 1.6277,
#     'End': 1.6277}},
#   {'ph': 'E',
#    'ts': 1627700,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 8,
#     'Offset': 65536,
#     'Length': 8192,
#     'Start': 1.6277,
#     'End': 1.6277}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1627800,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 49152,
#     'Length': 8192,
#     'Start': 1.6278,
#     'End': 1.6278}},
#   {'ph': 'E',
#    'ts': 1627800,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 49152,
#     'Length': 8192,
#     'Start': 1.6278,
#     'End': 1.6278}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1627800,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 9,
#     'Offset': 73728,
#     'Length': 8192,
#     'Start': 1.6278,
#     'End': 1.6482}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1627900,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 57344,
#     'Length': 8192,
#     'Start': 1.6279,
#     'End': 1.6279}},
#   {'ph': 'E',
#    'ts': 1627900,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 57344,
#     'Length': 8192,
#     'Start': 1.6279,
#     'End': 1.6279}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1628000,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 8,
#     'Offset': 65536,
#     'Length': 8192,
#     'Start': 1.628,
#     'End': 1.628}},
#   {'ph': 'E',
#    'ts': 1628000,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 8,
#     'Offset': 65536,
#     'Length': 8192,
#     'Start': 1.628,
#     'End': 1.628}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1628100,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 9,
#     'Offset': 73728,
#     'Length': 8192,
#     'Start': 1.6281,
#     'End': 1.6486}},
#   {'ph': 'E',
#    'ts': 1628900,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 40960,
#     'Length': 8192,
#     'Start': 1.6084,
#     'End': 1.6289}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1629100,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 49152,
#     'Length': 8192,
#     'Start': 1.6291,
#     'End': 1.6291}},
#   {'ph': 'E',
#    'ts': 1629100,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 49152,
#     'Length': 8192,
#     'Start': 1.6291,
#     'End': 1.6291}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1629200,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 57344,
#     'Length': 8192,
#     'Start': 1.6292,
#     'End': 1.6292}},
#   {'ph': 'E',
#    'ts': 1629200,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 57344,
#     'Length': 8192,
#     'Start': 1.6292,
#     'End': 1.6292}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1629300,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 8,
#     'Offset': 65536,
#     'Length': 8192,
#     'Start': 1.6293,
#     'End': 1.6293}},
#   {'ph': 'E',
#    'ts': 1629300,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 8,
#     'Offset': 65536,
#     'Length': 8192,
#     'Start': 1.6293,
#     'End': 1.6293}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1629400,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 9,
#     'Offset': 73728,
#     'Length': 8192,
#     'Start': 1.6294,
#     'End': 1.6499}},
#   {'ph': 'E',
#    'ts': 1629600,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 40960,
#     'Length': 8192,
#     'Start': 1.6092,
#     'End': 1.6296}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1629800,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 49152,
#     'Length': 8192,
#     'Start': 1.6298,
#     'End': 1.6298}},
#   {'ph': 'E',
#    'ts': 1629800,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 49152,
#     'Length': 8192,
#     'Start': 1.6298,
#     'End': 1.6298}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1629900,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 57344,
#     'Length': 8192,
#     'Start': 1.6299,
#     'End': 1.6299}},
#   {'ph': 'E',
#    'ts': 1629900,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 57344,
#     'Length': 8192,
#     'Start': 1.6299,
#     'End': 1.6299}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1629900,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 8,
#     'Offset': 65536,
#     'Length': 8192,
#     'Start': 1.6299,
#     'End': 1.63}},
#   {'ph': 'E',
#    'ts': 1630000,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 8,
#     'Offset': 65536,
#     'Length': 8192,
#     'Start': 1.6299,
#     'End': 1.63}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1630000,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 9,
#     'Offset': 73728,
#     'Length': 8192,
#     'Start': 1.63,
#     'End': 1.6505}},
#   {'ph': 'E',
#    'ts': 1631000,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 40960,
#     'Length': 8192,
#     'Start': 1.6108,
#     'End': 1.631}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1631300,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 49152,
#     'Length': 8192,
#     'Start': 1.6313,
#     'End': 1.6313}},
#   {'ph': 'E',
#    'ts': 1631300,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
# ...
#     'End': 1.6755}},
#   {'ph': 'E',
#    'ts': 1675500,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 83,
#     'Offset': 679936,
#     'Length': 8192,
#     'Start': 1.6755,
#     'End': 1.6755}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1675500,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 99,
#     'Offset': 811008,
#     'Length': 8192,
#     'Start': 1.6755,
#     'End': 1.6755}},
#   {'ph': 'E',
#    'ts': 1675500,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 99,
#     'Offset': 811008,
#     'Length': 8192,
#     'Start': 1.6755,
#     'End': 1.6755}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1675500,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 16,
#     'Offset': 131072,
#     'Length': 8192,
#     'Start': 1.6755,
#     'End': 1.6755}},
#   {'ph': 'E',
#    'ts': 1675500,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 16,
#     'Offset': 131072,
#     'Length': 8192,
#     'Start': 1.6755,
#     'End': 1.6755}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1675500,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 24,
#     'Offset': 196608,
#     'Length': 8192,
#     'Start': 1.6755,
#     'End': 1.6755}},
#   {'ph': 'E',
#    'ts': 1675500,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 24,
#     'Offset': 196608,
#     'Length': 8192,
#     'Start': 1.6755,
#     'End': 1.6755}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1675500,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 25,
#     'Offset': 204800,
#     'Length': 8192,
#     'Start': 1.6755,
#     'End': 1.6755}},
#   {'ph': 'E',
#    'ts': 1675500,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 25,
#     'Offset': 204800,
#     'Length': 8192,
#     'Start': 1.6755,
#     'End': 1.6755}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1675500,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 46,
#     'Offset': 376832,
#     'Length': 8192,
#     'Start': 1.6755,
#     'End': 1.6755}},
#   {'ph': 'E',
#    'ts': 1675500,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 46,
#     'Offset': 376832,
#     'Length': 8192,
#     'Start': 1.6755,
#     'End': 1.6755}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1675500,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 59,
#     'Offset': 483328,
#     'Length': 8192,
#     'Start': 1.6755,
#     'End': 1.6755}},
#   {'ph': 'E',
#    'ts': 1675500,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 59,
#     'Offset': 483328,
#     'Length': 8192,
#     'Start': 1.6755,
#     'End': 1.6755}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1675500,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 85,
#     'Offset': 696320,
#     'Length': 8192,
#     'Start': 1.6755,
#     'End': 1.6755}},
#   {'ph': 'E',
#    'ts': 1675500,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 85,
#     'Offset': 696320,
#     'Length': 8192,
#     'Start': 1.6755,
#     'End': 1.6755}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1675600,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 66,
#     'Offset': 540672,
#     'Length': 8192,
#     'Start': 1.6756,
#     'End': 1.6756}},
#   {'ph': 'E',
#    'ts': 1675600,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 66,
#     'Offset': 540672,
#     'Length': 8192,
#     'Start': 1.6756,
#     'End': 1.6756}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1675600,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 84,
#     'Offset': 688128,
#     'Length': 8192,
#     'Start': 1.6756,
#     'End': 1.6756}},
#   {'ph': 'E',
#    'ts': 1675600,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 84,
#     'Offset': 688128,
#     'Length': 8192,
#     'Start': 1.6756,
#     'End': 1.6756}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1675600,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 100,
#     'Offset': 819200,
#     'Length': 8192,
#     'Start': 1.6756,
#     'End': 1.6756}},
#   {'ph': 'E',
#    'ts': 1675600,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 100,
#     'Offset': 819200,
#     'Length': 8192,
#     'Start': 1.6756,
#     'End': 1.6756}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1675600,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 17,
#     'Offset': 139264,
#     'Length': 8192,
#     'Start': 1.6756,
#     'End': 1.6756}},
#   {'ph': 'E',
#    'ts': 1675600,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 17,
#     'Offset': 139264,
#     'Length': 8192,
#     'Start': 1.6756,
#     'End': 1.6756}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1675600,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 26,
#     'Offset': 212992,
#     'Length': 8192,
#     'Start': 1.6756,
#     'End': 1.6756}},
#   {'ph': 'E',
#    'ts': 1675600,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 26,
#     'Offset': 212992,
#     'Length': 8192,
#     'Start': 1.6756,
#     'End': 1.6756}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1675600,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 47,
#     'Offset': 385024,
#     'Length': 8192,
#     'Start': 1.6756,
#     'End': 1.6756}},
#   {'ph': 'E',
#    'ts': 1675600,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 47,
#     'Offset': 385024,
#     'Length': 8192,
#     'Start': 1.6756,
#     'End': 1.6756}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1675600,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 60,
#     'Offset': 491520,
#     'Length': 8192,
#     'Start': 1.6756,
#     'End': 1.6756}},
#   {'ph': 'E',
#    'ts': 1675600,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 60,
#     'Offset': 491520,
#     'Length': 8192,
#     'Start': 1.6756,
#     'End': 1.6756}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1675600,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 61,
#     'Offset': 499712,
#     'Length': 8192,
#     'Start': 1.6756,
#     'End': 1.6756}},
#   {'ph': 'E',
#    'ts': 1675600,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 61,
#     'Offset': 499712,
#     'Length': 8192,
#     'Start': 1.6756,
#     'End': 1.6756}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1675600,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 86,
#     'Offset': 704512,
#     'Length': 8192,
#     'Start': 1.6756,
#     'End': 1.6756}},
#   {'ph': 'E',
#    'ts': 1675600,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 86,
#     'Offset': 704512,
#     'Length': 8192,
#     'Start': 1.6756,
#     'End': 1.6756}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1675700,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 67,
#     'Offset': 548864,
#     'Length': 8192,
#     'Start': 1.6757,
#     'End': 1.6757}},
#   {'ph': 'E',
#    'ts': 1675700,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 67,
#     'Offset': 548864,
#     'Length': 8192,
#     'Start': 1.6757,
#     'End': 1.6757}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1675700,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 68,
#     'Offset': 557056,
#     'Length': 8192,
#     'Start': 1.6757,
#     'End': 1.6758}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1675700,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 85,
#     'Offset': 696320,
#     'Length': 8192,
#     'Start': 1.6757,
#     'End': 1.6757}},
#   {'ph': 'E',
#    'ts': 1675700,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 85,
#     'Offset': 696320,
#     'Length': 8192,
#     'Start': 1.6757,
#     'End': 1.6757}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1675700,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 86,
#     'Offset': 704512,
#     'Length': 8192,
#     'Start': 1.6757,
#     'End': 1.6758}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1675700,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 101,
#     'Offset': 827392,
#     'Length': 8192,
#     'Start': 1.6757,
#     'End': 1.6757}},
#   {'ph': 'E',
#    'ts': 1675700,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 101,
#     'Offset': 827392,
#     'Length': 8192,
#     'Start': 1.6757,
#     'End': 1.6757}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1675700,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 102,
#     'Offset': 835584,
#     'Length': 8192,
#     'Start': 1.6757,
#     'End': 1.6757}},
#   {'ph': 'E',
#    'ts': 1675700,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/candel/img_0_of_1.csv',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 102,
#     'Offset': 835584,
#     'Length': 8192,
#     'Start': 1.6757,
#     'End': 1.6757}},
#   ...],
#  'displayTimeUnit': 'ms',
#  'systemTraceEvents': 'SystemTraceData',
#  'otherData': {'version': 'VaniDL v1.0'},
#  'stackFrames': {},
#  'samples': []}

# %%
import csv
with open('/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv', newline='\n') as f:
    reader = csv.reader(f)
    row1 = next(reader)
    print(len(row1))
# Out:
# 60484

# %%
import pandas as pd
val = pd.read_csv('/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',header=None,low_memory=False)
