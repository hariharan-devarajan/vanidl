# %% [markdown]
# # DLProfile Example using Cosmic Tagger Application

# %% [markdown]
# ## Set imports and neccessary environment variables

# %%
import pathlib
import os
import sys
import matplotlib.pyplot as plt
import warnings
import pprint
import pandas

# %%
VANIDL_DIR="{}".format(pathlib.Path(os.getcwd()).parent.parent.parent.absolute())
sys.path.insert(0, VANIDL_DIR)
warnings.filterwarnings('ignore')

# %%
os.environ["DARSHAN_DIR"] = "/soft/perftools/darshan/darshan-3.1.8"
os.environ["VANIDL_DIR"] = VANIDL_DIR

# %% [markdown]
# #### Formatting

# %%
pp = pprint.PrettyPrinter(indent=1)
class color:
    PURPLE = '\033[95m'
    CYAN = '\033[96m'
    DARKCYAN = '\033[36m'
    BLUE = '\033[94m'
    GREEN = '\033[92m'
    YELLOW = '\033[93m'
    RED = '\033[91m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'
    END = '\033[0m'

# %% [markdown]
# ## Create instrance of DL Profile and load the darshan file

# %%
from src.vanidl import VaniDL
profile = VaniDL()

# %%
#import shutil
#shutil.rmtree('/tmp/temp_analysis')

# %%
DATAPATH_INCLUDES = []
status = profile.Load("/home/dhari/darshan-logs/benchmark/cosmic/optimization/16MB.darshan", data_paths_include=DATAPATH_INCLUDES)
if status:
    print("Darshan Trace loaded Successfully!")
else:
    print("Darshan Trace load Failed!")
    print(profile._error_str())
# Out:
# [============================================================] 100.0% 7328 of 7328 Parsing DXT File
# [============================================================] 100.0% 3855 of 3855 Parsing Darshan File
# Darshan Trace loaded Successfully!

# %% [markdown]
# ## Use Profile object to analyze the darshan I/O trace.

# %% [markdown]
# ### Verify if object works
#
# The GetDXTAsDF() function enables users to perform analysis

# %%
df = profile.GetDXTAsDF()
pp.pprint("Files used in the application")
pp.pprint(df['Filename'].unique().tolist())
# Out:
# 'Files used in the application'
# ['/projects/datascience/dhari/dlio_datasets/cosmic_16MB/img_1_of_1.h5']

# %%
df_normal = profile.GetTraceAsDF()
pp.pprint("Files used in the application")
pp.pprint(df_normal['Filename'].unique().tolist())
# Out:
# 'Files used in the application'
# ['/projects/datascience/dhari/dlio_datasets/cosmic_16MB/img_1_of_1.h5',
#  '/gpfs/mira-home/dhari/code/dlio_benchmark/scripts/logdir/plugins/profile/2020_07_31_23_34_09/nid03830.overview_page.pb',
#  '/gpfs/mira-home/dhari/code/dlio_benchmark/scripts/logdir/plugins/profile/2020_07_31_23_34_09/nid03830.kernel_stats.pb',
#  '/gpfs/mira-home/dhari/code/dlio_benchmark/scripts/logdir/plugins/profile/2020_07_31_23_34_09/nid03830.trace.json.gz',
#  '/gpfs/mira-home/dhari/code/dlio_benchmark/scripts/logdir/plugins/profile/2020_07_31_23_34_09/nid03830.input_pipeline.pb',
#  '/gpfs/mira-home/dhari/code/dlio_benchmark/scripts/logdir/plugins/profile/2020_07_31_23_34_09/nid03830.tensorflow_stats.pb',
#  '/gpfs/mira-home/dhari/code/dlio_benchmark/scripts/logdir/plugins/profile/2020_07_31_23_34_09/nid03832.overview_page.pb',
#  '/gpfs/mira-home/dhari/code/dlio_benchmark/scripts/logdir/plugins/profile/2020_07_31_23_34_09/nid03832.trace.json.gz',
#  '/gpfs/mira-home/dhari/code/dlio_benchmark/scripts/logdir/plugins/profile/2020_07_31_23_34_09/nid03832.input_pipeline.pb',
#  '/gpfs/mira-home/dhari/code/dlio_benchmark/scripts/logdir/plugins/profile/2020_07_31_23_34_09/nid03832.tensorflow_stats.pb',
#  '/gpfs/mira-home/dhari/code/dlio_benchmark/scripts/logdir/plugins/profile/2020_07_31_23_34_09/nid03832.kernel_stats.pb',
#  '/gpfs/mira-home/dhari/code/dlio_benchmark/scripts/logdir/plugins/profile/2020_07_31_23_34_09/nid03833.tensorflow_stats.pb',
#  '/gpfs/mira-home/dhari/code/dlio_benchmark/scripts/logdir/plugins/profile/2020_07_31_23_34_09/nid03833.kernel_stats.pb',
#  '/gpfs/mira-home/dhari/code/dlio_benchmark/scripts/logdir/plugins/profile/2020_07_31_23_34_09/nid03833.trace.json.gz',
#  '/gpfs/mira-home/dhari/code/dlio_benchmark/scripts/logdir/plugins/profile/2020_07_31_23_34_09/nid03833.overview_page.pb',
#  '/gpfs/mira-home/dhari/code/dlio_benchmark/scripts/logdir/plugins/profile/2020_07_31_23_34_09/nid03833.input_pipeline.pb',
#  '/gpfs/mira-home/dhari/code/dlio_benchmark/scripts/logdir/plugins/profile/2020_07_31_23_34_09/nid03834.input_pipeline.pb',
#  '/gpfs/mira-home/dhari/code/dlio_benchmark/scripts/logdir/plugins/profile/2020_07_31_23_34_09/nid03834.overview_page.pb',
#  '/gpfs/mira-home/dhari/code/dlio_benchmark/scripts/logdir/plugins/profile/2020_07_31_23_34_09/nid03834.tensorflow_stats.pb',
#  '/gpfs/mira-home/dhari/code/dlio_benchmark/scripts/logdir/plugins/profile/2020_07_31_23_34_09/nid03834.trace.json.gz',
#  '/gpfs/mira-home/dhari/code/dlio_benchmark/scripts/logdir/plugins/profile/2020_07_31_23_34_09/nid03834.kernel_stats.pb',
#  '/gpfs/mira-home/dhari/code/dlio_benchmark/scripts/logdir/plugins/profile/2020_07_31_23_34_09/nid03835.trace.json.gz',
#  '/gpfs/mira-home/dhari/code/dlio_benchmark/scripts/logdir/plugins/profile/2020_07_31_23_34_09/nid03835.input_pipeline.pb',
#  '/gpfs/mira-home/dhari/code/dlio_benchmark/scripts/logdir/plugins/profile/2020_07_31_23_34_09/nid03835.kernel_stats.pb',
#  '/gpfs/mira-home/dhari/code/dlio_benchmark/scripts/logdir/plugins/profile/2020_07_31_23_34_09/nid03835.tensorflow_stats.pb',
#  '/gpfs/mira-home/dhari/code/dlio_benchmark/scripts/logdir/plugins/profile/2020_07_31_23_34_09/nid03835.overview_page.pb',
#  '/gpfs/mira-home/dhari/code/dlio_benchmark/scripts/logdir/plugins/profile/2020_07_31_23_34_09/nid03836.input_pipeline.pb',
#  '/gpfs/mira-home/dhari/code/dlio_benchmark/scripts/logdir/plugins/profile/2020_07_31_23_34_09/nid03836.trace.json.gz',
#  '/gpfs/mira-home/dhari/code/dlio_benchmark/scripts/logdir/plugins/profile/2020_07_31_23_34_09/nid03836.tensorflow_stats.pb',
#  '/gpfs/mira-home/dhari/code/dlio_benchmark/scripts/logdir/plugins/profile/2020_07_31_23_34_09/nid03836.overview_page.pb',
#  '/gpfs/mira-home/dhari/code/dlio_benchmark/scripts/logdir/plugins/profile/2020_07_31_23_34_09/nid03836.kernel_stats.pb',
#  '/gpfs/mira-home/dhari/code/dlio_benchmark/scripts/logdir/plugins/profile/2020_07_31_23_34_09/nid03838.overview_page.pb',
#  '/gpfs/mira-home/dhari/code/dlio_benchmark/scripts/logdir/plugins/profile/2020_07_31_23_34_09/nid03838.trace.json.gz',
#  '/gpfs/mira-home/dhari/code/dlio_benchmark/scripts/logdir/plugins/profile/2020_07_31_23_34_09/nid03838.kernel_stats.pb',
#  '/gpfs/mira-home/dhari/code/dlio_benchmark/scripts/logdir/plugins/profile/2020_07_31_23_34_09/nid03838.tensorflow_stats.pb',
#  '/gpfs/mira-home/dhari/code/dlio_benchmark/scripts/logdir/plugins/profile/2020_07_31_23_34_09/nid03838.input_pipeline.pb',
#  '/gpfs/mira-home/dhari/code/dlio_benchmark/scripts/logdir/plugins/profile/2020_07_31_23_34_09/nid03839.overview_page.pb',
#  '/gpfs/mira-home/dhari/code/dlio_benchmark/scripts/logdir/plugins/profile/2020_07_31_23_34_09/nid03839.kernel_stats.pb',
#  '/gpfs/mira-home/dhari/code/dlio_benchmark/scripts/logdir/plugins/profile/2020_07_31_23_34_09/nid03839.tensorflow_stats.pb',
#  '/gpfs/mira-home/dhari/code/dlio_benchmark/scripts/logdir/plugins/profile/2020_07_31_23_34_09/nid03839.input_pipeline.pb',
#  '/gpfs/mira-home/dhari/code/dlio_benchmark/scripts/logdir/plugins/profile/2020_07_31_23_34_09/nid03839.trace.json.gz']

# %% [markdown]
# ### Collect the summary of the Application

# %%
summary = profile.GetSummary()
print("\n")
print(color.BOLD + "Data Access Summary (from Darshan):"+ color.END)
print("Total Job time\t\t\t:\t{:0.2f} seconds".format(summary['job_time']))
#FIXME: calculate time per rank and then take max across it.
print("Time spent in I/O\t\t:\t{:0.2f} seconds".format(summary['total_io_time']))
print("% Time spent in I/O\t\t:\t{:0.2f}%".format(float(summary['total_io_time'])*100/summary['job_time']))
print("Total Data Accessed\t\t:\t{:0.2f} GB".format(float(summary['total_io_bytes'])/1024.0/1024.0/1024.0))
print("Data Access Modules used\t:\t{}".format(summary['io_interface_used']))
print("Data Operations\t\t\t:\t{}".format(summary['io_operations_used']))
print("# of files used\t\t\t:\t{}".format(len(summary['files_used'])))
print("# of MPI Ranks\t\t\t:\t{:0.0f} ranks".format(summary['num_ranks']))
      
print(color.UNDERLINE + "Data Transfer size:"+ color.END)
print("\tMin,Max\t\t\t:\t{:0.0f} bytes and {:0.0f} bytes".format(summary['data_transfer_size']['min'],summary['data_transfer_size']['max']))
print("\tAverage\t\t\t:\t{:0.0f} bytes".format(summary['data_transfer_size']['mean']))
print("\tMedian\t\t\t:\t{:0.0f} bytes".format(summary['data_transfer_size']['median']))
      
print(color.UNDERLINE + "Data Transfer bandwidth: (per rank)"+ color.END)
print("\tMin,Max\t\t\t:\t{:0.0f} B/s and {:0.0f} MB/s".format(summary['data_transfer_bandwidth']['min'],summary['data_transfer_bandwidth']['max']/1024.0/1024.0))
print("\tAverage\t\t\t:\t{:0.0f} MB/s".format(summary['data_transfer_bandwidth']['mean']/1024.0/1024.0))
print("\tMedian\t\t\t:\t{:0.0f} MB/s".format(summary['data_transfer_bandwidth']['median']/1024.0/1024.0))
      
print(color.UNDERLINE + "Access Pattern:"+ color.END)
print("\tSequential\t\t:\t{:0.2f}%".format(float(summary['access_pattern']['sequential'])))
print("\tConsecutive\t\t:\t{:0.2f}%".format(float(summary['access_pattern']['consecutive'])))
#An I/O op issued at an offset greater than where the previous I/O op ended.
#An I/O op issued at the offset immediately after the end of the previous I/O

print("\n")
print(color.BOLD + "Files Summary:"+ color.END)
print("File Types\t\t\t:\t{}".format(summary['file_used_summary']['types']))
print(color.UNDERLINE + "Dataset Size:"+ color.END)
print("\tTotal\t\t\t:\t{:0.3f} GB".format(float(summary['file_used_summary']['size']['total'])/1024.0/1024.0/1024.0))
print("\tMin,Max\t\t\t:\t{:0.3f} GB and {:0.3f} GB".format(float(summary['file_used_summary']['size']['min'])/1024.0/1024.0/1024.0,float(summary['file_used_summary']['size']['max'])/1024.0/1024.0/1024.0))
print("\tAverage\t\t\t:\t{:0.3f} GB".format(float(summary['file_used_summary']['size']['mean'])/1024.0/1024.0/1024.0))
# Out:
# Data Access Summary (from Darshan):
# Total Job time			:	7.00 seconds
# Time spent in I/O		:	0.95 seconds
# % Time spent in I/O		:	13.57%
# Total Data Accessed		:	1.82 GB
# Data Access Modules used	:	['X_POSIX']
# Data Operations			:	['read']
# # of files used			:	1
# # of MPI Ranks			:	8 ranks
# Data Transfer size:
# 	Min,Max			:	8 bytes and 326432 bytes
# 	Average			:	313046 bytes
# 	Median			:	326432 bytes
# Data Transfer bandwidth: (per rank)
# 	Min,Max			:	544 B/s and 3113 MB/s
# 	Average			:	1469 MB/s
# 	Median			:	1557 MB/s
# Access Pattern:
# 	Sequential		:	97.04%
# 	Consecutive		:	92.89%
#
#
# Files Summary:
# File Types			:	['h5']
# Dataset Size:
# 	Total			:	1.824 GB
# 	Min,Max			:	0.000 GB and 1.824 GB
# 	Average			:	0.044 GB

# %%
pp.pprint("Job time : {} seconds".format(profile.GetJobTime()))
# Out:
# 'Job time : 7.0 seconds'

# %%
pp.pprint("Time spent by application on I/O: {} seconds".format(profile.GetIOTime()))
# Out:
# 'Time spent by application on I/O: 0.9498374999998892 seconds'

# %% [markdown]
# ### I/O time spent on each file

# %%
for file in df['Filename'].unique():
    print("I/O time for file {}: {:0.2f} seconds".format(file,profile.GetIOTime(filepath=file)))
# Out:
# I/O time for file /projects/datascience/dhari/dlio_datasets/cosmic_16MB/img_1_of_1.h5: 0.95 seconds

# %% [markdown]
# ### I/O Time spent per rank

# %%
for rank in df['Rank'].unique():
    print("I/O time for rank {}: {:0.2f} seconds".format(rank,profile.GetIOTime(rank=rank)))
# Out:
# I/O time for rank 0: 0.83 seconds
# I/O time for rank 1: 1.00 seconds
# I/O time for rank 2: 0.95 seconds
# I/O time for rank 3: 0.95 seconds
# I/O time for rank 4: 0.98 seconds
# I/O time for rank 5: 0.96 seconds
# I/O time for rank 6: 0.99 seconds
# I/O time for rank 7: 0.92 seconds

# %%
"Total I/O performed by application: {:0.2f} GB".format(float(profile.GetIOSize())/1024.0/1024.0/1024.0)
# Out:
# 'Total I/O performed by application: 1.82 GB'

# %% [markdown]
# ### I/O performed on each file

# %%
for file in df['Filename'].unique():
    print("I/O performed on file {}: {:0.2f} MB".format(file,float(profile.GetIOSize(filepath=file))/1024.0/1024.0))
# Out:
# I/O performed on file /projects/datascience/dhari/dlio_datasets/cosmic_16MB/img_1_of_1.h5: 1868.29 MB

# %%
for rank in df['Rank'].unique():
    print("I/O performed by rank {}: {:0.2f} MB".format(rank, float(profile.GetIOSize(rank=rank))/1024.0/1024.0))
# Out:
# I/O performed by rank 0: 233.54 MB
# I/O performed by rank 1: 233.54 MB
# I/O performed by rank 2: 233.54 MB
# I/O performed by rank 3: 233.54 MB
# I/O performed by rank 4: 233.54 MB
# I/O performed by rank 5: 233.54 MB
# I/O performed by rank 6: 233.54 MB
# I/O performed by rank 7: 233.54 MB

# %%
print("Size of dataset (bytes)")
pp.pprint(profile.GetFileSizes())
# Out:
# Size of dataset (bytes)
# {'img_1_of_1': 1958984944.0,
#  'nid03830.input_pipeline': 1721.0,
#  'nid03830.kernel_stats': 0.0,
#  'nid03830.overview_page': 2663.0,
#  'nid03830.tensorflow_stats': 682.0,
#  'nid03830.trace.json': 1227.0,
#  'nid03832.input_pipeline': 1721.0,
#  'nid03832.kernel_stats': 0.0,
#  'nid03832.overview_page': 2663.0,
#  'nid03832.tensorflow_stats': 682.0,
#  'nid03832.trace.json': 1182.0,
#  'nid03833.input_pipeline': 1721.0,
#  'nid03833.kernel_stats': 0.0,
#  'nid03833.overview_page': 2663.0,
#  'nid03833.tensorflow_stats': 682.0,
#  'nid03833.trace.json': 1229.0,
#  'nid03834.input_pipeline': 1721.0,
#  'nid03834.kernel_stats': 0.0,
#  'nid03834.overview_page': 2663.0,
#  'nid03834.tensorflow_stats': 682.0,
#  'nid03834.trace.json': 1210.0,
#  'nid03835.input_pipeline': 1721.0,
#  'nid03835.kernel_stats': 0.0,
#  'nid03835.overview_page': 2663.0,
#  'nid03835.tensorflow_stats': 682.0,
#  'nid03835.trace.json': 1208.0,
#  'nid03836.input_pipeline': 1721.0,
#  'nid03836.kernel_stats': 0.0,
#  'nid03836.overview_page': 2663.0,
#  'nid03836.tensorflow_stats': 682.0,
#  'nid03836.trace.json': 1186.0,
#  'nid03838.input_pipeline': 1721.0,
#  'nid03838.kernel_stats': 0.0,
#  'nid03838.overview_page': 2663.0,
#  'nid03838.tensorflow_stats': 682.0,
#  'nid03838.trace.json': 1252.0,
#  'nid03839.input_pipeline': 1721.0,
#  'nid03839.kernel_stats': 0.0,
#  'nid03839.overview_page': 2663.0,
#  'nid03839.tensorflow_stats': 682.0,
#  'nid03839.trace.json': 1189.0}

# %% [markdown]
# ### How application access data over time.

# %%
tl = profile.CreateIOTimeline(time_step=0.001)
plt.figure(figsize=(8,4))
plt.grid()
plt.ylabel("# of operations")
plt.xlabel("Timeline (ms)")
plt.plot(tl['time_step'], tl['operation_count']);
# Out:
# [============================================================] 100.0% 6258 of 6258 Creating Timeline

# %%
plt.figure(figsize=(8,4))
plt.grid()
plt.ylabel("I/O performed (bytes)")
plt.xlabel("Timeline (ms)")
plt.plot(tl['time_step'], tl['io_bytes']);

# %% [markdown]
# ### How files are accessed over the duration of the Job.

# %%
for file in df['Filename'].unique():
    tl = profile.CreateIOTimeline(filepath=file,time_step=0.001)
    tl.plot(x='time_step',y='operation_count', title=file)
    plt.show()
# Out:
# [============================================================] 100.0% 6258 of 6258 Creating Timeline

# %% [markdown]
# ### Show how each file is accessed by each rank.

# %%
for rank in df['Rank'].unique():
    tl = profile.CreateIOTimeline(rank=rank)
    tl.plot(x='time_step',y='operation_count', title=rank)
    plt.show()
# Out:
# [============================================================] 100.0% 782 of 782 Creating Timeline
# [============================================================] 100.0% 782 of 782 Creating Timeline
# [============================================================] 100.0% 782 of 782 Creating Timeline
# [============================================================] 100.0% 782 of 782 Creating Timeline
# [============================================================] 100.0% 783 of 783 Creating Timeline
# [============================================================] 100.0% 782 of 782 Creating Timeline
# [============================================================] 100.0% 783 of 783 Creating Timeline
# [============================================================] 100.0% 782 of 782 Creating Timeline

# %% [markdown]
# ### Data Transfer Size distribution within the application

# %%
request_df = profile.GetIORequestDistribution()
df['Length'].plot(kind='hist', figsize=(5, 3), bins=100);
plt.xlabel("Transfer Size (bytes)")
# Out:
# Text(0.5, 0, 'Transfer Size (bytes)')

# %% [markdown]
# ### Data Transfer Size distribution for each file.

# %%
for file in df['Filename'].unique():
    tl = profile.GetIORequestDistribution(filepath=file)
    tl.plot(kind='bar', figsize=(10, 4), title=file)
    plt.show()

# %% [markdown]
# ### Data Transfer Sizes per Rank

# %%
for rank in df['Rank'].unique():
    tl = profile.GetIORequestDistribution(rank=rank)
    tl.plot(kind='bar', figsize=(10, 4), title=rank)
    plt.show()

# %% [markdown]
# ### File summary of each file accessed by the Application

# %%
pp = pprint.PrettyPrinter(indent=1)
for file in df['Filename'].unique():
    if os.path.exists(file):
        pp.pprint(profile.GetFileSummary(file))
# Out:
# {'ext': 'h5',
#  'filename': 'img_1_of_1',
#  'io_size': 1959039872,
#  'io_time': 0.9498374999998892,
#  'path': '/projects/datascience/dhari/dlio_datasets/cosmic_16MB/img_1_of_1.h5',
#  'size': 1958984944,
#  'special': {'keys': [{'name': 'labels',
#                        'obj': <HDF5 dataset "labels": shape (6000,), type "<i8">,
#                        'shape': (6000,),
#                        'size': 6000,
#                        'type': 'dataset'},
#                       {'name': 'records',
#                        'obj': <HDF5 dataset "records": shape (6000, 202, 202), type "<f8">,
#                        'shape': (6000, 202, 202),
#                        'size': 244824000,
#                        'type': 'dataset'}],
#              'name': 'img_1_of_1',
#              'type': 'group'}}
