# %% [markdown]
# # DLProfile Example using Distributed FFN Application

# %% [markdown]
# ## Set imports and neccessary environment variables

# %%
import pathlib
import os
import sys
import matplotlib.pyplot as plt
import warnings
import pprint
import pandas as pd
import tensorflow as tf

# %%
VANIDL_DIR="{}".format(pathlib.Path(os.getcwd()).parent.parent.parent.absolute())
sys.path.insert(0, VANIDL_DIR)
warnings.filterwarnings('ignore')

# %%
os.environ["DARSHAN_DIR"] = "/soft/perftools/darshan/darshan-3.1.8"
os.environ["VANIDL_DIR"] = VANIDL_DIR

# %% [markdown]
# ### Formatting

# %%
pp = pprint.PrettyPrinter(indent=1)
class color:
    PURPLE = '\033[95m'
    CYAN = '\033[96m'
    DARKCYAN = '\033[36m'
    BLUE = '\033[94m'
    GREEN = '\033[92m'
    YELLOW = '\033[93m'
    RED = '\033[91m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'
    END = '\033[0m'

# %% [markdown]
# ## Create instrance of DL Profile and load the darshan file

# %%
from src.vanidl import VaniDL
profile = VaniDL()

# %%
DATAPATH_INCLUDES = []
status = profile.Load("/home/dhari/darshan-logs/benchmark/ffn/ffn_run2_p8.darshan", data_paths_include=DATAPATH_INCLUDES)
if status:
    print("Darshan Trace loaded Successfully!")
else:
    print("Darshan Trace load Failed!")
    print(profile._error_str())
# Out:
# [============================================================] 100.0% 1198 of 1198 Parsing DXT File
# [============================================================] 100.0% 3855 of 3855 Parsing Darshan File
# Darshan Trace loaded Successfully!

# %% [markdown]
# ## Use Profile object to analyze the darshan I/O trace.

# %% [markdown]
# ### Verify if object works
#
# The GetDXTAsDF() function enables users to perform analysis

# %%
pd.set_option('display.max_colwidth', -1)
df = profile.GetDXTAsDF()
pp.pprint("Files used in the application")
pp.pprint(df['Filename'].unique().tolist())
# Out:
# 'Files used in the application'
# ['/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5']

# %% [markdown]
# ### Collect the summary of the Application

# %%
summary = profile.GetSummary()
print("\n")
print(color.BOLD + "Data Access Summary (from Darshan):"+ color.END)
print("Total Job time\t\t\t:\t{:0.2f} seconds".format(summary['job_time']))
#FIXME: calculate time per rank and then take max across it.
print("Time spent in I/O\t\t:\t{:0.2f} seconds".format(summary['total_io_time']))
print("% Time spent in I/O\t\t:\t{:0.2f}%".format(float(summary['total_io_time'])*100/summary['job_time']))
print("Total Data Accessed\t\t:\t{:0.2f} GB".format(float(summary['total_io_bytes'])/1024.0/1024.0/1024.0))
print("Data Access Modules used\t:\t{}".format(summary['io_interface_used']))
print("Data Operations\t\t\t:\t{}".format(summary['io_operations_used']))
print("# of files used\t\t\t:\t{}".format(len(summary['files_used'])))
print("# of MPI Ranks\t\t\t:\t{:0.0f} ranks".format(summary['num_ranks']))
      
print(color.UNDERLINE + "Data Transfer size:"+ color.END)
print("\tMin,Max\t\t\t:\t{:0.0f} bytes and {:0.0f} bytes".format(summary['data_transfer_size']['min'],summary['data_transfer_size']['max']))
print("\tAverage\t\t\t:\t{:0.0f} bytes".format(summary['data_transfer_size']['mean']))
print("\tMedian\t\t\t:\t{:0.0f} bytes".format(summary['data_transfer_size']['median']))
      
print(color.UNDERLINE + "Data Transfer bandwidth: (per rank)"+ color.END)
print("\tMin,Max\t\t\t:\t{:0.0f} B/s and {:0.0f} MB/s".format(summary['data_transfer_bandwidth']['min'],summary['data_transfer_bandwidth']['max']/1024.0/1024.0))
print("\tAverage\t\t\t:\t{:0.0f} MB/s".format(summary['data_transfer_bandwidth']['mean']/1024.0/1024.0))
print("\tMedian\t\t\t:\t{:0.0f} MB/s".format(summary['data_transfer_bandwidth']['median']/1024.0/1024.0))
      
print(color.UNDERLINE + "Access Pattern:"+ color.END)
print("\tSequential\t\t:\t{:0.2f}%".format(float(summary['access_pattern']['sequential'])))
print("\tConsecutive\t\t:\t{:0.2f}%".format(float(summary['access_pattern']['consecutive'])))
#An I/O op issued at an offset greater than where the previous I/O op ended.
#An I/O op issued at the offset immediately after the end of the previous I/O

print("\n")
print(color.BOLD + "Files Summary:"+ color.END)
print("File Types\t\t\t:\t{}".format(summary['file_used_summary']['types']))
print(color.UNDERLINE + "Dataset Size:"+ color.END)
print("\tTotal\t\t\t:\t{:0.3f} GB".format(float(summary['file_used_summary']['size']['total'])/1024.0/1024.0/1024.0))
print("\tMin,Max\t\t\t:\t{:0.3f} GB and {:0.3f} GB".format(float(summary['file_used_summary']['size']['min'])/1024.0/1024.0/1024.0,float(summary['file_used_summary']['size']['max'])/1024.0/1024.0/1024.0))
print("\tAverage\t\t\t:\t{:0.3f} GB".format(float(summary['file_used_summary']['size']['mean'])/1024.0/1024.0/1024.0))
# Out:
# Data Access Summary (from Darshan):
# Total Job time			:	9.00 seconds
# Time spent in I/O		:	0.21 seconds
# % Time spent in I/O		:	2.30%
# Total Data Accessed		:	0.00 GB
# Data Access Modules used	:	['X_POSIX']
# Data Operations			:	['read']
# # of files used			:	1
# # of MPI Ranks			:	8 ranks
# Data Transfer size:
# 	Min,Max			:	8 bytes and 544 bytes
# 	Average			:	314 bytes
# 	Median			:	420 bytes
# Data Transfer bandwidth: (per rank)
# 	Min,Max			:	43 B/s and 5 MB/s
# 	Average			:	1 MB/s
# 	Median			:	0 MB/s
# Access Pattern:
# 	Sequential		:	50.00%
# 	Consecutive		:	25.00%
#
#
# Files Summary:
# File Types			:	['h5']
# Dataset Size:
# 	Total			:	10.500 GB
# 	Min,Max			:	0.000 GB and 10.500 GB
# 	Average			:	0.256 GB

# %%
pp.pprint("Job time : {} seconds".format(profile.GetJobTime()))
# Out:
# 'Job time : 9.0 seconds'

# %%
pp.pprint("Time spent by application on I/O: {} seconds".format(profile.GetIOTime()))
# Out:
# 'Time spent by application on I/O: 0.20722499999999922 seconds'

# %% [markdown]
# ### I/O time spent on each file

# %%
for file in df['Filename'].unique():
    print("I/O time for file {}: {:0.2f} seconds".format(file,profile.GetIOTime(filepath=file)))
# Out:
# I/O time for file /projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5: 0.21 seconds

# %% [markdown]
# ### I/O Time spent per rank

# %%
for rank in df['Rank'].unique()[:16]:
    print("I/O time for rank {}: {:0.2f} seconds".format(rank,profile.GetIOTime(rank=rank)))
# Out:
# I/O time for rank 0: 0.21 seconds
# I/O time for rank 1: 0.21 seconds
# I/O time for rank 2: 0.21 seconds
# I/O time for rank 3: 0.20 seconds
# I/O time for rank 4: 0.21 seconds
# I/O time for rank 5: 0.21 seconds
# I/O time for rank 6: 0.21 seconds
# I/O time for rank 7: 0.21 seconds

# %%
"Total I/O performed by application: {:0.2f} GB".format(float(profile.GetIOSize())/1024.0/1024.0/1024.0)
# Out:
# 'Total I/O performed by application: 0.00 GB'

# %% [markdown]
# ### I/O performed on each file

# %%
for file in df['Filename'].unique()[:16]:
    print("I/O performed on file {}: {:0.2f} MB".format(file,float(profile.GetIOSize(filepath=file))/1024.0/1024.0))
# Out:
# I/O performed on file /projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5: 0.04 MB

# %%
for rank in df['Rank'].unique()[:16]:
    print("I/O performed by rank {}: {:0.2f} MB".format(rank, float(profile.GetIOSize(rank=rank))/1024.0/1024.0))
# Out:
# I/O performed by rank 0: 0.00 MB
# I/O performed by rank 1: 0.00 MB
# I/O performed by rank 2: 0.00 MB
# I/O performed by rank 3: 0.00 MB
# I/O performed by rank 4: 0.00 MB
# I/O performed by rank 5: 0.00 MB
# I/O performed by rank 6: 0.00 MB
# I/O performed by rank 7: 0.00 MB

# %%
sizes = profile.GetFileSizes()
for key in sizes:
    sizes[key] = sizes[key]/1024.0/1024.0
print("Size of dataset (MB)")
pp.pprint(sizes)
# Out:
# Size of dataset (MB)
# {'img_0_of_1': 10752.33708190918,
#  'nid03824.input_pipeline': 0.0016412734985351562,
#  'nid03824.kernel_stats': 0.0,
#  'nid03824.overview_page': 0.0025396347045898438,
#  'nid03824.tensorflow_stats': 0.0006504058837890625,
#  'nid03824.trace.json': 0.0011854171752929688,
#  'nid03825.input_pipeline': 0.0016412734985351562,
#  'nid03825.kernel_stats': 0.0,
#  'nid03825.overview_page': 0.0025396347045898438,
#  'nid03825.tensorflow_stats': 0.0006504058837890625,
#  'nid03825.trace.json': 0.001201629638671875,
#  'nid03826.input_pipeline': 0.0016412734985351562,
#  'nid03826.kernel_stats': 0.0,
#  'nid03826.overview_page': 0.0025396347045898438,
#  'nid03826.tensorflow_stats': 0.0006504058837890625,
#  'nid03826.trace.json': 0.0011920928955078125,
#  'nid03827.input_pipeline': 0.0016412734985351562,
#  'nid03827.kernel_stats': 0.0,
#  'nid03827.overview_page': 0.0025396347045898438,
#  'nid03827.tensorflow_stats': 0.0006504058837890625,
#  'nid03827.trace.json': 0.00115966796875,
#  'nid03828.input_pipeline': 0.0016412734985351562,
#  'nid03828.kernel_stats': 0.0,
#  'nid03828.overview_page': 0.0025396347045898438,
#  'nid03828.tensorflow_stats': 0.0006504058837890625,
#  'nid03828.trace.json': 0.0012006759643554688,
#  'nid03829.input_pipeline': 0.0016412734985351562,
#  'nid03829.kernel_stats': 0.0,
#  'nid03829.overview_page': 0.0025396347045898438,
#  'nid03829.tensorflow_stats': 0.0006504058837890625,
#  'nid03829.trace.json': 0.0012063980102539062,
#  'nid03832.input_pipeline': 0.0016412734985351562,
#  'nid03832.kernel_stats': 0.0,
#  'nid03832.overview_page': 0.0025396347045898438,
#  'nid03832.tensorflow_stats': 0.0006504058837890625,
#  'nid03832.trace.json': 0.0011568069458007812,
#  'nid03837.input_pipeline': 0.0016412734985351562,
#  'nid03837.kernel_stats': 0.0,
#  'nid03837.overview_page': 0.0025396347045898438,
#  'nid03837.tensorflow_stats': 0.0006504058837890625,
#  'nid03837.trace.json': 0.0012083053588867188}

# %% [markdown]
# ### How application access data over time.

# %%
tl = profile.CreateIOTimeline(time_step=0.001)
plt.figure(figsize=(10,4))
plt.xlabel("Timeline (ms)")
plt.ylabel("# of Operations (ms)")
plt.grid()
plt.plot(tl['time_step'], tl['operation_count']);
# Out:
# [============================================================] 100.0% 128 of 128 Creating Timeline

# %%
plt.figure(figsize=(20,4))
plt.grid()
plt.plot(tl['time_step'], tl['io_bytes']);

# %% [markdown]
# ### How files are accessed over the duration of the Job.

# %%
for file in df['Filename'].unique():
    tl = profile.CreateIOTimeline(filepath=file, time_step=0.001)
    tl.plot(x='time_step',y='operation_count', title=file)
    plt.show()
# Out:
# [============================================================] 100.0% 128 of 128 Creating Timeline

# %% [markdown]
# ### Show how each file is accessed by each rank.

# %%
for rank in df['Rank'].unique()[:16]:
    tl = profile.CreateIOTimeline(rank=rank, time_step=0.001)
    tl.plot(x='time_step',y='operation_count', title=rank)
    plt.show()
# Out:
# [============================================================] 100.0% 16 of 16 Creating Timeline
# [============================================================] 100.0% 16 of 16 Creating Timeline
# [============================================================] 100.0% 16 of 16 Creating Timeline
# [============================================================] 100.0% 16 of 16 Creating Timeline
# [============================================================] 100.0% 16 of 16 Creating Timeline
# [============================================================] 100.0% 16 of 16 Creating Timeline
# [============================================================] 100.0% 16 of 16 Creating Timeline
# [============================================================] 100.0% 16 of 16 Creating Timeline

# %% [markdown]
# ### Data Transfer Size distribution within the application

# %%
request_df = profile.GetIORequestDistribution()
df['Length'].plot(kind='hist', figsize=(5, 3),bins=1000);
plt.xlabel("Transfer Size (bytes)")
# Out:
# Text(0.5, 0, 'Transfer Size (bytes)')

# %%
for file in df['Filename'].unique():
    #tl = profile.GetIORequestDistribution(filepath=file, bins=50)
    tl = df[df["Filename"].eq(file)]
    tl['Length'].plot(kind='hist', figsize=(5, 3),bins=50);
    plt.xlabel("Transfer Size (bytes)")
    plt.title(file)
    plt.show()

# %% [markdown]
# ### Data Transfer Sizes per Rank

# %%
for rank in df['Rank'].unique()[:16]:
    tl = profile.GetIORequestDistribution(rank=rank)
    tl.plot(kind='bar', figsize=(10, 4), title=rank)
    plt.show()

# %% [markdown]
# ### File summary of each file accessed by the Application

# %%
pp = pprint.PrettyPrinter(indent=1)
for file in df['Filename'].unique():
    if 'h5' in file:
        pp.pprint(profile.GetFileSummary(file,ext='h5'))
    else:
        pp.pprint(profile.GetFileSummary(file,ext='tfrecord',tf_record_features=dict(
                                        center=tf.io.FixedLenFeature(shape=[1, 3], dtype=tf.int64),
                                        label_volume_name=tf.io.FixedLenFeature(shape=[1], dtype=tf.string),)
                                        ))
# Out:
# {'ext': 'h5',
#  'filename': 'img_0_of_1',
#  'io_size': 40192,
#  'io_time': 0.03180000000000001,
#  'path': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#  'size': 134252544,
#  'special': {'keys': [{'name': 'labels',
#                        'obj': <HDF5 dataset "labels": shape (4096,), type "<i8">,
#                        'shape': (4096,),
#                        'size': 4096,
#                        'type': 'dataset'},
#                       {'name': 'records',
#                        'obj': <HDF5 dataset "records": shape (4096, 64, 64), type "<f8">,
#                        'shape': (4096, 64, 64),
#                        'size': 16777216,
#                        'type': 'dataset'}],
#              'name': 'img_0_of_1',
#              'type': 'group'}}

# %%
profile.CreateChromeTimeline(location="/home/dhari", filename="ffn_run1_p128_io.json")
# Out:
# [============================================================] 100.0% 128 of 128 Creating DXT Timeline
#
# [============================================================] 100.0% 1 of 1 Creating DXT Timeline
# {'traceEvents': [{'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 325600,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.3256,
#     'End': 0.3438}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 325700,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.3257,
#     'End': 0.3439}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 325800,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.3258,
#     'End': 0.3443}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 326000,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.326,
#     'End': 0.3439}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 326100,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.3261,
#     'End': 0.3445}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 326200,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.3262,
#     'End': 0.3443}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 326200,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.3262,
#     'End': 0.3442}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 326700,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.3267,
#     'End': 0.3446}},
#   {'ph': 'E',
#    'ts': 343800,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.3256,
#     'End': 0.3438}},
#   {'ph': 'E',
#    'ts': 343900,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.326,
#     'End': 0.3439}},
#   {'ph': 'E',
#    'ts': 343900,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.3257,
#     'End': 0.3439}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 344000,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.344,
#     'End': 0.344}},
#   {'ph': 'E',
#    'ts': 344000,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.344,
#     'End': 0.344}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 344000,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.344,
#     'End': 0.344}},
#   {'ph': 'E',
#    'ts': 344000,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.344,
#     'End': 0.344}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 344100,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.3441,
#     'End': 0.3441}},
#   {'ph': 'E',
#    'ts': 344100,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.3441,
#     'End': 0.3441}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 344100,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.3441,
#     'End': 0.3441}},
#   {'ph': 'E',
#    'ts': 344100,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.3441,
#     'End': 0.3441}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 344100,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.3441,
#     'End': 0.3441}},
#   {'ph': 'E',
#    'ts': 344100,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.3441,
#     'End': 0.3441}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 344100,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.3441,
#     'End': 0.3441}},
#   {'ph': 'E',
#    'ts': 344100,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.3441,
#     'End': 0.3441}},
#   {'ph': 'E',
#    'ts': 344200,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.3262,
#     'End': 0.3442}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 344200,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.3442,
#     'End': 0.3442}},
#   {'ph': 'E',
#    'ts': 344200,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.3442,
#     'End': 0.3442}},
#   {'ph': 'E',
#    'ts': 344300,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.3262,
#     'End': 0.3443}},
#   {'ph': 'E',
#    'ts': 344300,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.3258,
#     'End': 0.3443}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 344300,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.3443,
#     'End': 0.3443}},
#   {'ph': 'E',
#    'ts': 344300,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.3443,
#     'End': 0.3443}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 344400,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.3444,
#     'End': 0.3444}},
#   {'ph': 'E',
#    'ts': 344400,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.3444,
#     'End': 0.3444}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 344400,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.3444,
#     'End': 0.3444}},
#   {'ph': 'E',
#    'ts': 344400,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.3444,
#     'End': 0.3444}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 344400,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.3444,
#     'End': 0.3444}},
#   {'ph': 'E',
#    'ts': 344400,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.3444,
#     'End': 0.3444}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 344400,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.3444,
#     'End': 0.3444}},
#   {'ph': 'E',
#    'ts': 344400,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.3444,
#     'End': 0.3444}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 344400,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.3444,
#     'End': 0.3444}},
#   {'ph': 'E',
#    'ts': 344400,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.3444,
#     'End': 0.3444}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 344400,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.3444,
#     'End': 0.3444}},
#   {'ph': 'E',
#    'ts': 344400,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.3444,
#     'End': 0.3444}},
#   {'ph': 'E',
#    'ts': 344500,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.3261,
#     'End': 0.3445}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 344500,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.3445,
#     'End': 0.3445}},
#   {'ph': 'E',
#    'ts': 344500,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.3445,
#     'End': 0.3445}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 344600,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.3446,
#     'End': 0.3447}},
#   {'ph': 'E',
#    'ts': 344600,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.3267,
#     'End': 0.3446}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 344600,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.3446,
#     'End': 0.3446}},
#   {'ph': 'E',
#    'ts': 344600,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.3446,
#     'End': 0.3446}},
#   {'ph': 'E',
#    'ts': 344700,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.3446,
#     'End': 0.3447}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 344700,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.3447,
#     'End': 0.3447}},
#   {'ph': 'E',
#    'ts': 344700,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.3447,
#     'End': 0.3447}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 344700,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.3447,
#     'End': 0.3447}},
#   {'ph': 'E',
#    'ts': 344700,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.3447,
#     'End': 0.3447}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 344700,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.3447,
#     'End': 0.3447}},
#   {'ph': 'E',
#    'ts': 344700,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.3447,
#     'End': 0.3447}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 344700,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.3447,
#     'End': 0.3447}},
#   {'ph': 'E',
#    'ts': 344700,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.3447,
#     'End': 0.3447}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 344800,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.3448,
#     'End': 0.3448}},
#   {'ph': 'E',
#    'ts': 344800,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.3448,
#     'End': 0.3448}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 344900,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.3449,
#     'End': 0.3449}},
#   {'ph': 'E',
#    'ts': 344900,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.3449,
#     'End': 0.3449}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 345000,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.345,
#     'End': 0.345}},
#   {'ph': 'E',
#    'ts': 345000,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.345,
#     'End': 0.345}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 349100,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.3491,
#     'End': 0.3491}},
#   {'ph': 'E',
#    'ts': 349100,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.3491,
#     'End': 0.3491}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 349200,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.3492,
#     'End': 0.3492}},
#   {'ph': 'E',
#    'ts': 349200,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.3492,
#     'End': 0.3492}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 349200,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 1072,
#     'Length': 328,
#     'Start': 0.3492,
#     'End': 0.3492}},
#   {'ph': 'E',
#    'ts': 349200,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 1072,
#     'Length': 328,
#     'Start': 0.3492,
#     'End': 0.3492}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 349300,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 800,
#     'Length': 512,
#     'Start': 0.3493,
#     'End': 0.3493}},
#   {'ph': 'E',
#    'ts': 349300,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 800,
#     'Length': 512,
#     'Start': 0.3493,
#     'End': 0.3493}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 349600,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.3496,
#     'End': 0.3496}},
#   {'ph': 'E',
#    'ts': 349600,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.3496,
#     'End': 0.3496}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 349600,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.3496,
#     'End': 0.3497}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 349700,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.3497,
#     'End': 0.3497}},
#   {'ph': 'E',
#    'ts': 349700,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.3497,
#     'End': 0.3497}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 349700,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 1072,
#     'Length': 328,
#     'Start': 0.3497,
#     'End': 0.3497}},
#   {'ph': 'E',
#    'ts': 349700,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 1072,
#     'Length': 328,
#     'Start': 0.3497,
#     'End': 0.3497}},
#   {'ph': 'E',
#    'ts': 349700,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.3496,
#     'End': 0.3497}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 349700,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.3497,
#     'End': 0.3498}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 349800,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 800,
#     'Length': 512,
#     'Start': 0.3498,
#     'End': 0.3498}},
#   {'ph': 'E',
#    'ts': 349800,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 800,
#     'Length': 512,
#     'Start': 0.3498,
#     'End': 0.3498}},
#   {'ph': 'E',
#    'ts': 349800,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.3497,
#     'End': 0.3498}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 349800,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 1072,
#     'Length': 328,
#     'Start': 0.3498,
#     'End': 0.3498}},
#   {'ph': 'E',
#    'ts': 349800,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 1072,
#     'Length': 328,
#     'Start': 0.3498,
#     'End': 0.3498}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 349900,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.3499,
#     'End': 0.3499}},
#   {'ph': 'E',
#    'ts': 349900,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.3499,
#     'End': 0.3499}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 349900,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.3499,
#     'End': 0.3499}},
#   {'ph': 'E',
#    'ts': 349900,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.3499,
#     'End': 0.3499}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 349900,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 800,
#     'Length': 512,
#     'Start': 0.3499,
#     'End': 0.3499}},
#   {'ph': 'E',
#    'ts': 349900,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 800,
#     'Length': 512,
#     'Start': 0.3499,
#     'End': 0.3499}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 350000,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.35,
#     'End': 0.3501}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 350000,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.35,
#     'End': 0.35}},
#   {'ph': 'E',
#    'ts': 350000,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.35,
#     'End': 0.35}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 350000,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 1072,
#     'Length': 328,
#     'Start': 0.35,
#     'End': 0.35}},
#   {'ph': 'E',
#    'ts': 350000,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 1072,
#     'Length': 328,
#     'Start': 0.35,
#     'End': 0.35}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 350100,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.3501,
#     'End': 0.3501}},
#   {'ph': 'E',
#    'ts': 350100,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.3501,
#     'End': 0.3501}},
#   {'ph': 'E',
#    'ts': 350100,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.35,
#     'End': 0.3501}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 350100,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 1072,
#     'Length': 328,
#     'Start': 0.3501,
#     'End': 0.3501}},
#   {'ph': 'E',
#    'ts': 350100,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 1072,
#     'Length': 328,
#     'Start': 0.3501,
#     'End': 0.3501}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 350100,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 800,
#     'Length': 512,
#     'Start': 0.3501,
#     'End': 0.3501}},
#   {'ph': 'E',
#    'ts': 350100,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 800,
#     'Length': 512,
#     'Start': 0.3501,
#     'End': 0.3501}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 350200,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.3502,
#     'End': 0.3502}},
#   {'ph': 'E',
#    'ts': 350200,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.3502,
#     'End': 0.3502}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 350200,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.3502,
#     'End': 0.3502}},
#   {'ph': 'E',
#    'ts': 350200,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.3502,
#     'End': 0.3502}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 350200,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 800,
#     'Length': 512,
#     'Start': 0.3502,
#     'End': 0.3502}},
#   {'ph': 'E',
#    'ts': 350200,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 800,
#     'Length': 512,
#     'Start': 0.3502,
#     'End': 0.3502}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 350300,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.3503,
#     'End': 0.3503}},
#   {'ph': 'E',
#    'ts': 350300,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.3503,
#     'End': 0.3503}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 350300,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 1072,
#     'Length': 328,
#     'Start': 0.3503,
#     'End': 0.3503}},
#   {'ph': 'E',
#    'ts': 350300,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 1072,
#     'Length': 328,
#     'Start': 0.3503,
#     'End': 0.3503}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 350300,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 1072,
#     'Length': 328,
#     'Start': 0.3503,
#     'End': 0.3503}},
#   {'ph': 'E',
#    'ts': 350300,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 1072,
#     'Length': 328,
#     'Start': 0.3503,
#     'End': 0.3503}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 350400,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 800,
#     'Length': 512,
#     'Start': 0.3504,
#     'End': 0.3504}},
#   {'ph': 'E',
#    'ts': 350400,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 800,
#     'Length': 512,
#     'Start': 0.3504,
#     'End': 0.3504}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 350400,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 800,
#     'Length': 512,
#     'Start': 0.3504,
#     'End': 0.3504}},
#   {'ph': 'E',
#    'ts': 350400,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 800,
#     'Length': 512,
#     'Start': 0.3504,
#     'End': 0.3504}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 350700,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.3507,
#     'End': 0.3507}},
#   {'ph': 'E',
#    'ts': 350700,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.3507,
#     'End': 0.3507}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 350800,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.3508,
#     'End': 0.3508}},
#   {'ph': 'E',
#    'ts': 350800,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.3508,
#     'End': 0.3508}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 350800,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 1072,
#     'Length': 328,
#     'Start': 0.3508,
#     'End': 0.3509}},
#   {'ph': 'E',
#    'ts': 350900,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 1072,
#     'Length': 328,
#     'Start': 0.3508,
#     'End': 0.3509}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 350900,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 800,
#     'Length': 512,
#     'Start': 0.3509,
#     'End': 0.3509}},
#   {'ph': 'E',
#    'ts': 350900,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 800,
#     'Length': 512,
#     'Start': 0.3509,
#     'End': 0.3509}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 373200,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 8,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.3732,
#     'End': 0.3732}},
#   {'ph': 'E',
#    'ts': 373200,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 8,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.3732,
#     'End': 0.3732}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 373300,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 8,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.3733,
#     'End': 0.3733}},
#   {'ph': 'E',
#    'ts': 373300,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 8,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.3733,
#     'End': 0.3733}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 373300,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 9,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.3733,
#     'End': 0.3733}},
#   {'ph': 'E',
#    'ts': 373300,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 9,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.3733,
#     'End': 0.3733}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 373300,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 10,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.3733,
#     'End': 0.3733}},
#   {'ph': 'E',
#    'ts': 373300,
#    'pid': 6,
#    'tid': 0,
# ...
#    'ts': 374500,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 14,
#     'Offset': 1072,
#     'Length': 328,
#     'Start': 0.3745,
#     'End': 0.3745}},
#   {'ph': 'E',
#    'ts': 374500,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 14,
#     'Offset': 1072,
#     'Length': 328,
#     'Start': 0.3745,
#     'End': 0.3745}},
#   {'ph': 'E',
#    'ts': 374600,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 9,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.3745,
#     'End': 0.3746}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 374600,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 10,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.3746,
#     'End': 0.3746}},
#   {'ph': 'E',
#    'ts': 374600,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 10,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.3746,
#     'End': 0.3746}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 374600,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 11,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.3746,
#     'End': 0.3746}},
#   {'ph': 'E',
#    'ts': 374600,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 11,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.3746,
#     'End': 0.3746}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 374600,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 14,
#     'Offset': 1072,
#     'Length': 328,
#     'Start': 0.3746,
#     'End': 0.3746}},
#   {'ph': 'E',
#    'ts': 374600,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 14,
#     'Offset': 1072,
#     'Length': 328,
#     'Start': 0.3746,
#     'End': 0.3746}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 374600,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 15,
#     'Offset': 800,
#     'Length': 512,
#     'Start': 0.3746,
#     'End': 0.3746}},
#   {'ph': 'E',
#    'ts': 374600,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 15,
#     'Offset': 800,
#     'Length': 512,
#     'Start': 0.3746,
#     'End': 0.3746}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 374600,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 12,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.3746,
#     'End': 0.3746}},
#   {'ph': 'E',
#    'ts': 374600,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 12,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.3746,
#     'End': 0.3746}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 374600,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 13,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.3746,
#     'End': 0.3746}},
#   {'ph': 'E',
#    'ts': 374600,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 13,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.3746,
#     'End': 0.3746}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 374600,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 14,
#     'Offset': 1072,
#     'Length': 328,
#     'Start': 0.3746,
#     'End': 0.3746}},
#   {'ph': 'E',
#    'ts': 374600,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 14,
#     'Offset': 1072,
#     'Length': 328,
#     'Start': 0.3746,
#     'End': 0.3746}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 374600,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 15,
#     'Offset': 800,
#     'Length': 512,
#     'Start': 0.3746,
#     'End': 0.3746}},
#   {'ph': 'E',
#    'ts': 374600,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 15,
#     'Offset': 800,
#     'Length': 512,
#     'Start': 0.3746,
#     'End': 0.3746}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 374700,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 12,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.3747,
#     'End': 0.3747}},
#   {'ph': 'E',
#    'ts': 374700,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 12,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.3747,
#     'End': 0.3747}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 374700,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 12,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.3747,
#     'End': 0.3747}},
#   {'ph': 'E',
#    'ts': 374700,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 12,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.3747,
#     'End': 0.3747}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 374700,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 13,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.3747,
#     'End': 0.3747}},
#   {'ph': 'E',
#    'ts': 374700,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 13,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.3747,
#     'End': 0.3747}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 374700,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 14,
#     'Offset': 1072,
#     'Length': 328,
#     'Start': 0.3747,
#     'End': 0.3747}},
#   {'ph': 'E',
#    'ts': 374700,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 14,
#     'Offset': 1072,
#     'Length': 328,
#     'Start': 0.3747,
#     'End': 0.3747}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 374700,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 15,
#     'Offset': 800,
#     'Length': 512,
#     'Start': 0.3747,
#     'End': 0.3747}},
#   {'ph': 'E',
#    'ts': 374700,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 15,
#     'Offset': 800,
#     'Length': 512,
#     'Start': 0.3747,
#     'End': 0.3747}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 374800,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 13,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.3748,
#     'End': 0.3748}},
#   {'ph': 'E',
#    'ts': 374800,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 13,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.3748,
#     'End': 0.3748}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 374800,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 14,
#     'Offset': 1072,
#     'Length': 328,
#     'Start': 0.3748,
#     'End': 0.3748}},
#   {'ph': 'E',
#    'ts': 374800,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 14,
#     'Offset': 1072,
#     'Length': 328,
#     'Start': 0.3748,
#     'End': 0.3748}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 374800,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 15,
#     'Offset': 800,
#     'Length': 512,
#     'Start': 0.3748,
#     'End': 0.3749}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 374800,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 15,
#     'Offset': 800,
#     'Length': 512,
#     'Start': 0.3748,
#     'End': 0.3748}},
#   {'ph': 'E',
#    'ts': 374800,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 15,
#     'Offset': 800,
#     'Length': 512,
#     'Start': 0.3748,
#     'End': 0.3748}},
#   {'ph': 'E',
#    'ts': 374900,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 15,
#     'Offset': 800,
#     'Length': 512,
#     'Start': 0.3748,
#     'End': 0.3749}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 375400,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 12,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.3754,
#     'End': 0.3754}},
#   {'ph': 'E',
#    'ts': 375400,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 12,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.3754,
#     'End': 0.3754}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 375500,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 13,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.3755,
#     'End': 0.3755}},
#   {'ph': 'E',
#    'ts': 375500,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 13,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.3755,
#     'End': 0.3755}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 375500,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 14,
#     'Offset': 1072,
#     'Length': 328,
#     'Start': 0.3755,
#     'End': 0.3755}},
#   {'ph': 'E',
#    'ts': 375500,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 14,
#     'Offset': 1072,
#     'Length': 328,
#     'Start': 0.3755,
#     'End': 0.3755}},
#   {'name': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 375500,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 15,
#     'Offset': 800,
#     'Length': 512,
#     'Start': 0.3755,
#     'End': 0.3755}},
#   {'ph': 'E',
#    'ts': 375500,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/projects/datascience/dhari/dlio_datasets/ffn/img_0_of_1.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 15,
#     'Offset': 800,
#     'Length': 512,
#     'Start': 0.3755,
#     'End': 0.3755}}],
#  'displayTimeUnit': 'ms',
#  'systemTraceEvents': 'SystemTraceData',
#  'otherData': {'version': 'VaniDL v1.0'},
#  'stackFrames': {},
#  'samples': []}

# %% [markdown]
# ###
