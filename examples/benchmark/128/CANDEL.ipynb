# %% [markdown]
# # DLProfile Example using CANDEL Application

# %% [markdown]
# ## Set imports and neccessary environment variables

# %%
import pathlib
import os
import sys
import matplotlib.pyplot as plt
import warnings
import pprint
import pandas

# %%
VANIDL_DIR="{}".format(pathlib.Path(os.getcwd()).parent.absolute())
sys.path.insert(0, VANIDL_DIR)
warnings.filterwarnings('ignore')

# %%
os.environ["DARSHAN_DIR"] = "/soft/perftools/darshan/darshan-3.1.8"
os.environ["VANIDL_DIR"] = VANIDL_DIR

# %% [markdown]
# #### Formatting

# %%
pp = pprint.PrettyPrinter(indent=1)
class color:
    PURPLE = '\033[95m'
    CYAN = '\033[96m'
    DARKCYAN = '\033[36m'
    BLUE = '\033[94m'
    GREEN = '\033[92m'
    YELLOW = '\033[93m'
    RED = '\033[91m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'
    END = '\033[0m'

# %% [markdown]
# ## Create instrance of DL Profile and load the darshan file

# %%
from src.vanidl import VaniDL
profile = VaniDL()

# %%
#import shutil
#shutil.rmtree('/tmp/temp_analysis')

# %%
DATAPATH_INCLUDES = []
status = profile.Load("/home/dhari/darshan-logs/apps/candel/candel_run1_n128.darshan", data_paths_include=DATAPATH_INCLUDES)
if status:
    print("Darshan Trace loaded Successfully!")
else:
    print("Darshan Trace load Failed!")
    print(profile._error_str())
# Out:
# [============================================================] 100.0% 395211 of 395211 Parsing DXT File
# [============================================================] 100.0% 12929 of 12929 Parsing Darshan File
# Darshan Trace loaded Successfully!

# %% [markdown]
# ## Use Profile object to analyze the darshan I/O trace.

# %% [markdown]
# ### Verify if object works
#
# The GetDXTAsDF() function enables users to perform analysis

# %%
df = profile.GetDXTAsDF()
pp.pprint("Files used in the application")
pp.pprint(df['Filename'].unique().tolist())
# Out:
# 'Files used in the application'
# ['/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#  '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#  '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_test2.csv',
#  '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/run.RUN000.json']

# %% [markdown]
# ### Collect the summary of the Application

# %%
summary = profile.GetSummary()
print("\n")
print(color.BOLD + "Data Access Summary (from Darshan):"+ color.END)
print("Total Job time\t\t\t:\t{:0.2f} seconds".format(summary['job_time']))
#FIXME: calculate time per rank and then take max across it.
print("Time spent in I/O\t\t:\t{:0.2f} seconds".format(summary['total_io_time']))
print("% Time spent in I/O\t\t:\t{:0.2f}%".format(float(summary['total_io_time'])*100/summary['job_time']))
print("Total Data Accessed\t\t:\t{:0.2f} GB".format(float(summary['total_io_bytes'])/1024.0/1024.0/1024.0))
print("Data Access Modules used\t:\t{}".format(summary['io_interface_used']))
print("Data Operations\t\t\t:\t{}".format(summary['io_operations_used']))
print("# of files used\t\t\t:\t{}".format(len(summary['files_used'])))
print("# of MPI Ranks\t\t\t:\t{:0.0f} ranks".format(summary['num_ranks']))
      
print(color.UNDERLINE + "Data Transfer size:"+ color.END)
print("\tMin,Max\t\t\t:\t{:0.0f} bytes and {:0.0f} bytes".format(summary['data_transfer_size']['min'],summary['data_transfer_size']['max']))
print("\tAverage\t\t\t:\t{:0.0f} bytes".format(summary['data_transfer_size']['mean']))
print("\tMedian\t\t\t:\t{:0.0f} bytes".format(summary['data_transfer_size']['median']))
      
print(color.UNDERLINE + "Data Transfer bandwidth: (per rank)"+ color.END)
print("\tMin,Max\t\t\t:\t{:0.0f} B/s and {:0.0f} MB/s".format(summary['data_transfer_bandwidth']['min'],summary['data_transfer_bandwidth']['max']/1024.0/1024.0))
print("\tAverage\t\t\t:\t{:0.0f} MB/s".format(summary['data_transfer_bandwidth']['mean']/1024.0/1024.0))
print("\tMedian\t\t\t:\t{:0.0f} MB/s".format(summary['data_transfer_bandwidth']['median']/1024.0/1024.0))
      
print(color.UNDERLINE + "Access Pattern:"+ color.END)
print("\tSequential\t\t:\t{:0.2f}%".format(float(summary['access_pattern']['sequential'])))
print("\tConsecutive\t\t:\t{:0.2f}%".format(float(summary['access_pattern']['consecutive'])))
#An I/O op issued at an offset greater than where the previous I/O op ended.
#An I/O op issued at the offset immediately after the end of the previous I/O

print("\n")
print(color.BOLD + "Files Summary:"+ color.END)
print("File Types\t\t\t:\t{}".format(summary['file_used_summary']['types']))
print(color.UNDERLINE + "Dataset Size:"+ color.END)
print("\tTotal\t\t\t:\t{:0.3f} GB".format(float(summary['file_used_summary']['size']['total'])/1024.0/1024.0/1024.0))
print("\tMin,Max\t\t\t:\t{:0.3f} GB and {:0.3f} GB".format(float(summary['file_used_summary']['size']['min'])/1024.0/1024.0/1024.0,float(summary['file_used_summary']['size']['max'])/1024.0/1024.0/1024.0))
print("\tAverage\t\t\t:\t{:0.3f} GB".format(float(summary['file_used_summary']['size']['mean'])/1024.0/1024.0/1024.0))
# Out:
# Data Access Summary (from Darshan):
# Total Job time			:	233.00 seconds
# Time spent in I/O		:	40.30 seconds
# % Time spent in I/O		:	17.30%
# Total Data Accessed		:	93.27 GB
# Data Access Modules used	:	['X_POSIX']
# Data Operations			:	['read' 'write']
# # of files used			:	4
# # of MPI Ranks			:	128 ranks
# Data Transfer size:
# 	Min,Max			:	0 bytes and 262144 bytes
# 	Average			:	261597 bytes
# 	Median			:	262144 bytes
# Data Transfer bandwidth: (per rank)
# 	Min,Max			:	0 B/s and 625 MB/s
# 	Average			:	99 MB/s
# 	Median			:	17 MB/s
# Access Pattern:
# 	Sequential		:	99.90%
# 	Consecutive		:	99.90%
#
#
# Files Summary:
# File Types			:	['txt' 'csv' 'json']
# Dataset Size:
# 	Total			:	0.729 GB
# 	Min,Max			:	0.000 GB and 0.583 GB
# 	Average			:	0.146 GB

# %%
pp.pprint("Job time : {} seconds".format(profile.GetJobTime()))
# Out:
# 'Job time : 233.0 seconds'

# %%
pp.pprint("Time spent by application on I/O: {} seconds".format(profile.GetIOTime()))
# Out:
# 'Time spent by application on I/O: 40.301457031273124 seconds'

# %% [markdown]
# ### I/O time spent on each file

# %%
for file in df['Filename'].unique():
    print("I/O time for file {}: {:0.2f} seconds".format(file,profile.GetIOTime(filepath=file)))
# Out:
# I/O time for file /gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt: 0.02 seconds
# I/O time for file /gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv: 39.81 seconds
# I/O time for file /gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_test2.csv: 0.46 seconds
# I/O time for file /gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/run.RUN000.json: 0.01 seconds

# %% [markdown]
# ### I/O Time spent per rank

# %%
for rank in df['Rank'].unique()[:16]:
    print("I/O time for rank {}: {:0.2f} seconds".format(rank,profile.GetIOTime(rank=rank)))
# Out:
# I/O time for rank 0: 40.38 seconds
# I/O time for rank 1: 40.30 seconds
# I/O time for rank 2: 40.30 seconds
# I/O time for rank 3: 40.37 seconds
# I/O time for rank 4: 40.30 seconds
# I/O time for rank 5: 40.27 seconds
# I/O time for rank 6: 40.31 seconds
# I/O time for rank 7: 40.30 seconds
# I/O time for rank 8: 40.39 seconds
# I/O time for rank 9: 40.32 seconds
# I/O time for rank 10: 40.33 seconds
# I/O time for rank 11: 40.31 seconds
# I/O time for rank 12: 40.36 seconds
# I/O time for rank 13: 40.27 seconds
# I/O time for rank 14: 40.33 seconds
# I/O time for rank 15: 40.29 seconds

# %%
"Total I/O performed by application: {:0.2f} GB".format(float(profile.GetIOSize())/1024.0/1024.0/1024.0)
# Out:
# 'Total I/O performed by application: 93.27 GB'

# %% [markdown]
# ### I/O performed on each file

# %%
for file in df['Filename'].unique():
    print("I/O performed on file {}: {:0.2f} MB".format(file,float(profile.GetIOSize(filepath=file))/1024.0/1024.0))
# Out:
# I/O performed on file /gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt: 0.05 MB
# I/O performed on file /gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv: 76393.52 MB
# I/O performed on file /gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_test2.csv: 19118.18 MB
# I/O performed on file /gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/run.RUN000.json: 0.00 MB

# %%
for rank in df['Rank'].unique()[:16]:
    print("I/O performed by rank {}: {:0.2f} MB".format(rank, float(profile.GetIOSize(rank=rank))/1024.0/1024.0))
# Out:
# I/O performed by rank 0: 746.19 MB
# I/O performed by rank 1: 746.19 MB
# I/O performed by rank 2: 746.19 MB
# I/O performed by rank 3: 746.19 MB
# I/O performed by rank 4: 746.19 MB
# I/O performed by rank 5: 746.19 MB
# I/O performed by rank 6: 746.19 MB
# I/O performed by rank 7: 746.19 MB
# I/O performed by rank 8: 746.19 MB
# I/O performed by rank 9: 746.19 MB
# I/O performed by rank 10: 746.19 MB
# I/O performed by rank 11: 746.19 MB
# I/O performed by rank 12: 746.19 MB
# I/O performed by rank 13: 746.19 MB
# I/O performed by rank 14: 746.19 MB
# I/O performed by rank 15: 746.19 MB

# %%
print("Size of dataset (bytes)")
pp.pprint(profile.GetFileSizes())
# Out:
# Size of dataset (bytes)
# {'nt3_default_model': 397.0,
#  'nt_test2': 156616161.0,
#  'nt_train2': 625815725.0,
#  'run.RUN000': 259278.0,
#  'training': 0.0}

# %% [markdown]
# ### How application access data over time.

# %%
tl = profile.CreateIOTimeline()
plt.figure(figsize=(8,4))
plt.grid()
plt.ylabel("# of operations")
plt.xlabel("Timeline (ms)")
plt.plot(tl['time_step'], tl['operation_count']);
# Out:
# [============================================================] 100.0% 382847 of 382847 Creating Timeline

# %%
plt.figure(figsize=(8,4))
plt.grid()
plt.ylabel("I/O performed (bytes)")
plt.xlabel("Timeline (ms)")
plt.plot(tl['time_step'], tl['io_bytes']);

# %% [markdown]
# ### How files are accessed over the duration of the Job.

# %%
for file in df['Filename'].unique():
    tl = profile.CreateIOTimeline(filepath=file,time_step=0.001)
    tl.plot(x='time_step',y='operation_count', title=file)
    plt.show()
# Out:
# [============================================================] 100.0% 256 of 256 Creating Timeline
# [============================================================] 100.0% 305792 of 305792 Creating Timeline
# [============================================================] 100.0% 76672 of 76672 Creating Timeline
# [============================================================] 100.0% 127 of 127 Creating Timeline

# %% [markdown]
# ### Show how each file is accessed by each rank.

# %%
for rank in df['Rank'].unique()[:16]:
    tl = profile.CreateIOTimeline(rank=rank)
    tl.plot(x='time_step',y='operation_count', title=rank)
    plt.show()
# Out:
# [============================================================] 100.0% 2991 of 2991 Creating Timeline
# [============================================================] 100.0% 2991 of 2991 Creating Timeline
# [============================================================] 100.0% 2991 of 2991 Creating Timeline
# [============================================================] 100.0% 2991 of 2991 Creating Timeline
# [============================================================] 100.0% 2991 of 2991 Creating Timeline
# [============================================================] 100.0% 2991 of 2991 Creating Timeline
# [============================================================] 100.0% 2991 of 2991 Creating Timeline
# [============================================================] 100.0% 2991 of 2991 Creating Timeline
# [============================================================] 100.0% 2991 of 2991 Creating Timeline
# [============================================================] 100.0% 2991 of 2991 Creating Timeline
# [============================================================] 100.0% 2991 of 2991 Creating Timeline
# [============================================================] 100.0% 2991 of 2991 Creating Timeline
# [============================================================] 100.0% 2991 of 2991 Creating Timeline
# [============================================================] 100.0% 2991 of 2991 Creating Timeline
# [============================================================] 100.0% 2991 of 2991 Creating Timeline
# [============================================================] 100.0% 2991 of 2991 Creating Timeline

# %% [markdown]
# ### Data Transfer Size distribution within the application

# %%
request_df = profile.GetIORequestDistribution()
df['Length'].plot(kind='hist', figsize=(5, 3), bins=100);
plt.xlabel("Transfer Size (bytes)")
# Out:
# Text(0.5, 0, 'Transfer Size (bytes)')

# %% [markdown]
# ### Data Transfer Size distribution for each file.

# %%
for file in df['Filename'].unique():
    tl = profile.GetIORequestDistribution(filepath=file)
    tl.plot(kind='bar', figsize=(10, 4), title=file)
    plt.show()

# %% [markdown]
# ### Data Transfer Sizes per Rank

# %%
for rank in df['Rank'].unique()[:16]:
    tl = profile.GetIORequestDistribution(rank=rank)
    tl.plot(kind='bar', figsize=(10, 4), title=rank)
    plt.show()

# %% [markdown]
# ### File summary of each file accessed by the Application

# %%
pp = pprint.PrettyPrinter(indent=1)
for file in df['Filename'].unique():
    pp.pprint(profile.GetFileSummary(file))
# Out:
# {'ext': 'txt',
#  'filename': 'nt3_default_model',
#  'io_size': 50816,
#  'io_time': 0.022338281250000012,
#  'path': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#  'size': 397,
#  'special': {}}
# {'ext': 'csv',
#  'filename': 'nt_train2',
#  'io_size': 80104412800,
#  'io_time': 39.80785156251041,
#  'path': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#  'size': 625815725,
#  'special': {}}
# {'ext': 'csv',
#  'filename': 'nt_test2',
#  'io_size': 20046868608,
#  'io_time': 0.4568414062500423,
#  'path': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_test2.csv',
#  'size': 156616161,
#  'special': {}}
# {'ext': 'json',
#  'filename': 'run.RUN000',
#  'io_size': 1667,
#  'io_time': 0.014539370078741884,
#  'path': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/run.RUN000.json',
#  'size': 259278,
#  'special': {}}

# %%
profile.CreateChromeTimeline(location="/home/dhari/timeline/apps/candel", filename="candel_run1_n128.json")
# Out:
# [============================================================] 100.0% 382847 of 382847 Creating DXT Timeline
# [============================================================] 100.0% 5 of 5 Creating DXT Timeline
# {'traceEvents': [{'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 908400,
#    'pid': 14,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 14,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9084,
#     'End': 0.9374}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 908400,
#    'pid': 39,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 39,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9084,
#     'End': 0.9357}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 908400,
#    'pid': 98,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 98,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9084,
#     'End': 0.9341}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 908600,
#    'pid': 85,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 85,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9086,
#     'End': 0.9355}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 908700,
#    'pid': 53,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 53,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9087,
#     'End': 0.935}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 908700,
#    'pid': 114,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 114,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9087,
#     'End': 0.9373}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 908900,
#    'pid': 80,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 80,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9089,
#     'End': 0.9353}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 908900,
#    'pid': 96,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 96,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9089,
#     'End': 0.9377}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 908900,
#    'pid': 101,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 101,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9089,
#     'End': 0.9368}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 909000,
#    'pid': 23,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 23,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.909,
#     'End': 0.9359}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 909100,
#    'pid': 37,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 37,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9091,
#     'End': 0.9375}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 909200,
#    'pid': 57,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 57,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9092,
#     'End': 0.9373}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 909300,
#    'pid': 73,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 73,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9093,
#     'End': 0.935}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 909300,
#    'pid': 90,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 90,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9093,
#     'End': 0.9325}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 909300,
#    'pid': 111,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 111,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9093,
#     'End': 0.9344}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 909400,
#    'pid': 11,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 11,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9094,
#     'End': 0.9336}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 909400,
#    'pid': 71,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 71,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9094,
#     'End': 0.9329}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 909500,
#    'pid': 66,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 66,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9095,
#     'End': 0.9368}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 909500,
#    'pid': 78,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 78,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9095,
#     'End': 0.9372}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 909600,
#    'pid': 13,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 13,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9096,
#     'End': 0.9358}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 909600,
#    'pid': 67,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 67,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9096,
#     'End': 0.9372}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 909600,
#    'pid': 110,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 110,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9096,
#     'End': 0.9324}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 909700,
#    'pid': 56,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 56,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9097,
#     'End': 0.9368}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 909700,
#    'pid': 58,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 58,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9097,
#     'End': 0.9354}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 909700,
#    'pid': 68,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 68,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9097,
#     'End': 0.9366}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 909800,
#    'pid': 72,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 72,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9098,
#     'End': 0.9357}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 909800,
#    'pid': 123,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 123,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9098,
#     'End': 0.932}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 909900,
#    'pid': 61,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 61,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9099,
#     'End': 0.9367}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 910000,
#    'pid': 79,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 79,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.91,
#     'End': 0.9314}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 910100,
#    'pid': 99,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 99,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9101,
#     'End': 0.9364}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 910100,
#    'pid': 103,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 103,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9101,
#     'End': 0.9374}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 910100,
#    'pid': 109,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 109,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9101,
#     'End': 0.9346}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 910200,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9102,
#     'End': 0.9368}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 910300,
#    'pid': 44,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 44,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9103,
#     'End': 0.9342}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 910500,
#    'pid': 65,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 65,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9105,
#     'End': 0.9324}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 910600,
#    'pid': 100,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 100,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9106,
#     'End': 0.9333}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 910700,
#    'pid': 30,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 30,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9107,
#     'End': 0.9373}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 910700,
#    'pid': 107,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 107,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9107,
#     'End': 0.9363}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 910800,
#    'pid': 35,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 35,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9108,
#     'End': 0.9359}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 910800,
#    'pid': 62,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 62,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9108,
#     'End': 0.9311}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 910900,
#    'pid': 87,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 87,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9109,
#     'End': 0.933}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 911000,
#    'pid': 34,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 34,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.911,
#     'End': 0.931}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 911000,
#    'pid': 43,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 43,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.911,
#     'End': 0.9374}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 911000,
#    'pid': 93,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 93,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.911,
#     'End': 0.9327}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 911100,
#    'pid': 82,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 82,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9111,
#     'End': 0.9318}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 911300,
#    'pid': 126,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 126,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9113,
#     'End': 0.9364}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 911400,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9114,
#     'End': 0.9356}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 911400,
#    'pid': 112,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 112,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9114,
#     'End': 0.936}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 911500,
#    'pid': 63,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 63,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9115,
#     'End': 0.9329}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 911600,
#    'pid': 33,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 33,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9116,
#     'End': 0.9373}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 911600,
#    'pid': 38,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 38,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9116,
#     'End': 0.9362}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 911600,
#    'pid': 47,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 47,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9116,
#     'End': 0.9339}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 911600,
#    'pid': 54,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 54,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9116,
#     'End': 0.9364}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 911600,
#    'pid': 55,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 55,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9116,
#     'End': 0.9313}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 911600,
#    'pid': 64,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 64,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9116,
#     'End': 0.9344}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 911600,
#    'pid': 92,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 92,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9116,
#     'End': 0.9374}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 911700,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9117,
#     'End': 0.9341}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 911700,
#    'pid': 36,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 36,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9117,
#     'End': 0.9314}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 911700,
#    'pid': 48,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 48,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9117,
#     'End': 0.9359}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 911700,
#    'pid': 69,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 69,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9117,
#     'End': 0.9327}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 911700,
#    'pid': 120,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 120,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9117,
#     'End': 0.932}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 911800,
#    'pid': 83,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 83,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9118,
#     'End': 0.9332}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 911900,
#    'pid': 32,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 32,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9119,
#     'End': 0.9336}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 911900,
#    'pid': 106,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 106,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9119,
#     'End': 0.932}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 912000,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.912,
#     'End': 0.9326}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 912000,
#    'pid': 10,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 10,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.912,
#     'End': 0.9326}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 912100,
#    'pid': 16,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 16,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9121,
#     'End': 0.9323}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 912200,
#    'pid': 8,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 8,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9122,
#     'End': 0.9372}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 912200,
#    'pid': 20,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 20,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9122,
#     'End': 0.9373}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 912400,
#    'pid': 27,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 27,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9124,
#     'End': 0.934}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 912500,
#    'pid': 75,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 75,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9125,
#     'End': 0.9325}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 912500,
#    'pid': 119,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 119,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9125,
#     'End': 0.9341}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 912600,
#    'pid': 84,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 84,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9126,
#     'End': 0.9315}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 912600,
#    'pid': 105,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 105,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9126,
#     'End': 0.9316}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 912600,
#    'pid': 115,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 115,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9126,
#     'End': 0.9347}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 912800,
#    'pid': 102,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 102,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9128,
#     'End': 0.9317}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 913000,
#    'pid': 19,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 19,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.913,
#     'End': 0.932}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 913000,
#    'pid': 41,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 41,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.913,
#     'End': 0.9346}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 913000,
#    'pid': 86,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 86,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.913,
#     'End': 0.9323}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 913000,
#    'pid': 113,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 113,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.913,
#     'End': 0.9325}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 913100,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9131,
#     'End': 0.9318}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 913100,
#    'pid': 108,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 108,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9131,
#     'End': 0.9321}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 913100,
#    'pid': 127,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 127,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9131,
#     'End': 0.9321}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 913200,
#    'pid': 29,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 29,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9132,
#     'End': 0.9331}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 913200,
#    'pid': 45,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 45,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9132,
#     'End': 0.9327}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 913200,
#    'pid': 60,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 60,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9132,
#     'End': 0.9316}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 913200,
#    'pid': 74,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 74,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9132,
#     'End': 0.933}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 913200,
#    'pid': 94,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 94,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9132,
#     'End': 0.9338}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 913200,
#    'pid': 125,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 125,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9132,
#     'End': 0.9363}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 913400,
#    'pid': 22,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 22,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9134,
#     'End': 0.9328}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 913400,
#    'pid': 31,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 31,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9134,
#     'End': 0.9342}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 913400,
#    'pid': 52,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 52,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9134,
#     'End': 0.9345}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 913400,
#    'pid': 77,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 77,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9134,
#     'End': 0.9336}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 913400,
#    'pid': 88,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 88,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9134,
#     'End': 0.9352}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 913400,
#    'pid': 89,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 89,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9134,
#     'End': 0.9342}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 913500,
#    'pid': 76,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 76,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9135,
#     'End': 0.9351}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 913500,
#    'pid': 122,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 122,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9135,
#     'End': 0.9319}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 913600,
#    'pid': 116,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 116,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9136,
#     'End': 0.9329}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 913800,
#    'pid': 46,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 46,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9138,
#     'End': 0.9314}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 913900,
#    'pid': 15,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 15,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9139,
#     'End': 0.9332}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 913900,
#    'pid': 21,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 21,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9139,
#     'End': 0.9353}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 913900,
#    'pid': 51,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 51,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9139,
#     'End': 0.9321}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 913900,
#    'pid': 59,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 59,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9139,
#     'End': 0.9315}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 913900,
#    'pid': 104,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 104,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9139,
#     'End': 0.9338}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 913900,
#    'pid': 117,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 117,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.9139,
#     'End': 0.9352}},
# ...
#     'Rank': 122,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 524288,
#     'Length': 262144,
#     'Start': 1.0457,
#     'End': 1.0693}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1045800,
#    'pid': 22,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 22,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 524288,
#     'Length': 262144,
#     'Start': 1.0458,
#     'End': 1.0693}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1045800,
#    'pid': 41,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 41,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 524288,
#     'Length': 262144,
#     'Start': 1.0458,
#     'End': 1.0706}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1045800,
#    'pid': 68,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 68,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 524288,
#     'Length': 262144,
#     'Start': 1.0458,
#     'End': 1.0707}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1045800,
#    'pid': 98,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 98,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 524288,
#     'Length': 262144,
#     'Start': 1.0458,
#     'End': 1.0676}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1045800,
#    'pid': 113,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 113,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 524288,
#     'Length': 262144,
#     'Start': 1.0458,
#     'End': 1.0685}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1045800,
#    'pid': 119,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 119,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 524288,
#     'Length': 262144,
#     'Start': 1.0458,
#     'End': 1.0702}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1045900,
#    'pid': 90,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 90,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 524288,
#     'Length': 262144,
#     'Start': 1.0459,
#     'End': 1.0685}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1045900,
#    'pid': 124,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 124,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 524288,
#     'Length': 262144,
#     'Start': 1.0459,
#     'End': 1.0657}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1045900,
#    'pid': 127,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 127,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 524288,
#     'Length': 262144,
#     'Start': 1.0459,
#     'End': 1.0694}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1046000,
#    'pid': 53,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 53,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 524288,
#     'Length': 262144,
#     'Start': 1.046,
#     'End': 1.068}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1046000,
#    'pid': 81,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 81,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 524288,
#     'Length': 262144,
#     'Start': 1.046,
#     'End': 1.0661}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1046000,
#    'pid': 104,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 104,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 524288,
#     'Length': 262144,
#     'Start': 1.046,
#     'End': 1.0686}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1046100,
#    'pid': 11,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 11,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 524288,
#     'Length': 262144,
#     'Start': 1.0461,
#     'End': 1.0658}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1046100,
#    'pid': 30,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 30,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 524288,
#     'Length': 262144,
#     'Start': 1.0461,
#     'End': 1.0698}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1046100,
#    'pid': 126,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 126,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 524288,
#     'Length': 262144,
#     'Start': 1.0461,
#     'End': 1.0698}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1046200,
#    'pid': 23,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 23,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 524288,
#     'Length': 262144,
#     'Start': 1.0462,
#     'End': 1.07}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1046200,
#    'pid': 27,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 27,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 524288,
#     'Length': 262144,
#     'Start': 1.0462,
#     'End': 1.0682}},
#   {'ph': 'E',
#    'ts': 1046200,
#    'pid': 33,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 33,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 262144,
#     'Length': 262144,
#     'Start': 1.0438,
#     'End': 1.0462}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1046200,
#    'pid': 47,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 47,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 524288,
#     'Length': 262144,
#     'Start': 1.0462,
#     'End': 1.0658}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1046300,
#    'pid': 60,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 60,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 524288,
#     'Length': 262144,
#     'Start': 1.0463,
#     'End': 1.0649}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1046400,
#    'pid': 61,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 61,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 524288,
#     'Length': 262144,
#     'Start': 1.0464,
#     'End': 1.0693}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1046600,
#    'pid': 73,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 73,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 524288,
#     'Length': 262144,
#     'Start': 1.0466,
#     'End': 1.0682}},
#   {'ph': 'E',
#    'ts': 1046600,
#    'pid': 96,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 96,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 262144,
#     'Length': 262144,
#     'Start': 1.045,
#     'End': 1.0466}},
#   {'ph': 'E',
#    'ts': 1046700,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 262144,
#     'Length': 262144,
#     'Start': 1.0453,
#     'End': 1.0467}},
#   {'ph': 'E',
#    'ts': 1046700,
#    'pid': 12,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 12,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 262144,
#     'Length': 262144,
#     'Start': 1.0451,
#     'End': 1.0467}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1046700,
#    'pid': 102,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 102,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 262144,
#     'Length': 262144,
#     'Start': 1.0467,
#     'End': 1.0479}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1046700,
#    'pid': 123,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 123,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 524288,
#     'Length': 262144,
#     'Start': 1.0467,
#     'End': 1.0706}},
#   {'ph': 'E',
#    'ts': 1046800,
#    'pid': 34,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 34,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 262144,
#     'Start': 1.004,
#     'End': 1.0468}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1046899,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 524288,
#     'Length': 262144,
#     'Start': 1.0469,
#     'End': 1.0704}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1047199,
#    'pid': 101,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 101,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 524288,
#     'Length': 262144,
#     'Start': 1.0472,
#     'End': 1.0684}},
#   {'ph': 'E',
#    'ts': 1047299,
#    'pid': 100,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 100,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 262144,
#     'Length': 262144,
#     'Start': 1.045,
#     'End': 1.0473}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1047400,
#    'pid': 29,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 29,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 524288,
#     'Length': 262144,
#     'Start': 1.0474,
#     'End': 1.0693}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1047400,
#    'pid': 118,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 118,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 524288,
#     'Length': 262144,
#     'Start': 1.0474,
#     'End': 1.0711}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1047500,
#    'pid': 28,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 28,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 524288,
#     'Length': 262144,
#     'Start': 1.0475,
#     'End': 1.0687}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 1047500,
#    'pid': 84,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 84,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 524288,
#     'Length': 262144,
#     'Start': 1.0475,
#     'End': 1.0713}},
#   ...],
#  'displayTimeUnit': 'ms',
#  'systemTraceEvents': 'SystemTraceData',
#  'otherData': {'version': 'VaniDL v1.0'},
#  'stackFrames': {},
#  'samples': []}

# %%
import csv
with open('/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv', newline='\n') as f:
    reader = csv.reader(f)
    row1 = next(reader)
    print(len(row1))
# Out:
# 60484

# %%
import pandas as pd
val = pd.read_csv('/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',header=None,low_memory=False)
