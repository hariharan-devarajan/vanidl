# %% [markdown]
# # DLProfile Example using Climate Seg Benchmark

# %% [markdown]
# ## Set imports and neccessary environment variables

# %%
import pathlib
import os
import sys
import matplotlib.pyplot as plt
import warnings
import pprint
import pandas

# %%
VANIDL_DIR="{}".format(pathlib.Path(os.getcwd()).parent.absolute())
sys.path.insert(0, VANIDL_DIR)
warnings.filterwarnings('ignore')

# %%
os.environ["DARSHAN_DIR"] = "/soft/perftools/darshan/darshan-3.1.8"
os.environ["VANIDL_DIR"] = VANIDL_DIR

# %% [markdown]
# #### Formatting

# %%
pp = pprint.PrettyPrinter(indent=1)
class color:
    PURPLE = '\033[95m'
    CYAN = '\033[96m'
    DARKCYAN = '\033[36m'
    BLUE = '\033[94m'
    GREEN = '\033[92m'
    YELLOW = '\033[93m'
    RED = '\033[91m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'
    END = '\033[0m'

# %% [markdown]
# ## Create instrance of DL Profile and load the darshan file

# %%
from src.vanidl import VaniDL
profile = VaniDL()

# %%
#import shutil
#shutil.rmtree('/tmp/temp_analysis')

# %%
DATAPATH_INCLUDES = []
status = profile.Load("/home/dhari/darshan-logs/apps/climate/climate_run1_p8.darshan", data_paths_include=DATAPATH_INCLUDES)
if status:
    print("Darshan Trace loaded Successfully!")
else:
    print("Darshan Trace load Failed!")
    print(profile._error_str())
# Out:
# [============================================================] 100.0% 1563 of 1563 Parsing DXT File
# [============================================================] 100.0% 4732 of 4732 Parsing Darshan File
# Darshan Trace loaded Successfully!

# %% [markdown]
# ## Use Profile object to analyze the darshan I/O trace.

# %% [markdown]
# ### Verify if object works
#
# The GetDXTAsDF() function enables users to perform analysis

# %%
df = profile.GetDXTAsDF()
pp.pprint("Files used in the application")
pp.pprint(df['Filename'].unique().tolist())
# Out:
# 'Files used in the application'
# ['/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#  '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/validation/stats.h5',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_0.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_0.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_1.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_1.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_1.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_2.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_2.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_2.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_3.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_3.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_3.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_4.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_4.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_5.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_5.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_5.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_6.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_6.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_6.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_7.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_7.json']

# %%
df_normal = profile.GetTraceAsDF()
pp.pprint("Files used in the application")
pp.pprint(df_normal['Filename'].unique().tolist())
# Out:
# 'Files used in the application'
# ['/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_0.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_0.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_0.json',
#  '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/validation/stats.h5',
#  '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_1.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_1.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_1.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_2.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_2.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_2.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_3.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_3.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_3.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_4.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_4.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_4.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_5.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_5.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_5.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_6.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_6.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_6.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_7.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_7.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_7.json']

# %% [markdown]
# ### Collect the summary of the Application

# %%
summary = profile.GetSummary()
print("\n")
print(color.BOLD + "Data Access Summary (from Darshan):"+ color.END)
print("Total Job time\t\t\t:\t{:0.2f} seconds".format(summary['job_time']))
#FIXME: calculate time per rank and then take max across it.
print("Time spent in I/O\t\t:\t{:0.2f} seconds".format(summary['total_io_time']))
print("% Time spent in I/O\t\t:\t{:0.2f}%".format(float(summary['total_io_time'])*100/summary['job_time']))
print("Total Data Accessed\t\t:\t{:0.2f} GB".format(float(summary['total_io_bytes'])/1024.0/1024.0/1024.0))
print("Data Access Modules used\t:\t{}".format(summary['io_interface_used']))
print("Data Operations\t\t\t:\t{}".format(summary['io_operations_used']))
print("# of files used\t\t\t:\t{}".format(len(summary['files_used'])))
print("# of MPI Ranks\t\t\t:\t{:0.0f} ranks".format(summary['num_ranks']))
      
print(color.UNDERLINE + "Data Transfer size:"+ color.END)
print("\tMin,Max\t\t\t:\t{:0.0f} bytes and {:0.0f} bytes".format(summary['data_transfer_size']['min'],summary['data_transfer_size']['max']))
print("\tAverage\t\t\t:\t{:0.0f} bytes".format(summary['data_transfer_size']['mean']))
print("\tMedian\t\t\t:\t{:0.0f} bytes".format(summary['data_transfer_size']['median']))
      
print(color.UNDERLINE + "Data Transfer bandwidth: (per rank)"+ color.END)
print("\tMin,Max\t\t\t:\t{:0.0f} B/s and {:0.0f} MB/s".format(summary['data_transfer_bandwidth']['min'],summary['data_transfer_bandwidth']['max']/1024.0/1024.0))
print("\tAverage\t\t\t:\t{:0.0f} MB/s".format(summary['data_transfer_bandwidth']['mean']/1024.0/1024.0))
print("\tMedian\t\t\t:\t{:0.0f} MB/s".format(summary['data_transfer_bandwidth']['median']/1024.0/1024.0))
      
print(color.UNDERLINE + "Access Pattern:"+ color.END)
print("\tSequential\t\t:\t{:0.2f}%".format(float(summary['access_pattern']['sequential'])))
print("\tConsecutive\t\t:\t{:0.2f}%".format(float(summary['access_pattern']['consecutive'])))
#An I/O op issued at an offset greater than where the previous I/O op ended.
#An I/O op issued at the offset immediately after the end of the previous I/O

print("\n")
print(color.BOLD + "Files Summary:"+ color.END)
print("File Types\t\t\t:\t{}".format(summary['file_used_summary']['types']))
print(color.UNDERLINE + "Dataset Size:"+ color.END)
print("\tTotal\t\t\t:\t{:0.3f} GB".format(float(summary['file_used_summary']['size']['total'])/1024.0/1024.0/1024.0))
print("\tMin,Max\t\t\t:\t{:0.3f} GB and {:0.3f} GB".format(float(summary['file_used_summary']['size']['min'])/1024.0/1024.0/1024.0,float(summary['file_used_summary']['size']['max'])/1024.0/1024.0/1024.0))
print("\tAverage\t\t\t:\t{:0.3f} GB".format(float(summary['file_used_summary']['size']['mean'])/1024.0/1024.0/1024.0))
# Out:
# Data Access Summary (from Darshan):
# Total Job time			:	2278.00 seconds
# Time spent in I/O		:	0.09 seconds
# % Time spent in I/O		:	0.00%
# Total Data Accessed		:	0.08 GB
# Data Access Modules used	:	['X_POSIX']
# Data Operations			:	['read' 'write']
# # of files used			:	23
# # of MPI Ranks			:	8 ranks
# Data Transfer size:
# 	Min,Max			:	8 bytes and 4074017 bytes
# 	Average			:	345081 bytes
# 	Median			:	512 bytes
# Data Transfer bandwidth: (per rank)
# 	Min,Max			:	640 B/s and 346 MB/s
# 	Average			:	28 MB/s
# 	Median			:	0 MB/s
# Access Pattern:
# 	Sequential		:	45.71%
# 	Consecutive		:	13.06%
#
#
# Files Summary:
# File Types			:	['h5' 'json']
# Dataset Size:
# 	Total			:	0.090 GB
# 	Min,Max			:	0.004 GB and 0.004 GB
# 	Average			:	0.004 GB

# %%
pp.pprint("Job time : {} seconds".format(profile.GetJobTime()))
# Out:
# 'Job time : 2278.0 seconds'

# %%
pp.pprint("Time spent by application on I/O: {} seconds".format(profile.GetIOTime()))
# Out:
# 'Time spent by application on I/O: 0.08983749999998747 seconds'

# %% [markdown]
# ### I/O time spent on each file

# %%
for file in df['Filename'].unique():
    print("I/O time for file {}: {:0.2f} seconds".format(file,profile.GetIOTime(filepath=file)))
# Out:
# I/O time for file /lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5: 0.03 seconds
# I/O time for file /lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/validation/stats.h5: 0.03 seconds
# I/O time for file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_0.json: 0.01 seconds
# I/O time for file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_0.json: 0.01 seconds
# I/O time for file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_1.json: 0.01 seconds
# I/O time for file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_1.json: 0.01 seconds
# I/O time for file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_1.json: 0.01 seconds
# I/O time for file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_2.json: 0.01 seconds
# I/O time for file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_2.json: 0.01 seconds
# I/O time for file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_2.json: 0.01 seconds
# I/O time for file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_3.json: 0.01 seconds
# I/O time for file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_3.json: 0.01 seconds
# I/O time for file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_3.json: 0.01 seconds
# I/O time for file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_4.json: 0.01 seconds
# I/O time for file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_4.json: 0.01 seconds
# I/O time for file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_5.json: 0.01 seconds
# I/O time for file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_5.json: 0.01 seconds
# I/O time for file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_5.json: 0.01 seconds
# I/O time for file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_6.json: 0.01 seconds
# I/O time for file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_6.json: 0.01 seconds
# I/O time for file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_6.json: 0.01 seconds
# I/O time for file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_7.json: 0.01 seconds
# I/O time for file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_7.json: 0.01 seconds

# %% [markdown]
# ### I/O Time spent per rank

# %%
for rank in df['Rank'].unique():
    print("I/O time for rank {}: {:0.2f} seconds".format(rank,profile.GetIOTime(rank=rank)))
# Out:
# I/O time for rank 0: 0.08 seconds
# I/O time for rank 1: 0.09 seconds
# I/O time for rank 2: 0.09 seconds
# I/O time for rank 3: 0.09 seconds
# I/O time for rank 4: 0.08 seconds
# I/O time for rank 5: 0.10 seconds
# I/O time for rank 6: 0.10 seconds
# I/O time for rank 7: 0.09 seconds

# %%
"Total I/O performed by application: {:0.2f} GB".format(float(profile.GetIOSize())/1024.0/1024.0/1024.0)
# Out:
# 'Total I/O performed by application: 0.08 GB'

# %% [markdown]
# ### I/O performed on each file

# %%
for file in df['Filename'].unique():
    print("I/O performed on file {}: {:0.2f} MB".format(file,float(profile.GetIOSize(filepath=file))/1024.0/1024.0))
# Out:
# I/O performed on file /lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5: 0.04 MB
# I/O performed on file /lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/validation/stats.h5: 0.04 MB
# I/O performed on file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_0.json: 3.86 MB
# I/O performed on file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_0.json: 3.89 MB
# I/O performed on file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_1.json: 3.82 MB
# I/O performed on file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_1.json: 3.84 MB
# I/O performed on file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_1.json: 3.81 MB
# I/O performed on file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_2.json: 3.84 MB
# I/O performed on file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_2.json: 3.86 MB
# I/O performed on file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_2.json: 3.84 MB
# I/O performed on file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_3.json: 3.83 MB
# I/O performed on file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_3.json: 3.83 MB
# I/O performed on file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_3.json: 3.83 MB
# I/O performed on file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_4.json: 3.82 MB
# I/O performed on file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_4.json: 3.82 MB
# I/O performed on file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_5.json: 3.81 MB
# I/O performed on file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_5.json: 3.80 MB
# I/O performed on file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_5.json: 3.75 MB
# I/O performed on file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_6.json: 3.88 MB
# I/O performed on file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_6.json: 3.85 MB
# I/O performed on file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_6.json: 3.87 MB
# I/O performed on file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_7.json: 3.86 MB
# I/O performed on file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_7.json: 3.87 MB

# %%
for rank in df['Rank'].unique():
    print("I/O performed by rank {}: {:0.2f} MB".format(rank, float(profile.GetIOSize(rank=rank))/1024.0/1024.0))
# Out:
# I/O performed by rank 0: 7.76 MB
# I/O performed by rank 1: 11.48 MB
# I/O performed by rank 2: 11.55 MB
# I/O performed by rank 3: 11.49 MB
# I/O performed by rank 4: 7.65 MB
# I/O performed by rank 5: 11.37 MB
# I/O performed by rank 6: 11.61 MB
# I/O performed by rank 7: 7.74 MB

# %%
print("Size of dataset (bytes)")
pp.pprint(profile.GetFileSizes())
# Out:
# Size of dataset (bytes)
# {'timeline_2_0_0': 4043291.0,
#  'timeline_2_0_1': 3996526.0,
#  'timeline_2_0_2': 4023357.0,
#  'timeline_2_0_3': 4012988.0,
#  'timeline_2_0_4': 3959159.0,
#  'timeline_2_0_5': 3929153.0,
#  'timeline_2_0_6': 4059180.0,
#  'timeline_2_0_7': 4007668.0,
#  'timeline_3_0_0': 4074017.0,
#  'timeline_3_0_1': 4022804.0,
#  'timeline_3_0_2': 4048488.0,
#  'timeline_3_0_3': 4013581.0,
#  'timeline_3_0_4': 4008738.0,
#  'timeline_3_0_5': 3987909.0,
#  'timeline_3_0_6': 4033059.0,
#  'timeline_3_0_7': 4052768.0,
#  'timeline_4_0_0': 4050536.0,
#  'timeline_4_0_1': 4005437.0,
#  'timeline_4_0_2': 4026163.0,
#  'timeline_4_0_3': 4011885.0,
#  'timeline_4_0_4': 4001833.0,
#  'timeline_4_0_5': 3992591.0,
#  'timeline_4_0_6': 4066940.0,
#  'timeline_4_0_7': 4048271.0}

# %% [markdown]
# ### How application access data over time.

# %%
tl = profile.CreateIOTimeline()
plt.figure(figsize=(20,4))
plt.grid()
plt.plot('time_step', 'read_count', data=tl);
plt.plot('time_step', 'write_count', data=tl);
plt.legend()
# Out:
# [============================================================] 100.0% 245 of 245 Creating Timeline

# %%
plt.figure(figsize=(20,4))
plt.grid()
plt.plot('time_step', 'read_bytes', data=tl);
plt.show();
plt.figure(figsize=(20,4))
plt.grid()
plt.plot('time_step', 'write_bytes', data=tl);
plt.show();

# %% [markdown]
# ### How files are accessed over the duration of the Job.

# %%
for file in df['Filename'].unique():
    tl = profile.CreateIOTimeline(filepath=file)
    plt.plot('time_step', 'read_count', data=tl);
    plt.plot('time_step', 'write_count', data=tl);
    plt.legend()
    plt.show()
# Out:
# [============================================================] 100.0% 112 of 112 Creating Timeline
# Loaded Pre-processed Timeline from file: /tmp/temp_analysis/climate_run1_p8_tm_df_stats.csv
# [============================================================] 100.0% 1 of 1 Creating Timeline
# [============================================================] 100.0% 1 of 1 Creating Timeline
# [============================================================] 100.0% 1 of 1 Creating Timeline
# [============================================================] 100.0% 1 of 1 Creating Timeline
# [============================================================] 100.0% 1 of 1 Creating Timeline
# [============================================================] 100.0% 1 of 1 Creating Timeline
# [============================================================] 100.0% 1 of 1 Creating Timeline
# [============================================================] 100.0% 1 of 1 Creating Timeline
# [============================================================] 100.0% 1 of 1 Creating Timeline
# [============================================================] 100.0% 1 of 1 Creating Timeline
# [============================================================] 100.0% 1 of 1 Creating Timeline
# [============================================================] 100.0% 1 of 1 Creating Timeline
# [============================================================] 100.0% 1 of 1 Creating Timeline
# [============================================================] 100.0% 1 of 1 Creating Timeline
# [============================================================] 100.0% 1 of 1 Creating Timeline
# [============================================================] 100.0% 1 of 1 Creating Timeline
# [============================================================] 100.0% 1 of 1 Creating Timeline
# [============================================================] 100.0% 1 of 1 Creating Timeline
# [============================================================] 100.0% 1 of 1 Creating Timeline
# [============================================================] 100.0% 1 of 1 Creating Timeline
# [============================================================] 100.0% 1 of 1 Creating Timeline

# %% [markdown]
# ### Show how each file is accessed by each rank.

# %%
for rank in df['Rank'].unique():
    tl = profile.CreateIOTimeline(rank=rank)    
    plt.plot('time_step', 'read_count', data=tl);
    plt.plot('time_step', 'write_count', data=tl);
    plt.legend()
    plt.show()
# Out:
# [============================================================] 100.0% 30 of 30 Creating Timeline
# [============================================================] 100.0% 31 of 31 Creating Timeline
# [============================================================] 100.0% 31 of 31 Creating Timeline
# [============================================================] 100.0% 31 of 31 Creating Timeline
# [============================================================] 100.0% 30 of 30 Creating Timeline
# [============================================================] 100.0% 31 of 31 Creating Timeline
# [============================================================] 100.0% 31 of 31 Creating Timeline
# [============================================================] 100.0% 30 of 30 Creating Timeline

# %% [markdown]
# ### Data Transfer Size distribution within the application

# %%
request_df_read = profile.GetIORequestDistribution(operation='read')
ax = request_df_read.plot(kind='bar', figsize=(10, 4));
plt.show()

# %%
request_df_write = profile.GetIORequestDistribution(operation='write')
ax = request_df_write.plot(kind='bar', figsize=(10, 4));
plt.show()

# %% [markdown]
# ### Data Transfer Size distribution for each file.

# %%
for file in df['Filename'].unique():
    tl = profile.GetIORequestDistribution(filepath=file)
    tl.plot(kind='bar', figsize=(10, 4), title=file)

# %% [markdown]
# ### Data Transfer Sizes per Rank

# %%
for rank in df['Rank'].unique():
    fig, ax = plt.subplots(ncols=2,nrows=1)
    tl = profile.GetIORequestDistribution(rank=rank, operation='read')
    tl.plot(kind='bar', figsize=(10, 4), title=rank,ax=ax[0])
    ax[0].set_title("rank {}:read".format(rank))
    tl2 = profile.GetIORequestDistribution(rank=rank, operation='write')
    tl2.plot(kind='bar', figsize=(10, 4), title=rank,ax=ax[1])
    ax[1].set_title("rank {}:write".format(rank))
    plt.show()

# %% [markdown]
# ### File summary of each file accessed by the Application

# %%
pp = pprint.PrettyPrinter(indent=1)
for file in df['Filename'].unique():
    if os.path.exists(file):
        print(file)
        pp.pprint(profile.GetFileSummary(file))
# Out:
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_0.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_0',
#  'io_size': 4050536,
#  'io_time': 0.011299999999664578,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_0.json',
#  'size': 4050536,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_0.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_0',
#  'io_size': 4074017,
#  'io_time': 0.011299999999664578,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_0.json',
#  'size': 4074017,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_1.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_1',
#  'io_size': 4005437,
#  'io_time': 0.011300000000119326,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_1.json',
#  'size': 4005437,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_1.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_1',
#  'io_size': 4022804,
#  'io_time': 0.01139999999986685,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_1.json',
#  'size': 4022804,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_1.json
# {'ext': 'json',
#  'filename': 'timeline_2_0_1',
#  'io_size': 3996526,
#  'io_time': 0.011300000000119326,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_1.json',
#  'size': 3996526,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_2.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_2',
#  'io_size': 4026163,
#  'io_time': 0.011199999999917054,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_2.json',
#  'size': 4026163,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_2.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_2',
#  'io_size': 4048488,
#  'io_time': 0.011300000000119326,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_2.json',
#  'size': 4048488,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_2.json
# {'ext': 'json',
#  'filename': 'timeline_2_0_2',
#  'io_size': 4023357,
#  'io_time': 0.01110000000016953,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_2.json',
#  'size': 4023357,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_3.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_3',
#  'io_size': 4011885,
#  'io_time': 0.01110000000016953,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_3.json',
#  'size': 4011885,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_3.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_3',
#  'io_size': 4013581,
#  'io_time': 0.011199999999917054,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_3.json',
#  'size': 4013581,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_3.json
# {'ext': 'json',
#  'filename': 'timeline_2_0_3',
#  'io_size': 4012988,
#  'io_time': 0.011199999999917054,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_3.json',
#  'size': 4012988,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_4.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_4',
#  'io_size': 4001833,
#  'io_time': 0.012499999999818101,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_4.json',
#  'size': 4001833,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_4.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_4',
#  'io_size': 4008738,
#  'io_time': 0.012299999999868305,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_4.json',
#  'size': 4008738,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_5.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_5',
#  'io_size': 3992591,
#  'io_time': 0.012799999999970169,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_5.json',
#  'size': 3992591,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_5.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_5',
#  'io_size': 3987909,
#  'io_time': 0.012400000000070577,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_5.json',
#  'size': 3987909,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_5.json
# {'ext': 'json',
#  'filename': 'timeline_2_0_5',
#  'io_size': 3929153,
#  'io_time': 0.012000000000170985,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_5.json',
#  'size': 3929153,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_6.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_6',
#  'io_size': 4066940,
#  'io_time': 0.013300000000072032,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_6.json',
#  'size': 4066940,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_6.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_6',
#  'io_size': 4033059,
#  'io_time': 0.012600000000020373,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_6.json',
#  'size': 4033059,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_6.json
# {'ext': 'json',
#  'filename': 'timeline_2_0_6',
#  'io_size': 4059180,
#  'io_time': 0.013100000000122236,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_6.json',
#  'size': 4059180,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_7.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_7',
#  'io_size': 4048271,
#  'io_time': 0.013100000000122236,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_7.json',
#  'size': 4048271,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_7.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_7',
#  'io_size': 4052768,
#  'io_time': 0.012600000000020373,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_7.json',
#  'size': 4052768,
#  'special': {}}

# %%
profile.CreateChromeTimeline(location="/home/dhari/timeline/apps/climate", filename="climate_run1_p8.json")
# Out:
# [============================================================] 100.0% 245 of 245 Creating Timeline
# {'traceEvents': [{'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 271000,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.271,
#     'End': 0.2814}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 271400,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.2714,
#     'End': 0.2819}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 272600,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.2726,
#     'End': 0.2824}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 272600,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.2726,
#     'End': 0.2823}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 272900,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.2729,
#     'End': 0.2816}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 273300,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.2733,
#     'End': 0.2817}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 273400,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.2734,
#     'End': 0.2819}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 275500,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.2755,
#     'End': 0.2818}},
#   {'ph': 'E',
#    'ts': 281400,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.271,
#     'End': 0.2814}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 281600,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.2816,
#     'End': 0.2816}},
#   {'ph': 'E',
#    'ts': 281600,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.2816,
#     'End': 0.2816}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 281600,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.2816,
#     'End': 0.2816}},
#   {'ph': 'E',
#    'ts': 281600,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.2816,
#     'End': 0.2816}},
#   {'ph': 'E',
#    'ts': 281600,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.2729,
#     'End': 0.2816}},
#   {'ph': 'E',
#    'ts': 281700,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.2733,
#     'End': 0.2817}},
#   {'ph': 'E',
#    'ts': 281800,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.2755,
#     'End': 0.2818}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 281800,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.2818,
#     'End': 0.2818}},
#   {'ph': 'E',
#    'ts': 281800,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.2818,
#     'End': 0.2818}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 281800,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.2818,
#     'End': 0.2818}},
#   {'ph': 'E',
#    'ts': 281800,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.2818,
#     'End': 0.2818}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 281900,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.2819,
#     'End': 0.2819}},
#   {'ph': 'E',
#    'ts': 281900,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.2819,
#     'End': 0.2819}},
#   {'ph': 'E',
#    'ts': 281900,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.2734,
#     'End': 0.2819}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 281900,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.2819,
#     'End': 0.2819}},
#   {'ph': 'E',
#    'ts': 281900,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.2819,
#     'End': 0.2819}},
#   {'ph': 'E',
#    'ts': 281900,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.2714,
#     'End': 0.2819}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 282000,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.282,
#     'End': 0.282}},
#   {'ph': 'E',
#    'ts': 282000,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.282,
#     'End': 0.282}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 282000,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.282,
#     'End': 0.282}},
#   {'ph': 'E',
#    'ts': 282000,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.282,
#     'End': 0.282}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 282100,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.2821,
#     'End': 0.2821}},
#   {'ph': 'E',
#    'ts': 282100,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.2821,
#     'End': 0.2821}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 282100,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.2821,
#     'End': 0.2821}},
#   {'ph': 'E',
#    'ts': 282100,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.2821,
#     'End': 0.2821}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 282100,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.2821,
#     'End': 0.2821}},
#   {'ph': 'E',
#    'ts': 282100,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.2821,
#     'End': 0.2821}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 282100,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.2821,
#     'End': 0.2822}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 282100,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.2821,
#     'End': 0.2821}},
#   {'ph': 'E',
#    'ts': 282100,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.2821,
#     'End': 0.2821}},
#   {'ph': 'E',
#    'ts': 282200,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.2821,
#     'End': 0.2822}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 282200,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.2822,
#     'End': 0.2822}},
#   {'ph': 'E',
#    'ts': 282200,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.2822,
#     'End': 0.2822}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 282200,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.2822,
#     'End': 0.2822}},
#   {'ph': 'E',
#    'ts': 282200,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.2822,
#     'End': 0.2822}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 282300,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.2823,
#     'End': 0.2823}},
#   {'ph': 'E',
#    'ts': 282300,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.2823,
#     'End': 0.2823}},
#   {'ph': 'E',
#    'ts': 282300,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.2726,
#     'End': 0.2823}},
#   {'ph': 'E',
#    'ts': 282400,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.2726,
#     'End': 0.2824}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 282400,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.2824,
#     'End': 0.2824}},
#   {'ph': 'E',
#    'ts': 282400,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.2824,
#     'End': 0.2824}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 282400,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.2824,
#     'End': 0.2824}},
#   {'ph': 'E',
#    'ts': 282400,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.2824,
#     'End': 0.2824}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 282500,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.2825,
#     'End': 0.2825}},
#   {'ph': 'E',
#    'ts': 282500,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.2825,
#     'End': 0.2825}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 282600,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.2826,
#     'End': 0.2826}},
#   {'ph': 'E',
#    'ts': 282600,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.2826,
#     'End': 0.2826}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 282600,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.2826,
#     'End': 0.2826}},
#   {'ph': 'E',
#    'ts': 282600,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.2826,
#     'End': 0.2826}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 282600,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.2826,
#     'End': 0.2826}},
#   {'ph': 'E',
#    'ts': 282600,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.2826,
#     'End': 0.2826}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 282800,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.2828,
#     'End': 0.2828}},
#   {'ph': 'E',
#    'ts': 282800,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.2828,
#     'End': 0.2828}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 282900,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.2829,
#     'End': 0.2829}},
#   {'ph': 'E',
#    'ts': 282900,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.2829,
#     'End': 0.2829}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 288200,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.2882,
#     'End': 0.2882}},
#   {'ph': 'E',
#    'ts': 288200,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.2882,
#     'End': 0.2882}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 288200,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.2882,
#     'End': 0.2883}},
#   {'ph': 'E',
#    'ts': 288300,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.2882,
#     'End': 0.2883}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 288300,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 4096,
#     'Length': 328,
#     'Start': 0.2883,
#     'End': 0.2977}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 288500,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.2885,
#     'End': 0.2885}},
#   {'ph': 'E',
#    'ts': 288500,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.2885,
#     'End': 0.2885}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 288600,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.2886,
#     'End': 0.2886}},
#   {'ph': 'E',
#    'ts': 288600,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.2886,
#     'End': 0.2886}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 288600,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 4096,
#     'Length': 328,
#     'Start': 0.2886,
#     'End': 0.2984}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 289000,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.289,
#     'End': 0.289}},
#   {'ph': 'E',
#    'ts': 289000,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.289,
#     'End': 0.289}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 289100,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.2891,
#     'End': 0.2891}},
#   {'ph': 'E',
#    'ts': 289100,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.2891,
#     'End': 0.2891}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 289100,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.2891,
#     'End': 0.2891}},
#   {'ph': 'E',
#    'ts': 289100,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.2891,
#     'End': 0.2891}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 289100,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 4096,
#     'Length': 328,
#     'Start': 0.2891,
#     'End': 0.2982}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 289200,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.2892,
#     'End': 0.2892}},
#   {'ph': 'E',
#    'ts': 289200,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.2892,
#     'End': 0.2892}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 289200,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 4096,
#     'Length': 328,
#     'Start': 0.2892,
#     'End': 0.2983}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 289200,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.2892,
#     'End': 0.2892}},
#   {'ph': 'E',
#    'ts': 289200,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.2892,
#     'End': 0.2892}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 289200,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.2892,
#     'End': 0.2893}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 289300,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.2893,
#     'End': 0.2893}},
#   {'ph': 'E',
#    'ts': 289300,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.2893,
#     'End': 0.2893}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 289300,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 4096,
#     'Length': 328,
#     'Start': 0.2893,
#     'End': 0.2981}},
#   {'ph': 'E',
#    'ts': 289300,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.2892,
#     'End': 0.2893}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 289300,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.2893,
#     'End': 0.2893}},
#   {'ph': 'E',
#    'ts': 289300,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.2893,
#     'End': 0.2893}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 289400,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.2894,
#     'End': 0.2894}},
#   {'ph': 'E',
#    'ts': 289400,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.2894,
#     'End': 0.2894}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 289400,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 4096,
#     'Length': 328,
#     'Start': 0.2894,
#     'End': 0.2983}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 289500,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.2895,
#     'End': 0.2895}},
#   {'ph': 'E',
#    'ts': 289500,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.2895,
#     'End': 0.2895}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 289600,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 4096,
#     'Length': 328,
#     'Start': 0.2896,
#     'End': 0.2982}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 289700,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.2897,
#     'End': 0.2897}},
#   {'ph': 'E',
#    'ts': 289700,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.2897,
#     'End': 0.2897}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 289800,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.2898,
#     'End': 0.2898}},
#   {'ph': 'E',
#    'ts': 289800,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.2898,
#     'End': 0.2898}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 289800,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 4096,
#     'Length': 328,
#     'Start': 0.2898,
#     'End': 0.2985}},
#   {'ph': 'E',
#    'ts': 297700,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 4096,
#     'Length': 328,
#     'Start': 0.2883,
#     'End': 0.2977}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 297800,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 1072,
#     'Length': 512,
#     'Start': 0.2978,
#     'End': 0.2978}},
#   {'ph': 'E',
#    'ts': 297800,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 1072,
#     'Length': 512,
#     'Start': 0.2978,
#     'End': 0.2978}},
#   {'ph': 'E',
#    'ts': 298100,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 4096,
#     'Length': 328,
#     'Start': 0.2893,
#     'End': 0.2981}},
#   {'ph': 'E',
#    'ts': 298200,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 4096,
#     'Length': 328,
#     'Start': 0.2891,
#     'End': 0.2982}},
#   {'ph': 'E',
#    'ts': 298200,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 4096,
#     'Length': 328,
#     'Start': 0.2896,
#     'End': 0.2982}},
#   {'ph': 'E',
#    'ts': 298300,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 4096,
#     'Length': 328,
#     'Start': 0.2892,
#     'End': 0.2983}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 298300,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 1072,
#     'Length': 512,
#     'Start': 0.2983,
#     'End': 0.2983}},
#   {'ph': 'E',
#    'ts': 298300,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 1072,
#     'Length': 512,
#     'Start': 0.2983,
#     'End': 0.2983}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 298300,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 1072,
#     'Length': 512,
#     'Start': 0.2983,
#     'End': 0.2984}},
#   {'ph': 'E',
#    'ts': 298300,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 4096,
#     'Length': 328,
#     'Start': 0.2894,
#     'End': 0.2983}},
#   {'ph': 'E',
#    'ts': 298400,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 4096,
#     'Length': 328,
#     'Start': 0.2886,
#     'End': 0.2984}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 298400,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 1072,
#     'Length': 512,
#     'Start': 0.2984,
#     'End': 0.2984}},
#   {'ph': 'E',
#    'ts': 298400,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 1072,
#     'Length': 512,
#     'Start': 0.2984,
#     'End': 0.2984}},
#   {'ph': 'E',
#    'ts': 298400,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 1072,
#     'Length': 512,
#     'Start': 0.2983,
#     'End': 0.2984}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 298400,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 1072,
#     'Length': 512,
#     'Start': 0.2984,
#     'End': 0.2984}},
#   {'ph': 'E',
#    'ts': 298400,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 1072,
#     'Length': 512,
#     'Start': 0.2984,
#     'End': 0.2984}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 298500,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 1072,
#     'Length': 512,
#     'Start': 0.2985,
#     'End': 0.2985}},
#   {'ph': 'E',
#    'ts': 298500,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 1072,
#     'Length': 512,
#     'Start': 0.2985,
#     'End': 0.2985}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 298500,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 1072,
#     'Length': 512,
#     'Start': 0.2985,
#     'End': 0.2985}},
#   {'ph': 'E',
#    'ts': 298500,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 1072,
#     'Length': 512,
#     'Start': 0.2985,
#     'End': 0.2985}},
#   {'ph': 'E',
#    'ts': 298500,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 4096,
#     'Length': 328,
#     'Start': 0.2898,
#     'End': 0.2985}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 298600,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 1072,
#     'Length': 512,
#     'Start': 0.2986,
#     'End': 0.2986}},
#   {'ph': 'E',
#    'ts': 298600,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 1072,
#     'Length': 512,
#     'Start': 0.2986,
#     'End': 0.2986}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 318000,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 8,
#     'Offset': 1656,
#     'Length': 512,
#     'Start': 0.318,
#     'End': 0.318}},
#   {'ph': 'E',
#    'ts': 318000,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 8,
#     'Offset': 1656,
#     'Length': 512,
#     'Start': 0.318,
#     'End': 0.318}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 318000,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 9,
#     'Offset': 1112,
#     'Length': 544,
#     'Start': 0.318,
#     'End': 0.318}},
#   {'ph': 'E',
#    'ts': 318000,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 9,
#     'Offset': 1112,
#     'Length': 544,
#     'Start': 0.318,
#     'End': 0.318}},
# ...
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_3.json',
#     'Rank': 3,
#     'Operation': 'write',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 4011885,
#     'Start': 2276.912,
#     'End': 2276.9231}},
#   {'name': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_5.json',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 2276913100,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_5.json',
#     'Rank': 5,
#     'Operation': 'write',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 3992591,
#     'Start': 2276.9131,
#     'End': 2276.9259}},
#   {'name': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_4.json',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 2276913300,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_4.json',
#     'Rank': 4,
#     'Operation': 'write',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 4001833,
#     'Start': 2276.9133,
#     'End': 2276.9258}},
#   {'ph': 'E',
#    'ts': 2276920000,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_1.json',
#     'Rank': 1,
#     'Operation': 'write',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 4005437,
#     'Start': 2276.9087,
#     'End': 2276.92}},
#   {'name': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_7.json',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 2276921300,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_7.json',
#     'Rank': 7,
#     'Operation': 'write',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 4048271,
#     'Start': 2276.9213,
#     'End': 2276.9344}},
#   {'ph': 'E',
#    'ts': 2276923100,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_2.json',
#     'Rank': 2,
#     'Operation': 'write',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 4026163,
#     'Start': 2276.9119,
#     'End': 2276.9231}},
#   {'ph': 'E',
#    'ts': 2276923100,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_3.json',
#     'Rank': 3,
#     'Operation': 'write',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 4011885,
#     'Start': 2276.912,
#     'End': 2276.9231}},
#   {'ph': 'E',
#    'ts': 2276923600,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_6.json',
#     'Rank': 6,
#     'Operation': 'write',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 4066940,
#     'Start': 2276.9103,
#     'End': 2276.9236}},
#   {'name': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_0.json',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 2276924300,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_0.json',
#     'Rank': 0,
#     'Operation': 'write',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 4050536,
#     'Start': 2276.9243,
#     'End': 2276.9356}},
#   {'ph': 'E',
#    'ts': 2276925800,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_4.json',
#     'Rank': 4,
#     'Operation': 'write',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 4001833,
#     'Start': 2276.9133,
#     'End': 2276.9258}},
#   {'ph': 'E',
#    'ts': 2276925900,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_5.json',
#     'Rank': 5,
#     'Operation': 'write',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 3992591,
#     'Start': 2276.9131,
#     'End': 2276.9259}},
#   {'name': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_1.json',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 2276926000,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_1.json',
#     'Rank': 1,
#     'Operation': 'write',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 4022804,
#     'Start': 2276.926,
#     'End': 2276.9374}},
#   {'name': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_6.json',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 2276928600,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_6.json',
#     'Rank': 6,
#     'Operation': 'write',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 4033059,
#     'Start': 2276.9286,
#     'End': 2276.9412}},
#   {'name': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_2.json',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 2276928700,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_2.json',
#     'Rank': 2,
#     'Operation': 'write',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 4048488,
#     'Start': 2276.9287,
#     'End': 2276.94}},
#   {'name': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_3.json',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 2276929900,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_3.json',
#     'Rank': 3,
#     'Operation': 'write',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 4013581,
#     'Start': 2276.9299,
#     'End': 2276.9411}},
#   {'name': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_5.json',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 2276930100,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_5.json',
#     'Rank': 5,
#     'Operation': 'write',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 3987909,
#     'Start': 2276.9301,
#     'End': 2276.9425}},
#   {'name': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_4.json',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 2276930600,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_4.json',
#     'Rank': 4,
#     'Operation': 'write',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 4008738,
#     'Start': 2276.9306,
#     'End': 2276.9429}},
#   {'ph': 'E',
#    'ts': 2276934400,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_7.json',
#     'Rank': 7,
#     'Operation': 'write',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 4048271,
#     'Start': 2276.9213,
#     'End': 2276.9344}},
#   {'ph': 'E',
#    'ts': 2276935600,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_0.json',
#     'Rank': 0,
#     'Operation': 'write',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 4050536,
#     'Start': 2276.9243,
#     'End': 2276.9356}},
#   {'ph': 'E',
#    'ts': 2276937400,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_1.json',
#     'Rank': 1,
#     'Operation': 'write',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 4022804,
#     'Start': 2276.926,
#     'End': 2276.9374}},
#   {'name': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_7.json',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 2276939600,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_7.json',
#     'Rank': 7,
#     'Operation': 'write',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 4052768,
#     'Start': 2276.9396,
#     'End': 2276.9522}},
#   {'ph': 'E',
#    'ts': 2276940000,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_2.json',
#     'Rank': 2,
#     'Operation': 'write',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 4048488,
#     'Start': 2276.9287,
#     'End': 2276.94}},
#   {'ph': 'E',
#    'ts': 2276941100,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_3.json',
#     'Rank': 3,
#     'Operation': 'write',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 4013581,
#     'Start': 2276.9299,
#     'End': 2276.9411}},
#   {'ph': 'E',
#    'ts': 2276941200,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_6.json',
#     'Rank': 6,
#     'Operation': 'write',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 4033059,
#     'Start': 2276.9286,
#     'End': 2276.9412}},
#   {'name': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_0.json',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 2276942500,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_0.json',
#     'Rank': 0,
#     'Operation': 'write',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 4074017,
#     'Start': 2276.9425,
#     'End': 2276.9538}},
#   {'ph': 'E',
#    'ts': 2276942500,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_5.json',
#     'Rank': 5,
#     'Operation': 'write',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 3987909,
#     'Start': 2276.9301,
#     'End': 2276.9425}},
#   {'ph': 'E',
#    'ts': 2276942900,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_4.json',
#     'Rank': 4,
#     'Operation': 'write',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 4008738,
#     'Start': 2276.9306,
#     'End': 2276.9429}},
#   {'name': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_1.json',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 2276943100,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_1.json',
#     'Rank': 1,
#     'Operation': 'write',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 3996526,
#     'Start': 2276.9431,
#     'End': 2276.9544}},
#   {'name': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_2.json',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 2276945600,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_2.json',
#     'Rank': 2,
#     'Operation': 'write',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 4023357,
#     'Start': 2276.9456,
#     'End': 2276.9567}},
#   {'name': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_6.json',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 2276946500,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_6.json',
#     'Rank': 6,
#     'Operation': 'write',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 4059180,
#     'Start': 2276.9465,
#     'End': 2276.9596}},
#   {'name': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_3.json',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 2276947000,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_3.json',
#     'Rank': 3,
#     'Operation': 'write',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 4012988,
#     'Start': 2276.947,
#     'End': 2276.9582}},
#   {'name': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_5.json',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 2276947400,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_5.json',
#     'Rank': 5,
#     'Operation': 'write',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 3929153,
#     'Start': 2276.9474,
#     'End': 2276.9594}},
#   {'ph': 'E',
#    'ts': 2276952200,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_7.json',
#     'Rank': 7,
#     'Operation': 'write',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 4052768,
#     'Start': 2276.9396,
#     'End': 2276.9522}},
#   {'ph': 'E',
#    'ts': 2276953800,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_0.json',
#     'Rank': 0,
#     'Operation': 'write',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 4074017,
#     'Start': 2276.9425,
#     'End': 2276.9538}},
#   {'ph': 'E',
#    'ts': 2276954400,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_1.json',
#     'Rank': 1,
#     'Operation': 'write',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 3996526,
#     'Start': 2276.9431,
#     'End': 2276.9544}},
#   {'ph': 'E',
#    'ts': 2276956700,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_2.json',
#     'Rank': 2,
#     'Operation': 'write',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 4023357,
#     'Start': 2276.9456,
#     'End': 2276.9567}},
#   {'ph': 'E',
#    'ts': 2276958200,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_3.json',
#     'Rank': 3,
#     'Operation': 'write',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 4012988,
#     'Start': 2276.947,
#     'End': 2276.9582}},
#   {'ph': 'E',
#    'ts': 2276959400,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_5.json',
#     'Rank': 5,
#     'Operation': 'write',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 3929153,
#     'Start': 2276.9474,
#     'End': 2276.9594}},
#   {'ph': 'E',
#    'ts': 2276959600,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_6.json',
#     'Rank': 6,
#     'Operation': 'write',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 4059180,
#     'Start': 2276.9465,
#     'End': 2276.9596}}],
#  'displayTimeUnit': 'ms',
#  'systemTraceEvents': 'SystemTraceData',
#  'otherData': {'version': 'VaniDL v1.0'},
#  'stackFrames': {},
#  'samples': []}
