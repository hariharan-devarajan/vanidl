# %% [markdown]
# # DLProfile Example using Cosmic Tagger Application

# %% [markdown]
# ## Set imports and neccessary environment variables

# %%
import pathlib
import os
import sys
import matplotlib.pyplot as plt
import warnings
import pprint

# %%
DLPOFILE_DIR="{}".format(pathlib.Path(os.getcwd()).parent.absolute())
sys.path.insert(0, DLPOFILE_DIR)
warnings.filterwarnings('ignore')

# %%
os.environ["DARSHAN_DIR"] = "/soft/perftools/darshan/darshan-3.1.8"
os.environ["DLPROFILE_DIR"] = DLPOFILE_DIR

# %%
from src.dlprofile import DLProfile

# %% [markdown]
# ## Create instrance of DL Profile and load the darshan file

# %%
profile = DLProfile()

# %%
if os.path.exists("/tmp/temp_analysis/run1_p8_pattern.json"):
    os.remove("/tmp/temp_analysis/run1_p8_pattern.json")
DATAPATH_INCLUDES = ["/projects/datascience/dhari/datasets/cosmic_tagger/"]
status = profile.Load("/home/dhari/darshan-logs/apps/cosmic_tagger/run1_p8.darshan", data_paths_include=DATAPATH_INCLUDES)
if status:
    print("Darshan Trace loaded Successfully!")
else:
    print("Darshan Trace load Failed!")
    print(profile._error_str())
# Out:
# Loaded Pre-processed DXT from file: /tmp/temp_analysis/run1_p8_io_df.csv
# [============================================================] 100.0% 538 of 538 Analyzing Access Pattern
# Darshan Trace loaded Successfully!

# %%
df = profile.GetDXTAsDF()
df['Filename'].unique()
# Out:
# [/projects/datascience/dhari/datasets/cosmic_ta..., /projects/datascience/dhari/datasets/cosmic_ta...]
# Categories (2, object): [/projects/datascience/dhari/datasets/cosmic_ta..., /projects/datascience/dhari/datasets/cosmic_ta...]

# %%
class color:
    PURPLE = '\033[95m'
    CYAN = '\033[96m'
    DARKCYAN = '\033[36m'
    BLUE = '\033[94m'
    GREEN = '\033[92m'
    YELLOW = '\033[93m'
    RED = '\033[91m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'
    END = '\033[0m'

# %%
summary = profile.GetSummary()
print("\n")
print(color.BOLD + "Data Access Summary (from Darshan):"+ color.END)
print("Total Job time\t\t\t:\t{:0.2f} seconds".format(summary['job_time']))
#FIXME: calculate time per rank and then take max across it.
print("Time spent in I/O\t\t:\t{:0.2f} seconds".format(summary['total_io_time']))
print("% Time spent in I/O\t\t:\t{:0.2f}%".format(float(summary['total_io_time'])*100/summary['job_time']))
print("Total Data Accessed\t\t:\t{:0.2f} GB".format(float(summary['total_io_bytes'])/1024.0/1024.0/1024.0))
print("Data Access Modules used\t:\t{}".format(summary['io_interface_used']))
print("Data Operations\t\t\t:\t{}".format(summary['io_operations_used']))
print("# of files used\t\t\t:\t{}".format(summary['files_used']))
print("# of MPI Ranks\t\t\t:\t{:0.0f} ranks".format(summary['num_ranks']))
      
print(color.UNDERLINE + "Data Transfer size:"+ color.END)
print("\tMin,Max\t\t\t:\t{:0.0f} bytes and {:0.0f} bytes".format(summary['data_transfer_size']['min'],summary['data_transfer_size']['max']))
print("\tAverage\t\t\t:\t{:0.0f} bytes".format(summary['data_transfer_size']['mean']))
print("\tMedian\t\t\t:\t{:0.0f} bytes".format(summary['data_transfer_size']['median']))
      
print(color.UNDERLINE + "Data Transfer bandwidth: (per rank)"+ color.END)
print("\tMin,Max\t\t\t:\t{:0.0f} B/s and {:0.0f} MB/s".format(summary['data_transfer_bandwidth']['min'],summary['data_transfer_bandwidth']['max']/1024.0/1024.0))
print("\tAverage\t\t\t:\t{:0.0f} MB/s".format(summary['data_transfer_bandwidth']['mean']/1024.0/1024.0))
print("\tMedian\t\t\t:\t{:0.0f} MB/s".format(summary['data_transfer_bandwidth']['median']/1024.0/1024.0))
      
print(color.UNDERLINE + "Access Pattern:"+ color.END)
print("\tSequential\t\t:\t{:0.2f}%".format(float(summary['access_pattern']['sequential'])/summary['access_pattern']['total_operations']*100))
print("\tConsecutive\t\t:\t{:0.2f}%".format(float(summary['access_pattern']['consecutive'])/summary['access_pattern']['total_operations']*100))
#An I/O op issued at an offset greater than where the previous I/O op ended.
#An I/O op issued at the offset immediately after the end of the previous I/O

print("\n")
print(color.BOLD + "Files Summary:"+ color.END)
print("File Types\t\t\t:\t{}".format(summary['file_used_summary']['types']))
print(color.UNDERLINE + "Dataset Size:"+ color.END)
print("\tTotal\t\t\t:\t{:0.3f} GB".format(float(summary['file_used_summary']['size']['total'])/1024.0/1024.0/1024.0))
print("\tMin,Max\t\t\t:\t{:0.3f} GB and {:0.3f} GB".format(float(summary['file_used_summary']['size']['min'])/1024.0/1024.0/1024.0,float(summary['file_used_summary']['size']['max'])/1024.0/1024.0/1024.0))
print("\tAverage\t\t\t:\t{:0.3f} GB".format(float(summary['file_used_summary']['size']['mean'])/1024.0/1024.0/1024.0))
# Out:
# Data Access Summary (from Darshan):
# Total Job time			:	897.00 seconds
# Time spent in I/O		:	69.12 seconds
# % Time spent in I/O		:	7.71%
# Total Data Accessed		:	1.21 GB
# Data Access Modules used	:	['X_POSIX']
# Data Operations			:	['read']
# # of files used			:	['/projects/datascience/dhari/datasets/cosmic_tagger/cosmic_tagging_train.h5', '/projects/datascience/dhari/datasets/cosmic_tagger/cosmic_tagging_test.h5']
# # of MPI Ranks			:	8 ranks
# Data Transfer size:
# 	Min,Max			:	8 bytes and 6745 bytes
# 	Average			:	4177 bytes
# 	Median			:	2531 bytes
# Data Transfer bandwidth: (per rank)
# 	Min,Max			:	93 B/s and 64 MB/s
# 	Average			:	10 MB/s
# 	Median			:	6 MB/s
# Access Pattern:
# 	Sequential		:	nan%
# 	Consecutive		:	nan%
#
#
# Files Summary:
# File Types			:	['h5']
# Dataset Size:
# 	Total			:	32.995 GB
# 	Min,Max			:	4.801 GB and 28.194 GB
# 	Average			:	16.497 GB

# %%
profile.GetJobTime()
# Out:
# 897.0

# %%
profile.GetIOTime()
# Out:
# 370.76259999998746

# %%
for file in df['Filename'].unique():
    print(profile.GetIOTime(filepath=file))
# Out:
# 353.5436999999889
# 17.21889999999856

# %%
for rank in df['Rank'].unique():
    print(profile.GetIOTime(rank=rank))
# Out:
# 69.12400000000414
# 44.3840000000023
# 44.522499999995645
# 43.560499999994505
# 41.539899999992315
# 41.20089999999843
# 43.58680000000109
# 42.84399999999902

# %%
"{:0.2f} MB".format(float(profile.GetIOSize())/1024.0/1024.0)
# Out:
# '1238.90 MB'

# %%
for file in df['Filename'].unique():
    print("{:0.2f} MB".format(float(profile.GetIOSize(filepath=file))/1024.0/1024.0))
# Out:
# 1200.85 MB
# 38.05 MB

# %%
for rank in df['Rank'].unique():
    print("{:0.2f} MB".format(float(profile.GetIOSize(rank=rank))/1024.0/1024.0))
# Out:
# 162.21 MB
# 155.88 MB
# 156.68 MB
# 153.99 MB
# 151.35 MB
# 152.29 MB
# 154.37 MB
# 152.11 MB

# %%
profile.GetFileSizes()
# Out:
# {'cosmic_tagging_test': 5155110775.0, 'cosmic_tagging_train': 30272777678.0}

# %%
for file in df['Filename'].unique():
    print(profile.GetFileSizes(filepath=file))
# Out:
# {'/projects/datascience/dhari/datasets/cosmic_tagger/cosmic_tagging_train.h5': 30272777678}
# {'/projects/datascience/dhari/datasets/cosmic_tagger/cosmic_tagging_test.h5': 5155110775}

# %%
tf = profile.CreateIOTimeline()
plt.figure(figsize=(20,4))
plt.grid()
plt.plot(tf['time_step'], tf['operation_count']);
# Out:
# Loaded Pre-processed Timeline from file: /tmp/temp_analysis/run1_p8_tm_df.csv

# %%
plt.figure(figsize=(20,4))
plt.grid()
plt.plot(tf['time_step'], tf['io_bytes']);

# %%
fig, axs = plt.subplots(nrows=df['Filename'].nunique(), ncols=1, figsize=(20, 10))
i=0
for file in df['Filename'].unique():
    tf = profile.CreateIOTimeline(filepath=file)
    tf.plot(x='time_step',y='operation_count', ax=axs[i])
    axs[i].set_title(file)
    i+=1
# Out:
# Loaded Pre-processed Timeline from file: /tmp/temp_analysis/run1_p8_tm_df_cosmic_tagging_train.csv
# Loaded Pre-processed Timeline from file: /tmp/temp_analysis/run1_p8_tm_df_cosmic_tagging_test.csv

# %%
tfs= []
for rank in df['Rank'].unique():
    tf = profile.CreateIOTimeline(rank=rank)
    tfs.append(tf)
# Out:
# Loaded Pre-processed Timeline from file: /tmp/temp_analysis/run1_p8_tm_df_0.csv
# Loaded Pre-processed Timeline from file: /tmp/temp_analysis/run1_p8_tm_df_1.csv
# Loaded Pre-processed Timeline from file: /tmp/temp_analysis/run1_p8_tm_df_2.csv
# Loaded Pre-processed Timeline from file: /tmp/temp_analysis/run1_p8_tm_df_3.csv
# Loaded Pre-processed Timeline from file: /tmp/temp_analysis/run1_p8_tm_df_4.csv
# Loaded Pre-processed Timeline from file: /tmp/temp_analysis/run1_p8_tm_df_5.csv
# Loaded Pre-processed Timeline from file: /tmp/temp_analysis/run1_p8_tm_df_6.csv
# Loaded Pre-processed Timeline from file: /tmp/temp_analysis/run1_p8_tm_df_7.csv

# %%
tfs[0].plot(x='time_step',y='operation_count')

# %%
tfs[1].plot(x='time_step',y='operation_count')

# %%
tfs[2].plot(x='time_step',y='operation_count')

# %%
tfs[3].plot(x='time_step',y='operation_count')

# %%
tfs[4].plot(x='time_step',y='operation_count')

# %%
tfs[5].plot(x='time_step',y='operation_count')

# %%
tfs[6].plot(x='time_step',y='operation_count')

# %%
tfs[7].plot(x='time_step',y='operation_count')

# %%
request_df = profile.GetIORequestDistribution()
request_df.plot(kind='bar', figsize=(10, 4));

# %%
fig, axs = plt.subplots(nrows=df['Filename'].nunique(), ncols=1, figsize=(20, 10))
i=0
for file in df['Filename'].unique():
    tf = profile.GetIORequestDistribution(filepath=file)
    tf.plot(kind='bar', figsize=(10, 4), ax=axs[i])
    axs[i].set_title(file)
    i+=1

# %%
tfs =[]
for rank in df['Rank'].unique():
    tf = profile.GetIORequestDistribution(rank=rank)
    tfs.append(tf)

# %%
tfs[0].plot(kind='bar', figsize=(10, 4))

# %%
tfs[1].plot(kind='bar', figsize=(10, 4))

# %%
tfs[2].plot(kind='bar', figsize=(10, 4))

# %%
tfs[3].plot(kind='bar', figsize=(10, 4))

# %%
tfs[4].plot(kind='bar', figsize=(10, 4))

# %%
tfs[5].plot(kind='bar', figsize=(10, 4))

# %%
tfs[6].plot(kind='bar', figsize=(10, 4))

# %%
tfs[7].plot(kind='bar', figsize=(10, 4))

# %%
pp = pprint.PrettyPrinter(indent=1)
for file in df['Filename'].unique():
    pp.pprint(profile.GetFileSummary(file,ext='h5'))
# Out:
# {'ext': 'h5',
#  'filename': 'cosmic_tagging_train',
#  'io_size': 1259184741,
#  'io_time': 353.5436999999889,
#  'path': '/projects/datascience/dhari/datasets/cosmic_tagger/cosmic_tagging_train.h5',
#  'size': 30272777678,
#  'special': {'keys': [{'keys': [{'keys': [{'name': 'cluster_extents',
#                                            'obj': <HDF5 dataset "cluster_extents": shape (129225,), type "|V16">,
#                                            'shape': (129225,),
#                                            'size': 129225,
#                                            'type': 'dataset'},
#                                           {'name': 'extents',
#                                            'obj': <HDF5 dataset "extents": shape (43075,), type "|V16">,
#                                            'shape': (43075,),
#                                            'size': 43075,
#                                            'type': 'dataset'},
#                                           {'name': 'image_meta',
#                                            'obj': <HDF5 dataset "image_meta": shape (129225,), type "|V72">,
#                                            'shape': (129225,),
#                                            'size': 129225,
#                                            'type': 'dataset'},
#                                           {'name': 'projection_extents',
#                                            'obj': <HDF5 dataset "projection_extents": shape (129225,), type "|V16">,
#                                            'shape': (129225,),
#                                            'size': 129225,
#                                            'type': 'dataset'},
#                                           {'name': 'voxels',
#                                            'obj': <HDF5 dataset "voxels": shape (1162887,), type "|V16">,
#                                            'shape': (1162887,),
#                                            'size': 1162887,
#                                            'type': 'dataset'}],
#                                  'name': 'cluster2d_sbndneutrino_group',
#                                  'type': 'group'},
#                                 {'keys': [{'name': 'cluster_extents',
#                                            'obj': <HDF5 dataset "cluster_extents": shape (128946897,), type "|V16">,
#                                            'shape': (128946897,),
#                                            'size': 128946897,
#                                            'type': 'dataset'},
#                                           {'name': 'extents',
#                                            'obj': <HDF5 dataset "extents": shape (43075,), type "|V16">,
#                                            'shape': (43075,),
#                                            'size': 43075,
#                                            'type': 'dataset'},
#                                           {'name': 'image_meta',
#                                            'obj': <HDF5 dataset "image_meta": shape (129225,), type "|V72">,
#                                            'shape': (129225,),
#                                            'size': 129225,
#                                            'type': 'dataset'},
#                                           {'name': 'projection_extents',
#                                            'obj': <HDF5 dataset "projection_extents": shape (129225,), type "|V16">,
#                                            'shape': (129225,),
#                                            'size': 129225,
#                                            'type': 'dataset'},
#                                           {'name': 'voxels',
#                                            'obj': <HDF5 dataset "voxels": shape (1244443240,), type "|V16">,
#                                            'shape': (1244443240,),
#                                            'size': 1244443240,
#                                            'type': 'dataset'}],
#                                  'name': 'cluster2d_sbndsegmerged_group',
#                                  'type': 'group'},
#                                 {'keys': [{'name': 'extents',
#                                            'obj': <HDF5 dataset "extents": shape (43075,), type "|V16">,
#                                            'shape': (43075,),
#                                            'size': 43075,
#                                            'type': 'dataset'},
#                                           {'name': 'particles',
#                                            'obj': <HDF5 dataset "particles": shape (312644,), type "|V344">,
#                                            'shape': (312644,),
#                                            'size': 312644,
#                                            'type': 'dataset'}],
#                                  'name': 'particle_sbndneutrino_group',
#                                  'type': 'group'},
#                                 {'keys': [{'name': 'extents',
#                                            'obj': <HDF5 dataset "extents": shape (43075,), type "|V16">,
#                                            'shape': (43075,),
#                                            'size': 43075,
#                                            'type': 'dataset'},
#                                           {'name': 'image_meta',
#                                            'obj': <HDF5 dataset "image_meta": shape (129225,), type "|V72">,
#                                            'shape': (129225,),
#                                            'size': 129225,
#                                            'type': 'dataset'},
#                                           {'name': 'voxel_extents',
#                                            'obj': <HDF5 dataset "voxel_extents": shape (129225,), type "|V16">,
#                                            'shape': (129225,),
#                                            'size': 129225,
#                                            'type': 'dataset'},
#                                           {'name': 'voxels',
#                                            'obj': <HDF5 dataset "voxels": shape (2461214260,), type "|V16">,
#                                            'shape': (2461214260,),
#                                            'size': 2461214260,
#                                            'type': 'dataset'}],
#                                  'name': 'sparse2d_sbnd_cosmicseg_group',
#                                  'type': 'group'},
#                                 {'keys': [{'name': 'extents',
#                                            'obj': <HDF5 dataset "extents": shape (43075,), type "|V16">,
#                                            'shape': (43075,),
#                                            'size': 43075,
#                                            'type': 'dataset'},
#                                           {'name': 'image_meta',
#                                            'obj': <HDF5 dataset "image_meta": shape (129225,), type "|V72">,
#                                            'shape': (129225,),
#                                            'size': 129225,
#                                            'type': 'dataset'},
#                                           {'name': 'voxel_extents',
#                                            'obj': <HDF5 dataset "voxel_extents": shape (129225,), type "|V16">,
#                                            'shape': (129225,),
#                                            'size': 129225,
#                                            'type': 'dataset'},
#                                           {'name': 'voxels',
#                                            'obj': <HDF5 dataset "voxels": shape (2461214260,), type "|V16">,
#                                            'shape': (2461214260,),
#                                            'size': 2461214260,
#                                            'type': 'dataset'}],
#                                  'name': 'sparse2d_sbndwire_group',
#                                  'type': 'group'}],
#                        'name': 'Data',
#                        'type': 'group'},
#                       {'keys': [{'name': 'event_id',
#                                  'obj': <HDF5 dataset "event_id": shape (43075,), type "|V24">,
#                                  'shape': (43075,),
#                                  'size': 43075,
#                                  'type': 'dataset'}],
#                        'name': 'Events',
#                        'type': 'group'}],
#              'name': 'cosmic_tagging_train',
#              'type': 'group'}}
# {'ext': 'h5',
#  'filename': 'cosmic_tagging_test',
#  'io_size': 39899372,
#  'io_time': 17.21889999999856,
#  'path': '/projects/datascience/dhari/datasets/cosmic_tagger/cosmic_tagging_test.h5',
#  'size': 5155110775,
#  'special': {'keys': [{'keys': [{'keys': [{'name': 'cluster_extents',
#                                            'obj': <HDF5 dataset "cluster_extents": shape (22086,), type "|V16">,
#                                            'shape': (22086,),
#                                            'size': 22086,
#                                            'type': 'dataset'},
#                                           {'name': 'extents',
#                                            'obj': <HDF5 dataset "extents": shape (7362,), type "|V16">,
#                                            'shape': (7362,),
#                                            'size': 7362,
#                                            'type': 'dataset'},
#                                           {'name': 'image_meta',
#                                            'obj': <HDF5 dataset "image_meta": shape (22086,), type "|V72">,
#                                            'shape': (22086,),
#                                            'size': 22086,
#                                            'type': 'dataset'},
#                                           {'name': 'projection_extents',
#                                            'obj': <HDF5 dataset "projection_extents": shape (22086,), type "|V16">,
#                                            'shape': (22086,),
#                                            'size': 22086,
#                                            'type': 'dataset'},
#                                           {'name': 'voxels',
#                                            'obj': <HDF5 dataset "voxels": shape (198756,), type "|V16">,
#                                            'shape': (198756,),
#                                            'size': 198756,
#                                            'type': 'dataset'}],
#                                  'name': 'cluster2d_sbndneutrino_group',
#                                  'type': 'group'},
#                                 {'keys': [{'name': 'cluster_extents',
#                                            'obj': <HDF5 dataset "cluster_extents": shape (22021827,), type "|V16">,
#                                            'shape': (22021827,),
#                                            'size': 22021827,
#                                            'type': 'dataset'},
#                                           {'name': 'extents',
#                                            'obj': <HDF5 dataset "extents": shape (7362,), type "|V16">,
#                                            'shape': (7362,),
#                                            'size': 7362,
#                                            'type': 'dataset'},
#                                           {'name': 'image_meta',
#                                            'obj': <HDF5 dataset "image_meta": shape (22086,), type "|V72">,
#                                            'shape': (22086,),
#                                            'size': 22086,
#                                            'type': 'dataset'},
#                                           {'name': 'projection_extents',
#                                            'obj': <HDF5 dataset "projection_extents": shape (22086,), type "|V16">,
#                                            'shape': (22086,),
#                                            'size': 22086,
#                                            'type': 'dataset'},
#                                           {'name': 'voxels',
#                                            'obj': <HDF5 dataset "voxels": shape (211291577,), type "|V16">,
#                                            'shape': (211291577,),
#                                            'size': 211291577,
#                                            'type': 'dataset'}],
#                                  'name': 'cluster2d_sbndsegmerged_group',
#                                  'type': 'group'},
#                                 {'keys': [{'name': 'extents',
#                                            'obj': <HDF5 dataset "extents": shape (7362,), type "|V16">,
#                                            'shape': (7362,),
#                                            'size': 7362,
#                                            'type': 'dataset'},
#                                           {'name': 'particles',
#                                            'obj': <HDF5 dataset "particles": shape (53686,), type "|V344">,
#                                            'shape': (53686,),
#                                            'size': 53686,
#                                            'type': 'dataset'}],
#                                  'name': 'particle_sbndneutrino_group',
#                                  'type': 'group'},
#                                 {'keys': [{'name': 'extents',
#                                            'obj': <HDF5 dataset "extents": shape (7362,), type "|V16">,
#                                            'shape': (7362,),
#                                            'size': 7362,
#                                            'type': 'dataset'},
#                                           {'name': 'image_meta',
#                                            'obj': <HDF5 dataset "image_meta": shape (22086,), type "|V72">,
#                                            'shape': (22086,),
#                                            'size': 22086,
#                                            'type': 'dataset'},
#                                           {'name': 'voxel_extents',
#                                            'obj': <HDF5 dataset "voxel_extents": shape (22086,), type "|V16">,
#                                            'shape': (22086,),
#                                            'size': 22086,
#                                            'type': 'dataset'},
#                                           {'name': 'voxels',
#                                            'obj': <HDF5 dataset "voxels": shape (419485201,), type "|V16">,
#                                            'shape': (419485201,),
#                                            'size': 419485201,
#                                            'type': 'dataset'}],
#                                  'name': 'sparse2d_sbnd_cosmicseg_group',
#                                  'type': 'group'},
#                                 {'keys': [{'name': 'extents',
#                                            'obj': <HDF5 dataset "extents": shape (7362,), type "|V16">,
#                                            'shape': (7362,),
#                                            'size': 7362,
#                                            'type': 'dataset'},
#                                           {'name': 'image_meta',
#                                            'obj': <HDF5 dataset "image_meta": shape (22086,), type "|V72">,
#                                            'shape': (22086,),
#                                            'size': 22086,
#                                            'type': 'dataset'},
#                                           {'name': 'voxel_extents',
#                                            'obj': <HDF5 dataset "voxel_extents": shape (22086,), type "|V16">,
#                                            'shape': (22086,),
#                                            'size': 22086,
#                                            'type': 'dataset'},
#                                           {'name': 'voxels',
#                                            'obj': <HDF5 dataset "voxels": shape (419485201,), type "|V16">,
#                                            'shape': (419485201,),
#                                            'size': 419485201,
#                                            'type': 'dataset'}],
#                                  'name': 'sparse2d_sbndwire_group',
#                                  'type': 'group'}],
#                        'name': 'Data',
#                        'type': 'group'},
#                       {'keys': [{'name': 'event_id',
#                                  'obj': <HDF5 dataset "event_id": shape (7362,), type "|V24">,
#                                  'shape': (7362,),
#                                  'size': 7362,
#                                  'type': 'dataset'}],
#                        'name': 'Events',
#                        'type': 'group'}],
#              'name': 'cosmic_tagging_test',
#              'type': 'group'}}
