# %% [markdown]
# # DLProfile Example using Climate Seg Benchmark

# %% [markdown]
# ## Set imports and neccessary environment variables

# %%
import pathlib
import os
import sys
import matplotlib.pyplot as plt
import warnings
import pprint
import pandas

# %%
VANIDL_DIR="{}".format(pathlib.Path(os.getcwd()).parent.parent.parent.absolute())
sys.path.insert(0, VANIDL_DIR)
warnings.filterwarnings('ignore')

# %%
os.environ["DARSHAN_DIR"] = "/soft/perftools/darshan/darshan-3.1.8"
os.environ["VANIDL_DIR"] = VANIDL_DIR

# %% [markdown]
# #### Formatting

# %%
pp = pprint.PrettyPrinter(indent=1)
class color:
    PURPLE = '\033[95m'
    CYAN = '\033[96m'
    DARKCYAN = '\033[36m'
    BLUE = '\033[94m'
    GREEN = '\033[92m'
    YELLOW = '\033[93m'
    RED = '\033[91m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'
    END = '\033[0m'

# %% [markdown]
# ## Create instrance of DL Profile and load the darshan file

# %%
from src.vanidl import VaniDL
profile = VaniDL()

# %%
#import shutil
#shutil.rmtree('/tmp/temp_analysis')

# %%
DATAPATH_INCLUDES = []
status = profile.Load("/home/dhari/darshan-logs/apps/climate/climate_run1_p128.darshan", data_paths_include=DATAPATH_INCLUDES)
if status:
    print("Darshan Trace loaded Successfully!")
else:
    print("Darshan Trace load Failed!")
    print(profile._error_str())
# Out:
# [============================================================] 100.0% 23599 of 23599 Parsing DXT File
# [============================================================] 100.0% 47068 of 47068 Parsing Darshan File
# Darshan Trace loaded Successfully!

# %% [markdown]
# ## Use Profile object to analyze the darshan I/O trace.

# %% [markdown]
# ### Verify if object works
#
# The GetDXTAsDF() function enables users to perform analysis

# %%
df = profile.GetDXTAsDF()
pp.pprint("Files used in the application")
pp.pprint(df['Filename'].unique().tolist())
# Out:
# 'Files used in the application'
# ['/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#  '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/validation/stats.h5',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_0.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_0.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_1.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_1.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_2.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_2.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_3.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_3.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_4.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_4.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_4.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_5.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_5.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_6.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_6.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_7.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_7.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_7.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_8.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_8.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_9.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_9.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_9.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_10.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_10.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_11.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_11.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_12.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_12.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_13.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_13.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_14.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_14.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_15.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_15.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_16.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_16.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_17.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_17.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_18.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_18.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_18.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_19.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_19.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_19.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_20.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_20.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_21.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_21.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_22.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_22.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_23.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_23.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_24.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_24.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_25.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_25.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_26.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_26.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_26.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_27.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_28.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_28.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_29.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_29.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_30.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_30.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_30.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_31.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_31.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_32.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_32.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_33.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_33.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_34.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_35.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_35.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_35.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_36.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_36.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_37.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_37.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_38.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_38.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_39.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_39.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_39.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_40.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_40.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_41.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_41.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_42.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_42.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_42.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_43.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_43.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_43.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_44.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_44.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_45.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_45.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_46.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_46.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_47.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_47.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_48.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_49.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_49.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_49.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_50.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_50.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_50.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_51.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_51.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_51.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_52.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_52.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_53.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_53.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_54.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_54.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_54.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_55.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_55.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_55.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_56.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_56.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_56.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_57.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_57.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_57.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_58.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_58.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_58.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_59.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_59.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_59.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_60.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_60.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_60.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_61.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_61.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_62.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_62.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_63.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_63.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_63.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_64.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_64.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_65.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_65.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_66.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_66.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_67.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_67.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_67.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_68.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_68.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_68.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_69.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_69.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_70.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_70.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_71.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_71.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_72.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_72.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_72.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_73.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_73.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_74.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_74.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_74.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_75.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_75.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_75.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_76.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_76.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_76.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_77.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_77.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_78.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_78.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_78.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_79.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_79.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_80.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_80.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_81.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_81.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_82.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_82.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_83.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_83.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_83.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_84.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_84.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_84.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_85.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_85.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_86.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_86.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_87.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_87.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_87.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_88.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_88.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_89.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_89.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_89.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_90.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_90.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_91.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_91.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_91.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_92.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_92.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_93.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_93.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_93.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_94.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_94.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_94.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_95.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_95.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_96.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_96.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_97.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_97.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_98.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_98.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_99.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_99.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_100.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_100.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_100.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_101.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_101.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_102.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_102.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_102.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_103.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_103.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_104.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_104.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_104.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_105.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_105.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_105.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_106.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_106.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_106.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_107.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_107.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_108.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_108.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_109.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_109.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_110.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_110.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_111.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_111.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_112.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_112.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_113.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_113.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_114.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_114.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_115.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_115.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_115.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_116.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_116.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_116.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_117.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_117.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_118.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_118.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_119.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_120.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_120.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_121.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_121.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_122.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_122.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_123.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_123.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_124.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_124.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_124.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_125.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_125.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_126.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_126.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_127.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_127.json']

# %%
df_normal = profile.GetTraceAsDF()
pp.pprint("Files used in the application")
pp.pprint(df_normal['Filename'].unique().tolist())
# Out:
# 'Files used in the application'
# ['/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_0.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_0.json',
#  '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/validation/stats.h5',
#  '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_1.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_1.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_1.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_2.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_2.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_2.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_3.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_3.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_3.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_4.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_4.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_4.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_5.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_5.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_5.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_6.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_6.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_7.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_7.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_7.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_8.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_8.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_8.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_9.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_9.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_9.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_10.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_10.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_10.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_11.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_11.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_11.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_12.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_12.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_13.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_13.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_13.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_14.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_14.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_14.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_15.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_15.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_15.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_16.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_16.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_16.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_17.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_17.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_18.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_18.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_18.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_19.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_19.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_19.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_20.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_20.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_20.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_21.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_21.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_21.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_22.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_22.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_22.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_23.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_23.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_23.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_24.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_24.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_24.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_25.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_25.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_25.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_26.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_26.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_26.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_27.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_27.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_28.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_28.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_28.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_29.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_29.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_29.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_30.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_30.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_30.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_31.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_31.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_31.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_32.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_32.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_32.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_33.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_33.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_33.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_34.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_34.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_35.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_35.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_35.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_36.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_36.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_36.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_37.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_37.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_38.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_38.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_38.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_39.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_39.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_39.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_40.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_40.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_40.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_41.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_41.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_41.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_42.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_42.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_42.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_43.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_43.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_43.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_44.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_44.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_44.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_45.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_45.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_46.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_46.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_46.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_47.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_47.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_47.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_48.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_48.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_49.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_49.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_49.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_50.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_50.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_50.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_51.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_51.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_51.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_52.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_52.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_52.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_53.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_53.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_53.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_54.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_54.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_54.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_55.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_55.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_55.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_56.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_56.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_56.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_57.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_57.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_57.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_58.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_58.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_58.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_59.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_59.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_59.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_60.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_60.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_60.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_61.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_61.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_61.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_62.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_62.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_62.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_63.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_63.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_63.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_64.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_64.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_64.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_65.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_65.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_65.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_66.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_66.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_66.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_67.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_67.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_67.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_68.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_68.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_68.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_69.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_69.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_69.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_70.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_70.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_70.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_71.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_71.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_71.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_72.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_72.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_72.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_73.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_73.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_73.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_74.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_74.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_74.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_75.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_75.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_75.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_76.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_76.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_76.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_77.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_77.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_77.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_78.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_78.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_78.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_79.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_79.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_79.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_80.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_80.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_80.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_81.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_81.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_81.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_82.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_82.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_82.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_83.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_83.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_83.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_84.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_84.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_84.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_85.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_85.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_85.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_86.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_86.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_86.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_87.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_87.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_87.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_88.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_88.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_88.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_89.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_89.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_89.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_90.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_90.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_90.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_91.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_91.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_91.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_92.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_92.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_92.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_93.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_93.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_93.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_94.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_94.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_94.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_95.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_95.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_95.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_96.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_96.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_96.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_97.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_97.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_97.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_98.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_98.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_98.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_99.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_99.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_99.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_100.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_100.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_100.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_101.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_101.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_101.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_102.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_102.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_102.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_103.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_103.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_103.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_104.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_104.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_104.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_105.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_105.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_105.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_106.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_106.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_106.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_107.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_107.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_107.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_108.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_108.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_108.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_109.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_109.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_109.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_110.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_110.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_110.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_111.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_111.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_111.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_112.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_112.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_112.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_113.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_113.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_114.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_114.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_115.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_115.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_115.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_116.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_116.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_116.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_117.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_117.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_117.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_118.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_118.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_118.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_119.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_119.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_120.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_120.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_120.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_121.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_121.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_121.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_122.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_122.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_122.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_123.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_123.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_123.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_124.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_124.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_124.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_125.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_125.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_125.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_126.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_126.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_126.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_127.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_127.json',
#  '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_127.json']

# %% [markdown]
# ### Collect the summary of the Application

# %%
summary = profile.GetSummary()
print("\n")
print(color.BOLD + "Data Access Summary (from Darshan):"+ color.END)
print("Total Job time\t\t\t:\t{:0.2f} seconds".format(summary['job_time']))
#FIXME: calculate time per rank and then take max across it.
print("Time spent in I/O\t\t:\t{:0.2f} seconds".format(summary['total_io_time']))
print("% Time spent in I/O\t\t:\t{:0.2f}%".format(float(summary['total_io_time'])*100/summary['job_time']))
print("Total Data Accessed\t\t:\t{:0.2f} GB".format(float(summary['total_io_bytes'])/1024.0/1024.0/1024.0))
print("Data Access Modules used\t:\t{}".format(summary['io_interface_used']))
print("Data Operations\t\t\t:\t{}".format(summary['io_operations_used']))
print("# of files used\t\t\t:\t{}".format(len(summary['files_used'])))
print("# of MPI Ranks\t\t\t:\t{:0.0f} ranks".format(summary['num_ranks']))
      
print(color.UNDERLINE + "Data Transfer size:"+ color.END)
print("\tMin,Max\t\t\t:\t{:0.0f} bytes and {:0.0f} bytes".format(summary['data_transfer_size']['min'],summary['data_transfer_size']['max']))
print("\tAverage\t\t\t:\t{:0.0f} bytes".format(summary['data_transfer_size']['mean']))
print("\tMedian\t\t\t:\t{:0.0f} bytes".format(summary['data_transfer_size']['median']))
      
print(color.UNDERLINE + "Data Transfer bandwidth: (per rank)"+ color.END)
print("\tMin,Max\t\t\t:\t{:0.0f} B/s and {:0.0f} MB/s".format(summary['data_transfer_bandwidth']['min'],summary['data_transfer_bandwidth']['max']/1024.0/1024.0))
print("\tAverage\t\t\t:\t{:0.0f} MB/s".format(summary['data_transfer_bandwidth']['mean']/1024.0/1024.0))
print("\tMedian\t\t\t:\t{:0.0f} MB/s".format(summary['data_transfer_bandwidth']['median']/1024.0/1024.0))
      
print(color.UNDERLINE + "Access Pattern:"+ color.END)
print("\tSequential\t\t:\t{:0.2f}%".format(float(summary['access_pattern']['sequential'])))
print("\tConsecutive\t\t:\t{:0.2f}%".format(float(summary['access_pattern']['consecutive'])))
#An I/O op issued at an offset greater than where the previous I/O op ended.
#An I/O op issued at the offset immediately after the end of the previous I/O

print("\n")
print(color.BOLD + "Files Summary:"+ color.END)
print("File Types\t\t\t:\t{}".format(summary['file_used_summary']['types']))
print(color.UNDERLINE + "Dataset Size:"+ color.END)
print("\tTotal\t\t\t:\t{:0.3f} GB".format(float(summary['file_used_summary']['size']['total'])/1024.0/1024.0/1024.0))
print("\tMin,Max\t\t\t:\t{:0.3f} GB and {:0.3f} GB".format(float(summary['file_used_summary']['size']['min'])/1024.0/1024.0/1024.0,float(summary['file_used_summary']['size']['max'])/1024.0/1024.0/1024.0))
print("\tAverage\t\t\t:\t{:0.3f} GB".format(float(summary['file_used_summary']['size']['mean'])/1024.0/1024.0/1024.0))
# Out:
# Data Access Summary (from Darshan):
# Total Job time			:	395.00 seconds
# Time spent in I/O		:	0.08 seconds
# % Time spent in I/O		:	0.02%
# Total Data Accessed		:	1.19 GB
# Data Access Modules used	:	['X_POSIX']
# Data Operations			:	['read' 'write']
# # of files used			:	298
# # of MPI Ranks			:	128 ranks
# Data Transfer size:
# 	Min,Max			:	8 bytes and 4661871 bytes
# 	Average			:	330018 bytes
# 	Median			:	512 bytes
# Data Transfer bandwidth: (per rank)
# 	Min,Max			:	426 B/s and 332 MB/s
# 	Average			:	23 MB/s
# 	Median			:	0 MB/s
# Access Pattern:
# 	Sequential		:	46.19%
# 	Consecutive		:	13.20%
#
#
# Files Summary:
# File Types			:	['h5' 'json']
# Dataset Size:
# 	Total			:	1.493 GB
# 	Min,Max			:	0.000 GB and 0.004 GB
# 	Average			:	0.004 GB

# %%
pp.pprint("Job time : {} seconds".format(profile.GetJobTime()))
# Out:
# 'Job time : 395.0 seconds'

# %%
pp.pprint("Time spent by application on I/O: {} seconds".format(profile.GetIOTime()))
# Out:
# 'Time spent by application on I/O: 0.08062500000000031 seconds'

# %% [markdown]
# ### I/O time spent on each file

# %%
for file in df['Filename'].unique()[:16]:
    print("I/O time for file {}: {:0.2f} seconds".format(file,profile.GetIOTime(filepath=file)))
# Out:
# I/O time for file /lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5: 0.02 seconds
# I/O time for file /lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/validation/stats.h5: 0.03 seconds
# I/O time for file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_0.json: 0.01 seconds
# I/O time for file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_0.json: 0.01 seconds
# I/O time for file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_1.json: 0.01 seconds
# I/O time for file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_1.json: 0.01 seconds
# I/O time for file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_2.json: 0.01 seconds
# I/O time for file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_2.json: 0.01 seconds
# I/O time for file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_3.json: 0.01 seconds
# I/O time for file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_3.json: 0.01 seconds
# I/O time for file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_4.json: 0.01 seconds
# I/O time for file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_4.json: 0.01 seconds
# I/O time for file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_4.json: 0.01 seconds
# I/O time for file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_5.json: 0.01 seconds
# I/O time for file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_5.json: 0.01 seconds
# I/O time for file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_6.json: 0.01 seconds

# %% [markdown]
# ### I/O Time spent per rank

# %%
for rank in df['Rank'].unique()[:16]:
    print("I/O time for rank {}: {:0.2f} seconds".format(rank,profile.GetIOTime(rank=rank)))
# Out:
# I/O time for rank 0: 0.07 seconds
# I/O time for rank 1: 0.08 seconds
# I/O time for rank 2: 0.08 seconds
# I/O time for rank 3: 0.07 seconds
# I/O time for rank 4: 0.08 seconds
# I/O time for rank 5: 0.07 seconds
# I/O time for rank 6: 0.08 seconds
# I/O time for rank 7: 0.08 seconds
# I/O time for rank 8: 0.08 seconds
# I/O time for rank 9: 0.09 seconds
# I/O time for rank 10: 0.08 seconds
# I/O time for rank 11: 0.08 seconds
# I/O time for rank 12: 0.08 seconds
# I/O time for rank 13: 0.08 seconds
# I/O time for rank 14: 0.07 seconds
# I/O time for rank 15: 0.08 seconds

# %%
"Total I/O performed by application: {:0.2f} GB".format(float(profile.GetIOSize())/1024.0/1024.0/1024.0)
# Out:
# 'Total I/O performed by application: 1.19 GB'

# %% [markdown]
# ### I/O performed on each file

# %%
for file in df['Filename'].unique()[:16]:
    print("I/O performed on file {}: {:0.2f} MB".format(file,float(profile.GetIOSize(filepath=file))/1024.0/1024.0))
# Out:
# I/O performed on file /lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5: 0.60 MB
# I/O performed on file /lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/validation/stats.h5: 0.60 MB
# I/O performed on file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_0.json: 4.11 MB
# I/O performed on file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_0.json: 4.09 MB
# I/O performed on file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_1.json: 4.12 MB
# I/O performed on file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_1.json: 4.15 MB
# I/O performed on file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_2.json: 4.09 MB
# I/O performed on file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_2.json: 4.11 MB
# I/O performed on file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_3.json: 4.16 MB
# I/O performed on file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_3.json: 4.13 MB
# I/O performed on file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_4.json: 4.09 MB
# I/O performed on file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_4.json: 4.11 MB
# I/O performed on file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_4.json: 4.13 MB
# I/O performed on file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_5.json: 4.15 MB
# I/O performed on file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_5.json: 4.14 MB
# I/O performed on file /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_6.json: 4.31 MB

# %%
for rank in df['Rank'].unique()[:16]:
    print("I/O performed by rank {}: {:0.2f} MB".format(rank, float(profile.GetIOSize(rank=rank))/1024.0/1024.0))
# Out:
# I/O performed by rank 0: 8.20 MB
# I/O performed by rank 1: 8.28 MB
# I/O performed by rank 2: 8.21 MB
# I/O performed by rank 3: 8.30 MB
# I/O performed by rank 4: 12.34 MB
# I/O performed by rank 5: 8.30 MB
# I/O performed by rank 6: 8.60 MB
# I/O performed by rank 7: 12.25 MB
# I/O performed by rank 8: 8.36 MB
# I/O performed by rank 9: 12.25 MB
# I/O performed by rank 10: 8.63 MB
# I/O performed by rank 11: 8.22 MB
# I/O performed by rank 12: 8.30 MB
# I/O performed by rank 13: 8.30 MB
# I/O performed by rank 14: 8.29 MB
# I/O performed by rank 15: 8.23 MB

# %%
print("Size of dataset (bytes)")
pp.pprint(profile.GetFileSizes())
# Out:
# Size of dataset (bytes)
# {'stats': 4752.0,
#  'timeline_2_0_1': 4238334.0,
#  'timeline_2_0_10': 4548843.0,
#  'timeline_2_0_100': 4198490.0,
#  'timeline_2_0_101': 4312527.0,
#  'timeline_2_0_102': 4198715.0,
#  'timeline_2_0_103': 4173719.0,
#  'timeline_2_0_104': 4250058.0,
#  'timeline_2_0_105': 4210415.0,
#  'timeline_2_0_106': 4271223.0,
#  'timeline_2_0_107': 4206367.0,
#  'timeline_2_0_108': 4222534.0,
#  'timeline_2_0_109': 4194481.0,
#  'timeline_2_0_11': 4265874.0,
#  'timeline_2_0_110': 4260081.0,
#  'timeline_2_0_111': 4260599.0,
#  'timeline_2_0_112': 4237863.0,
#  'timeline_2_0_115': 4237596.0,
#  'timeline_2_0_116': 4581647.0,
#  'timeline_2_0_117': 4289276.0,
#  'timeline_2_0_118': 4202310.0,
#  'timeline_2_0_120': 4227704.0,
#  'timeline_2_0_121': 4249141.0,
#  'timeline_2_0_122': 4296774.0,
#  'timeline_2_0_123': 4199706.0,
#  'timeline_2_0_124': 4179225.0,
#  'timeline_2_0_125': 4243818.0,
#  'timeline_2_0_126': 4266992.0,
#  'timeline_2_0_127': 4289122.0,
#  'timeline_2_0_13': 4254797.0,
#  'timeline_2_0_14': 4293357.0,
#  'timeline_2_0_15': 4236797.0,
#  'timeline_2_0_16': 4180102.0,
#  'timeline_2_0_18': 4234094.0,
#  'timeline_2_0_19': 4210681.0,
#  'timeline_2_0_2': 4167736.0,
#  'timeline_2_0_20': 4371049.0,
#  'timeline_2_0_21': 4229744.0,
#  'timeline_2_0_22': 4285652.0,
#  'timeline_2_0_23': 4249694.0,
#  'timeline_2_0_24': 4363393.0,
#  'timeline_2_0_25': 4261156.0,
#  'timeline_2_0_26': 4221033.0,
#  'timeline_2_0_28': 4209259.0,
#  'timeline_2_0_29': 4273428.0,
#  'timeline_2_0_3': 4290987.0,
#  'timeline_2_0_30': 4241522.0,
#  'timeline_2_0_31': 4298446.0,
#  'timeline_2_0_32': 4237856.0,
#  'timeline_2_0_33': 4276828.0,
#  'timeline_2_0_35': 4265238.0,
#  'timeline_2_0_36': 4248701.0,
#  'timeline_2_0_38': 4259451.0,
#  'timeline_2_0_39': 4661871.0,
#  'timeline_2_0_4': 4327760.0,
#  'timeline_2_0_40': 4243168.0,
#  'timeline_2_0_41': 4231963.0,
#  'timeline_2_0_42': 4407632.0,
#  'timeline_2_0_43': 4168160.0,
#  'timeline_2_0_44': 4238804.0,
#  'timeline_2_0_46': 4236125.0,
#  'timeline_2_0_47': 4221099.0,
#  'timeline_2_0_49': 4184951.0,
#  'timeline_2_0_5': 4274925.0,
#  'timeline_2_0_50': 4204860.0,
#  'timeline_2_0_51': 4265193.0,
#  'timeline_2_0_52': 4356363.0,
#  'timeline_2_0_53': 4333772.0,
#  'timeline_2_0_54': 4191840.0,
#  'timeline_2_0_55': 4201101.0,
#  'timeline_2_0_56': 4234452.0,
#  'timeline_2_0_57': 4209785.0,
#  'timeline_2_0_58': 4275853.0,
#  'timeline_2_0_59': 4286387.0,
#  'timeline_2_0_60': 4184702.0,
#  'timeline_2_0_61': 4218838.0,
#  'timeline_2_0_62': 4270890.0,
#  'timeline_2_0_63': 4241035.0,
#  'timeline_2_0_64': 4428352.0,
#  'timeline_2_0_65': 4215249.0,
#  'timeline_2_0_66': 4204203.0,
#  'timeline_2_0_67': 4296149.0,
#  'timeline_2_0_68': 4213716.0,
#  'timeline_2_0_69': 4240915.0,
#  'timeline_2_0_7': 4233344.0,
#  'timeline_2_0_70': 4217929.0,
#  'timeline_2_0_71': 4374256.0,
#  'timeline_2_0_72': 4245349.0,
#  'timeline_2_0_73': 4241596.0,
#  'timeline_2_0_74': 4230932.0,
#  'timeline_2_0_75': 4209674.0,
#  'timeline_2_0_76': 4421590.0,
#  'timeline_2_0_77': 4248088.0,
#  'timeline_2_0_78': 4355165.0,
#  'timeline_2_0_79': 4378181.0,
#  'timeline_2_0_8': 4315923.0,
#  'timeline_2_0_80': 4235955.0,
#  'timeline_2_0_81': 4279978.0,
#  'timeline_2_0_82': 4276215.0,
#  'timeline_2_0_83': 4182543.0,
#  'timeline_2_0_84': 4251167.0,
#  'timeline_2_0_85': 4211475.0,
#  'timeline_2_0_86': 4214489.0,
#  'timeline_2_0_87': 4378600.0,
#  'timeline_2_0_88': 4210232.0,
#  'timeline_2_0_89': 4255711.0,
#  'timeline_2_0_9': 4228049.0,
#  'timeline_2_0_90': 4314481.0,
#  'timeline_2_0_91': 4254504.0,
#  'timeline_2_0_92': 4259421.0,
#  'timeline_2_0_93': 4221941.0,
#  'timeline_2_0_94': 4247501.0,
#  'timeline_2_0_95': 4225283.0,
#  'timeline_2_0_96': 4246968.0,
#  'timeline_2_0_97': 4279272.0,
#  'timeline_2_0_98': 4197116.0,
#  'timeline_2_0_99': 4267833.0,
#  'timeline_3_0_0': 4284021.0,
#  'timeline_3_0_1': 4349186.0,
#  'timeline_3_0_10': 4522421.0,
#  'timeline_3_0_100': 4304113.0,
#  'timeline_3_0_101': 4305494.0,
#  'timeline_3_0_102': 4302388.0,
#  'timeline_3_0_103': 4306624.0,
#  'timeline_3_0_104': 4289094.0,
#  'timeline_3_0_105': 4319621.0,
#  'timeline_3_0_106': 4349352.0,
#  'timeline_3_0_107': 4280730.0,
#  'timeline_3_0_108': 4317941.0,
#  'timeline_3_0_109': 4286516.0,
#  'timeline_3_0_11': 4278166.0,
#  'timeline_3_0_110': 4343718.0,
#  'timeline_3_0_111': 4329896.0,
#  'timeline_3_0_112': 4318564.0,
#  'timeline_3_0_113': 4276798.0,
#  'timeline_3_0_114': 4358923.0,
#  'timeline_3_0_115': 4266148.0,
#  'timeline_3_0_116': 4538407.0,
#  'timeline_3_0_117': 4327450.0,
#  'timeline_3_0_118': 4311916.0,
#  'timeline_3_0_119': 4296610.0,
#  'timeline_3_0_12': 4338951.0,
#  'timeline_3_0_120': 4325652.0,
#  'timeline_3_0_121': 4287656.0,
#  'timeline_3_0_122': 4342899.0,
#  'timeline_3_0_123': 4264848.0,
#  'timeline_3_0_124': 4297675.0,
#  'timeline_3_0_125': 4284756.0,
#  'timeline_3_0_126': 4316581.0,
#  'timeline_3_0_127': 4353799.0,
#  'timeline_3_0_13': 4310734.0,
#  'timeline_3_0_14': 4325922.0,
#  'timeline_3_0_15': 4313211.0,
#  'timeline_3_0_16': 4296826.0,
#  'timeline_3_0_17': 4318586.0,
#  'timeline_3_0_18': 4319695.0,
#  'timeline_3_0_19': 4318958.0,
#  'timeline_3_0_2': 4304472.0,
#  'timeline_3_0_20': 4312698.0,
#  'timeline_3_0_21': 4274189.0,
#  'timeline_3_0_22': 4300947.0,
#  'timeline_3_0_23': 4305368.0,
#  'timeline_3_0_24': 4341916.0,
#  'timeline_3_0_25': 4332580.0,
#  'timeline_3_0_26': 4311950.0,
#  'timeline_3_0_27': 4283519.0,
#  'timeline_3_0_28': 4310157.0,
#  'timeline_3_0_29': 4326057.0,
#  'timeline_3_0_3': 4331835.0,
#  'timeline_3_0_30': 4312636.0,
#  'timeline_3_0_31': 4312894.0,
#  'timeline_3_0_32': 4342752.0,
#  'timeline_3_0_33': 4336883.0,
#  'timeline_3_0_34': 4331179.0,
#  'timeline_3_0_35': 4335092.0,
#  'timeline_3_0_36': 4296171.0,
#  'timeline_3_0_37': 4244407.0,
#  'timeline_3_0_38': 4318791.0,
#  'timeline_3_0_39': 4548597.0,
#  'timeline_3_0_4': 4308026.0,
#  'timeline_3_0_40': 4287248.0,
#  'timeline_3_0_41': 4278031.0,
#  'timeline_3_0_42': 4306381.0,
#  'timeline_3_0_43': 4272245.0,
#  'timeline_3_0_44': 4287532.0,
#  'timeline_3_0_45': 4353891.0,
#  'timeline_3_0_46': 4304907.0,
#  'timeline_3_0_47': 4304414.0,
#  'timeline_3_0_48': 4300173.0,
#  'timeline_3_0_49': 4280452.0,
#  'timeline_3_0_5': 4341774.0,
#  'timeline_3_0_50': 4336743.0,
#  'timeline_3_0_51': 4291821.0,
#  'timeline_3_0_52': 4333793.0,
#  'timeline_3_0_53': 4274854.0,
#  'timeline_3_0_54': 4292726.0,
#  'timeline_3_0_55': 4309838.0,
#  'timeline_3_0_56': 4303602.0,
#  'timeline_3_0_57': 4298961.0,
#  'timeline_3_0_58': 4332017.0,
#  'timeline_3_0_59': 4339429.0,
#  'timeline_3_0_6': 4490413.0,
#  'timeline_3_0_60': 4300010.0,
#  'timeline_3_0_61': 4290857.0,
#  'timeline_3_0_62': 4319219.0,
#  'timeline_3_0_63': 4315913.0,
#  'timeline_3_0_64': 4337389.0,
#  'timeline_3_0_65': 4270449.0,
#  'timeline_3_0_66': 4293068.0,
#  'timeline_3_0_67': 4329018.0,
#  'timeline_3_0_68': 4330720.0,
#  'timeline_3_0_69': 4310091.0,
#  'timeline_3_0_7': 4278593.0,
#  'timeline_3_0_70': 4363318.0,
#  'timeline_3_0_71': 4318117.0,
#  'timeline_3_0_72': 4349754.0,
#  'timeline_3_0_73': 4293003.0,
#  'timeline_3_0_74': 4322682.0,
#  'timeline_3_0_75': 4302237.0,
#  'timeline_3_0_76': 4318933.0,
#  'timeline_3_0_77': 4164112.0,
#  'timeline_3_0_78': 4353152.0,
#  'timeline_3_0_79': 4290686.0,
#  'timeline_3_0_8': 4343060.0,
#  'timeline_3_0_80': 4348567.0,
#  'timeline_3_0_81': 4311970.0,
#  'timeline_3_0_82': 4341910.0,
#  'timeline_3_0_83': 4320107.0,
#  'timeline_3_0_84': 4313607.0,
#  'timeline_3_0_85': 4331685.0,
#  'timeline_3_0_86': 4307343.0,
#  'timeline_3_0_87': 4319071.0,
#  'timeline_3_0_88': 4252332.0,
#  'timeline_3_0_89': 4295472.0,
#  'timeline_3_0_9': 4294042.0,
#  'timeline_3_0_90': 4341942.0,
#  'timeline_3_0_91': 4312844.0,
#  'timeline_3_0_92': 4344280.0,
#  'timeline_3_0_93': 4280345.0,
#  'timeline_3_0_94': 4329016.0,
#  'timeline_3_0_95': 4306496.0,
#  'timeline_3_0_96': 4343592.0,
#  'timeline_3_0_97': 4342421.0,
#  'timeline_3_0_98': 4311985.0,
#  'timeline_3_0_99': 4362703.0,
#  'timeline_4_0_0': 4308021.0,
#  'timeline_4_0_1': 4318248.0,
#  'timeline_4_0_10': 4512946.0,
#  'timeline_4_0_100': 4326347.0,
#  'timeline_4_0_101': 4372671.0,
#  'timeline_4_0_102': 4314625.0,
#  'timeline_4_0_103': 4293178.0,
#  'timeline_4_0_104': 4367512.0,
#  'timeline_4_0_105': 4336899.0,
#  'timeline_4_0_106': 4338542.0,
#  'timeline_4_0_107': 4300776.0,
#  'timeline_4_0_108': 4326548.0,
#  'timeline_4_0_109': 4293647.0,
#  'timeline_4_0_11': 4328594.0,
#  'timeline_4_0_110': 4341634.0,
#  'timeline_4_0_111': 4372196.0,
#  'timeline_4_0_112': 4302557.0,
#  'timeline_4_0_113': 4293612.0,
#  'timeline_4_0_114': 4311871.0,
#  'timeline_4_0_115': 4332534.0,
#  'timeline_4_0_116': 4637417.0,
#  'timeline_4_0_117': 4354388.0,
#  'timeline_4_0_118': 4341052.0,
#  'timeline_4_0_119': 4365619.0,
#  'timeline_4_0_12': 4349461.0,
#  'timeline_4_0_120': 4346088.0,
#  'timeline_4_0_121': 4342070.0,
#  'timeline_4_0_122': 4383390.0,
#  'timeline_4_0_123': 4380655.0,
#  'timeline_4_0_124': 4307073.0,
#  'timeline_4_0_125': 4313227.0,
#  'timeline_4_0_126': 4352185.0,
#  'timeline_4_0_127': 4385934.0,
#  'timeline_4_0_13': 4379913.0,
#  'timeline_4_0_14': 4352100.0,
#  'timeline_4_0_15': 4304920.0,
#  'timeline_4_0_16': 4333602.0,
#  'timeline_4_0_17': 4324428.0,
#  'timeline_4_0_18': 4346351.0,
#  'timeline_4_0_19': 4327855.0,
#  'timeline_4_0_2': 4290510.0,
#  'timeline_4_0_20': 4411533.0,
#  'timeline_4_0_21': 4301453.0,
#  'timeline_4_0_22': 4393352.0,
#  'timeline_4_0_23': 4333818.0,
#  'timeline_4_0_24': 4388003.0,
#  'timeline_4_0_25': 4288528.0,
#  'timeline_4_0_26': 4348678.0,
#  'timeline_4_0_27': 4328071.0,
#  'timeline_4_0_28': 4271035.0,
#  'timeline_4_0_29': 4351954.0,
#  'timeline_4_0_3': 4356884.0,
#  'timeline_4_0_30': 4333454.0,
#  'timeline_4_0_31': 4335609.0,
#  'timeline_4_0_32': 4363445.0,
#  'timeline_4_0_33': 4379762.0,
#  'timeline_4_0_34': 4392456.0,
#  'timeline_4_0_35': 4342069.0,
#  'timeline_4_0_36': 4362578.0,
#  'timeline_4_0_37': 4331512.0,
#  'timeline_4_0_38': 4316833.0,
#  'timeline_4_0_39': 4652609.0,
#  'timeline_4_0_4': 4291801.0,
#  'timeline_4_0_40': 4314615.0,
#  'timeline_4_0_41': 4321107.0,
#  'timeline_4_0_42': 4345041.0,
#  'timeline_4_0_43': 4258626.0,
#  'timeline_4_0_44': 4330223.0,
#  'timeline_4_0_45': 4373024.0,
#  'timeline_4_0_46': 4342303.0,
#  'timeline_4_0_47': 4356968.0,
#  'timeline_4_0_48': 4292308.0,
#  'timeline_4_0_49': 4255128.0,
#  'timeline_4_0_5': 4350623.0,
#  'timeline_4_0_50': 4318419.0,
#  'timeline_4_0_51': 4328130.0,
#  'timeline_4_0_52': 4349012.0,
#  'timeline_4_0_53': 4327133.0,
#  'timeline_4_0_54': 4348986.0,
#  'timeline_4_0_55': 4306829.0,
#  'timeline_4_0_56': 4361623.0,
#  'timeline_4_0_57': 4285018.0,
#  'timeline_4_0_58': 4358822.0,
#  'timeline_4_0_59': 4387800.0,
#  'timeline_4_0_6': 4519879.0,
#  'timeline_4_0_60': 4371558.0,
#  'timeline_4_0_61': 4314689.0,
#  'timeline_4_0_62': 4362706.0,
#  'timeline_4_0_63': 4339311.0,
#  'timeline_4_0_64': 4388362.0,
#  'timeline_4_0_65': 4276980.0,
#  'timeline_4_0_66': 4298479.0,
#  'timeline_4_0_67': 4386600.0,
#  'timeline_4_0_68': 4337357.0,
#  'timeline_4_0_69': 4332861.0,
#  'timeline_4_0_7': 4322210.0,
#  'timeline_4_0_70': 4379329.0,
#  'timeline_4_0_71': 4303817.0,
#  'timeline_4_0_72': 4350666.0,
#  'timeline_4_0_73': 4346793.0,
#  'timeline_4_0_74': 4345565.0,
#  'timeline_4_0_75': 4281020.0,
#  'timeline_4_0_76': 4347160.0,
#  'timeline_4_0_77': 4339172.0,
#  'timeline_4_0_78': 4352444.0,
#  'timeline_4_0_79': 4303371.0,
#  'timeline_4_0_8': 4413669.0,
#  'timeline_4_0_80': 4341959.0,
#  'timeline_4_0_81': 4388912.0,
#  'timeline_4_0_82': 4351678.0,
#  'timeline_4_0_83': 4406743.0,
#  'timeline_4_0_84': 4369003.0,
#  'timeline_4_0_85': 4326739.0,
#  'timeline_4_0_86': 4285796.0,
#  'timeline_4_0_87': 4366337.0,
#  'timeline_4_0_88': 4320216.0,
#  'timeline_4_0_89': 4344504.0,
#  'timeline_4_0_9': 4312415.0,
#  'timeline_4_0_90': 4297475.0,
#  'timeline_4_0_91': 4337288.0,
#  'timeline_4_0_92': 4366593.0,
#  'timeline_4_0_93': 4285695.0,
#  'timeline_4_0_94': 4325338.0,
#  'timeline_4_0_95': 4319621.0,
#  'timeline_4_0_96': 4344743.0,
#  'timeline_4_0_97': 4356442.0,
#  'timeline_4_0_98': 4321187.0,
#  'timeline_4_0_99': 4340768.0}

# %% [markdown]
# ### How application access data over time.

# %%
tl = profile.CreateIOTimeline()
plt.figure(figsize=(20,4))
plt.grid()
plt.plot('time_step', 'read_count', data=tl);
plt.plot('time_step', 'write_count', data=tl);
plt.legend()
# Out:
# [============================================================] 100.0% 3880 of 3880 Creating Timeline

# %%
plt.figure(figsize=(20,4))
plt.grid()
plt.plot('time_step', 'read_bytes', data=tl);
plt.show();
plt.figure(figsize=(20,4))
plt.grid()
plt.plot('time_step', 'write_bytes', data=tl);
plt.show();

# %% [markdown]
# ### How files are accessed over the duration of the Job.

# %%
for file in df['Filename'].unique()[:16]:
    tl = profile.CreateIOTimeline(filepath=file)
    plt.plot('time_step', 'read_count', data=tl);
    plt.plot('time_step', 'write_count', data=tl);
    plt.legend()
    plt.show()
# Out:
# [============================================================] 100.0% 1792 of 1792 Creating Timeline
# Loaded Pre-processed Timeline from file: /tmp/temp_analysis/climate_run1_p128_tm_df_stats.csv
# [============================================================] 100.0% 1 of 1 Creating Timeline
# [============================================================] 100.0% 1 of 1 Creating Timeline
# [============================================================] 100.0% 1 of 1 Creating Timeline
# [============================================================] 100.0% 1 of 1 Creating Timeline
# [============================================================] 100.0% 1 of 1 Creating Timeline
# [============================================================] 100.0% 1 of 1 Creating Timeline
# [============================================================] 100.0% 1 of 1 Creating Timeline
# [============================================================] 100.0% 1 of 1 Creating Timeline
# [============================================================] 100.0% 1 of 1 Creating Timeline
# [============================================================] 100.0% 1 of 1 Creating Timeline
# [============================================================] 100.0% 1 of 1 Creating Timeline
# [============================================================] 100.0% 1 of 1 Creating Timeline
# [============================================================] 100.0% 1 of 1 Creating Timeline
# [============================================================] 100.0% 1 of 1 Creating Timeline

# %% [markdown]
# ### Show how each file is accessed by each rank.

# %%
for rank in df['Rank'].unique()[:16]:
    tl = profile.CreateIOTimeline(rank=rank)    
    plt.plot('time_step', 'read_count', data=tl);
    plt.plot('time_step', 'write_count', data=tl);
    plt.legend()
    plt.show()
# Out:
# [============================================================] 100.0% 30 of 30 Creating Timeline
# [============================================================] 100.0% 30 of 30 Creating Timeline
# [============================================================] 100.0% 30 of 30 Creating Timeline
# [============================================================] 100.0% 30 of 30 Creating Timeline
# [============================================================] 100.0% 31 of 31 Creating Timeline
# [============================================================] 100.0% 30 of 30 Creating Timeline
# [============================================================] 100.0% 30 of 30 Creating Timeline
# [============================================================] 100.0% 31 of 31 Creating Timeline
# [============================================================] 100.0% 30 of 30 Creating Timeline
# [============================================================] 100.0% 31 of 31 Creating Timeline
# [============================================================] 100.0% 30 of 30 Creating Timeline
# [============================================================] 100.0% 30 of 30 Creating Timeline
# [============================================================] 100.0% 30 of 30 Creating Timeline
# [============================================================] 100.0% 30 of 30 Creating Timeline
# [============================================================] 100.0% 30 of 30 Creating Timeline
# [============================================================] 100.0% 30 of 30 Creating Timeline

# %% [markdown]
# ### Data Transfer Size distribution within the application

# %%
request_df_read = profile.GetIORequestDistribution(operation='read')
ax = request_df_read.plot(kind='bar', figsize=(10, 4));
plt.show()

# %%
request_df_write = profile.GetIORequestDistribution(operation='write')
ax = request_df_write.plot(kind='bar', figsize=(10, 4));
plt.show()

# %% [markdown]
# ### Data Transfer Size distribution for each file.

# %%
for file in df['Filename'].unique()[:16]:
    tl = profile.GetIORequestDistribution(filepath=file)
    tl.plot(kind='bar', figsize=(10, 4), title=file)
    plt.show()

# %% [markdown]
# ### Data Transfer Sizes per Rank

# %%
for rank in df['Rank'].unique()[:16]:
    fig, ax = plt.subplots(ncols=2,nrows=1)
    tl = profile.GetIORequestDistribution(rank=rank, operation='read')
    tl.plot(kind='bar', figsize=(10, 4), title=rank,ax=ax[0])
    ax[0].set_title("rank {}:read".format(rank))
    tl2 = profile.GetIORequestDistribution(rank=rank, operation='write')
    tl2.plot(kind='bar', figsize=(10, 4), title=rank,ax=ax[1])
    ax[1].set_title("rank {}:write".format(rank))
    plt.show()

# %% [markdown]
# ### File summary of each file accessed by the Application

# %%
pp = pprint.PrettyPrinter(indent=1)
for file in df['Filename'].unique():
    if os.path.exists(file):
        print(file)
        pp.pprint(profile.GetFileSummary(file))
# Out:
# /lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5
# {'ext': 'h5',
#  'filename': 'stats',
#  'io_size': 628224,
#  'io_time': 0.0160742187499994,
#  'path': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#  'size': 4752,
#  'special': {'keys': [{'keys': [{'name': 'labels_stats',
#                                  'obj': <HDF5 dataset "labels_stats": shape (2, 3), type "<f4">,
#                                  'shape': (2, 3),
#                                  'size': 6,
#                                  'type': 'dataset'},
#                                 {'name': 'stats',
#                                  'obj': <HDF5 dataset "stats": shape (16, 4), type "<f4">,
#                                  'shape': (16, 4),
#                                  'size': 64,
#                                  'type': 'dataset'}],
#                        'name': 'climate',
#                        'type': 'group'}],
#              'name': 'stats',
#              'type': 'group'}}
# /lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/validation/stats.h5
# {'ext': 'h5',
#  'filename': 'stats',
#  'io_size': 628224,
#  'io_time': 0.03216171874999928,
#  'path': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/validation/stats.h5',
#  'size': 4752,
#  'special': {'keys': [{'keys': [{'name': 'labels_stats',
#                                  'obj': <HDF5 dataset "labels_stats": shape (2, 3), type "<f4">,
#                                  'shape': (2, 3),
#                                  'size': 6,
#                                  'type': 'dataset'},
#                                 {'name': 'stats',
#                                  'obj': <HDF5 dataset "stats": shape (16, 4), type "<f4">,
#                                  'shape': (16, 4),
#                                  'size': 64,
#                                  'type': 'dataset'}],
#                        'name': 'climate',
#                        'type': 'group'}],
#              'name': 'stats',
#              'type': 'group'}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_0.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_0',
#  'io_size': 4308021,
#  'io_time': 0.01269999999999527,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_0.json',
#  'size': 4308021,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_0.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_0',
#  'io_size': 4284021,
#  'io_time': 0.01259999999996353,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_0.json',
#  'size': 4284021,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_1.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_1',
#  'io_size': 4318248,
#  'io_time': 0.01320000000004029,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_1.json',
#  'size': 4318248,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_1.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_1',
#  'io_size': 4349186,
#  'io_time': 0.01320000000004029,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_1.json',
#  'size': 4349186,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_2.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_2',
#  'io_size': 4290510,
#  'io_time': 0.013000000000033651,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_2.json',
#  'size': 4290510,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_2.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_2',
#  'io_size': 4304472,
#  'io_time': 0.01290000000000191,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_2.json',
#  'size': 4304472,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_3.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_3',
#  'io_size': 4356884,
#  'io_time': 0.012799999999970169,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_3.json',
#  'size': 4356884,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_3.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_3',
#  'io_size': 4331835,
#  'io_time': 0.01269999999999527,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_3.json',
#  'size': 4331835,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_4.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_4',
#  'io_size': 4291801,
#  'io_time': 0.01269999999999527,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_4.json',
#  'size': 4291801,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_4.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_4',
#  'io_size': 4308026,
#  'io_time': 0.012499999999988631,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_4.json',
#  'size': 4308026,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_4.json
# {'ext': 'json',
#  'filename': 'timeline_2_0_4',
#  'io_size': 4327760,
#  'io_time': 0.01269999999999527,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_4.json',
#  'size': 4327760,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_5.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_5',
#  'io_size': 4350623,
#  'io_time': 0.01269999999999527,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_5.json',
#  'size': 4350623,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_5.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_5',
#  'io_size': 4341774,
#  'io_time': 0.012600000000020373,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_5.json',
#  'size': 4341774,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_6.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_6',
#  'io_size': 4519879,
#  'io_time': 0.013500000000021828,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_6.json',
#  'size': 4519879,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_6.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_6',
#  'io_size': 4490413,
#  'io_time': 0.013699999999971624,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_6.json',
#  'size': 4490413,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_7.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_7',
#  'io_size': 4322210,
#  'io_time': 0.012499999999988631,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_7.json',
#  'size': 4322210,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_7.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_7',
#  'io_size': 4278593,
#  'io_time': 0.012299999999981992,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_7.json',
#  'size': 4278593,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_7.json
# {'ext': 'json',
#  'filename': 'timeline_2_0_7',
#  'io_size': 4233344,
#  'io_time': 0.012300000000038835,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_7.json',
#  'size': 4233344,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_8.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_8',
#  'io_size': 4413669,
#  'io_time': 0.014299999999991542,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_8.json',
#  'size': 4413669,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_8.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_8',
#  'io_size': 4343060,
#  'io_time': 0.013800000000003365,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_8.json',
#  'size': 4343060,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_9.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_9',
#  'io_size': 4312415,
#  'io_time': 0.013800000000003365,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_9.json',
#  'size': 4312415,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_9.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_9',
#  'io_size': 4294042,
#  'io_time': 0.014000000000010004,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_9.json',
#  'size': 4294042,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_9.json
# {'ext': 'json',
#  'filename': 'timeline_2_0_9',
#  'io_size': 4228049,
#  'io_time': 0.013499999999964984,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_9.json',
#  'size': 4228049,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_10.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_10',
#  'io_size': 4512946,
#  'io_time': 0.014599999999973079,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_10.json',
#  'size': 4512946,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_10.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_10',
#  'io_size': 4522421,
#  'io_time': 0.014600000000029922,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_10.json',
#  'size': 4522421,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_11.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_11',
#  'io_size': 4328594,
#  'io_time': 0.014200000000016644,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_11.json',
#  'size': 4328594,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_11.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_11',
#  'io_size': 4278166,
#  'io_time': 0.013300000000015189,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_11.json',
#  'size': 4278166,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_12.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_12',
#  'io_size': 4349461,
#  'io_time': 0.013999999999953161,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_12.json',
#  'size': 4349461,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_12.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_12',
#  'io_size': 4338951,
#  'io_time': 0.013899999999978263,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_12.json',
#  'size': 4338951,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_13.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_13',
#  'io_size': 4379913,
#  'io_time': 0.014800000000036562,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_13.json',
#  'size': 4379913,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_13.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_13',
#  'io_size': 4310734,
#  'io_time': 0.014099999999984902,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_13.json',
#  'size': 4310734,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_14.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_14',
#  'io_size': 4352100,
#  'io_time': 0.01470000000000482,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_14.json',
#  'size': 4352100,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_14.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_14',
#  'io_size': 4325922,
#  'io_time': 0.0141999999999598,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_14.json',
#  'size': 4325922,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_15.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_15',
#  'io_size': 4304920,
#  'io_time': 0.013999999999953161,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_15.json',
#  'size': 4304920,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_15.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_15',
#  'io_size': 4313211,
#  'io_time': 0.014100000000041746,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_15.json',
#  'size': 4313211,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_16.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_16',
#  'io_size': 4333602,
#  'io_time': 0.013900000000035106,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_16.json',
#  'size': 4333602,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_16.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_16',
#  'io_size': 4296826,
#  'io_time': 0.013599999999996726,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_16.json',
#  'size': 4296826,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_17.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_17',
#  'io_size': 4324428,
#  'io_time': 0.013899999999978263,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_17.json',
#  'size': 4324428,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_17.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_17',
#  'io_size': 4318586,
#  'io_time': 0.013800000000003365,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_17.json',
#  'size': 4318586,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_18.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_18',
#  'io_size': 4346351,
#  'io_time': 0.014299999999991542,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_18.json',
#  'size': 4346351,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_18.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_18',
#  'io_size': 4319695,
#  'io_time': 0.013800000000003365,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_18.json',
#  'size': 4319695,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_18.json
# {'ext': 'json',
#  'filename': 'timeline_2_0_18',
#  'io_size': 4234094,
#  'io_time': 0.013699999999971624,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_18.json',
#  'size': 4234094,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_19.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_19',
#  'io_size': 4327855,
#  'io_time': 0.014300000000048385,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_19.json',
#  'size': 4327855,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_19.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_19',
#  'io_size': 4318958,
#  'io_time': 0.013700000000028467,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_19.json',
#  'size': 4318958,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_19.json
# {'ext': 'json',
#  'filename': 'timeline_2_0_19',
#  'io_size': 4210681,
#  'io_time': 0.01310000000000855,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_19.json',
#  'size': 4210681,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_20.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_20',
#  'io_size': 4411533,
#  'io_time': 0.014599999999973079,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_20.json',
#  'size': 4411533,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_20.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_20',
#  'io_size': 4312698,
#  'io_time': 0.0141999999999598,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_20.json',
#  'size': 4312698,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_21.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_21',
#  'io_size': 4301453,
#  'io_time': 0.014099999999984902,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_21.json',
#  'size': 4301453,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_21.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_21',
#  'io_size': 4274189,
#  'io_time': 0.013300000000015189,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_21.json',
#  'size': 4274189,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_22.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_22',
#  'io_size': 4393352,
#  'io_time': 0.015099999999961256,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_22.json',
#  'size': 4393352,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_22.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_22',
#  'io_size': 4300947,
#  'io_time': 0.014400000000023283,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_22.json',
#  'size': 4300947,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_23.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_23',
#  'io_size': 4333818,
#  'io_time': 0.014000000000010004,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_23.json',
#  'size': 4333818,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_23.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_23',
#  'io_size': 4305368,
#  'io_time': 0.014099999999984902,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_23.json',
#  'size': 4305368,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_24.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_24',
#  'io_size': 4388003,
#  'io_time': 0.015000000000043201,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_24.json',
#  'size': 4388003,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_24.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_24',
#  'io_size': 4341916,
#  'io_time': 0.014099999999984902,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_24.json',
#  'size': 4341916,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_25.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_25',
#  'io_size': 4288528,
#  'io_time': 0.014099999999984902,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_25.json',
#  'size': 4288528,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_25.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_25',
#  'io_size': 4332580,
#  'io_time': 0.013900000000035106,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_25.json',
#  'size': 4332580,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_26.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_26',
#  'io_size': 4348678,
#  'io_time': 0.014800000000036562,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_26.json',
#  'size': 4348678,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_26.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_26',
#  'io_size': 4311950,
#  'io_time': 0.014200000000016644,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_26.json',
#  'size': 4311950,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_26.json
# {'ext': 'json',
#  'filename': 'timeline_2_0_26',
#  'io_size': 4221033,
#  'io_time': 0.013599999999996726,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_26.json',
#  'size': 4221033,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_27.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_27',
#  'io_size': 4328071,
#  'io_time': 0.014299999999991542,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_27.json',
#  'size': 4328071,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_28.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_28',
#  'io_size': 4271035,
#  'io_time': 0.013599999999996726,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_28.json',
#  'size': 4271035,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_28.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_28',
#  'io_size': 4310157,
#  'io_time': 0.013599999999996726,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_28.json',
#  'size': 4310157,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_29.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_29',
#  'io_size': 4351954,
#  'io_time': 0.01470000000000482,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_29.json',
#  'size': 4351954,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_29.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_29',
#  'io_size': 4326057,
#  'io_time': 0.014000000000010004,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_29.json',
#  'size': 4326057,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_30.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_30',
#  'io_size': 4333454,
#  'io_time': 0.0141999999999598,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_30.json',
#  'size': 4333454,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_30.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_30',
#  'io_size': 4312636,
#  'io_time': 0.014100000000041746,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_30.json',
#  'size': 4312636,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_30.json
# {'ext': 'json',
#  'filename': 'timeline_2_0_30',
#  'io_size': 4241522,
#  'io_time': 0.013599999999996726,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_30.json',
#  'size': 4241522,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_31.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_31',
#  'io_size': 4335609,
#  'io_time': 0.014499999999998181,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_31.json',
#  'size': 4335609,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_31.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_31',
#  'io_size': 4312894,
#  'io_time': 0.014499999999998181,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_31.json',
#  'size': 4312894,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_32.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_32',
#  'io_size': 4363445,
#  'io_time': 0.01470000000000482,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_32.json',
#  'size': 4363445,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_32.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_32',
#  'io_size': 4342752,
#  'io_time': 0.013999999999953161,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_32.json',
#  'size': 4342752,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_33.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_33',
#  'io_size': 4379762,
#  'io_time': 0.014299999999991542,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_33.json',
#  'size': 4379762,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_33.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_33',
#  'io_size': 4336883,
#  'io_time': 0.0141999999999598,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_33.json',
#  'size': 4336883,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_34.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_34',
#  'io_size': 4392456,
#  'io_time': 0.01470000000000482,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_34.json',
#  'size': 4392456,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_35.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_35',
#  'io_size': 4342069,
#  'io_time': 0.014499999999998181,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_35.json',
#  'size': 4342069,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_35.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_35',
#  'io_size': 4335092,
#  'io_time': 0.013899999999978263,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_35.json',
#  'size': 4335092,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_35.json
# {'ext': 'json',
#  'filename': 'timeline_2_0_35',
#  'io_size': 4265238,
#  'io_time': 0.013599999999996726,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_35.json',
#  'size': 4265238,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_36.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_36',
#  'io_size': 4362578,
#  'io_time': 0.013899999999978263,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_36.json',
#  'size': 4362578,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_36.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_36',
#  'io_size': 4296171,
#  'io_time': 0.013700000000028467,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_36.json',
#  'size': 4296171,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_37.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_37',
#  'io_size': 4331512,
#  'io_time': 0.014599999999973079,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_37.json',
#  'size': 4331512,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_37.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_37',
#  'io_size': 4244407,
#  'io_time': 0.013700000000028467,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_37.json',
#  'size': 4244407,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_38.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_38',
#  'io_size': 4316833,
#  'io_time': 0.013499999999964984,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_38.json',
#  'size': 4316833,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_38.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_38',
#  'io_size': 4318791,
#  'io_time': 0.013700000000028467,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_38.json',
#  'size': 4318791,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_39.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_39',
#  'io_size': 4652609,
#  'io_time': 0.015300000000024738,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_39.json',
#  'size': 4652609,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_39.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_39',
#  'io_size': 4548597,
#  'io_time': 0.014499999999998181,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_39.json',
#  'size': 4548597,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_39.json
# {'ext': 'json',
#  'filename': 'timeline_2_0_39',
#  'io_size': 4661871,
#  'io_time': 0.015100000000018099,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_39.json',
#  'size': 4661871,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_40.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_40',
#  'io_size': 4314615,
#  'io_time': 0.014400000000023283,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_40.json',
#  'size': 4314615,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_40.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_40',
#  'io_size': 4287248,
#  'io_time': 0.013999999999953161,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_40.json',
#  'size': 4287248,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_41.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_41',
#  'io_size': 4321107,
#  'io_time': 0.014099999999984902,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_41.json',
#  'size': 4321107,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_41.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_41',
#  'io_size': 4278031,
#  'io_time': 0.013800000000003365,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_41.json',
#  'size': 4278031,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_42.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_42',
#  'io_size': 4345041,
#  'io_time': 0.014499999999998181,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_42.json',
#  'size': 4345041,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_42.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_42',
#  'io_size': 4306381,
#  'io_time': 0.014000000000010004,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_42.json',
#  'size': 4306381,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_42.json
# {'ext': 'json',
#  'filename': 'timeline_2_0_42',
#  'io_size': 4407632,
#  'io_time': 0.014000000000010004,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_42.json',
#  'size': 4407632,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_43.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_43',
#  'io_size': 4258626,
#  'io_time': 0.014200000000016644,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_43.json',
#  'size': 4258626,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_43.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_43',
#  'io_size': 4272245,
#  'io_time': 0.013699999999971624,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_43.json',
#  'size': 4272245,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_43.json
# {'ext': 'json',
#  'filename': 'timeline_2_0_43',
#  'io_size': 4168160,
#  'io_time': 0.013299999999958345,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_43.json',
#  'size': 4168160,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_44.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_44',
#  'io_size': 4330223,
#  'io_time': 0.014200000000016644,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_44.json',
#  'size': 4330223,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_44.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_44',
#  'io_size': 4287532,
#  'io_time': 0.013399999999990087,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_44.json',
#  'size': 4287532,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_45.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_45',
#  'io_size': 4373024,
#  'io_time': 0.014300000000048385,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_45.json',
#  'size': 4373024,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_45.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_45',
#  'io_size': 4353891,
#  'io_time': 0.013599999999996726,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_45.json',
#  'size': 4353891,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_46.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_46',
#  'io_size': 4342303,
#  'io_time': 0.01439999999996644,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_46.json',
#  'size': 4342303,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_46.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_46',
#  'io_size': 4304907,
#  'io_time': 0.013800000000003365,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_46.json',
#  'size': 4304907,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_47.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_47',
#  'io_size': 4356968,
#  'io_time': 0.014400000000023283,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_47.json',
#  'size': 4356968,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_47.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_47',
#  'io_size': 4304414,
#  'io_time': 0.013700000000028467,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_47.json',
#  'size': 4304414,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_48.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_48',
#  'io_size': 4292308,
#  'io_time': 0.01439999999996644,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_48.json',
#  'size': 4292308,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_49.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_49',
#  'io_size': 4255128,
#  'io_time': 0.013599999999996726,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_49.json',
#  'size': 4255128,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_49.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_49',
#  'io_size': 4280452,
#  'io_time': 0.013399999999990087,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_49.json',
#  'size': 4280452,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_49.json
# {'ext': 'json',
#  'filename': 'timeline_2_0_49',
#  'io_size': 4184951,
#  'io_time': 0.013199999999983447,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_49.json',
#  'size': 4184951,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_50.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_50',
#  'io_size': 4318419,
#  'io_time': 0.014600000000029922,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_50.json',
#  'size': 4318419,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_50.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_50',
#  'io_size': 4336743,
#  'io_time': 0.014099999999984902,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_50.json',
#  'size': 4336743,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_50.json
# {'ext': 'json',
#  'filename': 'timeline_2_0_50',
#  'io_size': 4204860,
#  'io_time': 0.014000000000010004,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_50.json',
#  'size': 4204860,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_51.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_51',
#  'io_size': 4328130,
#  'io_time': 0.014400000000023283,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_51.json',
#  'size': 4328130,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_51.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_51',
#  'io_size': 4291821,
#  'io_time': 0.013900000000035106,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_51.json',
#  'size': 4291821,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_51.json
# {'ext': 'json',
#  'filename': 'timeline_2_0_51',
#  'io_size': 4265193,
#  'io_time': 0.014300000000048385,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_51.json',
#  'size': 4265193,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_52.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_52',
#  'io_size': 4349012,
#  'io_time': 0.014200000000016644,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_52.json',
#  'size': 4349012,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_52.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_52',
#  'io_size': 4333793,
#  'io_time': 0.014100000000041746,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_52.json',
#  'size': 4333793,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_53.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_53',
#  'io_size': 4327133,
#  'io_time': 0.013899999999978263,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_53.json',
#  'size': 4327133,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_53.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_53',
#  'io_size': 4274854,
#  'io_time': 0.013700000000028467,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_53.json',
#  'size': 4274854,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_54.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_54',
#  'io_size': 4348986,
#  'io_time': 0.01470000000000482,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_54.json',
#  'size': 4348986,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_54.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_54',
#  'io_size': 4292726,
#  'io_time': 0.014099999999984902,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_54.json',
#  'size': 4292726,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_54.json
# {'ext': 'json',
#  'filename': 'timeline_2_0_54',
#  'io_size': 4191840,
#  'io_time': 0.013699999999971624,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_54.json',
#  'size': 4191840,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_55.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_55',
#  'io_size': 4306829,
#  'io_time': 0.013899999999978263,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_55.json',
#  'size': 4306829,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_55.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_55',
#  'io_size': 4309838,
#  'io_time': 0.013599999999996726,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_55.json',
#  'size': 4309838,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_55.json
# {'ext': 'json',
#  'filename': 'timeline_2_0_55',
#  'io_size': 4201101,
#  'io_time': 0.01320000000004029,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_55.json',
#  'size': 4201101,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_56.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_56',
#  'io_size': 4361623,
#  'io_time': 0.013699999999971624,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_56.json',
#  'size': 4361623,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_56.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_56',
#  'io_size': 4303602,
#  'io_time': 0.013499999999964984,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_56.json',
#  'size': 4303602,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_56.json
# {'ext': 'json',
#  'filename': 'timeline_2_0_56',
#  'io_size': 4234452,
#  'io_time': 0.013299999999958345,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_56.json',
#  'size': 4234452,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_57.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_57',
#  'io_size': 4285018,
#  'io_time': 0.014299999999991542,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_57.json',
#  'size': 4285018,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_57.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_57',
#  'io_size': 4298961,
#  'io_time': 0.014299999999991542,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_57.json',
#  'size': 4298961,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_57.json
# {'ext': 'json',
#  'filename': 'timeline_2_0_57',
#  'io_size': 4209785,
#  'io_time': 0.014599999999973079,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_57.json',
#  'size': 4209785,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_58.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_58',
#  'io_size': 4358822,
#  'io_time': 0.0141999999999598,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_58.json',
#  'size': 4358822,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_58.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_58',
#  'io_size': 4332017,
#  'io_time': 0.013999999999953161,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_58.json',
#  'size': 4332017,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_58.json
# {'ext': 'json',
#  'filename': 'timeline_2_0_58',
#  'io_size': 4275853,
#  'io_time': 0.013800000000003365,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_58.json',
#  'size': 4275853,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_59.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_59',
#  'io_size': 4387800,
#  'io_time': 0.015100000000018099,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_59.json',
#  'size': 4387800,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_59.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_59',
#  'io_size': 4339429,
#  'io_time': 0.014299999999991542,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_59.json',
#  'size': 4339429,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_59.json
# {'ext': 'json',
#  'filename': 'timeline_2_0_59',
#  'io_size': 4286387,
#  'io_time': 0.014100000000041746,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_59.json',
#  'size': 4286387,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_60.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_60',
#  'io_size': 4371558,
#  'io_time': 0.014499999999998181,
# ...
#  'size': 4210415,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_106.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_106',
#  'io_size': 4338542,
#  'io_time': 0.01439999999996644,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_106.json',
#  'size': 4338542,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_106.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_106',
#  'io_size': 4349352,
#  'io_time': 0.014100000000041746,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_106.json',
#  'size': 4349352,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_106.json
# {'ext': 'json',
#  'filename': 'timeline_2_0_106',
#  'io_size': 4271223,
#  'io_time': 0.013999999999953161,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_106.json',
#  'size': 4271223,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_107.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_107',
#  'io_size': 4300776,
#  'io_time': 0.014000000000010004,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_107.json',
#  'size': 4300776,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_107.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_107',
#  'io_size': 4280730,
#  'io_time': 0.013500000000021828,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_107.json',
#  'size': 4280730,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_108.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_108',
#  'io_size': 4326548,
#  'io_time': 0.013800000000003365,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_108.json',
#  'size': 4326548,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_108.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_108',
#  'io_size': 4317941,
#  'io_time': 0.01340000000004693,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_108.json',
#  'size': 4317941,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_109.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_109',
#  'io_size': 4293647,
#  'io_time': 0.014099999999984902,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_109.json',
#  'size': 4293647,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_109.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_109',
#  'io_size': 4286516,
#  'io_time': 0.014100000000041746,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_109.json',
#  'size': 4286516,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_110.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_110',
#  'io_size': 4341634,
#  'io_time': 0.014499999999998181,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_110.json',
#  'size': 4341634,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_110.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_110',
#  'io_size': 4343718,
#  'io_time': 0.0141999999999598,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_110.json',
#  'size': 4343718,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_111.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_111',
#  'io_size': 4372196,
#  'io_time': 0.014799999999979718,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_111.json',
#  'size': 4372196,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_111.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_111',
#  'io_size': 4329896,
#  'io_time': 0.013900000000035106,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_111.json',
#  'size': 4329896,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_112.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_112',
#  'io_size': 4302557,
#  'io_time': 0.014299999999991542,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_112.json',
#  'size': 4302557,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_112.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_112',
#  'io_size': 4318564,
#  'io_time': 0.014200000000016644,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_112.json',
#  'size': 4318564,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_113.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_113',
#  'io_size': 4293612,
#  'io_time': 0.014000000000010004,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_113.json',
#  'size': 4293612,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_113.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_113',
#  'io_size': 4276798,
#  'io_time': 0.013599999999996726,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_113.json',
#  'size': 4276798,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_114.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_114',
#  'io_size': 4311871,
#  'io_time': 0.013999999999953161,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_114.json',
#  'size': 4311871,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_114.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_114',
#  'io_size': 4358923,
#  'io_time': 0.013899999999978263,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_114.json',
#  'size': 4358923,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_115.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_115',
#  'io_size': 4332534,
#  'io_time': 0.014099999999984902,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_115.json',
#  'size': 4332534,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_115.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_115',
#  'io_size': 4266148,
#  'io_time': 0.013599999999996726,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_115.json',
#  'size': 4266148,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_115.json
# {'ext': 'json',
#  'filename': 'timeline_2_0_115',
#  'io_size': 4237596,
#  'io_time': 0.013300000000015189,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_115.json',
#  'size': 4237596,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_116.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_116',
#  'io_size': 4637417,
#  'io_time': 0.015100000000018099,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_116.json',
#  'size': 4637417,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_116.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_116',
#  'io_size': 4538407,
#  'io_time': 0.014699999999947977,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_116.json',
#  'size': 4538407,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_116.json
# {'ext': 'json',
#  'filename': 'timeline_2_0_116',
#  'io_size': 4581647,
#  'io_time': 0.014499999999998181,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_116.json',
#  'size': 4581647,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_117.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_117',
#  'io_size': 4354388,
#  'io_time': 0.014499999999998181,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_117.json',
#  'size': 4354388,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_117.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_117',
#  'io_size': 4327450,
#  'io_time': 0.013699999999971624,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_117.json',
#  'size': 4327450,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_118.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_118',
#  'io_size': 4341052,
#  'io_time': 0.014400000000023283,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_118.json',
#  'size': 4341052,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_118.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_118',
#  'io_size': 4311916,
#  'io_time': 0.014099999999984902,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_118.json',
#  'size': 4311916,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_119.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_119',
#  'io_size': 4365619,
#  'io_time': 0.014499999999998181,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_119.json',
#  'size': 4365619,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_120.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_120',
#  'io_size': 4346088,
#  'io_time': 0.01490000000001146,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_120.json',
#  'size': 4346088,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_120.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_120',
#  'io_size': 4325652,
#  'io_time': 0.014599999999973079,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_120.json',
#  'size': 4325652,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_121.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_121',
#  'io_size': 4342070,
#  'io_time': 0.014099999999984902,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_121.json',
#  'size': 4342070,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_121.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_121',
#  'io_size': 4287656,
#  'io_time': 0.014100000000041746,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_121.json',
#  'size': 4287656,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_122.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_122',
#  'io_size': 4383390,
#  'io_time': 0.014400000000023283,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_122.json',
#  'size': 4383390,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_122.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_122',
#  'io_size': 4342899,
#  'io_time': 0.014200000000016644,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_122.json',
#  'size': 4342899,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_123.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_123',
#  'io_size': 4380655,
#  'io_time': 0.014999999999986358,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_123.json',
#  'size': 4380655,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_123.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_123',
#  'io_size': 4264848,
#  'io_time': 0.013899999999978263,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_123.json',
#  'size': 4264848,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_124.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_124',
#  'io_size': 4307073,
#  'io_time': 0.014000000000010004,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_124.json',
#  'size': 4307073,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_124.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_124',
#  'io_size': 4297675,
#  'io_time': 0.014299999999991542,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_124.json',
#  'size': 4297675,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_124.json
# {'ext': 'json',
#  'filename': 'timeline_2_0_124',
#  'io_size': 4179225,
#  'io_time': 0.013699999999971624,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_2_0_124.json',
#  'size': 4179225,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_125.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_125',
#  'io_size': 4313227,
#  'io_time': 0.014499999999998181,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_125.json',
#  'size': 4313227,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_125.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_125',
#  'io_size': 4284756,
#  'io_time': 0.014000000000010004,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_125.json',
#  'size': 4284756,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_126.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_126',
#  'io_size': 4352185,
#  'io_time': 0.01470000000000482,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_126.json',
#  'size': 4352185,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_126.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_126',
#  'io_size': 4316581,
#  'io_time': 0.014299999999991542,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_126.json',
#  'size': 4316581,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_127.json
# {'ext': 'json',
#  'filename': 'timeline_4_0_127',
#  'io_size': 4385934,
#  'io_time': 0.014400000000023283,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_4_0_127.json',
#  'size': 4385934,
#  'special': {}}
# /lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_127.json
# {'ext': 'json',
#  'filename': 'timeline_3_0_127',
#  'io_size': 4353799,
#  'io_time': 0.014299999999991542,
#  'path': '/lus/theta-fs0/projects/datascience/dhari/climate-seg-benchmark/scratch/timeline_3_0_127.json',
#  'size': 4353799,
#  'special': {}}

# %%
profile.CreateChromeTimeline(location="/home/dhari/timeline/apps/climate", filename="climate_run1_p8.json")
# Out:
# [============================================================] 100.0% 3880 of 3880 Creating DXT Timeline
# [============================================================] 100.0% 374 of 374 Creating DXT Timeline
# {'traceEvents': [{'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416300,
#    'pid': 39,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 39,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4163,
#     'End': 0.4187}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416300,
#    'pid': 95,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 95,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4163,
#     'End': 0.4189}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416300,
#    'pid': 106,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 106,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4163,
#     'End': 0.4189}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416300,
#    'pid': 121,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 121,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4163,
#     'End': 0.4189}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416400,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4164,
#     'End': 0.419}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416400,
#    'pid': 33,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 33,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4164,
#     'End': 0.4192}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416400,
#    'pid': 74,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 74,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4164,
#     'End': 0.4188}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416400,
#    'pid': 104,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 104,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4164,
#     'End': 0.4184}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416500,
#    'pid': 14,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 14,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4165,
#     'End': 0.419}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416500,
#    'pid': 113,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 113,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4165,
#     'End': 0.4193}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416600,
#    'pid': 22,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 22,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4166,
#     'End': 0.4196}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416600,
#    'pid': 30,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 30,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4166,
#     'End': 0.4199}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416600,
#    'pid': 89,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 89,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4166,
#     'End': 0.4196}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416600,
#    'pid': 98,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 98,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4166,
#     'End': 0.4203}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416700,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4167,
#     'End': 0.4201}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416700,
#    'pid': 20,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 20,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4167,
#     'End': 0.4194}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416700,
#    'pid': 29,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 29,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4167,
#     'End': 0.42}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416700,
#    'pid': 31,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 31,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4167,
#     'End': 0.4206}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416700,
#    'pid': 40,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 40,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4167,
#     'End': 0.4193}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416700,
#    'pid': 47,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 47,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4167,
#     'End': 0.4204}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416700,
#    'pid': 51,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 51,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4167,
#     'End': 0.4195}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416700,
#    'pid': 63,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 63,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4167,
#     'End': 0.4198}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416700,
#    'pid': 86,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 86,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4167,
#     'End': 0.4195}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416700,
#    'pid': 91,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 91,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4167,
#     'End': 0.4193}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416700,
#    'pid': 93,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 93,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4167,
#     'End': 0.4195}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416700,
#    'pid': 103,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 103,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4167,
#     'End': 0.4198}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416700,
#    'pid': 107,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 107,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4167,
#     'End': 0.4195}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416700,
#    'pid': 109,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 109,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4167,
#     'End': 0.4193}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416700,
#    'pid': 127,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 127,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4167,
#     'End': 0.4197}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416800,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4168,
#     'End': 0.4205}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416800,
#    'pid': 27,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 27,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4168,
#     'End': 0.4202}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416800,
#    'pid': 32,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 32,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4168,
#     'End': 0.4191}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416800,
#    'pid': 48,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 48,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4168,
#     'End': 0.42}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416800,
#    'pid': 49,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 49,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4168,
#     'End': 0.4198}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416800,
#    'pid': 54,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 54,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4168,
#     'End': 0.4202}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416800,
#    'pid': 55,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 55,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4168,
#     'End': 0.4203}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416800,
#    'pid': 84,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 84,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4168,
#     'End': 0.4198}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416800,
#    'pid': 101,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 101,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4168,
#     'End': 0.421}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416800,
#    'pid': 105,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 105,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4168,
#     'End': 0.4198}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416800,
#    'pid': 112,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 112,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4168,
#     'End': 0.4197}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416800,
#    'pid': 114,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 114,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4168,
#     'End': 0.4192}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416800,
#    'pid': 115,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 115,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4168,
#     'End': 0.42}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416900,
#    'pid': 11,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 11,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4169,
#     'End': 0.4217}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416900,
#    'pid': 15,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 15,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4169,
#     'End': 0.4206}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416900,
#    'pid': 19,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 19,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4169,
#     'End': 0.4204}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416900,
#    'pid': 21,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 21,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4169,
#     'End': 0.4205}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416900,
#    'pid': 50,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 50,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4169,
#     'End': 0.4201}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416900,
#    'pid': 59,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 59,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4169,
#     'End': 0.421}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416900,
#    'pid': 65,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 65,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4169,
#     'End': 0.4205}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416900,
#    'pid': 78,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 78,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4169,
#     'End': 0.4208}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 416900,
#    'pid': 123,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 123,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4169,
#     'End': 0.4208}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417000,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.417,
#     'End': 0.4208}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417000,
#    'pid': 36,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 36,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.417,
#     'End': 0.421}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417000,
#    'pid': 67,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 67,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.417,
#     'End': 0.4211}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417000,
#    'pid': 96,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 96,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.417,
#     'End': 0.4209}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417000,
#    'pid': 117,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 117,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.417,
#     'End': 0.4222}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417000,
#    'pid': 118,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 118,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.417,
#     'End': 0.4216}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417100,
#    'pid': 9,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 9,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4171,
#     'End': 0.4214}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417100,
#    'pid': 10,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 10,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4171,
#     'End': 0.4211}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417100,
#    'pid': 23,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 23,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4171,
#     'End': 0.4219}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417100,
#    'pid': 26,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 26,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4171,
#     'End': 0.4219}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417100,
#    'pid': 37,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 37,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4171,
#     'End': 0.4218}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417100,
#    'pid': 53,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 53,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4171,
#     'End': 0.4218}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417100,
#    'pid': 58,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 58,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4171,
#     'End': 0.4214}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417100,
#    'pid': 68,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 68,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4171,
#     'End': 0.421}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417100,
#    'pid': 72,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 72,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4171,
#     'End': 0.4211}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417100,
#    'pid': 75,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 75,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4171,
#     'End': 0.4209}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417100,
#    'pid': 80,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 80,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4171,
#     'End': 0.4212}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417100,
#    'pid': 85,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 85,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4171,
#     'End': 0.4216}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417100,
#    'pid': 94,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 94,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4171,
#     'End': 0.4215}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417100,
#    'pid': 97,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 97,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4171,
#     'End': 0.4209}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417100,
#    'pid': 100,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 100,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4171,
#     'End': 0.4216}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417100,
#    'pid': 110,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 110,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4171,
#     'End': 0.4212}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417100,
#    'pid': 116,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 116,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4171,
#     'End': 0.4212}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417200,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4172,
#     'End': 0.4224}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417200,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4172,
#     'End': 0.4217}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417200,
#    'pid': 13,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 13,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4172,
#     'End': 0.4221}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417200,
#    'pid': 17,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 17,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4172,
#     'End': 0.4216}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417200,
#    'pid': 18,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 18,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4172,
#     'End': 0.4221}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417200,
#    'pid': 25,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 25,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4172,
#     'End': 0.4218}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417200,
#    'pid': 38,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 38,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4172,
#     'End': 0.4225}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417200,
#    'pid': 41,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 41,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4172,
#     'End': 0.4225}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417200,
#    'pid': 43,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 43,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4172,
#     'End': 0.4222}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417200,
#    'pid': 57,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 57,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4172,
#     'End': 0.4214}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417200,
#    'pid': 71,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 71,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4172,
#     'End': 0.421}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417200,
#    'pid': 73,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 73,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4172,
#     'End': 0.4224}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417200,
#    'pid': 83,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 83,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4172,
#     'End': 0.4226}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417200,
#    'pid': 99,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 99,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4172,
#     'End': 0.4222}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417300,
#    'pid': 28,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 28,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4173,
#     'End': 0.4225}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417300,
#    'pid': 35,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 35,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4173,
#     'End': 0.4228}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417300,
#    'pid': 61,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 61,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4173,
#     'End': 0.4229}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417300,
#    'pid': 64,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 64,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4173,
#     'End': 0.422}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417300,
#    'pid': 81,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 81,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4173,
#     'End': 0.4223}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417300,
#    'pid': 88,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 88,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4173,
#     'End': 0.4225}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417300,
#    'pid': 111,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 111,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4173,
#     'End': 0.4226}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417400,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4174,
#     'End': 0.4224}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417400,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4174,
#     'End': 0.4227}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417400,
#    'pid': 42,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 42,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4174,
#     'End': 0.4226}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417400,
#    'pid': 45,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 45,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4174,
#     'End': 0.4228}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417400,
#    'pid': 82,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 82,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4174,
#     'End': 0.422}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417500,
#    'pid': 16,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 16,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4175,
#     'End': 0.4231}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417500,
#    'pid': 60,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 60,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4175,
#     'End': 0.4231}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417500,
#    'pid': 66,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 66,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4175,
#     'End': 0.4229}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417500,
#    'pid': 102,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 102,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4175,
#     'End': 0.4228}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417500,
#    'pid': 124,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 124,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4175,
#     'End': 0.4229}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417500,
#    'pid': 126,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 126,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4175,
#     'End': 0.4227}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417600,
#    'pid': 44,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 44,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4176,
#     'End': 0.4235}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417600,
#    'pid': 46,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 46,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4176,
#     'End': 0.4233}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417600,
#    'pid': 62,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 62,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4176,
#     'End': 0.4234}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417600,
#    'pid': 69,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 69,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4176,
#     'End': 0.4226}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417600,
#    'pid': 77,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 77,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4176,
#     'End': 0.4238}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417600,
#    'pid': 87,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 87,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4176,
#     'End': 0.4233}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417600,
#    'pid': 119,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 119,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4176,
#     'End': 0.4233}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417600,
#    'pid': 120,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 120,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4176,
#     'End': 0.4231}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417600,
#    'pid': 125,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 125,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4176,
#     'End': 0.4232}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 417700,
#    'pid': 8,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 8,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
# ...
#     'Length': 80,
#     'Start': 0.4238,
#     'End': 0.4238}},
#   {'ph': 'E',
#    'ts': 423800,
#    'pid': 77,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 77,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4176,
#     'End': 0.4238}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 423800,
#    'pid': 79,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 79,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.4238,
#     'End': 0.4238}},
#   {'ph': 'E',
#    'ts': 423800,
#    'pid': 79,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 79,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.4238,
#     'End': 0.4238}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 423800,
#    'pid': 90,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 90,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.4238,
#     'End': 0.4238}},
#   {'ph': 'E',
#    'ts': 423800,
#    'pid': 90,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 90,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.4238,
#     'End': 0.4238}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 423800,
#    'pid': 90,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 90,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.4238,
#     'End': 0.4238}},
#   {'ph': 'E',
#    'ts': 423800,
#    'pid': 90,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 90,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.4238,
#     'End': 0.4238}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 423800,
#    'pid': 92,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 92,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.4238,
#     'End': 0.4238}},
#   {'ph': 'E',
#    'ts': 423800,
#    'pid': 92,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 92,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.4238,
#     'End': 0.4238}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 423900,
#    'pid': 76,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 76,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.4239,
#     'End': 0.4239}},
#   {'ph': 'E',
#    'ts': 423900,
#    'pid': 76,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 76,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.4239,
#     'End': 0.4239}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 423900,
#    'pid': 79,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 79,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.4239,
#     'End': 0.4239}},
#   {'ph': 'E',
#    'ts': 423900,
#    'pid': 79,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 79,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.4239,
#     'End': 0.4239}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 423900,
#    'pid': 87,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 87,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.4239,
#     'End': 0.4239}},
#   {'ph': 'E',
#    'ts': 423900,
#    'pid': 87,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 87,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.4239,
#     'End': 0.4239}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 423900,
#    'pid': 108,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 108,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.4239,
#     'End': 0.4239}},
#   {'ph': 'E',
#    'ts': 423900,
#    'pid': 108,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 108,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.4239,
#     'End': 0.4239}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 423900,
#    'pid': 119,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 119,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.4239,
#     'End': 0.4239}},
#   {'ph': 'E',
#    'ts': 423900,
#    'pid': 119,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 119,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.4239,
#     'End': 0.4239}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 423900,
#    'pid': 122,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 122,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.4239,
#     'End': 0.4239}},
#   {'ph': 'E',
#    'ts': 423900,
#    'pid': 122,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 122,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.4239,
#     'End': 0.4239}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 424000,
#    'pid': 12,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 12,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.424,
#     'End': 0.424}},
#   {'ph': 'E',
#    'ts': 424000,
#    'pid': 12,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 12,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.424,
#     'End': 0.424}},
#   {'ph': 'E',
#    'ts': 424000,
#    'pid': 24,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 24,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.418,
#     'End': 0.424}},
#   {'ph': 'E',
#    'ts': 424000,
#    'pid': 34,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 34,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4179,
#     'End': 0.424}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 424000,
#    'pid': 52,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 52,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.424,
#     'End': 0.424}},
#   {'ph': 'E',
#    'ts': 424000,
#    'pid': 52,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 52,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.424,
#     'End': 0.424}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 424000,
#    'pid': 62,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 62,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.424,
#     'End': 0.424}},
#   {'ph': 'E',
#    'ts': 424000,
#    'pid': 62,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 62,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.424,
#     'End': 0.424}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 424000,
#    'pid': 70,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 70,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.424,
#     'End': 0.424}},
#   {'ph': 'E',
#    'ts': 424000,
#    'pid': 70,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 70,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.424,
#     'End': 0.424}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 424000,
#    'pid': 77,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 77,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.424,
#     'End': 0.424}},
#   {'ph': 'E',
#    'ts': 424000,
#    'pid': 77,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 77,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.424,
#     'End': 0.424}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 424000,
#    'pid': 77,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 77,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.424,
#     'End': 0.424}},
#   {'ph': 'E',
#    'ts': 424000,
#    'pid': 77,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 77,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.424,
#     'End': 0.424}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 424000,
#    'pid': 92,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 92,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.424,
#     'End': 0.4241}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 424100,
#    'pid': 12,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 12,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.4241,
#     'End': 0.4241}},
#   {'ph': 'E',
#    'ts': 424100,
#    'pid': 12,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 12,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.4241,
#     'End': 0.4241}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 424100,
#    'pid': 44,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 44,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.4241,
#     'End': 0.4241}},
#   {'ph': 'E',
#    'ts': 424100,
#    'pid': 44,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 44,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.4241,
#     'End': 0.4241}},
#   {'ph': 'E',
#    'ts': 424100,
#    'pid': 56,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 56,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.4179,
#     'End': 0.4241}},
#   {'name': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 424100,
#    'pid': 90,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 90,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.4241,
#     'End': 0.4241}},
#   {'ph': 'E',
#    'ts': 424100,
#    'pid': 90,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 90,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.4241,
#     'End': 0.4241}},
#   {'ph': 'E',
#    'ts': 424100,
#    'pid': 92,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/MLPerfHPC/climate-seg/data/train/stats.h5',
#     'Rank': 92,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.424,
#     'End': 0.4241}},
#   ...],
#  'displayTimeUnit': 'ms',
#  'systemTraceEvents': 'SystemTraceData',
#  'otherData': {'version': 'VaniDL v1.0'},
#  'stackFrames': {},
#  'samples': []}
