# %% [markdown]
# # DLProfile Example using CANDEL Application

# %% [markdown]
# ## Set imports and neccessary environment variables

# %%
import pathlib
import os
import sys
import matplotlib.pyplot as plt
import warnings
import pprint
import pandas

# %%
VANIDL_DIR="{}".format(pathlib.Path(os.getcwd()).parent.parent.parent.absolute())
sys.path.insert(0, VANIDL_DIR)
warnings.filterwarnings('ignore')

# %%
os.environ["DARSHAN_DIR"] = "/soft/perftools/darshan/darshan-3.1.8"
os.environ["VANIDL_DIR"] = VANIDL_DIR

# %% [markdown]
# #### Formatting

# %%
pp = pprint.PrettyPrinter(indent=1)
class color:
    PURPLE = '\033[95m'
    CYAN = '\033[96m'
    DARKCYAN = '\033[36m'
    BLUE = '\033[94m'
    GREEN = '\033[92m'
    YELLOW = '\033[93m'
    RED = '\033[91m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'
    END = '\033[0m'

# %% [markdown]
# ## Create instrance of DL Profile and load the darshan file

# %%
from src.vanidl import VaniDL
profile = VaniDL()

# %%
#import shutil
#shutil.rmtree('/tmp/temp_analysis')

# %%
DATAPATH_INCLUDES = []
status = profile.Load("/home/dhari/darshan-logs/apps/candel/candel_run1_p8.darshan", data_paths_include=DATAPATH_INCLUDES)
if status:
    print("Darshan Trace loaded Successfully!")
else:
    print("Darshan Trace load Failed!")
    print(profile._error_str())
# Out:
# [============================================================] 100.0% 24815 of 24815 Parsing DXT File
# [============================================================] 100.0% 2523 of 2523 Parsing Darshan File
# Darshan Trace loaded Successfully!

# %% [markdown]
# ## Use Profile object to analyze the darshan I/O trace.

# %% [markdown]
# ### Verify if object works
#
# The GetDXTAsDF() function enables users to perform analysis

# %%
df = profile.GetDXTAsDF()
pp.pprint("Files used in the application")
pp.pprint(df['Filename'].unique().tolist())
# Out:
# 'Files used in the application'
# ['/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#  '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#  '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_test2.csv',
#  '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/training.log',
#  '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/run.RUN000.json']

# %% [markdown]
# ### Collect the summary of the Application

# %%
summary = profile.GetSummary()
print("\n")
print(color.BOLD + "Data Access Summary (from Darshan):"+ color.END)
print("Total Job time\t\t\t:\t{:0.2f} seconds".format(summary['job_time']))
#FIXME: calculate time per rank and then take max across it.
print("Time spent in I/O\t\t:\t{:0.2f} seconds".format(summary['total_io_time']))
print("% Time spent in I/O\t\t:\t{:0.2f}%".format(float(summary['total_io_time'])*100/summary['job_time']))
print("Total Data Accessed\t\t:\t{:0.2f} GB".format(float(summary['total_io_bytes'])/1024.0/1024.0/1024.0))
print("Data Access Modules used\t:\t{}".format(summary['io_interface_used']))
print("Data Operations\t\t\t:\t{}".format(summary['io_operations_used']))
print("# of files used\t\t\t:\t{}".format(len(summary['files_used'])))
print("# of MPI Ranks\t\t\t:\t{:0.0f} ranks".format(summary['num_ranks']))
      
print(color.UNDERLINE + "Data Transfer size:"+ color.END)
print("\tMin,Max\t\t\t:\t{:0.0f} bytes and {:0.0f} bytes".format(summary['data_transfer_size']['min'],summary['data_transfer_size']['max']))
print("\tAverage\t\t\t:\t{:0.0f} bytes".format(summary['data_transfer_size']['mean']))
print("\tMedian\t\t\t:\t{:0.0f} bytes".format(summary['data_transfer_size']['median']))
      
print(color.UNDERLINE + "Data Transfer bandwidth: (per rank)"+ color.END)
print("\tMin,Max\t\t\t:\t{:0.0f} B/s and {:0.0f} MB/s".format(summary['data_transfer_bandwidth']['min'],summary['data_transfer_bandwidth']['max']/1024.0/1024.0))
print("\tAverage\t\t\t:\t{:0.0f} MB/s".format(summary['data_transfer_bandwidth']['mean']/1024.0/1024.0))
print("\tMedian\t\t\t:\t{:0.0f} MB/s".format(summary['data_transfer_bandwidth']['median']/1024.0/1024.0))
      
print(color.UNDERLINE + "Access Pattern:"+ color.END)
print("\tSequential\t\t:\t{:0.2f}%".format(float(summary['access_pattern']['sequential'])))
print("\tConsecutive\t\t:\t{:0.2f}%".format(float(summary['access_pattern']['consecutive'])))
#An I/O op issued at an offset greater than where the previous I/O op ended.
#An I/O op issued at the offset immediately after the end of the previous I/O

print("\n")
print(color.BOLD + "Files Summary:"+ color.END)
print("File Types\t\t\t:\t{}".format(summary['file_used_summary']['types']))
print(color.UNDERLINE + "Dataset Size:"+ color.END)
print("\tTotal\t\t\t:\t{:0.3f} GB".format(float(summary['file_used_summary']['size']['total'])/1024.0/1024.0/1024.0))
print("\tMin,Max\t\t\t:\t{:0.3f} GB and {:0.3f} GB".format(float(summary['file_used_summary']['size']['min'])/1024.0/1024.0/1024.0,float(summary['file_used_summary']['size']['max'])/1024.0/1024.0/1024.0))
print("\tAverage\t\t\t:\t{:0.3f} GB".format(float(summary['file_used_summary']['size']['mean'])/1024.0/1024.0/1024.0))
# Out:
# Data Access Summary (from Darshan):
# Total Job time			:	608.00 seconds
# Time spent in I/O		:	2.23 seconds
# % Time spent in I/O		:	0.37%
# Total Data Accessed		:	5.83 GB
# Data Access Modules used	:	['X_POSIX']
# Data Operations			:	['read' 'write']
# # of files used			:	5
# # of MPI Ranks			:	8 ranks
# Data Transfer size:
# 	Min,Max			:	0 bytes and 262144 bytes
# 	Average			:	261520 bytes
# 	Median			:	262144 bytes
# Data Transfer bandwidth: (per rank)
# 	Min,Max			:	0 B/s and 625 MB/s
# 	Average			:	353 MB/s
# 	Median			:	357 MB/s
# Access Pattern:
# 	Sequential		:	99.87%
# 	Consecutive		:	99.86%
#
#
# Files Summary:
# File Types			:	['txt' 'csv' 'log' 'json']
# Dataset Size:
# 	Total			:	0.729 GB
# 	Min,Max			:	0.000 GB and 0.583 GB
# 	Average			:	0.146 GB

# %%
pp.pprint("Job time : {} seconds".format(profile.GetJobTime()))
# Out:
# 'Job time : 608.0 seconds'

# %%
pp.pprint("Time spent by application on I/O: {} seconds".format(profile.GetIOTime()))
# Out:
# 'Time spent by application on I/O: 2.229037500000028 seconds'

# %% [markdown]
# ### I/O time spent on each file

# %%
for file in df['Filename'].unique():
    print("I/O time for file {}: {:0.2f} seconds".format(file,profile.GetIOTime(filepath=file)))
# Out:
# I/O time for file /gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt: 0.00 seconds
# I/O time for file /gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv: 1.84 seconds
# I/O time for file /gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_test2.csv: 0.38 seconds
# I/O time for file /gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/training.log: 0.00 seconds
# I/O time for file /gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/run.RUN000.json: 0.00 seconds

# %% [markdown]
# ### I/O Time spent per rank

# %%
for rank in df['Rank'].unique()[:16]:
    print("I/O time for rank {}: {:0.2f} seconds".format(rank,profile.GetIOTime(rank=rank)))
# Out:
# I/O time for rank 0: 2.22 seconds
# I/O time for rank 1: 2.16 seconds
# I/O time for rank 2: 1.96 seconds
# I/O time for rank 3: 2.11 seconds
# I/O time for rank 4: 2.72 seconds
# I/O time for rank 5: 2.15 seconds
# I/O time for rank 6: 2.17 seconds
# I/O time for rank 7: 2.35 seconds

# %%
"Total I/O performed by application: {:0.2f} GB".format(float(profile.GetIOSize())/1024.0/1024.0/1024.0)
# Out:
# 'Total I/O performed by application: 5.83 GB'

# %% [markdown]
# ### I/O performed on each file

# %%
for file in df['Filename'].unique():
    print("I/O performed on file {}: {:0.2f} MB".format(file,float(profile.GetIOSize(filepath=file))/1024.0/1024.0))
# Out:
# I/O performed on file /gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt: 0.00 MB
# I/O performed on file /gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv: 4774.60 MB
# I/O performed on file /gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_test2.csv: 1194.89 MB
# I/O performed on file /gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/training.log: 0.00 MB
# I/O performed on file /gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/run.RUN000.json: 0.00 MB

# %%
for rank in df['Rank'].unique()[:16]:
    print("I/O performed by rank {}: {:0.2f} MB".format(rank, float(profile.GetIOSize(rank=rank))/1024.0/1024.0))
# Out:
# I/O performed by rank 0: 746.19 MB
# I/O performed by rank 1: 746.19 MB
# I/O performed by rank 2: 746.19 MB
# I/O performed by rank 3: 746.19 MB
# I/O performed by rank 4: 746.19 MB
# I/O performed by rank 5: 746.19 MB
# I/O performed by rank 6: 746.19 MB
# I/O performed by rank 7: 746.19 MB

# %%
print("Size of dataset (bytes)")
pp.pprint(profile.GetFileSizes())
# Out:
# Size of dataset (bytes)
# {'nt3_default_model': 397.0,
#  'nt_test2': 156616161.0,
#  'nt_train2': 625815725.0,
#  'run.RUN000': 259278.0,
#  'training': 0.0}

# %% [markdown]
# ### How application access data over time.

# %%
tl = profile.CreateIOTimeline()
plt.figure(figsize=(8,4))
plt.grid()
plt.ylabel("# of operations")
plt.xlabel("Timeline (ms)")
plt.plot(tl['time_step'], tl['operation_count']);
# Out:
# [============================================================] 100.0% 23935 of 23935 Creating Timeline

# %%
plt.figure(figsize=(8,4))
plt.grid()
plt.ylabel("I/O performed (bytes)")
plt.xlabel("Timeline (ms)")
plt.plot(tl['time_step'], tl['io_bytes']);

# %% [markdown]
# ### How files are accessed over the duration of the Job.

# %%
for file in df['Filename'].unique():
    tl = profile.CreateIOTimeline(filepath=file,time_step=0.001)
    tl.plot(x='time_step',y='operation_count', title=file)
    plt.show()
# Out:
# [============================================================] 100.0% 16 of 16 Creating Timeline
# [============================================================] 100.0% 19112 of 19112 Creating Timeline
# [============================================================] 100.0% 4792 of 4792 Creating Timeline
# [============================================================] 100.0% 8 of 8 Creating Timeline
# [============================================================] 100.0% 7 of 7 Creating Timeline

# %% [markdown]
# ### Show how each file is accessed by each rank.

# %%
for rank in df['Rank'].unique()[:16]:
    tl = profile.CreateIOTimeline(rank=rank)
    tl.plot(x='time_step',y='operation_count', title=rank)
    plt.show()
# Out:
# [============================================================] 100.0% 2992 of 2992 Creating Timeline
# [============================================================] 100.0% 2992 of 2992 Creating Timeline
# [============================================================] 100.0% 2992 of 2992 Creating Timeline
# [============================================================] 100.0% 2992 of 2992 Creating Timeline
# [============================================================] 100.0% 2992 of 2992 Creating Timeline
# [============================================================] 100.0% 2992 of 2992 Creating Timeline
# [============================================================] 100.0% 2992 of 2992 Creating Timeline
# [============================================================] 100.0% 2991 of 2991 Creating Timeline

# %% [markdown]
# ### Data Transfer Size distribution within the application

# %%
request_df = profile.GetIORequestDistribution()
df['Length'].plot(kind='hist', figsize=(5, 3), bins=100);
plt.xlabel("Transfer Size (bytes)")
# Out:
# Text(0.5, 0, 'Transfer Size (bytes)')

# %% [markdown]
# ### Data Transfer Size distribution for each file.

# %%
for file in df['Filename'].unique():
    tl = profile.GetIORequestDistribution(filepath=file)
    tl.plot(kind='bar', figsize=(10, 4), title=file)
    plt.show()

# %% [markdown]
# ### Data Transfer Sizes per Rank

# %%
for rank in df['Rank'].unique()[:16]:
    tl = profile.GetIORequestDistribution(rank=rank)
    tl.plot(kind='bar', figsize=(10, 4), title=rank)
    plt.show()

# %% [markdown]
# ### File summary of each file accessed by the Application

# %%
pp = pprint.PrettyPrinter(indent=1)
for file in df['Filename'].unique():
    pp.pprint(profile.GetFileSummary(file))
# Out:
# {'ext': 'txt',
#  'filename': 'nt3_default_model',
#  'io_size': 3176,
#  'io_time': 0.0018624999999999822,
#  'path': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#  'size': 397,
#  'special': {}}
# {'ext': 'csv',
#  'filename': 'nt_train2',
#  'io_size': 5006525800,
#  'io_time': 1.8393375000000267,
#  'path': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#  'size': 625815725,
#  'special': {}}
# {'ext': 'csv',
#  'filename': 'nt_test2',
#  'io_size': 1252929288,
#  'io_time': 0.38381249999999945,
#  'path': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_test2.csv',
#  'size': 156616161,
#  'special': {}}
# {'ext': 'log',
#  'filename': 'training',
#  'io_size': 892,
#  'io_time': 0.00041249999999593,
#  'path': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/training.log',
#  'size': 0,
#  'special': {}}
# {'ext': 'json',
#  'filename': 'run.RUN000',
#  'io_size': 2099,
#  'io_time': 0.004128571428558254,
#  'path': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/run.RUN000.json',
#  'size': 259278,
#  'special': {}}

# %%
profile.CreateChromeTimeline(location="/home/dhari/timeline/apps/candel", filename="candel_run1_n128.json")
# Out:
# [============================================================] 100.0% 23935 of 23935 Creating DXT Timeline
# [============================================================] 100.0% 5 of 5 Creating DXT Timeline
# {'traceEvents': [{'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 466600,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.4666,
#     'End': 0.4683}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 466900,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.4669,
#     'End': 0.4686}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 466900,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.4669,
#     'End': 0.4684}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 467000,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.467,
#     'End': 0.4687}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 467000,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.467,
#     'End': 0.4685}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 467000,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.467,
#     'End': 0.4685}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 467000,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.467,
#     'End': 0.4684}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 467100,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.4671,
#     'End': 0.4686}},
#   {'ph': 'E',
#    'ts': 468300,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.4666,
#     'End': 0.4683}},
#   {'ph': 'E',
#    'ts': 468400,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.467,
#     'End': 0.4684}},
#   {'ph': 'E',
#    'ts': 468400,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.4669,
#     'End': 0.4684}},
#   {'ph': 'E',
#    'ts': 468500,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.467,
#     'End': 0.4685}},
#   {'ph': 'E',
#    'ts': 468500,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.467,
#     'End': 0.4685}},
#   {'ph': 'E',
#    'ts': 468600,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.4671,
#     'End': 0.4686}},
#   {'ph': 'E',
#    'ts': 468600,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.4669,
#     'End': 0.4686}},
#   {'ph': 'E',
#    'ts': 468700,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 397,
#     'Start': 0.467,
#     'End': 0.4687}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 469900,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 397,
#     'Length': 0,
#     'Start': 0.4699,
#     'End': 0.4701}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 470000,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 397,
#     'Length': 0,
#     'Start': 0.47,
#     'End': 0.4702}},
#   {'ph': 'E',
#    'ts': 470100,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 397,
#     'Length': 0,
#     'Start': 0.4699,
#     'End': 0.4701}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 470100,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 397,
#     'Length': 0,
#     'Start': 0.4701,
#     'End': 0.4705}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 470100,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 397,
#     'Length': 0,
#     'Start': 0.4701,
#     'End': 0.4704}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 470100,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 397,
#     'Length': 0,
#     'Start': 0.4701,
#     'End': 0.4704}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 470100,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 397,
#     'Length': 0,
#     'Start': 0.4701,
#     'End': 0.4704}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 470200,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 397,
#     'Length': 0,
#     'Start': 0.4702,
#     'End': 0.4705}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 470200,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 397,
#     'Length': 0,
#     'Start': 0.4702,
#     'End': 0.4706}},
#   {'ph': 'E',
#    'ts': 470200,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 397,
#     'Length': 0,
#     'Start': 0.47,
#     'End': 0.4702}},
#   {'ph': 'E',
#    'ts': 470400,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 397,
#     'Length': 0,
#     'Start': 0.4701,
#     'End': 0.4704}},
#   {'ph': 'E',
#    'ts': 470400,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 397,
#     'Length': 0,
#     'Start': 0.4701,
#     'End': 0.4704}},
#   {'ph': 'E',
#    'ts': 470400,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 397,
#     'Length': 0,
#     'Start': 0.4701,
#     'End': 0.4704}},
#   {'ph': 'E',
#    'ts': 470500,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 397,
#     'Length': 0,
#     'Start': 0.4702,
#     'End': 0.4705}},
#   {'ph': 'E',
#    'ts': 470500,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 397,
#     'Length': 0,
#     'Start': 0.4701,
#     'End': 0.4705}},
#   {'ph': 'E',
#    'ts': 470600,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/Pilot1/NT3/nt3_default_model.txt',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 397,
#     'Length': 0,
#     'Start': 0.4702,
#     'End': 0.4706}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 510100,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 262144,
#     'Start': 0.5101,
#     'End': 0.5107}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 510100,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 262144,
#     'Start': 0.5101,
#     'End': 0.5106}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 510200,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 262144,
#     'Start': 0.5102,
#     'End': 0.5107}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 510200,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 262144,
#     'Start': 0.5102,
#     'End': 0.5107}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 510300,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 262144,
#     'Start': 0.5103,
#     'End': 0.511}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 510399,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 262144,
#     'Start': 0.5104,
#     'End': 0.5109}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 510399,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 262144,
#     'Start': 0.5104,
#     'End': 0.5109}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 510399,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 262144,
#     'Start': 0.5104,
#     'End': 0.5109}},
#   {'ph': 'E',
#    'ts': 510600,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 262144,
#     'Start': 0.5101,
#     'End': 0.5106}},
#   {'ph': 'E',
#    'ts': 510700,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 262144,
#     'Start': 0.5101,
#     'End': 0.5107}},
#   {'ph': 'E',
#    'ts': 510700,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 262144,
#     'Start': 0.5102,
#     'End': 0.5107}},
#   {'ph': 'E',
#    'ts': 510700,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 262144,
#     'Start': 0.5102,
#     'End': 0.5107}},
#   {'ph': 'E',
#    'ts': 510900,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 262144,
#     'Start': 0.5104,
#     'End': 0.5109}},
#   {'ph': 'E',
#    'ts': 510900,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 262144,
#     'Start': 0.5104,
#     'End': 0.5109}},
#   {'ph': 'E',
#    'ts': 510900,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 262144,
#     'Start': 0.5104,
#     'End': 0.5109}},
#   {'ph': 'E',
#    'ts': 511000,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 262144,
#     'Start': 0.5103,
#     'End': 0.511}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 518200,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 262144,
#     'Length': 262144,
#     'Start': 0.5182,
#     'End': 0.5188}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 518300,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 262144,
#     'Length': 262144,
#     'Start': 0.5183,
#     'End': 0.5192}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 518400,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 262144,
#     'Length': 262144,
#     'Start': 0.5184,
#     'End': 0.519}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 518400,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 262144,
#     'Length': 262144,
#     'Start': 0.5184,
#     'End': 0.5189}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 518499,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 262144,
#     'Length': 262144,
#     'Start': 0.5185,
#     'End': 0.5193}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 518499,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 262144,
#     'Length': 262144,
#     'Start': 0.5185,
#     'End': 0.5192}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 518599,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 262144,
#     'Length': 262144,
#     'Start': 0.5186,
#     'End': 0.5193}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 518700,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 262144,
#     'Length': 262144,
#     'Start': 0.5187,
#     'End': 0.5194}},
#   {'ph': 'E',
#    'ts': 518800,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 262144,
#     'Length': 262144,
#     'Start': 0.5182,
#     'End': 0.5188}},
#   {'ph': 'E',
#    'ts': 518900,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 262144,
#     'Length': 262144,
#     'Start': 0.5184,
#     'End': 0.5189}},
#   {'ph': 'E',
#    'ts': 519000,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 262144,
#     'Length': 262144,
#     'Start': 0.5184,
#     'End': 0.519}},
#   {'ph': 'E',
#    'ts': 519200,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 262144,
#     'Length': 262144,
#     'Start': 0.5183,
#     'End': 0.5192}},
#   {'ph': 'E',
#    'ts': 519200,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 262144,
#     'Length': 262144,
#     'Start': 0.5185,
#     'End': 0.5192}},
#   {'ph': 'E',
#    'ts': 519300,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 262144,
#     'Length': 262144,
#     'Start': 0.5186,
#     'End': 0.5193}},
#   {'ph': 'E',
#    'ts': 519300,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 262144,
#     'Length': 262144,
#     'Start': 0.5185,
#     'End': 0.5193}},
#   {'ph': 'E',
#    'ts': 519400,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 262144,
#     'Length': 262144,
#     'Start': 0.5187,
#     'End': 0.5194}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 525200,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 524288,
#     'Length': 262144,
#     'Start': 0.5252,
#     'End': 0.5258}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 525300,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 524288,
#     'Length': 262144,
#     'Start': 0.5253,
#     'End': 0.526}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 525400,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 524288,
#     'Length': 262144,
#     'Start': 0.5254,
#     'End': 0.5261}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 525600,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 524288,
#     'Length': 262144,
#     'Start': 0.5256,
#     'End': 0.5263}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 525700,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 524288,
#     'Length': 262144,
#     'Start': 0.5257,
#     'End': 0.5264}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 525700,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 524288,
#     'Length': 262144,
#     'Start': 0.5257,
#     'End': 0.5264}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 525800,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 524288,
#     'Length': 262144,
#     'Start': 0.5258,
#     'End': 0.5264}},
#   {'ph': 'E',
#    'ts': 525800,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 524288,
#     'Length': 262144,
#     'Start': 0.5252,
#     'End': 0.5258}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 525800,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 524288,
#     'Length': 262144,
#     'Start': 0.5258,
#     'End': 0.5264}},
#   {'ph': 'E',
#    'ts': 526000,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 524288,
#     'Length': 262144,
#     'Start': 0.5253,
#     'End': 0.526}},
#   {'ph': 'E',
#    'ts': 526100,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 524288,
#     'Length': 262144,
#     'Start': 0.5254,
#     'End': 0.5261}},
#   {'ph': 'E',
#    'ts': 526300,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 524288,
#     'Length': 262144,
#     'Start': 0.5256,
#     'End': 0.5263}},
#   {'ph': 'E',
#    'ts': 526400,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 524288,
#     'Length': 262144,
#     'Start': 0.5258,
#     'End': 0.5264}},
#   {'ph': 'E',
#    'ts': 526400,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 524288,
#     'Length': 262144,
#     'Start': 0.5258,
#     'End': 0.5264}},
#   {'ph': 'E',
#    'ts': 526400,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 524288,
#     'Length': 262144,
#     'Start': 0.5257,
#     'End': 0.5264}},
#   {'ph': 'E',
#    'ts': 526400,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 524288,
#     'Length': 262144,
#     'Start': 0.5257,
#     'End': 0.5264}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 545500,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 786432,
#     'Length': 262144,
#     'Start': 0.5455,
#     'End': 0.5463}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 545800,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 786432,
#     'Length': 262144,
#     'Start': 0.5458,
#     'End': 0.5467}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 545900,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 786432,
#     'Length': 262144,
#     'Start': 0.5459,
#     'End': 0.5465}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 546000,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 786432,
#     'Length': 262144,
#     'Start': 0.546,
#     'End': 0.5467}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 546200,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 786432,
#     'Length': 262144,
#     'Start': 0.5462,
#     'End': 0.5469}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 546300,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 786432,
#     'Length': 262144,
#     'Start': 0.5463,
#     'End': 0.547}},
#   {'ph': 'E',
#    'ts': 546300,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 786432,
#     'Length': 262144,
#     'Start': 0.5455,
#     'End': 0.5463}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 546400,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 786432,
#     'Length': 262144,
#     'Start': 0.5464,
#     'End': 0.5471}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 546400,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 786432,
#     'Length': 262144,
#     'Start': 0.5464,
#     'End': 0.547}},
#   {'ph': 'E',
#    'ts': 546500,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 786432,
#     'Length': 262144,
#     'Start': 0.5459,
#     'End': 0.5465}},
#   {'ph': 'E',
#    'ts': 546700,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 786432,
#     'Length': 262144,
#     'Start': 0.546,
#     'End': 0.5467}},
#   {'ph': 'E',
#    'ts': 546700,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 786432,
#     'Length': 262144,
#     'Start': 0.5458,
#     'End': 0.5467}},
#   {'ph': 'E',
#    'ts': 546900,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 786432,
#     'Length': 262144,
#     'Start': 0.5462,
#     'End': 0.5469}},
#   {'ph': 'E',
#    'ts': 547000,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 786432,
#     'Length': 262144,
#     'Start': 0.5463,
#     'End': 0.547}},
#   {'ph': 'E',
#    'ts': 547000,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 786432,
#     'Length': 262144,
#     'Start': 0.5464,
#     'End': 0.547}},
#   {'ph': 'E',
#    'ts': 547100,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 786432,
#     'Length': 262144,
#     'Start': 0.5464,
#     'End': 0.5471}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 552500,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 1048576,
#     'Length': 262144,
#     'Start': 0.5525,
#     'End': 0.5532}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 552700,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 1048576,
#     'Length': 262144,
#     'Start': 0.5527,
#     'End': 0.5534}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 552800,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 1048576,
#     'Length': 262144,
#     'Start': 0.5528,
#     'End': 0.5535}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 552900,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 1048576,
#     'Length': 262144,
#     'Start': 0.5529,
#     'End': 0.5536}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 553000,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 1048576,
#     'Length': 262144,
#     'Start': 0.553,
#     'End': 0.5537}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 553200,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 1048576,
#     'Length': 262144,
#     'Start': 0.5532,
#     'End': 0.5539}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 553200,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 1048576,
#     'Length': 262144,
#     'Start': 0.5532,
#     'End': 0.5537}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 553200,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 1048576,
#     'Length': 262144,
#     'Start': 0.5532,
#     'End': 0.554}},
#   {'ph': 'E',
#    'ts': 553200,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 1048576,
#     'Length': 262144,
#     'Start': 0.5525,
#     'End': 0.5532}},
#   {'ph': 'E',
#    'ts': 553400,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 1048576,
#     'Length': 262144,
#     'Start': 0.5527,
#     'End': 0.5534}},
#   {'ph': 'E',
#    'ts': 553500,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 1048576,
#     'Length': 262144,
#     'Start': 0.5528,
#     'End': 0.5535}},
#   {'ph': 'E',
#    'ts': 553600,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 1048576,
#     'Length': 262144,
#     'Start': 0.5529,
#     'End': 0.5536}},
#   {'ph': 'E',
#    'ts': 553700,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 1048576,
#     'Length': 262144,
#     'Start': 0.5532,
#     'End': 0.5537}},
#   {'ph': 'E',
#    'ts': 553700,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 1048576,
#     'Length': 262144,
#     'Start': 0.553,
#     'End': 0.5537}},
#   {'ph': 'E',
#    'ts': 553900,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 1048576,
#     'Length': 262144,
#     'Start': 0.5532,
#     'End': 0.5539}},
#   {'ph': 'E',
#    'ts': 554000,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 1048576,
#     'Length': 262144,
#     'Start': 0.5532,
#     'End': 0.554}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 559900,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 1310720,
#     'Length': 262144,
#     'Start': 0.5599,
#     'End': 0.5607}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 560100,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 1310720,
#     'Length': 262144,
#     'Start': 0.5601,
#     'End': 0.5608}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 560300,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 1310720,
#     'Length': 262144,
#     'Start': 0.5603,
#     'End': 0.561}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 560300,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 1310720,
#     'Length': 262144,
#     'Start': 0.5603,
#     'End': 0.561}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 560400,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 1310720,
#     'Length': 262144,
#     'Start': 0.5604,
#     'End': 0.5609}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 560500,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 1310720,
#     'Length': 262144,
#     'Start': 0.5605,
#     'End': 0.561}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 560600,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
# ...
#     'Start': 0.9756,
#     'End': 0.9766}},
#   {'ph': 'E',
#    'ts': 976800,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 58,
#     'Offset': 15204352,
#     'Length': 262144,
#     'Start': 0.976,
#     'End': 0.9768}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 977100,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 57,
#     'Offset': 14942208,
#     'Length': 262144,
#     'Start': 0.9771,
#     'End': 0.9779}},
#   {'ph': 'E',
#    'ts': 977900,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 57,
#     'Offset': 14942208,
#     'Length': 262144,
#     'Start': 0.9771,
#     'End': 0.9779}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 979100,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 58,
#     'Offset': 15204352,
#     'Length': 262144,
#     'Start': 0.9791,
#     'End': 0.9797}},
#   {'ph': 'E',
#    'ts': 979700,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 58,
#     'Offset': 15204352,
#     'Length': 262144,
#     'Start': 0.9791,
#     'End': 0.9797}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 980500,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 57,
#     'Offset': 14942208,
#     'Length': 262144,
#     'Start': 0.9805,
#     'End': 0.9812}},
#   {'ph': 'E',
#    'ts': 981200,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 57,
#     'Offset': 14942208,
#     'Length': 262144,
#     'Start': 0.9805,
#     'End': 0.9812}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 982700,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 59,
#     'Offset': 15466496,
#     'Length': 262144,
#     'Start': 0.9827,
#     'End': 0.9833}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 983000,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 59,
#     'Offset': 15466496,
#     'Length': 262144,
#     'Start': 0.983,
#     'End': 0.9837}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 983000,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 58,
#     'Offset': 15204352,
#     'Length': 262144,
#     'Start': 0.983,
#     'End': 0.9837}},
#   {'ph': 'E',
#    'ts': 983300,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 59,
#     'Offset': 15466496,
#     'Length': 262144,
#     'Start': 0.9827,
#     'End': 0.9833}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 983300,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 58,
#     'Offset': 15204352,
#     'Length': 262144,
#     'Start': 0.9833,
#     'End': 0.9842}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 983400,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 59,
#     'Offset': 15466496,
#     'Length': 262144,
#     'Start': 0.9834,
#     'End': 0.984}},
#   {'ph': 'E',
#    'ts': 983700,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 59,
#     'Offset': 15466496,
#     'Length': 262144,
#     'Start': 0.983,
#     'End': 0.9837}},
#   {'ph': 'E',
#    'ts': 983700,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 58,
#     'Offset': 15204352,
#     'Length': 262144,
#     'Start': 0.983,
#     'End': 0.9837}},
#   {'ph': 'E',
#    'ts': 984000,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 59,
#     'Offset': 15466496,
#     'Length': 262144,
#     'Start': 0.9834,
#     'End': 0.984}},
#   {'ph': 'E',
#    'ts': 984200,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 58,
#     'Offset': 15204352,
#     'Length': 262144,
#     'Start': 0.9833,
#     'End': 0.9842}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 984600,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 58,
#     'Offset': 15204352,
#     'Length': 262144,
#     'Start': 0.9846,
#     'End': 0.9854}},
#   {'ph': 'E',
#    'ts': 985400,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 58,
#     'Offset': 15204352,
#     'Length': 262144,
#     'Start': 0.9846,
#     'End': 0.9854}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 986300,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 59,
#     'Offset': 15466496,
#     'Length': 262144,
#     'Start': 0.9863,
#     'End': 0.9869}},
#   {'ph': 'E',
#    'ts': 986900,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 59,
#     'Offset': 15466496,
#     'Length': 262144,
#     'Start': 0.9863,
#     'End': 0.9869}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 987800,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 58,
#     'Offset': 15204352,
#     'Length': 262144,
#     'Start': 0.9878,
#     'End': 0.9885}},
#   {'ph': 'E',
#    'ts': 988500,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 58,
#     'Offset': 15204352,
#     'Length': 262144,
#     'Start': 0.9878,
#     'End': 0.9885}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 989900,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 60,
#     'Offset': 15728640,
#     'Length': 262144,
#     'Start': 0.9899,
#     'End': 0.9906}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 990300,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 60,
#     'Offset': 15728640,
#     'Length': 262144,
#     'Start': 0.9903,
#     'End': 0.991}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 990400,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 59,
#     'Offset': 15466496,
#     'Length': 262144,
#     'Start': 0.9904,
#     'End': 0.991}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 990500,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 60,
#     'Offset': 15728640,
#     'Length': 262144,
#     'Start': 0.9905,
#     'End': 0.9912}},
#   {'ph': 'E',
#    'ts': 990600,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 60,
#     'Offset': 15728640,
#     'Length': 262144,
#     'Start': 0.9899,
#     'End': 0.9906}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 990900,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 59,
#     'Offset': 15466496,
#     'Length': 262144,
#     'Start': 0.9909,
#     'End': 0.9919}},
#   {'ph': 'E',
#    'ts': 991000,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 60,
#     'Offset': 15728640,
#     'Length': 262144,
#     'Start': 0.9903,
#     'End': 0.991}},
#   {'ph': 'E',
#    'ts': 991000,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 59,
#     'Offset': 15466496,
#     'Length': 262144,
#     'Start': 0.9904,
#     'End': 0.991}},
#   {'ph': 'E',
#    'ts': 991200,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 60,
#     'Offset': 15728640,
#     'Length': 262144,
#     'Start': 0.9905,
#     'End': 0.9912}},
#   {'ph': 'E',
#    'ts': 991900,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 59,
#     'Offset': 15466496,
#     'Length': 262144,
#     'Start': 0.9909,
#     'End': 0.9919}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 992100,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 59,
#     'Offset': 15466496,
#     'Length': 262144,
#     'Start': 0.9921,
#     'End': 0.9929}},
#   {'ph': 'E',
#    'ts': 992900,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 59,
#     'Offset': 15466496,
#     'Length': 262144,
#     'Start': 0.9921,
#     'End': 0.9929}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 993500,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 60,
#     'Offset': 15728640,
#     'Length': 262144,
#     'Start': 0.9935,
#     'End': 0.9942}},
#   {'ph': 'E',
#    'ts': 994200,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 60,
#     'Offset': 15728640,
#     'Length': 262144,
#     'Start': 0.9935,
#     'End': 0.9942}},
#   {'name': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 995200,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 59,
#     'Offset': 15466496,
#     'Length': 262144,
#     'Start': 0.9952,
#     'End': 0.9959}},
#   {'ph': 'E',
#    'ts': 995900,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 59,
#     'Offset': 15466496,
#     'Length': 262144,
#     'Start': 0.9952,
#     'End': 0.9959}},
#   ...],
#  'displayTimeUnit': 'ms',
#  'systemTraceEvents': 'SystemTraceData',
#  'otherData': {'version': 'VaniDL v1.0'},
#  'stackFrames': {},
#  'samples': []}

# %%
import csv
with open('/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv', newline='\n') as f:
    reader = csv.reader(f)
    row1 = next(reader)
    print(len(row1))
# Out:
# 60484

# %%
import pandas as pd
val = pd.read_csv('/gpfs/mira-home/dhari/code/learnIO/benchmarks/candel/common/../Data/Pilot1/nt_train2.csv',header=None,low_memory=False)
