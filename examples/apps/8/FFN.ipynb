# %% [markdown]
# # DLProfile Example using Distributed FFN Application

# %% [markdown]
# ## Set imports and neccessary environment variables

# %%
import pathlib
import os
import sys
import matplotlib.pyplot as plt
import warnings
import pprint
import pandas as pd
import tensorflow as tf

# %%
VANIDL_DIR="{}".format(pathlib.Path(os.getcwd()).parent.parent.parent.absolute())
sys.path.insert(0, VANIDL_DIR)
warnings.filterwarnings('ignore')

# %%
os.environ["DARSHAN_DIR"] = "/soft/perftools/darshan/darshan-3.1.8"
os.environ["VANIDL_DIR"] = VANIDL_DIR

# %% [markdown]
# ### Formatting

# %%
pp = pprint.PrettyPrinter(indent=1)
class color:
    PURPLE = '\033[95m'
    CYAN = '\033[96m'
    DARKCYAN = '\033[36m'
    BLUE = '\033[94m'
    GREEN = '\033[92m'
    YELLOW = '\033[93m'
    RED = '\033[91m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'
    END = '\033[0m'

# %% [markdown]
# ## Create instrance of DL Profile and load the darshan file

# %%
from src.vanidl import VaniDL
profile = VaniDL()

# %%
DATAPATH_INCLUDES = []
status = profile.Load("/home/dhari/darshan-logs/apps/train_ffn/ffn_run1_p8.darshan", data_paths_include=DATAPATH_INCLUDES)
if status:
    print("Darshan Trace loaded Successfully!")
else:
    print("Darshan Trace load Failed!")
    print(profile._error_str())
# Out:
# Loaded Pre-processed DXT DF from file: /tmp/temp_analysis/ffn_run1_p8_io_dxt_df.csv
# Loaded Pre-processed DF from file: /tmp/temp_analysis/ffn_run1_p8_io_df.csv
# Loaded Pre-processed Pattern file: /tmp/temp_analysis/ffn_run1_p8_pattern.json
# Darshan Trace loaded Successfully!

# %% [markdown]
# ## Use Profile object to analyze the darshan I/O trace.

# %% [markdown]
# ### Verify if object works
#
# The GetDXTAsDF() function enables users to perform analysis

# %%
pd.set_option('display.max_colwidth', -1)
df = profile.GetDXTAsDF()
pp.pprint("Files used in the application")
pp.pprint(df['Filename'].unique().tolist())
# Out:
# 'Files used in the application'
# ['/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#  '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/grayscale_maps.h5',
#  '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/tf_record_file']

# %% [markdown]
# ### Collect the summary of the Application

# %%
summary = profile.GetSummary()
print("\n")
print(color.BOLD + "Data Access Summary (from Darshan):"+ color.END)
print("Total Job time\t\t\t:\t{:0.2f} seconds".format(summary['job_time']))
#FIXME: calculate time per rank and then take max across it.
print("Time spent in I/O\t\t:\t{:0.2f} seconds".format(summary['total_io_time']))
print("% Time spent in I/O\t\t:\t{:0.2f}%".format(float(summary['total_io_time'])*100/summary['job_time']))
print("Total Data Accessed\t\t:\t{:0.2f} GB".format(float(summary['total_io_bytes'])/1024.0/1024.0/1024.0))
print("Data Access Modules used\t:\t{}".format(summary['io_interface_used']))
print("Data Operations\t\t\t:\t{}".format(summary['io_operations_used']))
print("# of files used\t\t\t:\t{}".format(len(summary['files_used'])))
print("# of MPI Ranks\t\t\t:\t{:0.0f} ranks".format(summary['num_ranks']))
      
print(color.UNDERLINE + "Data Transfer size:"+ color.END)
print("\tMin,Max\t\t\t:\t{:0.0f} bytes and {:0.0f} bytes".format(summary['data_transfer_size']['min'],summary['data_transfer_size']['max']))
print("\tAverage\t\t\t:\t{:0.0f} bytes".format(summary['data_transfer_size']['mean']))
print("\tMedian\t\t\t:\t{:0.0f} bytes".format(summary['data_transfer_size']['median']))
      
print(color.UNDERLINE + "Data Transfer bandwidth: (per rank)"+ color.END)
print("\tMin,Max\t\t\t:\t{:0.0f} B/s and {:0.0f} MB/s".format(summary['data_transfer_bandwidth']['min'],summary['data_transfer_bandwidth']['max']/1024.0/1024.0))
print("\tAverage\t\t\t:\t{:0.0f} MB/s".format(summary['data_transfer_bandwidth']['mean']/1024.0/1024.0))
print("\tMedian\t\t\t:\t{:0.0f} MB/s".format(summary['data_transfer_bandwidth']['median']/1024.0/1024.0))
      
print(color.UNDERLINE + "Access Pattern:"+ color.END)
print("\tSequential\t\t:\t{:0.2f}%".format(float(summary['access_pattern']['sequential'])))
print("\tConsecutive\t\t:\t{:0.2f}%".format(float(summary['access_pattern']['consecutive'])))
#An I/O op issued at an offset greater than where the previous I/O op ended.
#An I/O op issued at the offset immediately after the end of the previous I/O

print("\n")
print(color.BOLD + "Files Summary:"+ color.END)
print("File Types\t\t\t:\t{}".format(summary['file_used_summary']['types']))
print(color.UNDERLINE + "Dataset Size:"+ color.END)
print("\tTotal\t\t\t:\t{:0.3f} GB".format(float(summary['file_used_summary']['size']['total'])/1024.0/1024.0/1024.0))
print("\tMin,Max\t\t\t:\t{:0.3f} GB and {:0.3f} GB".format(float(summary['file_used_summary']['size']['min'])/1024.0/1024.0/1024.0,float(summary['file_used_summary']['size']['max'])/1024.0/1024.0/1024.0))
print("\tAverage\t\t\t:\t{:0.3f} GB".format(float(summary['file_used_summary']['size']['mean'])/1024.0/1024.0/1024.0))
# Out:
# Data Access Summary (from Darshan):
# Total Job time			:	336.00 seconds
# Time spent in I/O		:	14.02 seconds
# % Time spent in I/O		:	4.17%
# Total Data Accessed		:	1.37 GB
# Data Access Modules used	:	['X_POSIX']
# Data Operations			:	['read']
# # of files used			:	3
# # of MPI Ranks			:	8 ranks
# Data Transfer size:
# 	Min,Max			:	8 bytes and 262144 bytes
# 	Average			:	19719 bytes
# 	Median			:	3729 bytes
# Data Transfer bandwidth: (per rank)
# 	Min,Max			:	519 B/s and 600 MB/s
# 	Average			:	45 MB/s
# 	Median			:	4 MB/s
# Access Pattern:
# 	Sequential		:	94.34%
# 	Consecutive		:	48.94%
#
#
# Files Summary:
# File Types			:	['h5' '']
# Dataset Size:
# 	Total			:	2.275 GB
# 	Min,Max			:	0.021 GB and 2.144 GB
# 	Average			:	0.758 GB

# %%
pp.pprint("Job time : {} seconds".format(profile.GetJobTime()))
# Out:
# 'Job time : 336.0 seconds'

# %%
pp.pprint("Time spent by application on I/O: {} seconds".format(profile.GetIOTime()))
# Out:
# 'Time spent by application on I/O: 14.016887499999633 seconds'

# %% [markdown]
# ### I/O time spent on each file

# %%
for file in df['Filename'].unique():
    print("I/O time for file {}: {:0.2f} seconds".format(file,profile.GetIOTime(filepath=file)))
# Out:
# I/O time for file /lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5: 5.25 seconds
# I/O time for file /lus/theta-fs0/projects/datascience/keceli/run/f3n/training/grayscale_maps.h5: 8.76 seconds
# I/O time for file /lus/theta-fs0/projects/datascience/keceli/run/f3n/training/tf_record_file: 0.01 seconds

# %% [markdown]
# ### I/O Time spent per rank

# %%
for rank in df['Rank'].unique()[:16]:
    print("I/O time for rank {}: {:0.2f} seconds".format(rank,profile.GetIOTime(rank=rank)))
# Out:
# I/O time for rank 0: 15.29 seconds
# I/O time for rank 1: 13.43 seconds
# I/O time for rank 2: 15.62 seconds
# I/O time for rank 3: 10.39 seconds
# I/O time for rank 4: 11.60 seconds
# I/O time for rank 5: 13.22 seconds
# I/O time for rank 6: 14.87 seconds
# I/O time for rank 7: 17.72 seconds

# %%
"Total I/O performed by application: {:0.2f} GB".format(float(profile.GetIOSize())/1024.0/1024.0/1024.0)
# Out:
# 'Total I/O performed by application: 1.37 GB'

# %% [markdown]
# ### I/O performed on each file

# %%
for file in df['Filename'].unique()[:16]:
    print("I/O performed on file {}: {:0.2f} MB".format(file,float(profile.GetIOSize(filepath=file))/1024.0/1024.0))
# Out:
# I/O performed on file /lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5: 131.89 MB
# I/O performed on file /lus/theta-fs0/projects/datascience/keceli/run/f3n/training/grayscale_maps.h5: 1240.51 MB
# I/O performed on file /lus/theta-fs0/projects/datascience/keceli/run/f3n/training/tf_record_file: 2.00 MB

# %%
for rank in df['Rank'].unique()[:16]:
    print("I/O performed by rank {}: {:0.2f} MB".format(rank, float(profile.GetIOSize(rank=rank))/1024.0/1024.0))
# Out:
# I/O performed by rank 0: 164.19 MB
# I/O performed by rank 1: 177.01 MB
# I/O performed by rank 2: 170.08 MB
# I/O performed by rank 3: 171.84 MB
# I/O performed by rank 4: 173.10 MB
# I/O performed by rank 5: 170.08 MB
# I/O performed by rank 6: 171.07 MB
# I/O performed by rank 7: 177.01 MB

# %%
sizes = profile.GetFileSizes()
for key in sizes:
    sizes[key] = sizes[key]/1024.0/1024.0
print("Size of dataset (MB)")
pp.pprint(sizes)
# Out:
# Size of dataset (MB)
# {'grayscale_maps': 112.82099628448486,
#  'groundtruth': 21.355467796325684,
#  'tf_record_file': 2195.8580656051636}

# %% [markdown]
# ### How application access data over time.

# %%
tl = profile.CreateIOTimeline(time_step=0.001)
plt.figure(figsize=(10,4))
plt.xlabel("Timeline (ms)")
plt.ylabel("# of Operations (ms)")
plt.grid()
plt.plot(tl['time_step'], tl['operation_count']);
# Out:
# Loaded Pre-processed Timeline from file: /tmp/temp_analysis/ffn_run1_p8_tm_df.csv

# %%
plt.figure(figsize=(20,4))
plt.grid()
plt.plot(tl['time_step'], tl['io_bytes']);

# %% [markdown]
# ### How files are accessed over the duration of the Job.

# %%
for file in df['Filename'].unique():
    tl = profile.CreateIOTimeline(filepath=file, time_step=0.001)
    tl.plot(x='time_step',y='operation_count', title=file)
    plt.show()
# Out:
# Loaded Pre-processed Timeline from file: /tmp/temp_analysis/ffn_run1_p8_tm_df_groundtruth.csv
# Loaded Pre-processed Timeline from file: /tmp/temp_analysis/ffn_run1_p8_tm_df_grayscale_maps.csv
# Loaded Pre-processed Timeline from file: /tmp/temp_analysis/ffn_run1_p8_tm_df_tf_record_file.csv

# %% [markdown]
# ### Show how each file is accessed by each rank.

# %%
for rank in df['Rank'].unique()[:16]:
    tl = profile.CreateIOTimeline(rank=rank, time_step=0.001)
    tl.plot(x='time_step',y='operation_count', title=rank)
    plt.show()
# Out:
# Loaded Pre-processed Timeline from file: /tmp/temp_analysis/ffn_run1_p8_tm_df_0.csv
# Loaded Pre-processed Timeline from file: /tmp/temp_analysis/ffn_run1_p8_tm_df_1.csv
# Loaded Pre-processed Timeline from file: /tmp/temp_analysis/ffn_run1_p8_tm_df_2.csv
# Loaded Pre-processed Timeline from file: /tmp/temp_analysis/ffn_run1_p8_tm_df_3.csv
# Loaded Pre-processed Timeline from file: /tmp/temp_analysis/ffn_run1_p8_tm_df_4.csv
# Loaded Pre-processed Timeline from file: /tmp/temp_analysis/ffn_run1_p8_tm_df_5.csv
# Loaded Pre-processed Timeline from file: /tmp/temp_analysis/ffn_run1_p8_tm_df_6.csv
# Loaded Pre-processed Timeline from file: /tmp/temp_analysis/ffn_run1_p8_tm_df_7.csv

# %% [markdown]
# ### Data Transfer Size distribution within the application

# %%
request_df = profile.GetIORequestDistribution()
df['Length'].plot(kind='hist', figsize=(5, 3),bins=1000,xlim=(0,70000));
plt.xlabel("Transfer Size (bytes)")
# Out:
# Text(0.5, 0, 'Transfer Size (bytes)')

# %% [markdown]
# ### Data Transfer Size distribution for each file.

# %%
for file in df['Filename'].unique():
    #tl = profile.GetIORequestDistribution(filepath=file, bins=50)
    tl = df[df["Filename"].eq(file)]
    tl['Length'].plot(kind='hist', figsize=(5, 3),bins=50);
    plt.xlabel("Transfer Size (bytes)")
    plt.title(file)
    plt.show()

# %% [markdown]
# ### Data Transfer Sizes per Rank

# %%
for rank in df['Rank'].unique()[:16]:
    tl = profile.GetIORequestDistribution(rank=rank)
    tl.plot(kind='bar', figsize=(10, 4), title=rank)
    plt.show()

# %% [markdown]
# ### File summary of each file accessed by the Application

# %%
pp = pprint.PrettyPrinter(indent=1)
for file in df['Filename'].unique():
    if 'h5' in file:
        pp.pprint(profile.GetFileSummary(file,ext='h5'))
    else:
        pp.pprint(profile.GetFileSummary(file,ext='tfrecord',tf_record_features=dict(
                                        center=tf.io.FixedLenFeature(shape=[1, 3], dtype=tf.int64),
                                        label_volume_name=tf.io.FixedLenFeature(shape=[1], dtype=tf.string),)
                                        ))
# Out:
# {'ext': 'h5',
#  'filename': 'groundtruth',
#  'io_size': 138292615,
#  'io_time': 5.251262499999755,
#  'path': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#  'size': 22392831,
#  'special': {'keys': [{'name': 'stack',
#                        'obj': <HDF5 dataset "stack": shape (520, 520, 520), type "<i8">,
#                        'shape': (520, 520, 520),
#                        'size': 140608000,
#                        'type': 'dataset'},
#                       {'name': 'synapse-annotations',
#                        'obj': <HDF5 dataset "synapse-annotations": shape (1,), type "|O">,
#                        'shape': (1,),
#                        'size': 1,
#                        'type': 'dataset'},
#                       {'name': 'transforms',
#                        'obj': <HDF5 dataset "transforms": shape (2084, 2), type "<u8">,
#                        'shape': (2084, 2),
#                        'size': 4168,
#                        'type': 'dataset'}],
#              'name': 'groundtruth',
#              'type': 'group'}}
# {'ext': 'h5',
#  'filename': 'grayscale_maps',
#  'io_size': 1300764675,
#  'io_time': 8.758699999999884,
#  'path': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/grayscale_maps.h5',
#  'size': 118301389,
#  'special': {'keys': [{'name': 'raw',
#                        'obj': <HDF5 dataset "raw": shape (520, 520, 520), type "|u1">,
#                        'shape': (520, 520, 520),
#                        'size': 140608000,
#                        'type': 'dataset'}],
#              'name': 'grayscale_maps',
#              'type': 'group'}}
# {'ext': 'tfrecord',
#  'filename': 'tf_record_file',
#  'io_size': 2097152,
#  'io_time': 0.006924999999995407,
#  'path': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/tf_record_file',
#  'size': 2302524067,
#  'special': <ParallelMapDataset shapes: {center: (1, 3), label_volume_name: (1,)}, types: {center: tf.int64, label_volume_name: tf.string}>}

# %%
profile.CreateChromeTimeline(location="/home/dhari", filename="ffn_run1_p128_io.json")
# Out:
# [============================================================] 100.0% 73086 of 73086 Creating DXT Timeline
# [============================================================] 100.0% 13 of 13 Creating DXT Timeline
# {'traceEvents': [{'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 679300,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.6793,
#     'End': 0.6947}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 681400,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.6814,
#     'End': 0.6955}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 681700,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.6817,
#     'End': 0.6949}},
#   {'ph': 'E',
#    'ts': 694700,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.6793,
#     'End': 0.6947}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 694900,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.6949,
#     'End': 0.6949}},
#   {'ph': 'E',
#    'ts': 694900,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.6949,
#     'End': 0.6949}},
#   {'ph': 'E',
#    'ts': 694900,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.6817,
#     'End': 0.6949}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 695000,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.695,
#     'End': 0.695}},
#   {'ph': 'E',
#    'ts': 695000,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.695,
#     'End': 0.695}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 695100,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.6951,
#     'End': 0.6951}},
#   {'ph': 'E',
#    'ts': 695100,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.6951,
#     'End': 0.6951}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 695200,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.6952,
#     'End': 0.6952}},
#   {'ph': 'E',
#    'ts': 695200,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.6952,
#     'End': 0.6952}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 695200,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.6952,
#     'End': 0.6952}},
#   {'ph': 'E',
#    'ts': 695200,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.6952,
#     'End': 0.6952}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 695400,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.6954,
#     'End': 0.6954}},
#   {'ph': 'E',
#    'ts': 695400,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.6954,
#     'End': 0.6954}},
#   {'ph': 'E',
#    'ts': 695500,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.6814,
#     'End': 0.6955}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 695700,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.6957,
#     'End': 0.6957}},
#   {'ph': 'E',
#    'ts': 695700,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.6957,
#     'End': 0.6957}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 695700,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.6957,
#     'End': 0.6957}},
#   {'ph': 'E',
#    'ts': 695700,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.6957,
#     'End': 0.6957}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 696000,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.696,
#     'End': 0.696}},
#   {'ph': 'E',
#    'ts': 696000,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.696,
#     'End': 0.696}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 700600,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.7006,
#     'End': 0.7006}},
#   {'ph': 'E',
#    'ts': 700600,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.7006,
#     'End': 0.7006}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 700700,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.7007,
#     'End': 0.7007}},
#   {'ph': 'E',
#    'ts': 700700,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.7007,
#     'End': 0.7007}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 700800,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 21833600,
#     'Length': 328,
#     'Start': 0.7008,
#     'End': 0.7141}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 701000,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.701,
#     'End': 0.7011}},
#   {'ph': 'E',
#    'ts': 701100,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.701,
#     'End': 0.7011}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 701100,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.7011,
#     'End': 0.7011}},
#   {'ph': 'E',
#    'ts': 701100,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.7011,
#     'End': 0.7011}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 701200,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 21833600,
#     'Length': 328,
#     'Start': 0.7012,
#     'End': 0.7147}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 702000,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.7020000000000001,
#     'End': 0.7021}},
#   {'ph': 'E',
#    'ts': 702100,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.7020000000000001,
#     'End': 0.7021}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 702100,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.7021,
#     'End': 0.7022}},
#   {'ph': 'E',
#    'ts': 702200,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.7021,
#     'End': 0.7022}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 702200,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 21833600,
#     'Length': 328,
#     'Start': 0.7022,
#     'End': 0.7146}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 704600,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.7046,
#     'End': 0.7059}},
#   {'ph': 'E',
#    'ts': 705900,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.7046,
#     'End': 0.7059}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 706100,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.7061,
#     'End': 0.7061}},
#   {'ph': 'E',
#    'ts': 706100,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.7061,
#     'End': 0.7061}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 706200,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.7062,
#     'End': 0.7062}},
#   {'ph': 'E',
#    'ts': 706200,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.7062,
#     'End': 0.7062}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 706400,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.7064,
#     'End': 0.7064}},
#   {'ph': 'E',
#    'ts': 706400,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.7064,
#     'End': 0.7064}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 711600,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.7116,
#     'End': 0.7116}},
#   {'ph': 'E',
#    'ts': 711600,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.7116,
#     'End': 0.7116}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 711700,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.7117,
#     'End': 0.7117}},
#   {'ph': 'E',
#    'ts': 711700,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.7117,
#     'End': 0.7117}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 711800,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 21833600,
#     'Length': 328,
#     'Start': 0.7118,
#     'End': 0.7145}},
#   {'ph': 'E',
#    'ts': 714100,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 21833600,
#     'Length': 328,
#     'Start': 0.7008,
#     'End': 0.7141}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 714200,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 800,
#     'Length': 512,
#     'Start': 0.7142,
#     'End': 0.7142}},
#   {'ph': 'E',
#    'ts': 714200,
#    'pid': 4,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 4,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 800,
#     'Length': 512,
#     'Start': 0.7142,
#     'End': 0.7142}},
#   {'ph': 'E',
#    'ts': 714500,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 21833600,
#     'Length': 328,
#     'Start': 0.7118,
#     'End': 0.7145}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 714500,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 800,
#     'Length': 512,
#     'Start': 0.7145,
#     'End': 0.7146}},
#   {'ph': 'E',
#    'ts': 714600,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 21833600,
#     'Length': 328,
#     'Start': 0.7022,
#     'End': 0.7146}},
#   {'ph': 'E',
#    'ts': 714600,
#    'pid': 7,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 7,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 800,
#     'Length': 512,
#     'Start': 0.7145,
#     'End': 0.7146}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 714700,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 800,
#     'Length': 512,
#     'Start': 0.7147,
#     'End': 0.7147}},
#   {'ph': 'E',
#    'ts': 714700,
#    'pid': 2,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 2,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 800,
#     'Length': 512,
#     'Start': 0.7147,
#     'End': 0.7147}},
#   {'ph': 'E',
#    'ts': 714700,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 21833600,
#     'Length': 328,
#     'Start': 0.7012,
#     'End': 0.7147}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 714800,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 800,
#     'Length': 512,
#     'Start': 0.7148,
#     'End': 0.7148}},
#   {'ph': 'E',
#    'ts': 714800,
#    'pid': 6,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 6,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 800,
#     'Length': 512,
#     'Start': 0.7148,
#     'End': 0.7148}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 717200,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.7172,
#     'End': 0.7188}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 717300,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.7173,
#     'End': 0.7190000000000001}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 717700,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.7177,
#     'End': 0.7191}},
#   {'ph': 'E',
#    'ts': 718800,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.7172,
#     'End': 0.7188}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 719000,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.7190000000000001,
#     'End': 0.7190000000000001}},
#   {'ph': 'E',
#    'ts': 719000,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.7190000000000001,
#     'End': 0.7190000000000001}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 719000,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.7190000000000001,
#     'End': 0.7190000000000001}},
#   {'ph': 'E',
#    'ts': 719000,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.7190000000000001,
#     'End': 0.7190000000000001}},
#   {'ph': 'E',
#    'ts': 719000,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.7173,
#     'End': 0.7190000000000001}},
#   {'ph': 'E',
#    'ts': 719100,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.7177,
#     'End': 0.7191}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 719100,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.7191,
#     'End': 0.7204}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 719200,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.7192,
#     'End': 0.7192}},
#   {'ph': 'E',
#    'ts': 719200,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.7192,
#     'End': 0.7192}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 719200,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.7192,
#     'End': 0.7192}},
#   {'ph': 'E',
#    'ts': 719200,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.7192,
#     'End': 0.7192}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 719300,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.7193,
#     'End': 0.7193}},
#   {'ph': 'E',
#    'ts': 719300,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.7193,
#     'End': 0.7193}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 719300,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.7193,
#     'End': 0.7193}},
#   {'ph': 'E',
#    'ts': 719300,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.7193,
#     'End': 0.7193}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 719400,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.7194,
#     'End': 0.7194}},
#   {'ph': 'E',
#    'ts': 719400,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.7194,
#     'End': 0.7194}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 719500,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.7195,
#     'End': 0.7195}},
#   {'ph': 'E',
#    'ts': 719500,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.7195,
#     'End': 0.7195}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 719600,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.7196,
#     'End': 0.7196}},
#   {'ph': 'E',
#    'ts': 719600,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.7196,
#     'End': 0.7196}},
#   {'ph': 'E',
#    'ts': 720400,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 0,
#     'Offset': 0,
#     'Length': 8,
#     'Start': 0.7191,
#     'End': 0.7204}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 720600,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.7206,
#     'End': 0.7206}},
#   {'ph': 'E',
#    'ts': 720600,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 1,
#     'Offset': 0,
#     'Length': 16,
#     'Start': 0.7206,
#     'End': 0.7206}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 720700,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.7207,
#     'End': 0.7207}},
#   {'ph': 'E',
#    'ts': 720700,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 2,
#     'Offset': 16,
#     'Length': 80,
#     'Start': 0.7207,
#     'End': 0.7207}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 720900,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.7209,
#     'End': 0.7209}},
#   {'ph': 'E',
#    'ts': 720900,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 3,
#     'Offset': 96,
#     'Length': 512,
#     'Start': 0.7209,
#     'End': 0.7209}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 725700,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.7257,
#     'End': 0.7257}},
#   {'ph': 'E',
#    'ts': 725700,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.7257,
#     'End': 0.7257}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 725800,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.7258,
#     'End': 0.7258}},
#   {'ph': 'E',
#    'ts': 725800,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.7258,
#     'End': 0.7258}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 725900,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 21833600,
#     'Length': 328,
#     'Start': 0.7259,
#     'End': 0.7272}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 726200,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.7262,
#     'End': 0.7262}},
#   {'ph': 'E',
#    'ts': 726200,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.7262,
#     'End': 0.7262}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 726300,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.7263,
#     'End': 0.7263}},
#   {'ph': 'E',
#    'ts': 726300,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.7263,
#     'End': 0.7263}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 726300,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 21833600,
#     'Length': 328,
#     'Start': 0.7263,
#     'End': 0.7278}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 726900,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.7269,
#     'End': 0.7269}},
#   {'ph': 'E',
#    'ts': 726900,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.7269,
#     'End': 0.7269}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 727000,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.727,
#     'End': 0.727}},
#   {'ph': 'E',
#    'ts': 727000,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.727,
#     'End': 0.727}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 727000,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 21833600,
#     'Length': 328,
#     'Start': 0.727,
#     'End': 0.7286}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 727000,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.727,
#     'End': 0.727}},
#   {'ph': 'E',
#    'ts': 727000,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 4,
#     'Offset': 680,
#     'Length': 512,
#     'Start': 0.727,
#     'End': 0.727}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 727100,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.7271,
#     'End': 0.7271}},
#   {'ph': 'E',
#    'ts': 727100,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 5,
#     'Offset': 136,
#     'Length': 544,
#     'Start': 0.7271,
#     'End': 0.7271}},
#   {'ph': 'E',
#    'ts': 727200,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 21833600,
#     'Length': 328,
#     'Start': 0.7259,
#     'End': 0.7272}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 727200,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 21833600,
#     'Length': 328,
#     'Start': 0.7272,
#     'End': 0.7287}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 727400,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 800,
#     'Length': 512,
#     'Start': 0.7274,
#     'End': 0.7274}},
#   {'ph': 'E',
#    'ts': 727400,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 800,
#     'Length': 512,
#     'Start': 0.7274,
#     'End': 0.7274}},
#   {'ph': 'E',
#    'ts': 727800,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 21833600,
#     'Length': 328,
#     'Start': 0.7263,
#     'End': 0.7278}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 727900,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 800,
#     'Length': 512,
#     'Start': 0.7279,
#     'End': 0.7279}},
#   {'ph': 'E',
#    'ts': 727900,
#    'pid': 3,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 3,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 800,
#     'Length': 512,
#     'Start': 0.7279,
#     'End': 0.7279}},
#   {'ph': 'E',
#    'ts': 728600,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 21833600,
#     'Length': 328,
#     'Start': 0.727,
#     'End': 0.7286}},
#   {'ph': 'E',
#    'ts': 728700,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 5,
#     'Operation': 'read',
#     'Segment': 6,
#     'Offset': 21833600,
#     'Length': 328,
#     'Start': 0.7272,
#     'End': 0.7287}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 728800,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 800,
#     'Length': 512,
#     'Start': 0.7288,
#     'End': 0.7288}},
#   {'ph': 'E',
#    'ts': 728800,
#    'pid': 1,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 1,
#     'Operation': 'read',
#     'Segment': 7,
#     'Offset': 800,
#     'Length': 512,
#     'Start': 0.7288,
#     'End': 0.7288}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 728800,
#    'pid': 5,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
# ...
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 94,
#     'Offset': 6630602,
#     'Length': 2984,
#     'Start': 80.5842,
#     'End': 80.5842}},
#   {'ph': 'E',
#    'ts': 80584200,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 94,
#     'Offset': 6630602,
#     'Length': 2984,
#     'Start': 80.5842,
#     'End': 80.5842}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 80585100,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 95,
#     'Offset': 6452041,
#     'Length': 3251,
#     'Start': 80.5851,
#     'End': 80.5851}},
#   {'ph': 'E',
#    'ts': 80585100,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 95,
#     'Offset': 6452041,
#     'Length': 3251,
#     'Start': 80.5851,
#     'End': 80.5851}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 80585800,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 96,
#     'Offset': 6455292,
#     'Length': 1321,
#     'Start': 80.5858,
#     'End': 80.5858}},
#   {'ph': 'E',
#    'ts': 80585800,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 96,
#     'Offset': 6455292,
#     'Length': 1321,
#     'Start': 80.5858,
#     'End': 80.5858}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 80586500,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 97,
#     'Offset': 6633586,
#     'Length': 3419,
#     'Start': 80.5865,
#     'End': 80.5865}},
#   {'ph': 'E',
#    'ts': 80586500,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 97,
#     'Offset': 6633586,
#     'Length': 3419,
#     'Start': 80.5865,
#     'End': 80.5865}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/grayscale_maps.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 80608800,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/grayscale_maps.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 33,
#     'Offset': 17895503,
#     'Length': 3136,
#     'Start': 80.6088,
#     'End': 80.6103}},
#   {'ph': 'E',
#    'ts': 80610300,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/grayscale_maps.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 33,
#     'Offset': 17895503,
#     'Length': 3136,
#     'Start': 80.6088,
#     'End': 80.6103}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/grayscale_maps.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 80610400,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/grayscale_maps.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 34,
#     'Offset': 18969386,
#     'Length': 59491,
#     'Start': 80.6104,
#     'End': 80.6265}},
#   {'ph': 'E',
#    'ts': 80626500,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/grayscale_maps.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 34,
#     'Offset': 18969386,
#     'Length': 59491,
#     'Start': 80.6104,
#     'End': 80.6265}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/grayscale_maps.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 80627900,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/grayscale_maps.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 35,
#     'Offset': 19452460,
#     'Length': 59394,
#     'Start': 80.6279,
#     'End': 80.6447}},
#   {'ph': 'E',
#    'ts': 80644700,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/grayscale_maps.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 35,
#     'Offset': 19452460,
#     'Length': 59394,
#     'Start': 80.6279,
#     'End': 80.6447}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/grayscale_maps.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 80646200,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/grayscale_maps.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 36,
#     'Offset': 19931983,
#     'Length': 54956,
#     'Start': 80.6462,
#     'End': 80.6488}},
#   {'ph': 'E',
#    'ts': 80648800,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/grayscale_maps.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 36,
#     'Offset': 19931983,
#     'Length': 54956,
#     'Start': 80.6462,
#     'End': 80.6488}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/grayscale_maps.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 80650300,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/grayscale_maps.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 37,
#     'Offset': 25096222,
#     'Length': 3136,
#     'Start': 80.6503,
#     'End': 80.6651}},
#   {'ph': 'E',
#    'ts': 80665100,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/grayscale_maps.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 37,
#     'Offset': 25096222,
#     'Length': 3136,
#     'Start': 80.6503,
#     'End': 80.6651}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/grayscale_maps.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 80665200,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/grayscale_maps.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 38,
#     'Offset': 26536903,
#     'Length': 60351,
#     'Start': 80.6652,
#     'End': 80.6887}},
#   {'ph': 'E',
#    'ts': 80688700,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/grayscale_maps.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 38,
#     'Offset': 26536903,
#     'Length': 60351,
#     'Start': 80.6652,
#     'End': 80.6887}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/grayscale_maps.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 80690100,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/grayscale_maps.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 39,
#     'Offset': 27023685,
#     'Length': 59122,
#     'Start': 80.6901,
#     'End': 80.7077}},
#   {'ph': 'E',
#    'ts': 80707700,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/grayscale_maps.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 39,
#     'Offset': 27023685,
#     'Length': 59122,
#     'Start': 80.6901,
#     'End': 80.7077}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/grayscale_maps.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 80709100,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/grayscale_maps.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 40,
#     'Offset': 27503090,
#     'Length': 59794,
#     'Start': 80.7091,
#     'End': 80.7138}},
#   {'ph': 'E',
#    'ts': 80713800,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/grayscale_maps.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 40,
#     'Offset': 27503090,
#     'Length': 59794,
#     'Start': 80.7091,
#     'End': 80.7138}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/grayscale_maps.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 80715300,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/grayscale_maps.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 41,
#     'Offset': 32302785,
#     'Length': 3136,
#     'Start': 80.7153,
#     'End': 80.7181}},
#   {'ph': 'E',
#    'ts': 80718100,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/grayscale_maps.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 41,
#     'Offset': 32302785,
#     'Length': 3136,
#     'Start': 80.7153,
#     'End': 80.7181}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/grayscale_maps.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 80718200,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/grayscale_maps.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 42,
#     'Offset': 34113905,
#     'Length': 59627,
#     'Start': 80.7182,
#     'End': 80.7216}},
#   {'ph': 'E',
#    'ts': 80721600,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/grayscale_maps.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 42,
#     'Offset': 34113905,
#     'Length': 59627,
#     'Start': 80.7182,
#     'End': 80.7216}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/grayscale_maps.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 80723000,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/grayscale_maps.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 43,
#     'Offset': 34598270,
#     'Length': 59570,
#     'Start': 80.723,
#     'End': 80.741}},
#   {'ph': 'E',
#    'ts': 80741000,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/grayscale_maps.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 43,
#     'Offset': 34598270,
#     'Length': 59570,
#     'Start': 80.723,
#     'End': 80.741}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/grayscale_maps.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 80742500,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/grayscale_maps.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 44,
#     'Offset': 35077467,
#     'Length': 60472,
#     'Start': 80.7425,
#     'End': 80.74600000000001}},
#   {'ph': 'E',
#    'ts': 80746000,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/grayscale_maps.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 44,
#     'Offset': 35077467,
#     'Length': 60472,
#     'Start': 80.7425,
#     'End': 80.74600000000001}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 80777500,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 98,
#     'Offset': 9140262,
#     'Length': 3136,
#     'Start': 80.7775,
#     'End': 80.7776}},
#   {'ph': 'E',
#    'ts': 80777600,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 98,
#     'Offset': 9140262,
#     'Length': 3136,
#     'Start': 80.7775,
#     'End': 80.7776}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 80777600,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 99,
#     'Offset': 9257684,
#     'Length': 507,
#     'Start': 80.7776,
#     'End': 80.7777}},
#   {'ph': 'E',
#    'ts': 80777700,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 99,
#     'Offset': 9257684,
#     'Length': 507,
#     'Start': 80.7776,
#     'End': 80.7777}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 80778400,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 100,
#     'Offset': 9258191,
#     'Length': 3470,
#     'Start': 80.7784,
#     'End': 80.7784}},
#   {'ph': 'E',
#    'ts': 80778400,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 100,
#     'Offset': 9258191,
#     'Length': 3470,
#     'Start': 80.7784,
#     'End': 80.7784}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 80779200,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 101,
#     'Offset': 9294985,
#     'Length': 3136,
#     'Start': 80.7792,
#     'End': 80.7792}},
#   {'ph': 'E',
#    'ts': 80779200,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 101,
#     'Offset': 9294985,
#     'Length': 3136,
#     'Start': 80.7792,
#     'End': 80.7792}},
#   {'name': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#    'cat': 'X_POSIX',
#    'ph': 'B',
#    'ts': 80779300,
#    'pid': 0,
#    'tid': 0,
#    'args': {'Module': 'X_POSIX',
#     'Filename': '/lus/theta-fs0/projects/datascience/keceli/run/f3n/training/groundtruth.h5',
#     'Rank': 0,
#     'Operation': 'read',
#     'Segment': 102,
#     'Offset': 9294742,
#     'Length': 243,
#     'Start': 80.7793,
#     'End': 80.7793}},
#   ...],
#  'displayTimeUnit': 'ms',
#  'systemTraceEvents': 'SystemTraceData',
#  'otherData': {'version': 'VaniDL v1.0'},
#  'stackFrames': {},
#  'samples': []}

# %% [markdown]
# ###
